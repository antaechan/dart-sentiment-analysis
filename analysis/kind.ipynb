# %%
import pandas as pd

# %%
import sys
import os
sys.path.append('../dags')

from database import create_database_engine


# 환경 변수 설정
os.environ["POSTGRES_USER"] = "airflow"
os.environ["POSTGRES_PASSWORD"] = "airflow"
os.environ["POSTGRES_DB"] = "events"
os.environ["POSTGRES_PORT"] = "5433"

engine = create_database_engine(host="127.0.0.1")
print("Successfully connected to the database")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 5
#       2 import os
#       3 sys.path.append('../dags')
# ----> 5 from database import create_database_engine
#       8 # 환경 변수 설정
#       9 os.environ["POSTGRES_USER"] = "airflow"
#
# File ~/dart-sentiment-analysis/analysis/../dags/database.py:10
#       8 from datetime import datetime
#       9 from typing import List, Optional
# ---> 10 import polars as pl
#      11 import FinanceDataReader as fdr
#      12 from sqlalchemy import text
#
# File ~/dart-sentiment-analysis/venv/lib/python3.13/site-packages/polars/__init__.py:24
#      20     os.environ["_RJEM_MALLOC_CONF"] = jemalloc_conf
#      22     # Initialize polars on the rust side. This function is highly
#      23     # unsafe and should only be called once.
# ---> 24     from polars.polars import __register_startup_deps
#      26     __register_startup_deps()
#      28 from typing import Any
#
# KeyboardInterrupt:

# %%
import pandas as pd
from datetime import datetime
table = "kind"
# 날짜 범위 설정

query = f"""SELECT k.*, d.dart_disclosure_id as dart_unique_id
FROM {table} k
LEFT JOIN dart_unique_number d ON k.short_code = d.stock_code
WHERE k.stock_code is not NULL
  AND k.company_name is not NULL
  AND k.title is not NULL
  AND k.market IN ('KOSPI', 'KOSDAQ')
  AND k.is_modify = 0
  AND d.dart_disclosure_id is not NULL
ORDER BY k.disclosed_at ASC"""

df = pd.read_sql(query, engine)
print(f"데이터베이스에서 조회된 공시 이벤트 수: {len(df)}")
df
# Out:
# WARNING:  database "events" has a collation version mismatch
# DETAIL:  The database was created using collation version 2.36, but the operating system provides version 2.41.
# HINT:  Rebuild all objects in this database that use the default collation and run ALTER DATABASE events REFRESH COLLATION VERSION, or build PostgreSQL with the right library version.
# 데이터베이스에서 조회된 공시 이벤트 수: 100710
#             id   disclosure_id        disclosed_at company_name    stock_code  \
# 0       157475  20201231000584 2021-01-04 07:30:00        아시아종묘  KR7154030001
# 1       157474  20210104000005 2021-01-04 08:01:00         대웅제약  KR7069620003
# 2       157473  20210104000022 2021-01-04 08:02:00           대웅  KR7003090008
# 3       157471  20210104000042 2021-01-04 08:40:00          디모아  KR7016670002
# 4       157470  20210104000060 2021-01-04 09:17:00         고려제약  KR7014570006
# ...        ...             ...                 ...          ...           ...
# 100705       4  20220630001052 2022-06-30 18:14:00       코아시아씨엠  KR7196450001
# 100706       3  20220630001053 2022-06-30 18:14:00         코아시아  KR7045970001
# 100707       6  20220630001035 2022-06-30 18:14:00       코아시아씨엠  KR7196450001
# 100708       2  20220630001078 2022-06-30 18:24:00       코아시아씨엠  KR7196450001
# 100709       1  20220630001079 2022-06-30 18:48:00        이원컴포텍  KR7088290002
#
#        short_code  market                              title summary_kr raw  \
# 0          154030  KOSDAQ              사외이사의선임ㆍ해임또는중도퇴임에관한신고
# 1          069620   KOSPI                     투자판단 관련 주요경영사항
# 2          003090   KOSPI        투자판단 관련 주요경영사항(자회사의 주요경영사항)
# 3          016670  KOSDAQ                               영업정지
# 4          014570  KOSDAQ                임원ㆍ주요주주특정증권등소유상황보고서
# ...           ...     ...                                ...        ...  ..
# 100705     196450  KOSDAQ                     타법인주식및출자증권취득결정
# 100706     045970  KOSDAQ                    주권 관련 사채권의 취득결정
# 100707     196450  KOSDAQ                     타법인주식및출자증권취득결정
# 100708     196450  KOSDAQ                      증권 발행결과(자율공시)
# 100709     088290  KOSDAQ  유상증자결정(자율공시)(종속회사의 주요경영사항)(제3자배정)
#
#                                                detail_url  \
# 0       https://kind.krx.co.kr/common/disclsviewer.do?...
# 1       https://kind.krx.co.kr/common/disclsviewer.do?...
# 2       https://kind.krx.co.kr/common/disclsviewer.do?...
# 3       https://kind.krx.co.kr/common/disclsviewer.do?...
# 4       https://kind.krx.co.kr/common/disclsviewer.do?...
# ...                                                   ...
# 100705  https://kind.krx.co.kr/common/disclsviewer.do?...
# 100706  https://kind.krx.co.kr/common/disclsviewer.do?...
# 100707  https://kind.krx.co.kr/common/disclsviewer.do?...
# 100708  https://kind.krx.co.kr/common/disclsviewer.do?...
# 100709  https://kind.krx.co.kr/common/disclsviewer.do?...
#
#                        created_at                 updated_at  is_modify  \
# 0      2025-09-20 12:22:30.082533 2025-09-20 12:22:30.082533          0
# 1      2025-09-20 12:22:30.082207 2025-09-20 12:22:30.082207          0
# 2      2025-09-20 12:22:30.081843 2025-09-20 12:22:30.081843          0
# 3      2025-09-20 12:22:30.081166 2025-09-20 12:22:30.081166          0
# 4      2025-09-20 12:22:30.080827 2025-09-20 12:22:30.080827          0
# ...                           ...                        ...        ...
# 100705 2025-08-20 07:21:10.832003 2025-09-21 09:44:55.884903          0
# 100706 2025-08-20 07:21:10.831574 2025-09-21 09:44:55.883075          0
# 100707 2025-08-20 07:21:10.833531 2025-09-21 09:44:55.889670          0
# 100708 2025-08-20 07:21:10.830859 2025-09-21 09:44:55.880183          0
# 100709 2025-08-20 07:21:10.813957 2025-09-21 09:44:55.787550          0
#
#        dart_unique_id
# 0            00867478
# 1            00427483
# 2            00111810
# 3            00125725
# 4            00103015
# ...               ...
# 100705       01031502
# 100706       00271501
# 100707       01031502
# 100708       01031502
# 100709       00409140
#
# [100710 rows x 15 columns]

# %%
df["title"].value_counts()
# Out:
# title
# 임원ㆍ주요주주특정증권등소유상황보고서                                                           16413
# 주식등의대량보유상황보고서(일반)                                                              9090
# 분기보고서(일반법인)                                                                    6417
# 주주총회소집공고                                                                       4959
# 주주총회소집결의                                                                       4824
#                                                                               ...
# 기타 경영사항(자율공시)(전환상환우선주의 보통주 전환)                                                    1
# 기타 경영사항(특허권 취득)(자율공시)(간세포 성장인자 및 기질세포 유발인자1알파를 포함하는 말초동맥질환의 예방 또는 치료용 조성물)        1
# 기타 경영사항(특허권 취득)(자율공시)(부티릴 프락토올리고당을 포함하는 프리바이오틱스 조성물)                              1
# 기타 주요경영사항(전환사채 콜옵션 행사 매도청구권자 제3자 지정)                                              1
# 투자판단 관련 주요경영사항(자본시장과 금융투자에 관한 법률" 위반혐의 3심)                                        1
# Name: count, Length: 2271, dtype: int64

# %%
from config import keywords

# %%
df[df["title"].str.contains("임상")]["title"].to_list()
# Out:
# ['투자판단 관련 주요경영사항(코로나치료제로 임상중인 안트로퀴노놀의 라이센스계약체결)',
#  '임상시험단계 진입ㆍ종료(자율공시)',
#  '투자판단 관련 주요경영사항(체외진단 의료기기 제조허가(임상자료심사) 신청 자진 취하(BRCAaccuTest PLUS))',
#  '투자판단 관련 주요경영사항(이영양성수포성표피박리증환자를 대상으로 ALLO-ASC-SHEET의 유효성과 안전성을 평가하는 제 3상 임상시험 계획 승인(일본))',
#  '투자판단 관련 주요경영사항(재발 및 난치성 유잉육종(Ewing Sarcoma) 제 1상 임상시험 계획 승인)',
#  '투자판단 관련 주요경영사항(CT-P43 국내 임상3상 시험계획 승인)',
#  '기타 주요경영사항(자율공시)(신경내분비종양 표적 치료용 방사성의약품의 국내 임상2상 시험 진행 중단 및 관련 계약 해지)',
#  '투자판단 관련 주요경영사항(CT-P41(프롤리아 바이오시밀러) 임상 3상 시험계획 미국 FDA 신청)',
#  '투자판단 관련 주요경영사항(면역항암제 EU101의 임상 1/2상 시험 승인)',
#  '투자판단 관련 주요경영사항(코로나치료제 DWJ1248의 COVID-19 예방 목적 임상3상 시험계획 승인)',
#  '투자판단 관련 주요경영사항(코로나치료제 DWJ1248의 COVID-19 예방 목적 임상3상 시험계획 승인)(자회사의 주요경영사항)',
#  '투자판단 관련 주요경영사항(COVID-19 치료제 Lenzilumab의 식약처 가교임상시험 계획 (IND) 승인 신청)',
#  '투자판단 관련 주요경영사항(COVID-19 치료제 Lenzilumab의 식약처 가교임상시험 계획 (IND) 승인 신청)',
#  '투자판단 관련 주요경영사항(알츠하이머병 치료제로서 GV 1001의 국내 제3상 임상시험계획 승인 신청)',
#  '투자판단 관련 주요경영사항(보툴리눔 톡신 액상제제 "HG102" 임상1상 시험계획 승인)',
#  '투자판단 관련 주요경영사항(이중항체 면역항암제 ABL503의 미국 FDA 제1상 임상시험계획 (IND) 승인)',
#  '투자판단 관련 주요경영사항(무릎골관절염 환자를 대상으로 EVA-001(카티스템) 일본임상 3상 임상시험계획승인(CTN) 신청)',
#  '투자판단 관련 주요경영사항(코로나바이러스-19 감염으로 인한 폐렴 환자에게서 동종 지방유래 중간엽 줄기세포치료제 아스트로스템-V의 안전성 및 유효성을 탐색하기 위한 국내 제1/2a상 임상시험계획 반려)',
#  '투자판단 관련 주요경영사항(자궁내막증 치료제 TU2670의 폴란드 임상 2a상 시험 계획 신청)',
#  '투자판단 관련 주요경영사항(무릎골관절염 환자를 대상으로 EVA-001(카티스템)의 일본임상 3상 임상시험계획(CTN) 승인)',
#  '투자판단 관련 주요경영사항(알츠하이머 치료제로서 도네페질패치의 다국가 제3상 임상시험 Primary Endpoint 결과 [Key results Report수령])',
#  '투자판단 관련 주요경영사항(CT-P41(프롤리아 바이오시밀러) 임상 3상 시험계획 국내 식약처 신청)',
#  '투자판단 관련 주요경영사항(CT-P42(아일리아 바이오시밀러) 임상 3상 시험계획 국내 식약처 신청)',
#  '투자판단 관련 주요경영사항(. 이영양성수포성표피박리증환자를 대상으로 ALL-ASC-SHEET의 유효성과 안전성을 평가하는 제 2상 임상시험 계획 승인(미국))',
#  '투자판단 관련 주요경영사항(CT-P41(프롤리아 바이오시밀러) 임상 3상 시험계획 미국 FDA 승인)',
#  '투자판단 관련 주요경영사항(CT-P42(아일리아 바이오시밀러) 임상 3상 시험계획 미국 FDA 신청)',
#  '투자판단 관련 주요경영사항(면역항암제 EU101의 임상 1/2상 시험 계획 신청)',
#  '투자판단 관련 주요경영사항(CT-P41(프롤리아 바이오시밀러) 임상 3상 시험계획 유럽 우크라이나 신청)',
#  '투자판단 관련 주요경영사항(자궁내막증 치료제 TU2670의 이탈리아 임상 2a상 시험 계획 신청)',
#  '투자판단 관련 주요경영사항(비마약성 진통제 VVZ-149 주사의 국내 제 3상 임상시험계획 승인)',
#  '투자판단 관련 주요경영사항(중등도 이상의 급성 호흡곤란증후군 환자에서 SCM-AGH의 유효성 및 안전성 평가를 위한 다기관, 공개, 무작위배정, 용량·용법 탐색, 제2a상 임상시험계획(IND) 자진 취하 신청)',
#  '투자판단 관련 주요경영사항(경증 및 중등증 코로나바이러스감염증-19 (COVID-19) 환자를 대상으로 BLS-H01 유효성과 안전성을 평가하기 위한 다기관, 무작위배정, 이중눈가림, 위약 대조, 평행군, 제 2 상 임상시험 계획 (IND) 자진 취하)',
#  '투자판단 관련 주요경영사항(이중항체 면역항암제 ABL111의 미국 FDA 제1상 임상시험계획 (IND) 신청)',
#  '투자판단 관련 주요경영사항(국책과제 선정(아데노바이러스 벡터를 기반으로 한 코로나19 예방백신의 임상 1/2a상 개발))',
#  '투자판단 관련 주요경영사항(페디오코커스 펜토사세우스 (Pediococcus pentosaseus)에서 생산한 P8 (대장암 유전자 치료제) 의 임상 1상 시험계획 신청)',
#  '투자판단 관련 주요경영사항(OLP-1002 비마약성진통제 신약 호주 임상1b상 시험 진행 현황)',
#  '투자판단 관련 주요경영사항(나파벨탄주 임상 3상 신청)',
#  '투자판단 관련 주요경영사항(나파벨탄주 임상 3상 신청)(자회사의 주요경영사항)',
#  '투자판단 관련 주요경영사항(제1b/2a상 임상 시험 계획 변경 신청-전이성 또는 절제 불가능한 신세포암(RCC, 신장암) 이 있는 시험대상자에서 Cemiplimab(REGN2810, 항-PD-1)과 병용투여 한 펙사벡의 용량 증량 및 안전성/유효성 평가)',
#  '투자판단 관련 주요경영사항(마이크로바이옴 신약 KBL693 호주 1상 임상시험 종료)',
#  '투자판단 관련 주요경영사항(골관절염 주사요법제 SP5M001주의 임상3상 시험계획 승인)',
#  '투자판단 관련 주요경영사항(COVID-19 예방 DNA 백신 GX-19N 의 2/3상 임상시험 계획 신청)',
#  '투자판단 관련 주요경영사항(K&L grade 2~3의 무릎 골관절염 환자를 대상으로 한 SMUP-IA-01의 안전성 및 탐색적인 유효성을 평가하는 국내 제1상 임상시험 결과)',
#  '투자판단 관련 주요경영사항(COVID-19 치료제 APX-115의 US FDA 2상 임상시험 IND 승인)',
#  '투자판단 관련 주요경영사항(CT-P42(아일리아 바이오시밀러) 임상 3상 시험계획 미국 FDA 승인)',
#  '투자판단 관련 주요경영사항(이중항체 면역항암제 ABL111의 미국 FDA 제1상 임상시험계획 (IND) 승인)',
#  '투자판단 관련 주요경영사항(OLP-1002 비마약성진통제 신약 영국 임상1상 시험결과)',
#  '투자판단 관련 주요경영사항(PolyQ 척수소뇌 실조증 치료에 대한 Stemchymal 투여의 안전성 및 유효성을 평가하기 위한 공개, 다기관, 단일군, 제2상 임상시험 계획승인(IND) 신청)',
#  '투자판단 관련 주요경영사항(수술이 불가능한 진행성 또는 전이성 췌장암 환자들을 대상으로 한 임상3상 계획(IND) 승인 신청)',
#  '투자판단 관련 주요경영사항(도네페질패취의 미국 FDA 제1상 임상시험계획 (IND) 신청)',
#  '투자판단 관련 주요경영사항(제테마더톡신주 100단위의 미간주름개선 제1상 임상시험 종료 )',
#  '투자판단 관련 주요경영사항(제테마더톡신주 100단위의 미간주름개선 제3상 임상시험계획  IND 신청 )',
#  '투자판단 관련 주요경영사항(나파벨탄주 임상 3상 승인)',
#  '투자판단 관련 주요경영사항(나파벨탄주 임상 3상 승인)(자회사의 주요경영사항)',
#  '투자판단 관련 주요경영사항(자궁내막증 치료제 TU2670의 체코 임상 2a상 시험 계획 승인)',
#  '투자판단 관련 주요경영사항(진행성 또는 전이성 위암 및 위식도접합부암 환자 대상 1차 치료로 캄렐리주맙과 카페시타빈/옥살리플라틴 병용 투여 후 리보세라닙(아파티닙)과 캄렐리주맙 병용투여, 3상 임상시험 계획(IND) 승인 신청)',
#  '투자판단 관련 주요경영사항(알츠하이머병 치료제로서 GV 1001의 국내 제3상 임상시험계획 반려)',
#  '투자판단 관련 주요경영사항(다계통위축증(MSA) 치료제 KM819의 2상 임상시험 계획 신청)',
#  '투자판단 관련 주요경영사항(CT-P41(프롤리아 바이오시밀러) 임상 3상 시험계획 국내 식약처 승인)',
#  '투자판단 관련 주요경영사항(도네페질패취의 미국 FDA 제1상 임상시험계획 승인)',
#  '투자판단 관련 주요경영사항(CT-P42(아일리아 바이오시밀러) 3상 임상시험계획 국내 식약처 승인)',
#  '투자판단 관련 주요경영사항(중등도 이상의 만성 아토피피부염 환자를 대상으로 퓨어스템-에이디주(FURESTEM-AD Inj.)의 제3상 임상시험 승인)',
#  '투자판단 관련 주요경영사항(자궁내막증 치료제 TU2670의 폴란드 임상 2a상 시험 계획 승인)',
#  '투자판단 관련 주요경영사항(식약처 유권해석으로 인한 [인공지능 기반 위종양 병리 솔루션 VUNO Med - PathGC AI의 유효성을 평가하기 위한 후향적, 확증 임상적 성능시험] 시험 계획 승인 신청 취하)',
#  '투자판단 관련 주요경영사항(HU024 점안제의 국내 임상시험계획(IND) 자진 취하 신청)',
#  '투자판단 관련 주요경영사항(면역항암제 EU101의 임상 1/2상 시험 계획 승인 )',
#  '투자판단 관련 주요경영사항(이중항체 면역항암제 ABL501의 국내 제1상 임상시험계획 (IND) 신청)',
#  '투자판단 관련 주요경영사항(궤양성대장염 치료제 BBT-401의 한국 식약처 제 2a상 임상시험 계획 승인)',
#  '투자판단 관련 주요경영사항(이중항체 항암제 ABL001의 제1a상 임상시험 결과)',
#  '투자판단 관련 주요경영사항(전립선암 진단용 방사성의약품으로 개발중인 [F-18]Florastamin (프로젝트명: FC303)의 유럽 임상 3상 승인 - 유럽 오스트리아 보건식품안전청 (AGES))',
#  '투자판단 관련 주요경영사항(마이크로바이옴 신약 KBL697 미국 FDA 2a 임상시험계획 신청)',
#  '투자판단 관련 주요경영사항(투자판단 관련 주요경영사항 (NT-I7(NT-109) 임상 2상 시험계획 유럽 이탈리아 승인))',
#  '투자판단 관련 주요경영사항(코로나19 바이러스(SARS-CoV-2) 감염환자 치료제(CT-P59) 임상 3상 결과 발표)',
#  '투자판단 관련 주요경영사항(대상포진 예방백신 ‘EG-HZ’ 호주 1상 임상시험 완료)',
#  '투자판단 관련 주요경영사항(VM202-ALS 임상 2a상 시험 계획에 대한 국내 식약처 승인)',
#  '투자판단 관련 주요경영사항(당뇨병성 족부궤양(diabetic foot ulcer) 환자를 대상으로 한 엔젠시스 미국 임상 3상 시험 분석 결과 공개)',
#  '투자판단 관련 주요경영사항(AXL 저해제 SKI-G-801 임상 1상 시험 신청)',
#  '기타 경영사항(자율공시)(PBP1510 임상 1/2a상 시험 계획에 대한 프랑스 ANSM의 승인)',
#  '투자판단 관련 주요경영사항(코로나바이러스감염증-19(COVID-19) 예방 백신의 제1/2a상 임상시험 계획(IND) 변경 신청)',
#  '투자판단 관련 주요경영사항(중등도에서 중증 판상형 건선 환자를 대상으로 CT303(동종편도유래중간엽줄기세포)의 단회투여 및 반복투여 시 안전성, 내약성 및 유효성 평가를 위한 공개, 용량 증량, 제1상 임상시험 신청)',
#  '투자판단 관련 주요경영사항(재발성 또는 불응성 B세포 비호지킨 림프종 환자에서 AT101 (항-CD19 키메릭항원수용체 T세포)의 안전성, 내약성 및 유효성을 평가하기 위한 공개, 단일군, 다기관, 제1/2상 국내 임상시험계획 (IND) 신청)',
#  '투자판단 관련 주요경영사항(알츠하이머병 치료제로서 GV 1001의 국내 제3상 임상시험계획 승인 신청)',
#  '투자판단 관련 주요경영사항(자궁내막증 치료제 TU2670의 이탈리아 임상 2a상 시험 계획 승인)',
#  '투자판단 관련 주요경영사항(A형 혈우병 치료제 PGA40의 다국가 임상3상시험 계획변경 신청)',
#  '투자판단 관련 주요경영사항(mRNA 기반 코로나-19 예방백신 (EG-COVID) 국내 임상 제 1/2a상 시험 계획 (IND) 승인 신청)',
#  '투자판단 관련 주요경영사항(마이크로바이옴 신약 KBL697 미국 FDA 2a 임상시험계획 승인)',
#  '투자판단 관련 주요경영사항(COVID-19 치료제 피라맥스정의 임상 3상 시험계획 승인 신청)',
#  '투자판단 관련 주요경영사항(COVID-19 예방 합성항원 백신 유코백-19의 1/2상 임상시험계획 신청서 제출)',
#  '투자판단 관련 주요경영사항(COVID-19 예방 합성항원 백신 유코백-19의 1/2상 임상시험계획 승인)',
#  '투자판단 관련 주요경영사항(COVID-19 예방 DNA 백신 GX-19N 의 2/3상 임상시험 계획 인도네시아 식약처 승인)',
#  '기타 경영사항(자율공시)(코로나19 치료제 백신 신약개발사업 비임상 지원과제 선정)',
#  '투자판단 관련 주요경영사항(당뇨망막증치료제 ‘EG-Mirotin’ 국내 2상 임상시험 완료)',
#  '투자판단 관련 주요경영사항(COVID-19 치료제 Lenzilumab의 식약처 임상(제1상)시험 계획(IND) 승인)',
#  '투자판단 관련 주요경영사항(코로나바이러스감염증-19(COVID-19) 예방 백신의 제1/2a상 임상시험 계획(IND) 변경 승인)',
#  '투자판단 관련 주요경영사항(면역항암제 TU2218 의 미국 FDA 임상 1/2상 시험계획 (IND) 신청)',
#  '투자판단 관련 주요경영사항(무릎 골관절염 환자를 대상으로 SMUP-IA-01의 국내 임상2상 임상시험계획승인신청(IND))',
#  '투자판단 관련 주요경영사항(AXL 저해제 SKI-G-801 임상 1상 시험 승인)',
#  '투자판단 관련 주요경영사항(앱비앤티셀의 임상1/2a상 적응증 추가 임상시험계획 신청)',
#  '투자판단 관련 주요경영사항(OLP-1002 비마약성진통제 신약 호주 임상1B상 임상시험 종료)',
#  '투자판단 관련 주요경영사항(마이크로바이옴 면역항암 치료제 GEN-001의 국내 제2상 임상시험계획 (IND) 신청)',
#  '투자판단 관련 주요경영사항(HER2 양성 유방암 대상자 중 표준 치료에 실패한 전이를 가진 진행성 또는 재발성 환자에게 ALT-P7을 주사제로 투여하여 안전성, 약동학, 항암효과를 평가하는 국내 임상1상 시험결과)',
#  '투자판단 관련 주요경영사항(이중항체 면역항암제 ABL501의 국내 제1상 임상시험계획 (IND) 승인)',
#  '기타 경영사항(자율공시)(아일리아 바이오시밀러 ALT-L9 국내 임상 1상 시험 결과)',
#  '투자판단 관련 주요경영사항(동물용의약품(유전자치료제) 허니가드-R액의 국내 임상시험계획서(IND) 승인)',
#  '투자판단 관련 주요경영사항(SYK 저해제 SKI-O-703 임상 2a상 결과)',
#  '투자판단 관련 주요경영사항(중등도에서 중증 판상형 건선 환자를 대상으로 CT303(동종편도유래중간엽줄기세포)의 단회투여 및 반복투여 시 안전성, 내약성 및 유효성 평가를 위한 공개, 용량 증량, 제1상 임상시험 승인)',
#  '투자판단 관련 주요경영사항(과민성 방광 증상 치료제 UIP620 임상1상 시험 종료보고서 제출)',
#  '투자판단 관련 주요경영사항(급성호흡곤란증후군 환자를 대상으로 CT303(동종편도유래중간엽줄기세포)의 단회투여 시 안전성, 내약성 및 유효성 평가를 위한 다기관, 공개, 용량 증량 및 용량 탐색, 제1상 임상시험 계획 신청)',
#  '투자판단 관련 주요경영사항(비마약성진통제(OLP-1002) 호주 임상 2a상 시험 계획 신청)',
#  '투자판단 관련 주요경영사항(면역항암제 TU2218 의 미국 FDA 임상 1/2상 시험계획 (IND) 승인)',
#  '투자판단 관련 주요경영사항(신종 코로나바이러스 환자를 대상으로 폐렴에서 중증폐렴 또는 급성호흡곤란증후군으로의 이행을 예방하는 EC-18의 안전성과 유효성을 평가하는 국내 임상2상 시험 결과)',
#  '투자판단 관련 주요경영사항(수술이 불가능한 진행성 또는 전이성 췌장암 환자들을 대상으로 한 임상3상 계획(IND)  자진 취하 신청)',
#  '투자판단 관련 주요경영사항(수술이 불가능한 진행성 또는 전이성 췌장암 환자들을 대상으로한 2/3상 임상시험계획(IND) 승인 신청)',
#  '투자판단 관련 주요경영사항(COVID-19 예방 DNA 백신 GX-19N 의 2/3상 임상시험 계획 변경 신청)',
#  '투자판단 관련 주요경영사항(무릎 골관절염 환자에서 퓨어스템-오에이 키트 주 (FURESTEM-OA Kit Inj.) 투여 시의 안전성 및 탐색적인 유효성 평가를 위한, 단회투여, 단계적 용량증량 및 적정용량 탐색, 제 1/2a 상 임상시험계획(IND) 신청)',
#  '투자판단 관련 주요경영사항(mRNA 기반 코로나-19 예방백신 (EG-COVID) 국내 임상 제 1/2a상 시험 계획 (IND) 승인)',
#  '투자판단 관련 주요경영사항(전이성 삼중 음성 유방암 환자에서 펨브롤리주맙과 병용한 올린베시맙의 제2상, 공개, 다기관 임상시험계획 승인)',
#  '투자판단 관련 주요경영사항(이전 치료력이 없는 진행성 또는 전이성 위암 및 위식도 접합부암 환자를 대상으로 캄렐리주맙+카페시타빈/옥살리플라틴 병용투여 후 리보세라닙+캄렐리주맙 투여에 대한 제2상 임상시험 계획(IND) 승인)',
#  '투자판단 관련 주요경영사항(EuMCV4주(수막구균 단백 접합 백신) 임상 1상시험 종료)',
#  '투자판단 관련 주요경영사항(ALT-BB4 (테르가제, 재조합 히알루로니다제)의 안전성과 내약성 및 약동학 특성을 평가하기 위한 임상시험 1상 계획 승인)',
#  '투자판단 관련 주요경영사항(A형 혈우병 치료제 PGA40의 다국가 임상3상시험 계획변경 승인)',
#  '투자판단 관련 주요경영사항(당뇨병성 신증 치료제 CU01-1001의 식품의약품안전처 3상 임상시험계획(IND) 신청)',
#  '투자판단 관련 주요경영사항(PolyQ 척수소뇌 실조증 치료에 대한 Stemchymal (동종 지방유래 중간엽줄기세포) 투여의 안전성 및 유효성을 평가하기 위한 공개, 다기관, 단일군, 제2상 임상시험계획(IND) 자진취하 신청)',
#  '투자판단 관련 주요경영사항(COVID-19 치료제 CP-COV03의 1상 임상시험계획 신청서 제출)',
#  '투자판단 관련 주요경영사항(마이크로바이옴 면역항암 치료제 GEN-001의 국내 제2상 임상시험계획(IND) 승인)',
#  '투자판단 관련 주요경영사항(앱비앤티셀의 임상1/2a상 적응증 추가 임상시험계획 승인)',
#  '투자판단 관련 주요경영사항(COVID-19 예방 합성항원 백신 유코백-19의 제3상 임상시험계획(IND) 신청)',
#  '투자판단 관련 주요경영사항(비마약성진통제(OLP-1002) 호주 임상 2a상 시험 계획 승인)',
#  '투자판단 관련 주요경영사항(면역항암제 TU2218 의 식품의약품안전처 임상 1/2상 시험계획 신청)',
#  '투자판단 관련 주요경영사항(알레르기비염 면역치료제 DF19001의 임상 1상 임상시험계획승인)',
#  '투자판단 관련 주요경영사항(항암화학방사선요법 치료를 받는 구강, 구인두, 하인두, 비인두 환자에게 유발되는 구강점막염에 대한 EC-18의 안전성과 유효성을 평가하기 위한 다기관, 무작위배정, 이중 눈가림, 위약대조 임상2상 시험 결과)',
#  '투자판단 관련 주요경영사항(작약복합추출물의 제2A상 임상시험계획 승인 양도·양수 계약 체결)',
#  '투자판단 관련 주요경영사항(급성호흡곤란증후군 환자를 대상으로 CT303(동종편도유래중간엽줄기세포)의 단회투여 시 안전성, 내약성 및 유효성 평가를 위한 다기관, 공개, 용량 증량 및 용량 탐색, 제1상 임상시험 계획 승인)',
#  '투자판단 관련 주요경영사항(다계통위축증(MSA) 치료제 KM819의 2상 임상시험 계획 신청 승인)',
#  '투자판단 관련 주요경영사항(무릎 골관절염 환자를 대상으로 SMUP-IA-01의 국내 임상2상 임상시험계획(IND) 승인)',
#  '투자판단 관련 주요경영사항(샤르코-마리-투스병 치료제(Engensis: VM202) 제1/2a상 임상시험 Topline data 발표)',
#  '투자판단 관련 주요경영사항(재발성 교모세포종 환자에서 베바시주맙 (bevacizumab) 과 GX-I7 병용 투여의 유효성 및 안전성을 확인하기 위한 2상 임상시험계획 변경 승인)',
#  '투자판단 관련 주요경영사항(COVID-19 치료제 CP-COV03의 1상 임상시험계획 승인)',
#  '투자판단 관련 주요경영사항(COVID-19 예방 백신 AdCLD-CoV19-1의 제2b/3상 임상시험 계획(IND) 신청)',
#  '투자판단 관련 주요경영사항(COVID-19 감염 중등증 환자에게 PAX-1(경구용)을 경구투여하는 2개의 코호트 대한 파키스탄 식약처(DRAP) 임상1상 시험계획 신청)',
#  '투자판단 관련 주요경영사항(TG-C 추가 적응증 미국FDA 임상2상 검토(Review) 완료 )',
#  '투자판단 관련 주요경영사항(면역항암제 hSTC810의 식품의약품안전처 임상1상 시험계획 신청)',
#  '기타 경영사항(자율공시)(MSD와 대장암 임상3상 공동임상 및 의약품 지원 계약 체결)',
#  '투자판단 관련 주요경영사항(면역항암제 hSTC810 의 미국FDA 임상 1상 시험계획 신청)',
#  '투자판단 관련 주요경영사항(IN-A001(Tegoprazan) 적응증 추가를 위한 임상 3상 시험 결과)',
#  '투자판단 관련 주요경영사항(전이성 췌장암 환자 대상 ivaltinostat/capecitabine 병용요법 또는 capecitabine 단독요법 투여 비교 평가하기 위한 미국 2상 임상시험계획 (IND) 신청)',
#  '투자판단 관련 주요경영사항(중등도 코로나바이러스감염증-19 (COVID-19) 환자를 대상으로 BLS-H01 유효성과 안전성을 평가하기 위한 다기관, 무작위배정, 이중눈가림, 위약 대조, 평행군, 제2상 임상시험)',
#  '투자판단 관련 주요경영사항(COVID19 치료제 SpikeDown 이스라엘 보건부(MoH) 임상1/2상 시험 계획 신청)',
#  '투자판단 관련 주요경영사항(mRNA기반 COVID-19 예방 백신 STP-2104의 임상 제1상 시험계획(IND) 신청)',
#  '투자판단 관련 주요경영사항(재발성 또는 불응성 B세포 비호지킨 림프종 환자에서 AT101 (항-CD19 키메릭항원수용체 T세포)의 안전성, 내약성 및 유효성을 평가하기 위한 공개, 단일군, 다기관, 제1/2상 국내 임상시험 계획(IND) 승인)',
#  '투자판단 관련 주요경영사항(면역항암제 TU2218 의 식품의약품안전처 임상 1/2상 시험계획승인)',
#  '투자판단 관련 주요경영사항(노인 근감소증 환자에서 KP203 반복 투여의 유효성 및 안전성 평가를 위한 다기관, 용량 탐색, 제2상 임상시험계획 신청)',
#  '투자판단 관련 주요경영사항(아이진 mRNA 기반 코로나-19 예방백신 (EG-COVID) 호주 부스터 임상 제 1/2a상 시험 계획  신청  )',
#  '투자판단 관련 주요경영사항(항암치료제 Q901 미국FDA 임상 1/2상 시험 계획(IND) 신청)',
#  '투자판단 관련 주요경영사항(습성 연령관련 황반변성의 경구용 치료제 CU03-1001 임상 2a상 결과)',
#  '투자판단 관련 주요경영사항(알츠하이머병 치료제로서 GV 1001의 국내 제3상 임상시험계획 승인)',
#  '투자판단 관련 주요경영사항(면역항암제 hSTC810 의 미국FDA 임상 1상 시험계획 승인)',
#  '투자판단 관련 주요경영사항(전이성 췌장암 환자 대상 ivaltinostat/capecitabine 병용요법 또는 capectabine 단독요법 투여 비교 평가하기 위한 미국 2상 임상시험계획(IND) 승인)',
#  '투자판단 관련 주요경영사항(항암면역치료백신 BVAC-M의 제1상 임상시험 계획(IND) 신청)',
#  '투자판단 관련 주요경영사항(COVID-19 치료제 피라맥스정의 임상 3상 시험계획 영국 승인 신청)',
#  '투자판단 관련 주요경영사항(COVID-19 치료제 CP-COV03의 제2상 임상시험계획 신청서 제출)',
#  '투자판단 관련 주요경영사항(Wagner grade 1 및 2 당뇨병성 족부궤양 환자를 대상으로 한 ALLO-ASC-DFU 국내 임상 3상 분석 결과)',
#  '투자판단 관련 주요경영사항(COVID-19 예방 백신 AdCLD-CoV19-1의 제2b상 임상시험 계획(IND) 승인)',
#  '투자판단 관련 주요경영사항(COVID-19 예방 합성항원 백신 유코백-19의 제3상 임상시험 계획(IND) 승인)',
#  '투자판단 관련 주요경영사항(mRNA 기반 코로나-19 예방백신 (EG-COVID) 부스터 임상 제 1/2a상 시험 계획 남아프리카공화국 신청)',
#  '투자판단 관련 주요경영사항(전립선암 진단용 방사성의약품 미국임상 1상 종료)',
#  '투자판단 관련 주요경영사항(생화학적 재발 전립선암(BRPC) 환자에서의 [18F]Florastamin PET/CT 영상검사의 진단 유효성 및 안전성을 평가하기 위한 다기관, 단일군, 공개, 제3상 임상시험 IND 신청)',
#  '기타 경영사항(자율공시)([국책과제 선정] 코로나19 치료제.백신 개발 - 코로나 19 백신 임상 지원)',
#  '투자판단 관련 주요경영사항(PSI-401 경구 투여 후 안전성, 내약성 및 약동/약력학적 특성을 평가하기 위한 제1상 임상시험 계획 신청)',
#  '투자판단 관련 주요경영사항(전이성 거세저항성 전립선암 환자에 대한 [177Lu]루도타다이펩의 반복투여 치료의 안전성 및 유효성 평가; 제2상 임상시험계획 신청)',
#  '투자판단 관련 주요경영사항(항암치료제 Q901 미국 임상 1/2상 시험 계획(IND) 승인)',
#  '투자판단 관련 주요경영사항(코로나-19 치료제 CP-COV03의 국내 제1상 임상시험 결과)',
#  '투자판단 관련 주요경영사항(COVID-19 치료제 후보물질 텔라세벡(Telacebec) 임상 2상 시험 자진 중단 결정)',
#  '투자판단 관련 주요경영사항(면역항암제 Q702와 Pembrolizumab(키투르다) 병용 임상1B/2상 시험계획 제출)',
#  '기타 경영사항(자율공시)(PBP1510 임상 1/2a상 시험 계획에 대한 스페인 AEMPS의 승인)',
#  '투자판단 관련 주요경영사항(아이진 mRNA 기반 코로나-19 예방백신 (EG-COVID) 호주 부스터 임상 제 1/2a상 시험 계획 승인)',
#  '투자판단 관련 주요경영사항(재조합 대상포진 백신(CVI-VZV-001)의 한국 식품의약품안전처(MFDS) 제1상 임상시험 계획(IND) 자진취하)',
#  '투자판단 관련 주요경영사항(당뇨병성 신증 치료제 CU01-1001의 식품의약품안전처 3상 임상시험계획(IND) 신청 반려)',
#  '투자판단 관련 주요경영사항(CT-P63+CT-P66(코로나19 흡입형 치료제) 유럽 임상 3상 시험계획 신청)',
#  '투자판단 관련 주요경영사항(중등도 코로나바이러스감염증-19 (COVID-19) 환자를 대상으로 BLS-H01 유효성과 안전성을 평가하기 위한 다기관, 무작위배정, 이중눈가림, 위약 대조, 평행군, 제2상 임상시험계획신청(신청내용 일부 변경))',
#  '투자판단 관련 주요경영사항(수술이 불가능한 진행성 또는 전이성 췌장암 환자에서 Ivaltinostat/Gemcitabine/Erlotinib병용요법 또는FOLFIRINOX요법 후, 안전성과 유효성을 비교 평가하기 위한 2/3상 임상 시험 자진 취하)',
#  '기타 경영사항(자율공시)(담도암 2상 임상시험 협력 및 의약품 지원 계약 체결)',
#  '투자판단 관련 주요경영사항(COVID-19 치료제 피라맥스정의 임상 3상 시험계획 영국 승인)',
#  '투자판단 관련 주요경영사항(항암화학방사선 치료를 받는 두경부암 환자에게 유발되는 구강점막염에 대한 임상2상 최종결과보고서(Final CSR) 수령 )',
#  '투자판단 관련 주요경영사항(COVID-19 예방 DNA 백신 GX-19N의 2/3상 임상시험 자진 철회 결정)',
#  '투자판단 관련 주요경영사항(COVID-19 치료제 CP-COV03의 2상 임상시험계획 신청서 제출(신청내용 일부변경))',
#  '투자판단 관련 주요경영사항(면역항암제 hSTC810의 식품의약품안전처 임상 1상 시험계획 승인)',
#  '투자판단 관련 주요경영사항(COVID-19 치료제 CP-COV03의 2상 임상시험계획 승인)',
#  '투자판단 관련 주요경영사항(신종코로나-19 바이러스 감염이 확진된 입원을 요하는 중등증 및 중증 COVID-19 환자에서 Ivaltinostat 치료 유효성 및 안전성 평가를 위한 국내2상 임상시험계획 자진 취하 신청)',
#  '투자판단 관련 주요경영사항(COVID-19 백신 GBP510의 부스터샷 제3상 임상시험계획(IND) 신청)',
#  '투자판단 관련 주요경영사항(중등증 코로나바이러스감염증-19 (COVID-19) 환자를 대상으로 BLS-H01의 유효성과 안전성을 평가하기 위한 다기관, 무작위배정, 이중눈가림, 위약 대조, 평행군, 제2상 임상시험 계획 승인)',
#  '투자판단 관련 주요경영사항(mRNA-LNP 기반 코로나19 예방 백신 후보물질STP2104의 임상 제1상 시험계획(IND) 승인)',
#  '투자판단 관련 주요경영사항(이중항체 항암제 ABL001의 제1b상 임상시험 결과)',
#  '투자판단 관련 주요경영사항(자궁경부전암에 대한 치료제 BLS-ILB-E710c의 유효성 확증을 위한 다기관, 이중눈가림, 층화 블록 무작위 배정, 위약 대조, 심리스 2 파트, 적응적 제2/3상 임상시험 계획 신청)',
#  '투자판단 관련 주요경영사항(급성골수성 백혈병치료제 (SKI-G-801)에 대한 미국 FDA 임상 1상 시험 결과 - 임상시험결과보고서(Clinical Study Report) 수령)',
#  '투자판단 관련 주요경영사항(호중구감소증 치료 목적 EC-18의 임상2상시험 자진 중단)',
#  '투자판단 관련 주요경영사항(제테마더톡신주 100단위의 미간주름개선 제3상 임상시험계획 승인)',
#  '투자판단 관련 주요경영사항(건강한 미국인을 대상으로 Tegoprazan의 약동/약력학적 특성 및 안전성/내약성을 평가하기 위한 제1상 임상시험 결과)',
#  '투자판단 관련 주요경영사항(COVID-19 백신 GBP510의 부스터샷 제3상 임상시험계획(IND) 승인)',
#  '투자판단 관련 주요경영사항(COVID-19 백신 GBP510의 제3상 임상시험 결과 발표)',
#  '투자판단 관련 주요경영사항(당뇨병성 신증 치료제 CU01-1001의 식품의약품안전처 2b상 임상시험계획(IND) 신청)',
#  '투자판단 관련 주요경영사항(전이성 거세저항성 전립선암 환자에 대한 [177Lu] 루도타다이펩의 단일투여 및 반복투여 치료의 안정성 및 유효성 평가; 제1/2a상 임상시험계획 신청)',
#  '투자판단 관련 주요경영사항(국책과제 선정(아데노바이러스 벡터를 기반으로 한 코로나19 예방백신의 임상 2b/3상 개발))',
#  '투자판단 관련 주요경영사항(보툴리눔 톡신 무통 액상제제 "HG102" 임상1상 시험 결과)',
#  '기타 경영사항(자율공시)(COVID-19 예방 합성항원 백신 유코백-19의 제3상 임상시험계획(IND) 승인)',
#  '투자판단 관련 주요경영사항(COVID-19 예방 백신(IN-B009) 국내 임상1상 시험 자진 중단)',
#  '기타 경영사항(자율공시)(국책과제선정(혁신 CD19 표적 CAR-T 치료제 임상 1상 연구))',
#  '투자판단 관련 주요경영사항(재조합 대상포진 백신(CVI-VZV-001)의 안전성 및 유효성을 확인하기 위한 한국 식품의약품안전처(MFDS) 제1상 임상시험계획(IND) 승인 신청(재신청))',
#  '투자판단 관련 주요경영사항(COVID-19 예방 백신 AdCLD-CoV19-1 OMI의 제1/2상 임상시험 계획(IND) 신청)',
#  '투자판단 관련 주요경영사항(퓨어스템-알에이주(동종제대혈유래중간엽줄기세포)치료제 1/2a상 임상시험 Topline data 발표)',
#  '투자판단 관련 주요경영사항(전이성 거세저항성 전립선암 환자에 대한 [177Lu]루도타다이펩의 반복투여 치료의 안전성 및 유효성 평가; 제2상 임상시험계획 승인)',
#  '투자판단 관련 주요경영사항(CT-P47(악템라 바이오시밀러) 유럽 임상 3상 시험계획 신청)',
#  '투자판단 관련 주요경영사항(표적항암제 ABN401의 한국/호주 제1-2상 임상시험 결과)',
#  '투자판단 관련 주요경영사항(무릎 연골 관절염 치료재 MegaCarti®(메가카티®) 임상시험(Topline data) 결과)',
#  '투자판단 관련 주요경영사항(재발성 교모세포종 치료제 VT-Tri(2)의 식품의약품안전처 제1상 임상시험계획(IND) 신청)',
#  '투자판단 관련 주요경영사항(COVID-19 백신 GBP510의 부스터샷 태국 제3상 임상시험계획(IND) 신청)',
#  '기타 경영사항(자율공시)([국책과제 선정]다가 코로나19예방 mRNA백신개발-신변종 감염병대응 mRNA백신 임상지원)',
#  '투자판단 관련 주요경영사항(전이성 거세저항성 전립선암 환자에 대한 [177Lu] 루도타다이펩의 단일투여 및 반복투여 치료의 안정성 및 유효성 평가; 제1/2a상 임상시험계획 승인(FDA))',
#  '기타 경영사항(자율공시)([국책과제 선정] 신변종출현 감염병 신속대응 mRNA백신 플랫폼 구축 및 임상시험 개발)',
#  '투자판단 관련 주요경영사항(CT-P47(악템라 바이오시밀러) 미국 임상 3상 시험계획 신청)',
#  '기타 경영사항(자율공시)(MSD와 공동임상 및 의약품 지원 계약 체결)',
#  '투자판단 관련 주요경영사항(조영제유발급성신장손상(CI-AKI) 치료제 Isuzinaxib(APX-115)의 미국 FDA 2상 임상시험 계획(IND) 신청)',
#  '투자판단 관련 주요경영사항(CT-P63+CT-P66(코로나19 흡입형 치료제) 유럽 임상 3상 시험계획 승인)',
#  '투자판단 관련 주요경영사항(나이벡 펩타이드 기반 폐섬유증 치료제(NIPEP-PF, 임상시험코드명 NP-201) 호주 임상 1상 시험계획 신청)',
#  '투자판단 관련 주요경영사항(퓨어스템-오에이 키트 주 (FURESTEM-OA Kit Inj.) 제 1/2a 상 임상시험계획(IND) 자진취하)',
#  '투자판단 관련 주요경영사항(마약성진통제(아편유사제)를 복용중인 암환자에게 PAX-1(경구용)을 경구투여하는 한국식약처(MFDS) 임상2상 시험계획 신청)',
#  '투자판단 관련 주요경영사항(CU06-1004의 약동학적 특성 및 안전성/내약성을 평가하기 위한 미국 제1상 임상시험 결과)',
#  '기타 경영사항(자율공시)(PBP1510 임상 1/2a상 시험 계획에 대한 미국 식품의약국(FDA)의 승인)',
#  '투자판단 관련 주요경영사항(CT-P63+CT-P66(코로나19 흡입형 치료제) 유럽 임상 중단)',
#  '투자판단 관련 주요경영사항(티로신키나아제 저해제(TKI) 치료에 실패한 국소 진행성 또는 전이성 비소세포폐암 환자를 대상으로 젬시타빈/카보플라틴 등과 병용 투여하는 SNK01(NK Cells)의 제1/2a상 임상시험(SNK_ASTER) 계획 승인)']

# %%
df[df["title"].str.contains("임상")]["title"].to_list()
# Out:
# ['투자판단 관련 주요경영사항(코로나치료제로 임상중인 안트로퀴노놀의 라이센스계약체결)',
#  '임상시험단계 진입ㆍ종료(자율공시)',
#  '투자판단 관련 주요경영사항(체외진단 의료기기 제조허가(임상자료심사) 신청 자진 취하(BRCAaccuTest PLUS))',
#  '투자판단 관련 주요경영사항(이영양성수포성표피박리증환자를 대상으로 ALLO-ASC-SHEET의 유효성과 안전성을 평가하는 제 3상 임상시험 계획 승인(일본))',
#  '투자판단 관련 주요경영사항(재발 및 난치성 유잉육종(Ewing Sarcoma) 제 1상 임상시험 계획 승인)',
#  '투자판단 관련 주요경영사항(CT-P43 국내 임상3상 시험계획 승인)',
#  '기타 주요경영사항(자율공시)(신경내분비종양 표적 치료용 방사성의약품의 국내 임상2상 시험 진행 중단 및 관련 계약 해지)',
#  '투자판단 관련 주요경영사항(CT-P41(프롤리아 바이오시밀러) 임상 3상 시험계획 미국 FDA 신청)',
#  '투자판단 관련 주요경영사항(면역항암제 EU101의 임상 1/2상 시험 승인)',
#  '투자판단 관련 주요경영사항(코로나치료제 DWJ1248의 COVID-19 예방 목적 임상3상 시험계획 승인)',
#  '투자판단 관련 주요경영사항(코로나치료제 DWJ1248의 COVID-19 예방 목적 임상3상 시험계획 승인)(자회사의 주요경영사항)',
#  '투자판단 관련 주요경영사항(COVID-19 치료제 Lenzilumab의 식약처 가교임상시험 계획 (IND) 승인 신청)',
#  '투자판단 관련 주요경영사항(COVID-19 치료제 Lenzilumab의 식약처 가교임상시험 계획 (IND) 승인 신청)',
#  '투자판단 관련 주요경영사항(알츠하이머병 치료제로서 GV 1001의 국내 제3상 임상시험계획 승인 신청)',
#  '투자판단 관련 주요경영사항(보툴리눔 톡신 액상제제 "HG102" 임상1상 시험계획 승인)',
#  '투자판단 관련 주요경영사항(이중항체 면역항암제 ABL503의 미국 FDA 제1상 임상시험계획 (IND) 승인)',
#  '투자판단 관련 주요경영사항(무릎골관절염 환자를 대상으로 EVA-001(카티스템) 일본임상 3상 임상시험계획승인(CTN) 신청)',
#  '투자판단 관련 주요경영사항(코로나바이러스-19 감염으로 인한 폐렴 환자에게서 동종 지방유래 중간엽 줄기세포치료제 아스트로스템-V의 안전성 및 유효성을 탐색하기 위한 국내 제1/2a상 임상시험계획 반려)',
#  '투자판단 관련 주요경영사항(자궁내막증 치료제 TU2670의 폴란드 임상 2a상 시험 계획 신청)',
#  '투자판단 관련 주요경영사항(무릎골관절염 환자를 대상으로 EVA-001(카티스템)의 일본임상 3상 임상시험계획(CTN) 승인)',
#  '투자판단 관련 주요경영사항(알츠하이머 치료제로서 도네페질패치의 다국가 제3상 임상시험 Primary Endpoint 결과 [Key results Report수령])',
#  '투자판단 관련 주요경영사항(CT-P41(프롤리아 바이오시밀러) 임상 3상 시험계획 국내 식약처 신청)',
#  '투자판단 관련 주요경영사항(CT-P42(아일리아 바이오시밀러) 임상 3상 시험계획 국내 식약처 신청)',
#  '투자판단 관련 주요경영사항(. 이영양성수포성표피박리증환자를 대상으로 ALL-ASC-SHEET의 유효성과 안전성을 평가하는 제 2상 임상시험 계획 승인(미국))',
#  '투자판단 관련 주요경영사항(CT-P41(프롤리아 바이오시밀러) 임상 3상 시험계획 미국 FDA 승인)',
#  '투자판단 관련 주요경영사항(CT-P42(아일리아 바이오시밀러) 임상 3상 시험계획 미국 FDA 신청)',
#  '투자판단 관련 주요경영사항(면역항암제 EU101의 임상 1/2상 시험 계획 신청)',
#  '투자판단 관련 주요경영사항(CT-P41(프롤리아 바이오시밀러) 임상 3상 시험계획 유럽 우크라이나 신청)',
#  '투자판단 관련 주요경영사항(자궁내막증 치료제 TU2670의 이탈리아 임상 2a상 시험 계획 신청)',
#  '투자판단 관련 주요경영사항(비마약성 진통제 VVZ-149 주사의 국내 제 3상 임상시험계획 승인)',
#  '투자판단 관련 주요경영사항(중등도 이상의 급성 호흡곤란증후군 환자에서 SCM-AGH의 유효성 및 안전성 평가를 위한 다기관, 공개, 무작위배정, 용량·용법 탐색, 제2a상 임상시험계획(IND) 자진 취하 신청)',
#  '투자판단 관련 주요경영사항(경증 및 중등증 코로나바이러스감염증-19 (COVID-19) 환자를 대상으로 BLS-H01 유효성과 안전성을 평가하기 위한 다기관, 무작위배정, 이중눈가림, 위약 대조, 평행군, 제 2 상 임상시험 계획 (IND) 자진 취하)',
#  '투자판단 관련 주요경영사항(이중항체 면역항암제 ABL111의 미국 FDA 제1상 임상시험계획 (IND) 신청)',
#  '투자판단 관련 주요경영사항(국책과제 선정(아데노바이러스 벡터를 기반으로 한 코로나19 예방백신의 임상 1/2a상 개발))',
#  '투자판단 관련 주요경영사항(페디오코커스 펜토사세우스 (Pediococcus pentosaseus)에서 생산한 P8 (대장암 유전자 치료제) 의 임상 1상 시험계획 신청)',
#  '투자판단 관련 주요경영사항(OLP-1002 비마약성진통제 신약 호주 임상1b상 시험 진행 현황)',
#  '투자판단 관련 주요경영사항(나파벨탄주 임상 3상 신청)',
#  '투자판단 관련 주요경영사항(나파벨탄주 임상 3상 신청)(자회사의 주요경영사항)',
#  '투자판단 관련 주요경영사항(제1b/2a상 임상 시험 계획 변경 신청-전이성 또는 절제 불가능한 신세포암(RCC, 신장암) 이 있는 시험대상자에서 Cemiplimab(REGN2810, 항-PD-1)과 병용투여 한 펙사벡의 용량 증량 및 안전성/유효성 평가)',
#  '투자판단 관련 주요경영사항(마이크로바이옴 신약 KBL693 호주 1상 임상시험 종료)',
#  '투자판단 관련 주요경영사항(골관절염 주사요법제 SP5M001주의 임상3상 시험계획 승인)',
#  '투자판단 관련 주요경영사항(COVID-19 예방 DNA 백신 GX-19N 의 2/3상 임상시험 계획 신청)',
#  '투자판단 관련 주요경영사항(K&L grade 2~3의 무릎 골관절염 환자를 대상으로 한 SMUP-IA-01의 안전성 및 탐색적인 유효성을 평가하는 국내 제1상 임상시험 결과)',
#  '투자판단 관련 주요경영사항(COVID-19 치료제 APX-115의 US FDA 2상 임상시험 IND 승인)',
#  '투자판단 관련 주요경영사항(CT-P42(아일리아 바이오시밀러) 임상 3상 시험계획 미국 FDA 승인)',
#  '투자판단 관련 주요경영사항(이중항체 면역항암제 ABL111의 미국 FDA 제1상 임상시험계획 (IND) 승인)',
#  '투자판단 관련 주요경영사항(OLP-1002 비마약성진통제 신약 영국 임상1상 시험결과)',
#  '투자판단 관련 주요경영사항(PolyQ 척수소뇌 실조증 치료에 대한 Stemchymal 투여의 안전성 및 유효성을 평가하기 위한 공개, 다기관, 단일군, 제2상 임상시험 계획승인(IND) 신청)',
#  '투자판단 관련 주요경영사항(수술이 불가능한 진행성 또는 전이성 췌장암 환자들을 대상으로 한 임상3상 계획(IND) 승인 신청)',
#  '투자판단 관련 주요경영사항(도네페질패취의 미국 FDA 제1상 임상시험계획 (IND) 신청)',
#  '투자판단 관련 주요경영사항(제테마더톡신주 100단위의 미간주름개선 제1상 임상시험 종료 )',
#  '투자판단 관련 주요경영사항(제테마더톡신주 100단위의 미간주름개선 제3상 임상시험계획  IND 신청 )',
#  '투자판단 관련 주요경영사항(나파벨탄주 임상 3상 승인)',
#  '투자판단 관련 주요경영사항(나파벨탄주 임상 3상 승인)(자회사의 주요경영사항)',
#  '투자판단 관련 주요경영사항(자궁내막증 치료제 TU2670의 체코 임상 2a상 시험 계획 승인)',
#  '투자판단 관련 주요경영사항(진행성 또는 전이성 위암 및 위식도접합부암 환자 대상 1차 치료로 캄렐리주맙과 카페시타빈/옥살리플라틴 병용 투여 후 리보세라닙(아파티닙)과 캄렐리주맙 병용투여, 3상 임상시험 계획(IND) 승인 신청)',
#  '투자판단 관련 주요경영사항(알츠하이머병 치료제로서 GV 1001의 국내 제3상 임상시험계획 반려)',
#  '투자판단 관련 주요경영사항(다계통위축증(MSA) 치료제 KM819의 2상 임상시험 계획 신청)',
#  '투자판단 관련 주요경영사항(CT-P41(프롤리아 바이오시밀러) 임상 3상 시험계획 국내 식약처 승인)',
#  '투자판단 관련 주요경영사항(도네페질패취의 미국 FDA 제1상 임상시험계획 승인)',
#  '투자판단 관련 주요경영사항(CT-P42(아일리아 바이오시밀러) 3상 임상시험계획 국내 식약처 승인)',
#  '투자판단 관련 주요경영사항(중등도 이상의 만성 아토피피부염 환자를 대상으로 퓨어스템-에이디주(FURESTEM-AD Inj.)의 제3상 임상시험 승인)',
#  '투자판단 관련 주요경영사항(자궁내막증 치료제 TU2670의 폴란드 임상 2a상 시험 계획 승인)',
#  '투자판단 관련 주요경영사항(식약처 유권해석으로 인한 [인공지능 기반 위종양 병리 솔루션 VUNO Med - PathGC AI의 유효성을 평가하기 위한 후향적, 확증 임상적 성능시험] 시험 계획 승인 신청 취하)',
#  '투자판단 관련 주요경영사항(HU024 점안제의 국내 임상시험계획(IND) 자진 취하 신청)',
#  '투자판단 관련 주요경영사항(면역항암제 EU101의 임상 1/2상 시험 계획 승인 )',
#  '투자판단 관련 주요경영사항(이중항체 면역항암제 ABL501의 국내 제1상 임상시험계획 (IND) 신청)',
#  '투자판단 관련 주요경영사항(궤양성대장염 치료제 BBT-401의 한국 식약처 제 2a상 임상시험 계획 승인)',
#  '투자판단 관련 주요경영사항(이중항체 항암제 ABL001의 제1a상 임상시험 결과)',
#  '투자판단 관련 주요경영사항(전립선암 진단용 방사성의약품으로 개발중인 [F-18]Florastamin (프로젝트명: FC303)의 유럽 임상 3상 승인 - 유럽 오스트리아 보건식품안전청 (AGES))',
#  '투자판단 관련 주요경영사항(마이크로바이옴 신약 KBL697 미국 FDA 2a 임상시험계획 신청)',
#  '투자판단 관련 주요경영사항(투자판단 관련 주요경영사항 (NT-I7(NT-109) 임상 2상 시험계획 유럽 이탈리아 승인))',
#  '투자판단 관련 주요경영사항(코로나19 바이러스(SARS-CoV-2) 감염환자 치료제(CT-P59) 임상 3상 결과 발표)',
#  '투자판단 관련 주요경영사항(대상포진 예방백신 ‘EG-HZ’ 호주 1상 임상시험 완료)',
#  '투자판단 관련 주요경영사항(VM202-ALS 임상 2a상 시험 계획에 대한 국내 식약처 승인)',
#  '투자판단 관련 주요경영사항(당뇨병성 족부궤양(diabetic foot ulcer) 환자를 대상으로 한 엔젠시스 미국 임상 3상 시험 분석 결과 공개)',
#  '투자판단 관련 주요경영사항(AXL 저해제 SKI-G-801 임상 1상 시험 신청)',
#  '기타 경영사항(자율공시)(PBP1510 임상 1/2a상 시험 계획에 대한 프랑스 ANSM의 승인)',
#  '투자판단 관련 주요경영사항(코로나바이러스감염증-19(COVID-19) 예방 백신의 제1/2a상 임상시험 계획(IND) 변경 신청)',
#  '투자판단 관련 주요경영사항(중등도에서 중증 판상형 건선 환자를 대상으로 CT303(동종편도유래중간엽줄기세포)의 단회투여 및 반복투여 시 안전성, 내약성 및 유효성 평가를 위한 공개, 용량 증량, 제1상 임상시험 신청)',
#  '투자판단 관련 주요경영사항(재발성 또는 불응성 B세포 비호지킨 림프종 환자에서 AT101 (항-CD19 키메릭항원수용체 T세포)의 안전성, 내약성 및 유효성을 평가하기 위한 공개, 단일군, 다기관, 제1/2상 국내 임상시험계획 (IND) 신청)',
#  '투자판단 관련 주요경영사항(알츠하이머병 치료제로서 GV 1001의 국내 제3상 임상시험계획 승인 신청)',
#  '투자판단 관련 주요경영사항(자궁내막증 치료제 TU2670의 이탈리아 임상 2a상 시험 계획 승인)',
#  '투자판단 관련 주요경영사항(A형 혈우병 치료제 PGA40의 다국가 임상3상시험 계획변경 신청)',
#  '투자판단 관련 주요경영사항(mRNA 기반 코로나-19 예방백신 (EG-COVID) 국내 임상 제 1/2a상 시험 계획 (IND) 승인 신청)',
#  '투자판단 관련 주요경영사항(마이크로바이옴 신약 KBL697 미국 FDA 2a 임상시험계획 승인)',
#  '투자판단 관련 주요경영사항(COVID-19 치료제 피라맥스정의 임상 3상 시험계획 승인 신청)',
#  '투자판단 관련 주요경영사항(COVID-19 예방 합성항원 백신 유코백-19의 1/2상 임상시험계획 신청서 제출)',
#  '투자판단 관련 주요경영사항(COVID-19 예방 합성항원 백신 유코백-19의 1/2상 임상시험계획 승인)',
#  '투자판단 관련 주요경영사항(COVID-19 예방 DNA 백신 GX-19N 의 2/3상 임상시험 계획 인도네시아 식약처 승인)',
#  '기타 경영사항(자율공시)(코로나19 치료제 백신 신약개발사업 비임상 지원과제 선정)',
#  '투자판단 관련 주요경영사항(당뇨망막증치료제 ‘EG-Mirotin’ 국내 2상 임상시험 완료)',
#  '투자판단 관련 주요경영사항(COVID-19 치료제 Lenzilumab의 식약처 임상(제1상)시험 계획(IND) 승인)',
#  '투자판단 관련 주요경영사항(코로나바이러스감염증-19(COVID-19) 예방 백신의 제1/2a상 임상시험 계획(IND) 변경 승인)',
#  '투자판단 관련 주요경영사항(면역항암제 TU2218 의 미국 FDA 임상 1/2상 시험계획 (IND) 신청)',
#  '투자판단 관련 주요경영사항(무릎 골관절염 환자를 대상으로 SMUP-IA-01의 국내 임상2상 임상시험계획승인신청(IND))',
#  '투자판단 관련 주요경영사항(AXL 저해제 SKI-G-801 임상 1상 시험 승인)',
#  '투자판단 관련 주요경영사항(앱비앤티셀의 임상1/2a상 적응증 추가 임상시험계획 신청)',
#  '투자판단 관련 주요경영사항(OLP-1002 비마약성진통제 신약 호주 임상1B상 임상시험 종료)',
#  '투자판단 관련 주요경영사항(마이크로바이옴 면역항암 치료제 GEN-001의 국내 제2상 임상시험계획 (IND) 신청)',
#  '투자판단 관련 주요경영사항(HER2 양성 유방암 대상자 중 표준 치료에 실패한 전이를 가진 진행성 또는 재발성 환자에게 ALT-P7을 주사제로 투여하여 안전성, 약동학, 항암효과를 평가하는 국내 임상1상 시험결과)',
#  '투자판단 관련 주요경영사항(이중항체 면역항암제 ABL501의 국내 제1상 임상시험계획 (IND) 승인)',
#  '기타 경영사항(자율공시)(아일리아 바이오시밀러 ALT-L9 국내 임상 1상 시험 결과)',
#  '투자판단 관련 주요경영사항(동물용의약품(유전자치료제) 허니가드-R액의 국내 임상시험계획서(IND) 승인)',
#  '투자판단 관련 주요경영사항(SYK 저해제 SKI-O-703 임상 2a상 결과)',
#  '투자판단 관련 주요경영사항(중등도에서 중증 판상형 건선 환자를 대상으로 CT303(동종편도유래중간엽줄기세포)의 단회투여 및 반복투여 시 안전성, 내약성 및 유효성 평가를 위한 공개, 용량 증량, 제1상 임상시험 승인)',
#  '투자판단 관련 주요경영사항(과민성 방광 증상 치료제 UIP620 임상1상 시험 종료보고서 제출)',
#  '투자판단 관련 주요경영사항(급성호흡곤란증후군 환자를 대상으로 CT303(동종편도유래중간엽줄기세포)의 단회투여 시 안전성, 내약성 및 유효성 평가를 위한 다기관, 공개, 용량 증량 및 용량 탐색, 제1상 임상시험 계획 신청)',
#  '투자판단 관련 주요경영사항(비마약성진통제(OLP-1002) 호주 임상 2a상 시험 계획 신청)',
#  '투자판단 관련 주요경영사항(면역항암제 TU2218 의 미국 FDA 임상 1/2상 시험계획 (IND) 승인)',
#  '투자판단 관련 주요경영사항(신종 코로나바이러스 환자를 대상으로 폐렴에서 중증폐렴 또는 급성호흡곤란증후군으로의 이행을 예방하는 EC-18의 안전성과 유효성을 평가하는 국내 임상2상 시험 결과)',
#  '투자판단 관련 주요경영사항(수술이 불가능한 진행성 또는 전이성 췌장암 환자들을 대상으로 한 임상3상 계획(IND)  자진 취하 신청)',
#  '투자판단 관련 주요경영사항(수술이 불가능한 진행성 또는 전이성 췌장암 환자들을 대상으로한 2/3상 임상시험계획(IND) 승인 신청)',
#  '투자판단 관련 주요경영사항(COVID-19 예방 DNA 백신 GX-19N 의 2/3상 임상시험 계획 변경 신청)',
#  '투자판단 관련 주요경영사항(무릎 골관절염 환자에서 퓨어스템-오에이 키트 주 (FURESTEM-OA Kit Inj.) 투여 시의 안전성 및 탐색적인 유효성 평가를 위한, 단회투여, 단계적 용량증량 및 적정용량 탐색, 제 1/2a 상 임상시험계획(IND) 신청)',
#  '투자판단 관련 주요경영사항(mRNA 기반 코로나-19 예방백신 (EG-COVID) 국내 임상 제 1/2a상 시험 계획 (IND) 승인)',
#  '투자판단 관련 주요경영사항(전이성 삼중 음성 유방암 환자에서 펨브롤리주맙과 병용한 올린베시맙의 제2상, 공개, 다기관 임상시험계획 승인)',
#  '투자판단 관련 주요경영사항(이전 치료력이 없는 진행성 또는 전이성 위암 및 위식도 접합부암 환자를 대상으로 캄렐리주맙+카페시타빈/옥살리플라틴 병용투여 후 리보세라닙+캄렐리주맙 투여에 대한 제2상 임상시험 계획(IND) 승인)',
#  '투자판단 관련 주요경영사항(EuMCV4주(수막구균 단백 접합 백신) 임상 1상시험 종료)',
#  '투자판단 관련 주요경영사항(ALT-BB4 (테르가제, 재조합 히알루로니다제)의 안전성과 내약성 및 약동학 특성을 평가하기 위한 임상시험 1상 계획 승인)',
#  '투자판단 관련 주요경영사항(A형 혈우병 치료제 PGA40의 다국가 임상3상시험 계획변경 승인)',
#  '투자판단 관련 주요경영사항(당뇨병성 신증 치료제 CU01-1001의 식품의약품안전처 3상 임상시험계획(IND) 신청)',
#  '투자판단 관련 주요경영사항(PolyQ 척수소뇌 실조증 치료에 대한 Stemchymal (동종 지방유래 중간엽줄기세포) 투여의 안전성 및 유효성을 평가하기 위한 공개, 다기관, 단일군, 제2상 임상시험계획(IND) 자진취하 신청)',
#  '투자판단 관련 주요경영사항(COVID-19 치료제 CP-COV03의 1상 임상시험계획 신청서 제출)',
#  '투자판단 관련 주요경영사항(마이크로바이옴 면역항암 치료제 GEN-001의 국내 제2상 임상시험계획(IND) 승인)',
#  '투자판단 관련 주요경영사항(앱비앤티셀의 임상1/2a상 적응증 추가 임상시험계획 승인)',
#  '투자판단 관련 주요경영사항(COVID-19 예방 합성항원 백신 유코백-19의 제3상 임상시험계획(IND) 신청)',
#  '투자판단 관련 주요경영사항(비마약성진통제(OLP-1002) 호주 임상 2a상 시험 계획 승인)',
#  '투자판단 관련 주요경영사항(면역항암제 TU2218 의 식품의약품안전처 임상 1/2상 시험계획 신청)',
#  '투자판단 관련 주요경영사항(알레르기비염 면역치료제 DF19001의 임상 1상 임상시험계획승인)',
#  '투자판단 관련 주요경영사항(항암화학방사선요법 치료를 받는 구강, 구인두, 하인두, 비인두 환자에게 유발되는 구강점막염에 대한 EC-18의 안전성과 유효성을 평가하기 위한 다기관, 무작위배정, 이중 눈가림, 위약대조 임상2상 시험 결과)',
#  '투자판단 관련 주요경영사항(작약복합추출물의 제2A상 임상시험계획 승인 양도·양수 계약 체결)',
#  '투자판단 관련 주요경영사항(급성호흡곤란증후군 환자를 대상으로 CT303(동종편도유래중간엽줄기세포)의 단회투여 시 안전성, 내약성 및 유효성 평가를 위한 다기관, 공개, 용량 증량 및 용량 탐색, 제1상 임상시험 계획 승인)',
#  '투자판단 관련 주요경영사항(다계통위축증(MSA) 치료제 KM819의 2상 임상시험 계획 신청 승인)',
#  '투자판단 관련 주요경영사항(무릎 골관절염 환자를 대상으로 SMUP-IA-01의 국내 임상2상 임상시험계획(IND) 승인)',
#  '투자판단 관련 주요경영사항(샤르코-마리-투스병 치료제(Engensis: VM202) 제1/2a상 임상시험 Topline data 발표)',
#  '투자판단 관련 주요경영사항(재발성 교모세포종 환자에서 베바시주맙 (bevacizumab) 과 GX-I7 병용 투여의 유효성 및 안전성을 확인하기 위한 2상 임상시험계획 변경 승인)',
#  '투자판단 관련 주요경영사항(COVID-19 치료제 CP-COV03의 1상 임상시험계획 승인)',
#  '투자판단 관련 주요경영사항(COVID-19 예방 백신 AdCLD-CoV19-1의 제2b/3상 임상시험 계획(IND) 신청)',
#  '투자판단 관련 주요경영사항(COVID-19 감염 중등증 환자에게 PAX-1(경구용)을 경구투여하는 2개의 코호트 대한 파키스탄 식약처(DRAP) 임상1상 시험계획 신청)',
#  '투자판단 관련 주요경영사항(TG-C 추가 적응증 미국FDA 임상2상 검토(Review) 완료 )',
#  '투자판단 관련 주요경영사항(면역항암제 hSTC810의 식품의약품안전처 임상1상 시험계획 신청)',
#  '기타 경영사항(자율공시)(MSD와 대장암 임상3상 공동임상 및 의약품 지원 계약 체결)',
#  '투자판단 관련 주요경영사항(면역항암제 hSTC810 의 미국FDA 임상 1상 시험계획 신청)',
#  '투자판단 관련 주요경영사항(IN-A001(Tegoprazan) 적응증 추가를 위한 임상 3상 시험 결과)',
#  '투자판단 관련 주요경영사항(전이성 췌장암 환자 대상 ivaltinostat/capecitabine 병용요법 또는 capecitabine 단독요법 투여 비교 평가하기 위한 미국 2상 임상시험계획 (IND) 신청)',
#  '투자판단 관련 주요경영사항(중등도 코로나바이러스감염증-19 (COVID-19) 환자를 대상으로 BLS-H01 유효성과 안전성을 평가하기 위한 다기관, 무작위배정, 이중눈가림, 위약 대조, 평행군, 제2상 임상시험)',
#  '투자판단 관련 주요경영사항(COVID19 치료제 SpikeDown 이스라엘 보건부(MoH) 임상1/2상 시험 계획 신청)',
#  '투자판단 관련 주요경영사항(mRNA기반 COVID-19 예방 백신 STP-2104의 임상 제1상 시험계획(IND) 신청)',
#  '투자판단 관련 주요경영사항(재발성 또는 불응성 B세포 비호지킨 림프종 환자에서 AT101 (항-CD19 키메릭항원수용체 T세포)의 안전성, 내약성 및 유효성을 평가하기 위한 공개, 단일군, 다기관, 제1/2상 국내 임상시험 계획(IND) 승인)',
#  '투자판단 관련 주요경영사항(면역항암제 TU2218 의 식품의약품안전처 임상 1/2상 시험계획승인)',
#  '투자판단 관련 주요경영사항(노인 근감소증 환자에서 KP203 반복 투여의 유효성 및 안전성 평가를 위한 다기관, 용량 탐색, 제2상 임상시험계획 신청)',
#  '투자판단 관련 주요경영사항(아이진 mRNA 기반 코로나-19 예방백신 (EG-COVID) 호주 부스터 임상 제 1/2a상 시험 계획  신청  )',
#  '투자판단 관련 주요경영사항(항암치료제 Q901 미국FDA 임상 1/2상 시험 계획(IND) 신청)',
#  '투자판단 관련 주요경영사항(습성 연령관련 황반변성의 경구용 치료제 CU03-1001 임상 2a상 결과)',
#  '투자판단 관련 주요경영사항(알츠하이머병 치료제로서 GV 1001의 국내 제3상 임상시험계획 승인)',
#  '투자판단 관련 주요경영사항(면역항암제 hSTC810 의 미국FDA 임상 1상 시험계획 승인)',
#  '투자판단 관련 주요경영사항(전이성 췌장암 환자 대상 ivaltinostat/capecitabine 병용요법 또는 capectabine 단독요법 투여 비교 평가하기 위한 미국 2상 임상시험계획(IND) 승인)',
#  '투자판단 관련 주요경영사항(항암면역치료백신 BVAC-M의 제1상 임상시험 계획(IND) 신청)',
#  '투자판단 관련 주요경영사항(COVID-19 치료제 피라맥스정의 임상 3상 시험계획 영국 승인 신청)',
#  '투자판단 관련 주요경영사항(COVID-19 치료제 CP-COV03의 제2상 임상시험계획 신청서 제출)',
#  '투자판단 관련 주요경영사항(Wagner grade 1 및 2 당뇨병성 족부궤양 환자를 대상으로 한 ALLO-ASC-DFU 국내 임상 3상 분석 결과)',
#  '투자판단 관련 주요경영사항(COVID-19 예방 백신 AdCLD-CoV19-1의 제2b상 임상시험 계획(IND) 승인)',
#  '투자판단 관련 주요경영사항(COVID-19 예방 합성항원 백신 유코백-19의 제3상 임상시험 계획(IND) 승인)',
#  '투자판단 관련 주요경영사항(mRNA 기반 코로나-19 예방백신 (EG-COVID) 부스터 임상 제 1/2a상 시험 계획 남아프리카공화국 신청)',
#  '투자판단 관련 주요경영사항(전립선암 진단용 방사성의약품 미국임상 1상 종료)',
#  '투자판단 관련 주요경영사항(생화학적 재발 전립선암(BRPC) 환자에서의 [18F]Florastamin PET/CT 영상검사의 진단 유효성 및 안전성을 평가하기 위한 다기관, 단일군, 공개, 제3상 임상시험 IND 신청)',
#  '기타 경영사항(자율공시)([국책과제 선정] 코로나19 치료제.백신 개발 - 코로나 19 백신 임상 지원)',
#  '투자판단 관련 주요경영사항(PSI-401 경구 투여 후 안전성, 내약성 및 약동/약력학적 특성을 평가하기 위한 제1상 임상시험 계획 신청)',
#  '투자판단 관련 주요경영사항(전이성 거세저항성 전립선암 환자에 대한 [177Lu]루도타다이펩의 반복투여 치료의 안전성 및 유효성 평가; 제2상 임상시험계획 신청)',
#  '투자판단 관련 주요경영사항(항암치료제 Q901 미국 임상 1/2상 시험 계획(IND) 승인)',
#  '투자판단 관련 주요경영사항(코로나-19 치료제 CP-COV03의 국내 제1상 임상시험 결과)',
#  '투자판단 관련 주요경영사항(COVID-19 치료제 후보물질 텔라세벡(Telacebec) 임상 2상 시험 자진 중단 결정)',
#  '투자판단 관련 주요경영사항(면역항암제 Q702와 Pembrolizumab(키투르다) 병용 임상1B/2상 시험계획 제출)',
#  '기타 경영사항(자율공시)(PBP1510 임상 1/2a상 시험 계획에 대한 스페인 AEMPS의 승인)',
#  '투자판단 관련 주요경영사항(아이진 mRNA 기반 코로나-19 예방백신 (EG-COVID) 호주 부스터 임상 제 1/2a상 시험 계획 승인)',
#  '투자판단 관련 주요경영사항(재조합 대상포진 백신(CVI-VZV-001)의 한국 식품의약품안전처(MFDS) 제1상 임상시험 계획(IND) 자진취하)',
#  '투자판단 관련 주요경영사항(당뇨병성 신증 치료제 CU01-1001의 식품의약품안전처 3상 임상시험계획(IND) 신청 반려)',
#  '투자판단 관련 주요경영사항(CT-P63+CT-P66(코로나19 흡입형 치료제) 유럽 임상 3상 시험계획 신청)',
#  '투자판단 관련 주요경영사항(중등도 코로나바이러스감염증-19 (COVID-19) 환자를 대상으로 BLS-H01 유효성과 안전성을 평가하기 위한 다기관, 무작위배정, 이중눈가림, 위약 대조, 평행군, 제2상 임상시험계획신청(신청내용 일부 변경))',
#  '투자판단 관련 주요경영사항(수술이 불가능한 진행성 또는 전이성 췌장암 환자에서 Ivaltinostat/Gemcitabine/Erlotinib병용요법 또는FOLFIRINOX요법 후, 안전성과 유효성을 비교 평가하기 위한 2/3상 임상 시험 자진 취하)',
#  '기타 경영사항(자율공시)(담도암 2상 임상시험 협력 및 의약품 지원 계약 체결)',
#  '투자판단 관련 주요경영사항(COVID-19 치료제 피라맥스정의 임상 3상 시험계획 영국 승인)',
#  '투자판단 관련 주요경영사항(항암화학방사선 치료를 받는 두경부암 환자에게 유발되는 구강점막염에 대한 임상2상 최종결과보고서(Final CSR) 수령 )',
#  '투자판단 관련 주요경영사항(COVID-19 예방 DNA 백신 GX-19N의 2/3상 임상시험 자진 철회 결정)',
#  '투자판단 관련 주요경영사항(COVID-19 치료제 CP-COV03의 2상 임상시험계획 신청서 제출(신청내용 일부변경))',
#  '투자판단 관련 주요경영사항(면역항암제 hSTC810의 식품의약품안전처 임상 1상 시험계획 승인)',
#  '투자판단 관련 주요경영사항(COVID-19 치료제 CP-COV03의 2상 임상시험계획 승인)',
#  '투자판단 관련 주요경영사항(신종코로나-19 바이러스 감염이 확진된 입원을 요하는 중등증 및 중증 COVID-19 환자에서 Ivaltinostat 치료 유효성 및 안전성 평가를 위한 국내2상 임상시험계획 자진 취하 신청)',
#  '투자판단 관련 주요경영사항(COVID-19 백신 GBP510의 부스터샷 제3상 임상시험계획(IND) 신청)',
#  '투자판단 관련 주요경영사항(중등증 코로나바이러스감염증-19 (COVID-19) 환자를 대상으로 BLS-H01의 유효성과 안전성을 평가하기 위한 다기관, 무작위배정, 이중눈가림, 위약 대조, 평행군, 제2상 임상시험 계획 승인)',
#  '투자판단 관련 주요경영사항(mRNA-LNP 기반 코로나19 예방 백신 후보물질STP2104의 임상 제1상 시험계획(IND) 승인)',
#  '투자판단 관련 주요경영사항(이중항체 항암제 ABL001의 제1b상 임상시험 결과)',
#  '투자판단 관련 주요경영사항(자궁경부전암에 대한 치료제 BLS-ILB-E710c의 유효성 확증을 위한 다기관, 이중눈가림, 층화 블록 무작위 배정, 위약 대조, 심리스 2 파트, 적응적 제2/3상 임상시험 계획 신청)',
#  '투자판단 관련 주요경영사항(급성골수성 백혈병치료제 (SKI-G-801)에 대한 미국 FDA 임상 1상 시험 결과 - 임상시험결과보고서(Clinical Study Report) 수령)',
#  '투자판단 관련 주요경영사항(호중구감소증 치료 목적 EC-18의 임상2상시험 자진 중단)',
#  '투자판단 관련 주요경영사항(제테마더톡신주 100단위의 미간주름개선 제3상 임상시험계획 승인)',
#  '투자판단 관련 주요경영사항(건강한 미국인을 대상으로 Tegoprazan의 약동/약력학적 특성 및 안전성/내약성을 평가하기 위한 제1상 임상시험 결과)',
#  '투자판단 관련 주요경영사항(COVID-19 백신 GBP510의 부스터샷 제3상 임상시험계획(IND) 승인)',
#  '투자판단 관련 주요경영사항(COVID-19 백신 GBP510의 제3상 임상시험 결과 발표)',
#  '투자판단 관련 주요경영사항(당뇨병성 신증 치료제 CU01-1001의 식품의약품안전처 2b상 임상시험계획(IND) 신청)',
#  '투자판단 관련 주요경영사항(전이성 거세저항성 전립선암 환자에 대한 [177Lu] 루도타다이펩의 단일투여 및 반복투여 치료의 안정성 및 유효성 평가; 제1/2a상 임상시험계획 신청)',
#  '투자판단 관련 주요경영사항(국책과제 선정(아데노바이러스 벡터를 기반으로 한 코로나19 예방백신의 임상 2b/3상 개발))',
#  '투자판단 관련 주요경영사항(보툴리눔 톡신 무통 액상제제 "HG102" 임상1상 시험 결과)',
#  '기타 경영사항(자율공시)(COVID-19 예방 합성항원 백신 유코백-19의 제3상 임상시험계획(IND) 승인)',
#  '투자판단 관련 주요경영사항(COVID-19 예방 백신(IN-B009) 국내 임상1상 시험 자진 중단)',
#  '기타 경영사항(자율공시)(국책과제선정(혁신 CD19 표적 CAR-T 치료제 임상 1상 연구))',
#  '투자판단 관련 주요경영사항(재조합 대상포진 백신(CVI-VZV-001)의 안전성 및 유효성을 확인하기 위한 한국 식품의약품안전처(MFDS) 제1상 임상시험계획(IND) 승인 신청(재신청))',
#  '투자판단 관련 주요경영사항(COVID-19 예방 백신 AdCLD-CoV19-1 OMI의 제1/2상 임상시험 계획(IND) 신청)',
#  '투자판단 관련 주요경영사항(퓨어스템-알에이주(동종제대혈유래중간엽줄기세포)치료제 1/2a상 임상시험 Topline data 발표)',
#  '투자판단 관련 주요경영사항(전이성 거세저항성 전립선암 환자에 대한 [177Lu]루도타다이펩의 반복투여 치료의 안전성 및 유효성 평가; 제2상 임상시험계획 승인)',
#  '투자판단 관련 주요경영사항(CT-P47(악템라 바이오시밀러) 유럽 임상 3상 시험계획 신청)',
#  '투자판단 관련 주요경영사항(표적항암제 ABN401의 한국/호주 제1-2상 임상시험 결과)',
#  '투자판단 관련 주요경영사항(무릎 연골 관절염 치료재 MegaCarti®(메가카티®) 임상시험(Topline data) 결과)',
#  '투자판단 관련 주요경영사항(재발성 교모세포종 치료제 VT-Tri(2)의 식품의약품안전처 제1상 임상시험계획(IND) 신청)',
#  '투자판단 관련 주요경영사항(COVID-19 백신 GBP510의 부스터샷 태국 제3상 임상시험계획(IND) 신청)',
#  '기타 경영사항(자율공시)([국책과제 선정]다가 코로나19예방 mRNA백신개발-신변종 감염병대응 mRNA백신 임상지원)',
#  '투자판단 관련 주요경영사항(전이성 거세저항성 전립선암 환자에 대한 [177Lu] 루도타다이펩의 단일투여 및 반복투여 치료의 안정성 및 유효성 평가; 제1/2a상 임상시험계획 승인(FDA))',
#  '기타 경영사항(자율공시)([국책과제 선정] 신변종출현 감염병 신속대응 mRNA백신 플랫폼 구축 및 임상시험 개발)',
#  '투자판단 관련 주요경영사항(CT-P47(악템라 바이오시밀러) 미국 임상 3상 시험계획 신청)',
#  '기타 경영사항(자율공시)(MSD와 공동임상 및 의약품 지원 계약 체결)',
#  '투자판단 관련 주요경영사항(조영제유발급성신장손상(CI-AKI) 치료제 Isuzinaxib(APX-115)의 미국 FDA 2상 임상시험 계획(IND) 신청)',
#  '투자판단 관련 주요경영사항(CT-P63+CT-P66(코로나19 흡입형 치료제) 유럽 임상 3상 시험계획 승인)',
#  '투자판단 관련 주요경영사항(나이벡 펩타이드 기반 폐섬유증 치료제(NIPEP-PF, 임상시험코드명 NP-201) 호주 임상 1상 시험계획 신청)',
#  '투자판단 관련 주요경영사항(퓨어스템-오에이 키트 주 (FURESTEM-OA Kit Inj.) 제 1/2a 상 임상시험계획(IND) 자진취하)',
#  '투자판단 관련 주요경영사항(마약성진통제(아편유사제)를 복용중인 암환자에게 PAX-1(경구용)을 경구투여하는 한국식약처(MFDS) 임상2상 시험계획 신청)',
#  '투자판단 관련 주요경영사항(CU06-1004의 약동학적 특성 및 안전성/내약성을 평가하기 위한 미국 제1상 임상시험 결과)',
#  '기타 경영사항(자율공시)(PBP1510 임상 1/2a상 시험 계획에 대한 미국 식품의약국(FDA)의 승인)',
#  '투자판단 관련 주요경영사항(CT-P63+CT-P66(코로나19 흡입형 치료제) 유럽 임상 중단)',
#  '투자판단 관련 주요경영사항(티로신키나아제 저해제(TKI) 치료에 실패한 국소 진행성 또는 전이성 비소세포폐암 환자를 대상으로 젬시타빈/카보플라틴 등과 병용 투여하는 SNK01(NK Cells)의 제1/2a상 임상시험(SNK_ASTER) 계획 승인)']

# %%
df[df["title"].str.contains("품목")]["title"].to_list()
# Out:
# ['투자판단 관련 주요경영사항(HANAROSTENT Trachea/Bronchium (CCC) FDA 품목허가취득)',
#  '투자판단 관련 주요경영사항(리즈톡스주 100단위 품목변경 허가)',
#  '투자판단 관련 주요경영사항(보툴렉스주 300단위 품목허가 승인)',
#  '투자판단 관련 주요경영사항(Botulinum Toxin Type A for Injection 50unit 중국 품목허가 획득)',
#  '소송등의판결ㆍ결정(제조판매품목허가 취소처분 취소의 소)',
#  '투자판단 관련 주요경영사항(무릎골관절염치료제 카티스템 말레이시아 품목허가(BLA) 신청)',
#  '투자판단 관련 주요경영사항(호중구감소증치료제 신약 ‘롤론티스’ 식품의약품안전처 품목허가 승인)',
#  '투자판단 관련 주요경영사항(호중구감소증치료제 신약 ‘롤론티스’ 식품의약품안전처 품목허가 승인)(자회사의 주요경영사항)',
#  '투자판단 관련 주요경영사항(e.p.t.q. 리도카인 S100(필러)외 2건 러시아 품목허가 승인)',
#  '투자판단 관련 주요경영사항(Letibotulinum Toxin A 50/100unit 미국 품목허가 신청)',
#  '투자판단 관련 주요경영사항(에피티콘 러시아 품목허가 승인 )',
#  '기타 경영사항(자율공시)(COVID-19 변이바이러스 진단키트 2개 품목 식품의약품안전처 수출용 제조허가)',
#  '투자판단 관련 주요경영사항(도네페질 패취 식품의약품안전처 국내 품목허가 신청)',
#  '투자판단 관련 주요경영사항(도네페질 패취 식품의약품안전처 국내 품목허가 신청)',
#  '투자판단 관련 주요경영사항(도네페질 패취 의약품품목허가 신청(수출용의약품))',
#  '투자판단 관련 주요경영사항(e.p.t.q. 리도카인 S100(필러)외 2건 태국 품목허가 승인)',
#  '기타 경영사항(자율공시)(브라질 보건부 위생감시국(ANVISA)의 의료기기 품목허가 취득)',
#  '기타 경영사항(자율공시)(브라질 보건부 위생감시국(ANVISA)의 의료기기 품목허가 취득)',
#  '기타 경영사항(자율공시)(도네페질 패취 의약품품목허가 승인(수출용))',
#  '투자판단 관련 주요경영사항(리즈톡스주 50단위 품목허가 완료)',
#  '투자판단 관련 주요경영사항(복합점안제(HU007)의 품목허가 자진 취하 신청)',
#  '기타 경영사항(자율공시)(COVID-19 변이바이러스 진단키트 1개 품목 식품의약품안전처 수출용 제조허가)',
#  '투자판단 관련 주요경영사항(Letybo (letibotulinumtoxinA) 50unit, 100unit 캐나다/호주 품목허가 신청)',
#  '기타 경영사항(자율공시)(체외진단의료기기 제조품목 허가)',
#  '투자판단 관련 주요경영사항(리즈톡스주 200단위 품목허가 완료)',
#  '투자판단 관련 주요경영사항(제테마더톡신주 200U(클리스트리디움 보툴리눔독소A형) 수출용 품목허가 신청)',
#  '투자판단 관련 주요경영사항(HANAROSTENT Esophagus (CCC),HANAROSTENT Esophagus (NCN) FDA 품목허가 취득)',
#  '투자판단 관련 주요경영사항(CKD-701(루센티스 바이오시밀러) 식품의약품안전처 국내 품목허가 신청)',
#  '투자판단 관련 주요경영사항(CKD-701(루센티스 바이오시밀러) 식품의약품안전처 국내 품목허가 신청)(자회사의 주요경영사항)',
#  '투자판단 관련 주요경영사항(코로나19 바이러스(SARS-CoV-2) 감염환자 치료제(CT-P59) 국내 품목변경허가 신청)',
#  '투자판단 관련 주요경영사항(e.p.t.q. 리도카인 S100(필러)외 2건 페루 품목허가 승인)',
#  '투자판단 관련 주요경영사항(코로나19 바이러스(SARS-CoV-2) 감염환자 치료제(CT-P59) 국내 품목변경허가 를 통한 정식 품목허가 획득)',
#  '기타 주요경영사항(자율공시)(의약품 제조판매품목 허가)',
#  '투자판단 관련 주요경영사항(CT-P16(아바스틴 바이오시밀러) 국내 품목허가 신청)',
#  '투자판단 관련 주요경영사항(CT-P16(아바스틴 바이오시밀러) 미국 품목허가 신청)',
#  '투자판단 관련 주요경영사항(HANAROSTENT Esophagus Asymmetric (CCC) FDA 품목허가 신청)',
#  '투자판단 관련 주요경영사항(코로나19 바이러스(SARS-CoV-2) 감염환자 치료제(CT-P59) 유럽 정식 품목허가 신청)',
#  '투자판단 관련 주요경영사항(알제리 식약처 애브서틴주 200,400단위 품목허가)',
#  '투자판단 관련 주요경영사항(CT-P16(아바스틴 바이오시밀러) 유럽 품목허가 신청)',
#  '투자판단 관련 주요경영사항(CT-P17(휴미라 바이오시밀러) 국내 품목허가 획득)',
#  '투자판단 관련 주요경영사항(제테마더톡신주 200U(클리스트리디움 보툴리눔독소A형) 품목허가(수출용에 한함))',
#  '투자판단 관련 주요경영사항(도네페질 패취 식품의약품안전처 국내 품목 허가 획득)',
#  '투자판단 관련 주요경영사항(도네페질 패취(도네시브패취 87.5 밀리그램/도네시브패취 175 밀리그램) 국내 품목허가 획득)',
#  '투자판단 관련 주요경영사항(노바백스 코로나19 백신 국내 품목허가 신청)',
#  '투자판단 관련 주요경영사항(HANAROSTENT Esophagus Asymmetric (CCC) FDA 품목허가 취득)',
#  '투자판단 관련 주요경영사항(보툴렉스주 등 품목허가 취소 행정처분 통지 및 회수폐기명령)',
#  '기타 경영사항(자율공시)(품목허가 취소처분, 판매업무정지처분 및 회수폐기명령에 대한 집행정지 잠정처분 신청 인용 결정)',
#  '기타 경영사항(자율공시)(동물용의료기기 제조품목허가 획득)',
#  '투자판단 관련 주요경영사항(동물용의약품 제조품목(박스루킨-15주)허가 신청 철회)',
#  '기타 경영사항(자율공시)(품목허가 취소처분, 판매업무정지처분 및 회수폐기명령에 대한 집행정지 인용 결정)',
#  '기타 경영사항(자율공시)(체외진단의료기기 제조품목허가 (STANDARD™ M10 SARS-CoV-2))',
#  '투자판단 관련 주요경영사항(노바백스 코로나19 백신 국내 품목허가 획득)',
#  '투자판단 관련 주요경영사항(보툴렉스(Botulax, 수출명 Letybo) 50유닛의 유럽 품목허가 승인권고 획득)',
#  '투자판단 관련 주요경영사항(보툴렉스(Botulax, 수출명 Letybo) 50유닛의 프랑스 품목허가 획득)',
#  '투자판단 관련 주요경영사항(보툴렉스(Botulax, 수출명 Letybo) 50유닛의 오스트리아 품목허가 획득)',
#  '기타 경영사항(자율공시)(미국식품의약국(FDA)의 의료기기 품목허가 취득 (추간체유합보형재))',
#  '투자판단 관련 주요경영사항(보툴렉스(Botulax, 수출명 Letybo) 50유닛의 영국 품목허가 획득)',
#  '투자판단 관련 주요경영사항(보툴렉스(Botulax, 수출명 Letybo) 50유닛의 루마니아 품목허가 획득)',
#  '투자판단 관련 주요경영사항(보툴렉스(Botulax, 수출명 Letybo) 50유닛의 아일랜드 품목허가 획득)',
#  '투자판단 관련 주요경영사항(보툴렉스(Botulax, 수출명 Letybo) 50유닛의 네덜란드 품목허가 획득)',
#  '투자판단 관련 주요경영사항(노바백스 코로나19 백신 국내 품목허가 변경 신청(만 12~17세 청소년 적응증 추가))',
#  '투자판단 관련 주요경영사항(보툴렉스(Botulax, 수출명 Letybo) 50유닛의 포르투갈 품목허가 획득)',
#  '투자판단 관련 주요경영사항(보툴렉스(Botulax, 수출명 Letybo) 50유닛의 이탈리아 품목허가 획득)',
#  '투자판단 관련 주요경영사항(케이캡정(테고프라잔) 중국 품목허가 획득)',
#  '투자판단 관련 주요경영사항(보툴렉스(Botulax, 수출명 Letybo) 50유닛의 독일 품목허가 획득)',
#  '투자판단 관련 주요경영사항(유비톡스주 100단위(클로스트리디움 보툴리눔 독소 A형) 국내 품목허가 신청)',
#  '투자판단 관련 주요경영사항(COVID-19 백신 스카이코비원(GBP510)의 국내 품목허가 신청)',
#  '투자판단 관련 주요경영사항(스카이타이포이드멀티주(장티푸스 접합백신) 수출용 품목허가 획득)',
#  '투자판단 관련 주요경영사항(케이캡정(테고프라잔) 필리핀 품목 허가 승인)',
#  '기타 경영사항(자율공시)(미국식품의약국(FDA)의 의료기기 품목허가 취득(인공고관절))',
#  '투자판단 관련 주요경영사항(보툴렉스(Botulax, 수출명 Letybo) 50유닛의 폴란드 품목허가 획득)',
#  '투자판단 관련 주요경영사항(무릎 연골 관절염 치료재 MegaCarti®(메가카티®) 품목허가(NDA) 신청)',
#  '투자판단 관련 주요경영사항(보툴렉스(Botulax, 수출명 Letybo) 50유닛,100유닛의 캐나다 품목허가 획득)',
#  '투자판단 관련 주요경영사항(제미다파정 국내 품목 허가 획득)',
#  '투자판단 관련 주요경영사항(제미다파정 국내 품목 허가 획득)(자회사의 주요경영사항)',
#  '투자판단 관련 주요경영사항(COVID-19 백신 스카이코비원(GBP510)의 국내 품목허가 획득)']

# %%
import os
from config import keywords

# df["title"] 컬럼의 앞뒤 공백 제거
df["title"] = df["title"].str.strip()

# df에 disclosure_type 필드 추가
df["disclosure_type"] = None

# keywords를 기반으로 disclosure_type 매핑
for disclosure_type, title_variations in keywords.items():
    if title_variations:  # 빈 리스트가 아닌 경우
        # 각 title_variation이 title에 포함되어 있는지 확인
        for variation in title_variations:
            mask = df["title"].str.contains(variation, na=False, regex=True)
            df.loc[mask, "disclosure_type"] = disclosure_type
    else:  # 빈 리스트인 경우, key 자체를 검색
        mask = df["title"].str.contains(disclosure_type, na=False, regex=True)
        df.loc[mask, "disclosure_type"] = disclosure_type

# 결과 확인
print("disclosure_type 분포:")
print(df["disclosure_type"].value_counts(dropna=False))
print(f"\n전체 행 수: {len(df)}")
print(f"매핑된 행 수: {df['disclosure_type'].notna().sum()}")
print(f"매핑되지 않은 행 수: {df['disclosure_type'].isna().sum()}")

# 임상 관련 공시들이 제대로 분류되었는지 확인
clinical_titles = df[df["title"].str.contains("임상", na=False)]
print(f"\n임상 관련 공시 수: {len(clinical_titles)}")
print("임상 관련 공시 분류 현황:")
print(clinical_titles["disclosure_type"].value_counts(dropna=False))

# 매핑되지 않은 공시 제목들을 CSV로 저장
unmapped_titles = df[df["disclosure_type"].isna()]["title"].value_counts()
unmapped_titles_df = unmapped_titles.reset_index()
unmapped_titles_df.columns = ["title", "count"]
unmapped_titles_df.to_csv("unmapped_disclosure_titles.csv", index=True, encoding="utf-8-sig")
print(f"매핑되지 않은 공시 제목 {len(unmapped_titles_df)}개를 'unmapped_disclosure_titles.csv' 파일로 저장했습니다.")

# type_kind 폴더 생성
os.makedirs("type_kind", exist_ok=True)

# disclosure_type별로 CSV 파일 저장
for disclosure_type in df["disclosure_type"].dropna().unique():
    type_df = df[df["disclosure_type"] == disclosure_type]
    filename = f"type_kind/{disclosure_type}.csv"
    type_df.to_csv(filename, index=False, encoding="utf-8-sig")
    print(f"{disclosure_type}: {len(type_df)}개 행을 '{filename}' 파일로 저장했습니다.")

unmapped_titles
# Out:
# disclosure_type 분포:
# disclosure_type
# None                   36483
# 지분공시                   33540
# 실적공시                   13051
# 매출액변동                   4047
# 단일판매ㆍ공급계약체결             3030
# 배당                      2492
# 타법인 주식 및 출자증권 양수결정      1134
# 유상증자 결정                  944
# 전환사채권 발행결정               721
# 자기주식 처분 결정               611
# 특허권취득                    584
# 소송등의판결ㆍ결정                384
# 자기주식취득 신탁계약 체결 결정        352
# 소송 등의 제기                 346
# 타법인 주식 및 출자증권 양도결정       298
# 신규시설투자                   256
# 회사합병 결정                  254
# 자기주식 취득 결정               229
# 유형자산 양수 결정               213
# 유형자산 양도 결정               163
# 자기주식취득 신탁계약 해지 결정        159
# 무상증자 결정                  158
# 회사분할 결정                  123
# 임상 계획 승인                 105
# 단일판매ㆍ공급계약해지               91
# 감자 결정                     88
# 주권 관련 사채권 양수 결정           88
# 생산중단                      87
# 임상 계획 신청                  70
# 자기주식 소각 결정                66
# 신주인수권부사채권 발행결정            64
# 교환사채권 발행결정                60
# 영업정지                      49
# 품목허가 승인                   42
# 상각형 조건부자본증권 발행결정          41
# 임상 계획 결과 발표               37
# 횡령ㆍ배임혐의발생                 33
# 주권 관련 사채권 양도 결정           25
# 유무상증자 결정                  23
# 해산사유 발생                   21
# 품목허가 신청                   20
# 기술이전계약체결                  17
# 회생절차 개시신청                 16
# 영업양수 결정                   16
# 품목허가 철회                   15
# 자산양수도(기타), 풋백옵션           14
# 영업양도 결정                   12
# 공개매수                      11
# 임상 계획 철회                   9
# 회사분할합병 결정                  4
# 해외 증권시장 주권등 상장             4
# 해외 증권시장 주권등 상장폐지 결정        4
# 채권은행 등의 관리절차 개시            2
# 기술이전계약해지                   2
# 해외 증권시장 주권등 상장폐지           2
# Name: count, dtype: int64
#
# 전체 행 수: 100710
# 매핑된 행 수: 64227
# 매핑되지 않은 행 수: 36483
#
# 임상 관련 공시 수: 230
# 임상 관련 공시 분류 현황:
# disclosure_type
# 임상 계획 승인       94
# 임상 계획 신청       69
# 임상 계획 결과 발표    37
# None           12
# 품목허가 철회        10
# 임상 계획 철회        8
# Name: count, dtype: int64
# 매핑되지 않은 공시 제목 999개를 'unmapped_disclosure_titles.csv' 파일로 저장했습니다.
# 영업정지: 49개 행을 'type_kind/영업정지.csv' 파일로 저장했습니다.
# 지분공시: 33540개 행을 'type_kind/지분공시.csv' 파일로 저장했습니다.
# 단일판매ㆍ공급계약체결: 3030개 행을 'type_kind/단일판매ㆍ공급계약체결.csv' 파일로 저장했습니다.
# 품목허가 승인: 42개 행을 'type_kind/품목허가 승인.csv' 파일로 저장했습니다.
# 배당: 2492개 행을 'type_kind/배당.csv' 파일로 저장했습니다.
# 유상증자 결정: 944개 행을 'type_kind/유상증자 결정.csv' 파일로 저장했습니다.
# 타법인 주식 및 출자증권 양수결정: 1134개 행을 'type_kind/타법인 주식 및 출자증권 양수결정.csv' 파일로 저장했습니다.
# 자기주식취득 신탁계약 해지 결정: 159개 행을 'type_kind/자기주식취득 신탁계약 해지 결정.csv' 파일로 저장했습니다.
# 신규시설투자: 256개 행을 'type_kind/신규시설투자.csv' 파일로 저장했습니다.
# 유형자산 양도 결정: 163개 행을 'type_kind/유형자산 양도 결정.csv' 파일로 저장했습니다.
# 소송등의판결ㆍ결정: 384개 행을 'type_kind/소송등의판결ㆍ결정.csv' 파일로 저장했습니다.
# 유형자산 양수 결정: 213개 행을 'type_kind/유형자산 양수 결정.csv' 파일로 저장했습니다.
# 생산중단: 87개 행을 'type_kind/생산중단.csv' 파일로 저장했습니다.
# 전환사채권 발행결정: 721개 행을 'type_kind/전환사채권 발행결정.csv' 파일로 저장했습니다.
# 해산사유 발생: 21개 행을 'type_kind/해산사유 발생.csv' 파일로 저장했습니다.
# 자기주식 처분 결정: 611개 행을 'type_kind/자기주식 처분 결정.csv' 파일로 저장했습니다.
# 소송 등의 제기: 346개 행을 'type_kind/소송 등의 제기.csv' 파일로 저장했습니다.
# 신주인수권부사채권 발행결정: 64개 행을 'type_kind/신주인수권부사채권 발행결정.csv' 파일로 저장했습니다.
# 임상 계획 결과 발표: 37개 행을 'type_kind/임상 계획 결과 발표.csv' 파일로 저장했습니다.
# 특허권취득: 584개 행을 'type_kind/특허권취득.csv' 파일로 저장했습니다.
# 타법인 주식 및 출자증권 양도결정: 298개 행을 'type_kind/타법인 주식 및 출자증권 양도결정.csv' 파일로 저장했습니다.
# 무상증자 결정: 158개 행을 'type_kind/무상증자 결정.csv' 파일로 저장했습니다.
# 자기주식 취득 결정: 229개 행을 'type_kind/자기주식 취득 결정.csv' 파일로 저장했습니다.
# 품목허가 철회: 15개 행을 'type_kind/품목허가 철회.csv' 파일로 저장했습니다.
# 임상 계획 승인: 105개 행을 'type_kind/임상 계획 승인.csv' 파일로 저장했습니다.
# 자기주식취득 신탁계약 체결 결정: 352개 행을 'type_kind/자기주식취득 신탁계약 체결 결정.csv' 파일로 저장했습니다.
# 주권 관련 사채권 양수 결정: 88개 행을 'type_kind/주권 관련 사채권 양수 결정.csv' 파일로 저장했습니다.
# 주권 관련 사채권 양도 결정: 25개 행을 'type_kind/주권 관련 사채권 양도 결정.csv' 파일로 저장했습니다.
# 회사합병 결정: 254개 행을 'type_kind/회사합병 결정.csv' 파일로 저장했습니다.
# 매출액변동: 4047개 행을 'type_kind/매출액변동.csv' 파일로 저장했습니다.
# 실적공시: 13051개 행을 'type_kind/실적공시.csv' 파일로 저장했습니다.
# 공개매수: 11개 행을 'type_kind/공개매수.csv' 파일로 저장했습니다.
# 임상 계획 철회: 9개 행을 'type_kind/임상 계획 철회.csv' 파일로 저장했습니다.
# 감자 결정: 88개 행을 'type_kind/감자 결정.csv' 파일로 저장했습니다.
# 회사분할 결정: 123개 행을 'type_kind/회사분할 결정.csv' 파일로 저장했습니다.
# 임상 계획 신청: 70개 행을 'type_kind/임상 계획 신청.csv' 파일로 저장했습니다.
# 자기주식 소각 결정: 66개 행을 'type_kind/자기주식 소각 결정.csv' 파일로 저장했습니다.
# 교환사채권 발행결정: 60개 행을 'type_kind/교환사채권 발행결정.csv' 파일로 저장했습니다.
# 상각형 조건부자본증권 발행결정: 41개 행을 'type_kind/상각형 조건부자본증권 발행결정.csv' 파일로 저장했습니다.
# 횡령ㆍ배임혐의발생: 33개 행을 'type_kind/횡령ㆍ배임혐의발생.csv' 파일로 저장했습니다.
# 자산양수도(기타), 풋백옵션: 14개 행을 'type_kind/자산양수도(기타), 풋백옵션.csv' 파일로 저장했습니다.
# 영업양수 결정: 16개 행을 'type_kind/영업양수 결정.csv' 파일로 저장했습니다.
# 단일판매ㆍ공급계약해지: 91개 행을 'type_kind/단일판매ㆍ공급계약해지.csv' 파일로 저장했습니다.
# 기술이전계약체결: 17개 행을 'type_kind/기술이전계약체결.csv' 파일로 저장했습니다.
# 해외 증권시장 주권등 상장: 4개 행을 'type_kind/해외 증권시장 주권등 상장.csv' 파일로 저장했습니다.
# 영업양도 결정: 12개 행을 'type_kind/영업양도 결정.csv' 파일로 저장했습니다.
# 채권은행 등의 관리절차 개시: 2개 행을 'type_kind/채권은행 등의 관리절차 개시.csv' 파일로 저장했습니다.
# 회사분할합병 결정: 4개 행을 'type_kind/회사분할합병 결정.csv' 파일로 저장했습니다.
# 회생절차 개시신청: 16개 행을 'type_kind/회생절차 개시신청.csv' 파일로 저장했습니다.
# 품목허가 신청: 20개 행을 'type_kind/품목허가 신청.csv' 파일로 저장했습니다.
# 유무상증자 결정: 23개 행을 'type_kind/유무상증자 결정.csv' 파일로 저장했습니다.
# 기술이전계약해지: 2개 행을 'type_kind/기술이전계약해지.csv' 파일로 저장했습니다.
# 해외 증권시장 주권등 상장폐지 결정: 4개 행을 'type_kind/해외 증권시장 주권등 상장폐지 결정.csv' 파일로 저장했습니다.
# 해외 증권시장 주권등 상장폐지: 2개 행을 'type_kind/해외 증권시장 주권등 상장폐지.csv' 파일로 저장했습니다.
# title
# 주주총회소집공고                                              4959
# 주주총회소집결의                                              4824
# 감사보고서 제출                                              4310
# 정기주주총회결과                                              4243
# 참고서류                                                  2700
#                                                       ...
# 조회공시요구(풍문또는보도)(단일판매ㆍ공급계약 발주처의 수주계약 취소설)                  1
# 투자판단 관련 주요경영사항(유양디앤유 주식양도를 위한 양해각서(MOU) 체결)              1
# 조회공시요구(풍문또는보도)에대한답변(미확정)(단일판매ㆍ공급계약의 발주처의 수주계약 취소설)       1
# 기타 경영사항(자율공시)(제9회차 무기명식 이권부 무보증 사모 전환사채 일부 소각의 건)        1
# 투자판단 관련 주요경영사항(자본시장과 금융투자에 관한 법률" 위반혐의 3심)               1
# Name: count, Length: 999, dtype: int64

# %%
def format_convertible_bond_info(data):
    """전환사채 발행정보를 포맷팅하여 출력하는 함수"""
    if not data or data.get('status') != '000' or not data.get('list'):
        print("❌ 데이터가 없습니다.")
        return
    
    bond_info = data['list'][0]
    
    # 숫자 포맷팅 함수 (억원 단위로 변환)
    def format_amount(amount_str):
        if not amount_str or amount_str == '-':
            return '-'
        try:
            amount = int(amount_str)
            return f"{amount:,}원 ({amount/100000000:.1f}억)"
        except:
            return amount_str
    
    # 퍼센트 포맷팅 함수
    def format_percent(percent_str):
        if not percent_str or percent_str == '-':
            return '-'
        return f"{percent_str}%"
    
    print(f"📊 전환사채 발행정보")
    print(f"=" * 50)
    print(f"회사명: {bond_info.get('corp_name', '-')}")
    print(f"접수번호: {bond_info.get('rcept_no', '-')}")
    print(f"이사회결의일: {bond_info.get('bddd', '-')}")
    print()
    
    print(f"💰 발행정보")
    print(f"사채종류: {bond_info.get('bd_knd', '-')}")
    print(f"발행금액: {format_amount(bond_info.get('bd_fta'))}")
    print(f"발행방법: {bond_info.get('bdis_mthn', '-')}")
    print(f"사채만기일: {bond_info.get('bd_mtd', '-')}")
    print()
    
    print(f"📈 이자율 정보")
    print(f"표면이자율: {format_percent(bond_info.get('bd_intr_ex'))}")
    print(f"만기이자율: {format_percent(bond_info.get('bd_intr_sf'))}")
    print()
    
    print(f"🔄 전환 정보")
    print(f"전환가액: {format_amount(bond_info.get('cv_prc'))} (1주당)")
    print(f"전환비율: {format_percent(bond_info.get('cv_rt'))}")
    # print(f"전환주식수: {bond_info.get('cvisstk_cnt', '-'):,}주" if bond_info.get('cvisstk_cnt', '-') != '-' else "전환주식수: -")
    print(f"주식총수 대비: {format_percent(bond_info.get('cvisstk_tisstk_vs'))}")
    print(f"전환청구기간: {bond_info.get('cvrqpd_bgd', '-')} ~ {bond_info.get('cvrqpd_edd', '-')}")
    print(f"최저조정가액: {format_amount(bond_info.get('act_mktprcfl_cvprc_lwtrsprc'))}")
    print()
    
    print(f"📅 일정")
    print(f"청약일: {bond_info.get('sbd', '-')}")
    print(f"납입일: {bond_info.get('pymd', '-')}")
    print()
    
    # 자금조달 목적이 있는 경우만 출력
    funding_purposes = []
    if bond_info.get('fdpp_fclt') not in [None, '-', '']:
        funding_purposes.append(f"시설자금: {format_amount(bond_info.get('fdpp_fclt'))}")
    if bond_info.get('fdpp_op') not in [None, '-', '']:
        funding_purposes.append(f"운영자금: {format_amount(bond_info.get('fdpp_op'))}")
    if bond_info.get('fdpp_dtrp') not in [None, '-', '']:
        funding_purposes.append(f"채무상환자금: {format_amount(bond_info.get('fdpp_dtrp'))}")
    if bond_info.get('fdpp_ocsa') not in [None, '-', '']:
        funding_purposes.append(f"타법인증권취득자금: {format_amount(bond_info.get('fdpp_ocsa'))}")
    if bond_info.get('fdpp_etc') not in [None, '-', '']:
        funding_purposes.append(f"기타자금: {format_amount(bond_info.get('fdpp_etc'))}")
    
    if funding_purposes:
        print(f"💼 자금조달 목적")
        for purpose in funding_purposes:
            print(f"{purpose}")
        print()
    
    print(f"ℹ️ 기타정보")
    if bond_info.get('rpmcmp') not in [None, '-', '']:
        print(f"대표주관회사: {bond_info.get('rpmcmp', '-')}")
    if bond_info.get('grint') not in [None, '-', '']:
        print(f"보증기관: {bond_info.get('grint', '-')}")
    print(f"증권신고서 제출대상: {bond_info.get('rs_sm_atn', '-')}")
    if bond_info.get('ex_sm_r') not in [None, '-', '']:
        print(f"제출면제사유: {bond_info.get('ex_sm_r', '-')}")

# %%
import time
from datetime import datetime
from dart import get_convertible_bond

for index, row in df[(df["disclosure_type"] == "전환사채권 발행결정") & (df["dart_unique_id"].notna())].iterrows():
    # row["disclosed_at"]이 이미 datetime 타입이므로 strptime이 필요 없음
    disclosed_date = row["disclosed_at"]
    
    date = disclosed_date.strftime("%Y%m%d")
    print(date)
    dart_unique_id = row["dart_unique_id"]
    result = get_convertible_bond(dart_unique_id, date)
    if(result['status'] == '000'):
        format_convertible_bond_info(result)
    else:
        print(result['message'])
    time.sleep(0.5)
# Out:
# 20210104
# 📊 전환사채 발행정보
# ==================================================
# 회사명: 테라사이언스
# 접수번호: 20210104000362
# 이사회결의일: 2021년 01월 04일
#
# 💰 발행정보
# 사채종류: 무기명식 이권부 무보증 사모 전환사채
# 발행금액: 10,000,000,000
# 발행방법: 사모
# 사채만기일: 2024년 01월 08일
#
# 📈 이자율 정보
# 표면이자율: 2.0%
# 만기이자율: 5.0%
#
# 🔄 전환 정보
# 전환가액: 2,177 (1주당)
# 전환비율: 100%
# 주식총수 대비: 7.3%
# 전환청구기간: 2022년 01월 08일 ~ 2023년 12월 08일
# 최저조정가액: 100원 (0.0억)
#
# 📅 일정
# 청약일: 2021년 01월 05일
# 납입일: 2021년 01월 08일
#
# 💼 자금조달 목적
# 타법인증권취득자금: 10,000,000,000
#
# ℹ️ 기타정보
# 증권신고서 제출대상: 아니오
# 제출면제사유: 사모 발행(사채 발행일로부터1년간 전환 및 권면분할 금지)
# 20210104
# 📊 전환사채 발행정보
# ==================================================
# 회사명: THE CUBE&
# 접수번호: 20210225002741
# 이사회결의일: 2021년 02월 25일
#
# 💰 발행정보
# 사채종류: 무기명식 이권부 무보증 사모 전환사채
# 발행금액: 10,000,000,000
# 발행방법: 사모
# 사채만기일: 2024년 02월 26일
#
# 📈 이자율 정보
# 표면이자율: 2.0%
# 만기이자율: 3.0%
#
# 🔄 전환 정보
# 전환가액: 8,751 (1주당)
# 전환비율: 100%
# 주식총수 대비: 13.97%
# 전환청구기간: 2022년 02월 26일 ~ 2024년 01월 26일
# 최저조정가액: 6,126
#
# 📅 일정
# 청약일: 2021년 01월 04일
# 납입일: 2021년 02월 26일
#
# 💼 자금조달 목적
# 타법인증권취득자금: 10,000,000,000
#
# ℹ️ 기타정보
# 증권신고서 제출대상: 아니오
# 제출면제사유: 사모발행(사채 발행일로부터 1년간 전환 및 권면분할 금지)
# 20210105
# 📊 전환사채 발행정보
# ==================================================
# 회사명: 케어랩스
# 접수번호: 20210106000368
# 이사회결의일: 2021년 01월 05일
#
# 💰 발행정보
# 사채종류: 무기명식 무보증 사모 전환사채
# 발행금액: 20,000,000,000
# 발행방법: 사모
# 사채만기일: 2024년 01월 07일
#
# 📈 이자율 정보
# 표면이자율: 0.00%
# 만기이자율: 1.00%
#
# 🔄 전환 정보
# 전환가액: 8,702 (1주당)
# 전환비율: 100.00%
# 주식총수 대비: 11.77%
# 전환청구기간: 2022년 01월 07일 ~ 2023년 12월 07일
# 최저조정가액: 6,092
#
# 📅 일정
# 청약일: 2021년 01월 07일
# 납입일: 2021년 01월 07일
#
# 💼 자금조달 목적
# 타법인증권취득자금: 20,000,000,000
#
# ℹ️ 기타정보
# 증권신고서 제출대상: 아니오
# 제출면제사유: 사모발행(사채 발행일로부터 1년간 전환 및 권면분할 금지)
# 20210105
# 📊 전환사채 발행정보
# ==================================================
# 회사명: 오르비텍
# 접수번호: 20210329001106
# 이사회결의일: 2021년 01월 05일
#
# 💰 발행정보
# 사채종류: 무기명식 이권부 무보증 사모 전환사채
# 발행금액: 10,000,000,000
# 발행방법: 사모
# 사채만기일: 2024년 03월 29일
#
# 📈 이자율 정보
# 표면이자율: 1.0%
# 만기이자율: 3.0%
#
# 🔄 전환 정보
# 전환가액: 4,761 (1주당)
# 전환비율: 100%
# 주식총수 대비: 8.22%
# 전환청구기간: 2022년 03월 29일 ~ 2024년 02월 29일
# 최저조정가액: 3,333
#
# 📅 일정
# 청약일: 2021년 01월 05일
# 납입일: 2021년 03월 29일
#
# 💼 자금조달 목적
# 운영자금: 10,000,000,000
#
# ℹ️ 기타정보
# 증권신고서 제출대상: 아니오
# 제출면제사유: 사모발행에 의한 1년간 행사 및 분할 금지
# 20210105
# 📊 전환사채 발행정보
# ==================================================
# 회사명: 아나패스
# 접수번호: 20210105000515
# 이사회결의일: 2021년 01월 05일
#
# 💰 발행정보
# 사채종류: 무기명식 이권부 무보증 사모 전환사채
# 발행금액: 2,000,000,000
# 발행방법: 사모
# 사채만기일: 2026년 01월 07일
#
# 📈 이자율 정보
# 표면이자율: 0.0%
# 만기이자율: 0.0%
#
# 🔄 전환 정보
# 전환가액: 26,504 (1주당)
# 전환비율: 100%
# 주식총수 대비: 0.69%
# 전환청구기간: 2022년 01월 07일 ~ 2025년 12월 07일
# 최저조정가액: 18,553
#
# 📅 일정
# 청약일: 2021년 01월 07일
# 납입일: 2021년 01월 07일
#
# 💼 자금조달 목적
# 운영자금: 2,000,000,000
#
# ℹ️ 기타정보
# 증권신고서 제출대상: 아니오
# 제출면제사유: 사모 발행(사채 발행일로부터1년간 전환 및 권면분할 금지)
# 20210106
# 📊 전환사채 발행정보
# ==================================================
# 회사명: 글로본
# 접수번호: 20210106000454
# 이사회결의일: 2021년 01월 06일
#
# 💰 발행정보
# 사채종류: 무기명식 이권부 무보증 사모 전환사채
# 발행금액: 2,996,250,000
# 발행방법: 사모
# 사채만기일: 2024년 01월 06일
#
# 📈 이자율 정보
# 표면이자율: 0%
# 만기이자율: 0%
#
# 🔄 전환 정보
# 전환가액: 4,395 (1주당)
# 전환비율: 100%
# 주식총수 대비: 2.21%
# 전환청구기간: 2022년 01월 06일 ~ 2023년 12월 06일
# 최저조정가액: -
#
# 📅 일정
# 청약일: 2021년 01월 06일
# 납입일: 2021년 01월 06일
#
# 💼 자금조달 목적
# 타법인증권취득자금: 2,996,250,000
#
# ℹ️ 기타정보
# 증권신고서 제출대상: 아니오
# 제출면제사유:       사모 발행(사채발행일로부터 1년이내 전환금지 및 권면분할 금지)
# 20210107
# 📊 전환사채 발행정보
# ==================================================
# 회사명: 에이프로젠
# 접수번호: 20210107000440
# 이사회결의일: 2021년 01월 07일
#
# 💰 발행정보
# 사채종류: 무기명이권부무보증사모전환사채
# 발행금액: 20,000,000,000
# 발행방법: 사모
# 사채만기일: 2024년 01월 21일
#
# 📈 이자율 정보
# 표면이자율: 1%
# 만기이자율: 1%
#
# 🔄 전환 정보
# 전환가액: 2,118 (1주당)
# 전환비율: 100%
# 주식총수 대비: 5.14%
# 전환청구기간: 2022년 01월 22일 ~ 2023년 12월 21일
# 최저조정가액: 1,483
#
# 📅 일정
# 청약일: 2021년 01월 07일
# 납입일: 2021년 01월 21일
#
# 💼 자금조달 목적
# 운영자금: 20,000,000,000
#
# ℹ️ 기타정보
# 증권신고서 제출대상: 아니오
# 제출면제사유: 사모 전환사채 발행으로 인한 증권신고서 제출 면제
# (사모발행에 의한 1년간 권면분할 및 전환금지)
# 20210108
# 📊 전환사채 발행정보
# ==================================================
# 회사명: 동일스틸럭스
# 접수번호: 20210108000222
# 이사회결의일: 2021년 01월 08일
#
# 💰 발행정보
# 사채종류: 무기명식 이권부
# 무보증 사모 전환사채
# 발행금액: 7,000,000,000
# 발행방법: 사모
# 사채만기일: 2025년 01월 12일
#
# 📈 이자율 정보
# 표면이자율: 2.0%
# 만기이자율: 3.0%
#
# 🔄 전환 정보
# 전환가액: 6,145 (1주당)
# 전환비율: 100%
# 주식총수 대비: 13.43%
# 전환청구기간: 2022년 01월 12일 ~ 2024년 12월 12일
# 최저조정가액: 4,302
#
# 📅 일정
# 청약일: -
# 납입일: 2021년 01월 12일
#
# 💼 자금조달 목적
# 타법인증권취득자금: 7,000,000,000
#
# ℹ️ 기타정보
# 증권신고서 제출대상: 아니오
# 제출면제사유: 사모 발행(사채 발행일로부터 1년간 전환 및 거래단위 분할 금지)
# 20210108
# 📊 전환사채 발행정보
# ==================================================
# 회사명: 세토피아
# 접수번호: 20231211000286
# 이사회결의일: 2021년 01월 08일
#
# 💰 발행정보
# 사채종류: 무기명식 이권부 무보증 사모 전환사채
# 발행금액: 4,000,000,000
# 발행방법: 사모
# 사채만기일: 2029년 01월 11일
#
# 📈 이자율 정보
# 표면이자율: 0.0%
# 만기이자율: 3.0%
#
# 🔄 전환 정보
# 전환가액: 2,010 (1주당)
# 전환비율: 100%
# 주식총수 대비: 2.64%
# 전환청구기간: 2022년 01월 11일 ~ 2028년 12월 11일
# 최저조정가액: -
#
# 📅 일정
# 청약일: 2021년 01월 08일
# 납입일: 2021년 01월 11일
#
# 💼 자금조달 목적
# 타법인증권취득자금: 4,000,000,000
#
# ℹ️ 기타정보
# 증권신고서 제출대상: 아니오
# 제출면제사유: 사모발행(사채 발행일로부터 1년간 전환 및 권면분할 금지)
# 20210112
# 📊 전환사채 발행정보
# ==================================================
# 회사명: 텔레칩스
# 접수번호: 20210112000314
# 이사회결의일: 2021년 01월 12일
#
# 💰 발행정보
# 사채종류: 무기명식 이권부 사모 전환사채
# 발행금액: 20,000,000,000
# 발행방법: 사모
# 사채만기일: 2026년 01월 14일
#
# 📈 이자율 정보
# 표면이자율: 0.0%
# 만기이자율: 0.0%
#
# 🔄 전환 정보
# 전환가액: 17,248 (1주당)
# 전환비율: 100%
# 주식총수 대비: 8.45%
# 전환청구기간: 2022년 01월 14일 ~ 2025년 12월 14일
# 최저조정가액: 15,524
#
# 📅 일정
# 청약일: 2021년 01월 14일
# 납입일: 2021년 01월 14일
#
# 💼 자금조달 목적
# 운영자금: 20,000,000,000
#
# ℹ️ 기타정보
# 증권신고서 제출대상: 아니오
# 제출면제사유: 사모발행(사채 발행일로 부터 1년간 전환 및 권면분할 금지)
# 20210113
# 📊 전환사채 발행정보
# ==================================================
# 회사명: 쎄트렉아이
# 접수번호: 20210113000002
# 이사회결의일: 2021년 01월 12일
#
# 💰 발행정보
# 사채종류: 기명식 무보증 사모 전환사채
# 발행금액: 50,000,000,000
# 발행방법: 사모
# 사채만기일: 2024년 01월 15일
#
# 📈 이자율 정보
# 표면이자율: 0%
# 만기이자율: 0%
#
# 🔄 전환 정보
# 전환가액: 38,219 (1주당)
# 전환비율: 100%
# 주식총수 대비: 17.99%
# 전환청구기간: 2022년 01월 16일 ~ 2024년 01월 08일
# 최저조정가액: 26,753
#
# 📅 일정
# 청약일: 2021년 01월 12일
# 납입일: 2021년 01월 15일
#
# 💼 자금조달 목적
# 시설자금: 20,000,000,000
# 운영자금: 30,000,000,000
#
# ℹ️ 기타정보
# 증권신고서 제출대상: 아니오
# 제출면제사유: 면제(사모 발행에 의한 1년간 행사 및 분할 또는 병합 금지)
# 20210114
# 📊 전환사채 발행정보
# ==================================================
# 회사명: 다산솔루에타
# 접수번호: 20210114000354
# 이사회결의일: 2021년 01월 14일
#
# 💰 발행정보
# 사채종류: 무기명식 이권부 무보증
# 사모 전환사채
# 발행금액: 10,000,000,000
# 발행방법: 사모
# 사채만기일: 2025년 01월 18일
#
# 📈 이자율 정보
# 표면이자율: 0.0%
# 만기이자율: 2.0%
#
# 🔄 전환 정보
# 전환가액: 4,635 (1주당)
# 전환비율: 100.0%
# 주식총수 대비: 14.25%
# 전환청구기간: 2022년 01월 18일 ~ 2024년 12월 18일
# 최저조정가액: 3,245
#
# 📅 일정
# 청약일: 2021년 01월 18일
# 납입일: 2021년 01월 18일
#
# 💼 자금조달 목적
# 운영자금: 10,000,000,000
#
# ℹ️ 기타정보
# 증권신고서 제출대상: 아니오
# 제출면제사유: 사모 발행에 의한 1년간 분할 및 병합 금지
# 20210114
# 📊 전환사채 발행정보
# ==================================================
# 회사명: 다산솔루에타
# 접수번호: 20210114000354
# 이사회결의일: 2021년 01월 14일
#
# 💰 발행정보
# 사채종류: 무기명식 이권부 무보증
# 사모 전환사채
# 발행금액: 10,000,000,000
# 발행방법: 사모
# 사채만기일: 2025년 01월 18일
#
# 📈 이자율 정보
# 표면이자율: 0.0%
# 만기이자율: 2.0%
#
# 🔄 전환 정보
# 전환가액: 4,635 (1주당)
# 전환비율: 100.0%
# 주식총수 대비: 14.25%
# 전환청구기간: 2022년 01월 18일 ~ 2024년 12월 18일
# 최저조정가액: 3,245
#
# 📅 일정
# 청약일: 2021년 01월 18일
# 납입일: 2021년 01월 18일
#
# 💼 자금조달 목적
# 운영자금: 10,000,000,000
#
# ℹ️ 기타정보
# 증권신고서 제출대상: 아니오
# 제출면제사유: 사모 발행에 의한 1년간 분할 및 병합 금지
# 20210114
# 📊 전환사채 발행정보
# ==================================================
# 회사명: 수성웹툰
# 접수번호: 20210329001003
# 이사회결의일: 2021년 01월 14일
#
# 💰 발행정보
# 사채종류: 무기명식 이권부 무보증 사모 전환사채
# 발행금액: 6,000,000,000
# 발행방법: 사모
# 사채만기일: 2024년 04월 09일
#
# 📈 이자율 정보
# 표면이자율: 2%
# 만기이자율: 5%
#
# 🔄 전환 정보
# 전환가액: 2,325 (1주당)
# 전환비율: 100%
# 주식총수 대비: 12.78%
# 전환청구기간: 2022년 04월 09일 ~ 2024년 03월 09일
# 최저조정가액: 500원 (0.0억)
#
# 📅 일정
# 청약일: 2021년 03월 26일
# 납입일: 2021년 04월 09일
#
# 💼 자금조달 목적
# 타법인증권취득자금: 6,000,000,000
#
# ℹ️ 기타정보
# 증권신고서 제출대상: 아니오
# 제출면제사유: 사모발행(사채 발행일로부터 1년간 전환 및 권면분할 금지
# 20210115
# 📊 전환사채 발행정보
# ==================================================
# 회사명: SG
# 접수번호: 20210115000531
# 이사회결의일: 2021년 01월 15일
#
# 💰 발행정보
# 사채종류: 무기명식 무보증 사모 전환사채
# 발행금액: 16,500,000,000
# 발행방법: 사모
# 사채만기일: 2026년 01월 19일
#
# 📈 이자율 정보
# 표면이자율: 0.0%
# 만기이자율: 1.0%
#
# 🔄 전환 정보
# 전환가액: 2,157 (1주당)
# 전환비율: 100.0%
# 주식총수 대비: 17.24%
# 전환청구기간: 2022년 01월 19일 ~ 2025년 12월 19일
# 최저조정가액: 1,510
#
# 📅 일정
# 청약일: 2021년 01월 19일
# 납입일: 2021년 01월 19일
#
# 💼 자금조달 목적
# 시설자금: 3,000,000,000
# 운영자금: 3,500,000,000
# 채무상환자금: 10,000,000,000
#
# ℹ️ 기타정보
# 증권신고서 제출대상: 아니오
# 제출면제사유: 사모발행(사채발행일로부터 1년간 전환 및 분할ㆍ병합 금지)
# 20210115
# 조회된 데이타가 없습니다.
# 20210118
# 📊 전환사채 발행정보
# ==================================================
# 회사명: 케이피엠테크
# 접수번호: 20210118000203
# 이사회결의일: 2021년 01월 18일
#
# 💰 발행정보
# 사채종류: 국내 무기명식 이권부 무보증 사모 전환사채
# 발행금액: 10,000,000,000
# 발행방법: 사모
# 사채만기일: 2024년 01월 18일
#
# 📈 이자율 정보
# 표면이자율: 4.0%
# 만기이자율: 4.0%
#
# 🔄 전환 정보
# 전환가액: 2,825 (1주당)
# 전환비율: 100%
# 주식총수 대비: 2.46%
# 전환청구기간: 2022년 01월 18일 ~ 2023년 12월 18일
# 최저조정가액: 100원 (0.0억)
#
# 📅 일정
# 청약일: 2021년 01월 18일
# 납입일: 2021년 01월 18일
#
# 💼 자금조달 목적
# 운영자금: 10,000,000,000
#
# ℹ️ 기타정보
# 증권신고서 제출대상: 아니오
# 제출면제사유: 사모발행(1년간 행사 및 분할금지)
# 20210118
# 📊 전환사채 발행정보
# ==================================================
# 회사명: KH 건설
# 접수번호: 20210118000231
# 이사회결의일: 2021년 01월 18일
#
# 💰 발행정보
# 사채종류: 무기명식 이권부 무보증 사모 전환사채
# 발행금액: 5,000,000,000
# 발행방법: 사모
# 사채만기일: 2024년 01월 19일
#
# 📈 이자율 정보
# 표면이자율: 2.0%
# 만기이자율: 3.0%
#
# 🔄 전환 정보
# 전환가액: 2,810 (1주당)
# 전환비율: 100%
# 주식총수 대비: 3.28%
# 전환청구기간: 2022년 01월 19일 ~ 2023년 12월 19일
# 최저조정가액: 100원 (0.0억)
#
# 📅 일정
# 청약일: 2021년 01월 18일
# 납입일: 2021년 01월 19일
#
# 💼 자금조달 목적
# 타법인증권취득자금: 5,000,000,000
#
# ℹ️ 기타정보
# 증권신고서 제출대상: 아니오
# 제출면제사유: 사모발행에 의한 1년간 전환청구권 행사 및 권면분할 금지
# 20210118
# 📊 전환사채 발행정보
# ==================================================
# 회사명: 일동제약
# 접수번호: 20210118000221
# 이사회결의일: 2021년 01월 18일
#
# 💰 발행정보
# 사채종류: 무기명식 무이권부 무보증 사모 전환사채
# 발행금액: 100,000,000,000
# 발행방법: 사모
# 사채만기일: 2026년 01월 28일
#
# 📈 이자율 정보
# 표면이자율: 0.0%
# 만기이자율: 0.0%
#
# 🔄 전환 정보
# 전환가액: 20,000 (1주당)
# 전환비율: 100%
# 주식총수 대비: 21.01%
# 전환청구기간: 2022년 01월 28일 ~ 2025년 12월 28일
# 최저조정가액: 16,000
#
# 📅 일정
# 청약일: 2021년 01월 20일
# 납입일: 2021년 01월 28일
#
# 💼 자금조달 목적
# 운영자금: 100,000,000,000
#
# ℹ️ 기타정보
# 증권신고서 제출대상: 아니오
# 제출면제사유: 사모발행(사채발행일로부터 1년간 전환 및 권면 분할·병합 금지)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 17
#      15 else:
#      16     print(result['message'])
# ---> 17 time.sleep(0.5)
#
# KeyboardInterrupt:

# %% [markdown]
# 2025.09.23 16:59:34
# 기업명: 서플러스글로벌(시가총액: 943억)
# 보고서명: 주요사항보고서(전환사채권발행결정)
#
# 발행금액 : 83억(전체대비 : 7.96%)
# 발행방법 : 사모
# 전환가액 : 2,602원(현재가 : 2,550원)
# 최저조정 : -
# 표면이율 : 0.0%
# 만기이율 : 0.0%
#
# 납입일자 : 2025-10-01
# 청구시작 : 2026-10-01
# 청구종료 : 2030-09-01
#
# * 투자자
# 타이거 코스닥벤처 와이즈메자닌 322 일반 사모투자신탁
# 타이거 코스닥벤처 위닝메자닌 326 일반 사모투자신탁
# 타이거 코스닥벤처 파워메자닌 337 일반 사모투자신탁
# 타이거 코스닥벤처 으뜸 338 일반 사모투자신탁
# 타이거 코스닥벤처 프리즘 339 일반 사모투자신탁
# ...

# %%
example_df[(example_df["disclosure_type"] == "타법인 주식 및 출자증권 양수결정") & (example_df["unique_number"].notna())]
# Out:
#          disclosed_at company_name    stock_code short_code  market  \
# 3    2022-06-30 18:14       코아시아씨엠  KR7196450001     196450  KOSDAQ
# 5    2022-06-30 18:14       코아시아씨엠  KR7196450001     196450  KOSDAQ
# 7    2022-06-30 18:09       하나금융지주  KR7086790003     086790   KOSPI
# 38   2022-06-30 17:29         삼성공조  KR7006660005     006660   KOSPI
# 44   2022-06-30 17:26           SK  KR7034730002     034730   KOSPI
# 53   2022-06-30 17:23      SK이노베이션  KR7096770003     096770   KOSPI
# 61   2022-06-30 17:20      SK이노베이션  KR7096770003     096770   KOSPI
# 71   2022-06-30 17:13           엔켐  KR7348370008     348370  KOSDAQ
# 72   2022-06-30 17:13           엔켐  KR7348370008     348370  KOSDAQ
# 77   2022-06-30 17:10          한진칼  KR7180640005     180640   KOSPI
# 87   2022-06-30 17:05      SK이노베이션  KR7096770003     096770   KOSPI
# 116  2022-06-30 16:48         대한항공  KR7003490000     003490   KOSPI
# 155  2022-06-30 16:23           기아  KR7000270009     000270   KOSPI
# 162  2022-06-30 16:20        현대모비스  KR7012330007     012330   KOSPI
# 260  2022-06-30 15:22           한창  KR7005110002     005110   KOSPI
# 344  2022-06-30 12:35         에이엔피  KR7015260003     015260   KOSPI
# 444  2022-06-30 12:35         에이엔피  KR7015260003     015260   KOSPI
#
#                                  title   disclosure_id  \
# 3                       타법인주식및출자증권취득결정  20220630001052
# 5                       타법인주식및출자증권취득결정  20220630001035
# 7          타법인주식및출자증권취득결정(자회사의 주요경영사항)  20220630001073
# 38                      타법인주식및출자증권취득결정  20220630000931
# 44         타법인주식및출자증권취득결정(자회사의 주요경영사항)  20220630000979
# 53         타법인주식및출자증권취득결정(자회사의 주요경영사항)  20220630000960
# 61   타법인주식및출자증권취득결정(자율공시)(자회사의 주요경영사항)  20220630000967
# 71                      타법인주식및출자증권취득결정  20220630000925
# 72                      타법인주식및출자증권취득결정  20220630000906
# 77         타법인주식및출자증권취득결정(자회사의 주요경영사항)  20220630000856
# 87   타법인주식및출자증권취득결정(자율공시)(자회사의 주요경영사항)  20220630000917
# 116                     타법인주식및출자증권취득결정  20220630000799
# 155               타법인주식및출자증권취득결정(자율공시)  20220630000777
# 162               타법인주식및출자증권취득결정(자율공시)  20220630000764
# 260                     타법인주식및출자증권취득결정  20220630000459
# 344                     타법인주식및출자증권취득결정  20220630000222
# 444                     타법인주식및출자증권취득결정  20220630000222
#
#                                             detail_url unique_number  \
# 3    https://kind.krx.co.kr/common/disclsviewer.do?...      01031502
# 5    https://kind.krx.co.kr/common/disclsviewer.do?...      01031502
# 7    https://kind.krx.co.kr/common/disclsviewer.do?...      00547583
# 38   https://kind.krx.co.kr/common/disclsviewer.do?...      00126201
# 44   https://kind.krx.co.kr/common/disclsviewer.do?...      00181712
# 53   https://kind.krx.co.kr/common/disclsviewer.do?...      00631518
# 61   https://kind.krx.co.kr/common/disclsviewer.do?...      00631518
# 71   https://kind.krx.co.kr/common/disclsviewer.do?...      01011526
# 72   https://kind.krx.co.kr/common/disclsviewer.do?...      01011526
# 77   https://kind.krx.co.kr/common/disclsviewer.do?...      00983040
# 87   https://kind.krx.co.kr/common/disclsviewer.do?...      00631518
# 116  https://kind.krx.co.kr/common/disclsviewer.do?...      00113526
# 155  https://kind.krx.co.kr/common/disclsviewer.do?...      00106641
# 162  https://kind.krx.co.kr/common/disclsviewer.do?...      00164788
# 260  https://kind.krx.co.kr/common/disclsviewer.do?...      00163716
# 344  https://kind.krx.co.kr/common/disclsviewer.do?...      00143314
# 444  https://kind.krx.co.kr/common/disclsviewer.do?...      00143314
#
#         disclosure_type
# 3    타법인 주식 및 출자증권 양수결정
# 5    타법인 주식 및 출자증권 양수결정
# 7    타법인 주식 및 출자증권 양수결정
# 38   타법인 주식 및 출자증권 양수결정
# 44   타법인 주식 및 출자증권 양수결정
# 53   타법인 주식 및 출자증권 양수결정
# 61   타법인 주식 및 출자증권 양수결정
# 71   타법인 주식 및 출자증권 양수결정
# 72   타법인 주식 및 출자증권 양수결정
# 77   타법인 주식 및 출자증권 양수결정
# 87   타법인 주식 및 출자증권 양수결정
# 116  타법인 주식 및 출자증권 양수결정
# 155  타법인 주식 및 출자증권 양수결정
# 162  타법인 주식 및 출자증권 양수결정
# 260  타법인 주식 및 출자증권 양수결정
# 344  타법인 주식 및 출자증권 양수결정
# 444  타법인 주식 및 출자증권 양수결정

# %%
import time
from datetime import datetime
from dart import get_stock_acquisition

for index, row in example_df[(example_df["disclosure_type"] == "타법인 주식 및 출자증권 양수결정") & (example_df["unique_number"].notna())].iterrows():
    disclosed_date = datetime.strptime(row["disclosed_at"], "%Y-%m-%d %H:%M")
    
    date = disclosed_date.strftime("%Y%m%d")
    unique_number = row["unique_number"]
    result = get_stock_acquisition(unique_number, date)
    if(result['status'] == '000'):
        print(result['list'][0])
    else:
        print(result['message'])
    time.sleep(0.5)
# Out:
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.

# %%
import time
from datetime import datetime
from dart import get_treasury_stock_trust

for index, row in example_df[(example_df["disclosure_type"] == "자기주식취득 신탁계약 체결 결정") & (example_df["unique_number"].notna())].iterrows():
    disclosed_date = datetime.strptime(row["disclosed_at"], "%Y-%m-%d %H:%M")
    
    date = disclosed_date.strftime("%Y%m%d")
    unique_number = row["unique_number"]
    result = get_treasury_stock_trust(unique_number, date)
    if(result['status'] == '000'):
        print(result['list'][0])
    else:
        print(result['message'])
    time.sleep(0.5)
# Out:
# {'rcept_no': '20220630000744', 'corp_cls': 'Y', 'corp_code': '00372873', 'corp_name': 'KTis', 'bddd': '2022년 06월 30일', 'od_a_at_t': '3', 'od_a_at_b': '0', 'adt_a_atn': '-', 'cs_iv_bk': 'KB증권(KB Securities co., Ltd.)', 'aq_wtn_div_ostk': '2,350,081', 'aq_wtn_div_ostk_rt': '6.75', 'aq_wtn_div_estk': '-', 'aq_wtn_div_estk_rt': '-', 'eaq_ostk': '-', 'eaq_ostk_rt': '-', 'eaq_estk': '-', 'eaq_estk_rt': '-', 'ctr_prc': '5,000,000,000', 'ctr_pd_bgd': '2022년 07월 01일', 'ctr_pd_edd': '2022년 12월 31일', 'ctr_pp': '주가안정 및 주주가치 제고', 'ctr_cns_int': 'KB증권(KB Securities co., Ltd.)', 'ctr_cns_prd': '2022년 07월 01일'}
# {'rcept_no': '20220630000648', 'corp_cls': 'Y', 'corp_code': '00372882', 'corp_name': 'KTcs', 'bddd': '2022년 06월 30일', 'od_a_at_t': '3', 'od_a_at_b': '0', 'adt_a_atn': '-', 'cs_iv_bk': 'NH투자증권 (NH INVESTMENT & SECURITIES CO.,LTD.)', 'aq_wtn_div_ostk': '2,544,056', 'aq_wtn_div_ostk_rt': '5.96', 'aq_wtn_div_estk': '-', 'aq_wtn_div_estk_rt': '-', 'eaq_ostk': '-', 'eaq_ostk_rt': '-', 'eaq_estk': '-', 'eaq_estk_rt': '-', 'ctr_prc': '5,000,000,000', 'ctr_pd_bgd': '2022년 07월 01일', 'ctr_pd_edd': '2022년 12월 31일', 'ctr_pp': '주가안정 및 주주가치 제고', 'ctr_cns_int': 'NH투자증권(NH INVESTMENT & SECURITIES CO.,LTD.)', 'ctr_cns_prd': '2022년 07월 01일'}
# 조회된 데이타가 없습니다.
# {'rcept_no': '20221229000344', 'corp_cls': 'K', 'corp_code': '00610083', 'corp_name': '비아트론', 'bddd': '2022년 12월 29일', 'od_a_at_t': '1', 'od_a_at_b': '-', 'adt_a_atn': '참석', 'cs_iv_bk': '대신증권', 'aq_wtn_div_ostk': '792,976', 'aq_wtn_div_ostk_rt': '6.54', 'aq_wtn_div_estk': '-', 'aq_wtn_div_estk_rt': '-', 'eaq_ostk': '-', 'eaq_ostk_rt': '-', 'eaq_estk': '-', 'eaq_estk_rt': '-', 'ctr_prc': '5,000,000,000', 'ctr_pd_bgd': '2022년 12월 30일', 'ctr_pd_edd': '2023년 06월 29일', 'ctr_pp': '주가안정 및 주주가치 제고', 'ctr_cns_int': '대신증권', 'ctr_cns_prd': '2022년 12월 30일'}
# {'rcept_no': '20220630000161', 'corp_cls': 'K', 'corp_code': '01310773', 'corp_name': '엔시스', 'bddd': '2022년 06월 30일', 'od_a_at_t': '3', 'od_a_at_b': '-', 'adt_a_atn': '-', 'cs_iv_bk': 'NH투자증권(주)', 'aq_wtn_div_ostk': '-', 'aq_wtn_div_ostk_rt': '-', 'aq_wtn_div_estk': '-', 'aq_wtn_div_estk_rt': '-', 'eaq_ostk': '7', 'eaq_ostk_rt': '0.00', 'eaq_estk': '-', 'eaq_estk_rt': '-', 'ctr_prc': '5,000,000,000', 'ctr_pd_bgd': '2022년 06월 30일', 'ctr_pd_edd': '2023년 06월 29일', 'ctr_pp': '주가안정 및 주주가치 제고', 'ctr_cns_int': '엔에이치투자증권 주식회사(NH INVESTMENT & SECURITIES CO.,LTD. )', 'ctr_cns_prd': '2022년 06월 30일'}
# {'rcept_no': '20221229000344', 'corp_cls': 'K', 'corp_code': '00610083', 'corp_name': '비아트론', 'bddd': '2022년 12월 29일', 'od_a_at_t': '1', 'od_a_at_b': '-', 'adt_a_atn': '참석', 'cs_iv_bk': '대신증권', 'aq_wtn_div_ostk': '792,976', 'aq_wtn_div_ostk_rt': '6.54', 'aq_wtn_div_estk': '-', 'aq_wtn_div_estk_rt': '-', 'eaq_ostk': '-', 'eaq_ostk_rt': '-', 'eaq_estk': '-', 'eaq_estk_rt': '-', 'ctr_prc': '5,000,000,000', 'ctr_pd_bgd': '2022년 12월 30일', 'ctr_pd_edd': '2023년 06월 29일', 'ctr_pp': '주가안정 및 주주가치 제고', 'ctr_cns_int': '대신증권', 'ctr_cns_prd': '2022년 12월 30일'}
# {'rcept_no': '20220630000161', 'corp_cls': 'K', 'corp_code': '01310773', 'corp_name': '엔시스', 'bddd': '2022년 06월 30일', 'od_a_at_t': '3', 'od_a_at_b': '-', 'adt_a_atn': '-', 'cs_iv_bk': 'NH투자증권(주)', 'aq_wtn_div_ostk': '-', 'aq_wtn_div_ostk_rt': '-', 'aq_wtn_div_estk': '-', 'aq_wtn_div_estk_rt': '-', 'eaq_ostk': '7', 'eaq_ostk_rt': '0.00', 'eaq_estk': '-', 'eaq_estk_rt': '-', 'ctr_prc': '5,000,000,000', 'ctr_pd_bgd': '2022년 06월 30일', 'ctr_pd_edd': '2023년 06월 29일', 'ctr_pp': '주가안정 및 주주가치 제고', 'ctr_cns_int': '엔에이치투자증권 주식회사(NH INVESTMENT & SECURITIES CO.,LTD. )', 'ctr_cns_prd': '2022년 06월 30일'}

# %%
{'rcept_no': '20220630000744', 'corp_cls': 'Y', 'corp_code': '00372873', 'corp_name': 'KTis', 'bddd': '2022년 06월 30일', 'od_a_at_t': '3', 'od_a_at_b': '0', 'adt_a_atn': '-', 'cs_iv_bk': 'KB증권(KB Securities co., Ltd.)', 'aq_wtn_div_ostk': '2,350,081', 'aq_wtn_div_ostk_rt': '6.75', 'aq_wtn_div_estk': '-', 'aq_wtn_div_estk_rt': '-', 'eaq_ostk': '-', 'eaq_ostk_rt': '-', 'eaq_estk': '-', 'eaq_estk_rt': '-', 'ctr_prc': '5,000,000,000', 'ctr_pd_bgd': '2022년 07월 01일', 'ctr_pd_edd': '2022년 12월 31일', 'ctr_pp': '주가안정 및 주주가치 제고', 'ctr_cns_int': 'KB증권(KB Securities co., Ltd.)', 'ctr_cns_prd': '2022년 07월 01일'}

# %%
2024.09.05 16:02:35
기업명: 에스트래픽(시가총액: 995억)
보고서명: 주요사항보고서(자기주식취득신탁계약체결결정)

계약금액 : 30억
시총대비 : 3.15%
계약목적 : 주주가치 제고를 위한 자사주 취득 및 소각(15억원) 목적의 신탁계약
체결기관 : 삼성증권

시작일자 : 2024-09-06
종료일자 : 2025-03-05


공시링크: https://dart.fss.or.kr/dsaf001/main.do?rcpNo=20240905000252
회사정보: https://finance.naver.com/item/main.nhn?code=234300

# %%
from dart import get_treasury_stock_buy
import time
from datetime import datetime

for index, row in example_df[(example_df["disclosure_type"] == "자기주식 취득 결정") & (example_df["unique_number"].notna())].iterrows():
    disclosed_date = datetime.strptime(row["disclosed_at"], "%Y-%m-%d %H:%M")
    
    date = disclosed_date.strftime("%Y%m%d")
    unique_number = row["unique_number"]
    result = get_treasury_stock_buy(unique_number, date)
    if(result['status'] == '000'):
        print(result['list'][0])
    else:
        print(result['message'])
    time.sleep(0.5)
# Out:
# {'rcept_no': '20220630000670', 'corp_cls': 'K', 'corp_code': '00109781', 'corp_name': '대림제지', 'od_a_at_t': '3', 'od_a_at_b': '-', 'adt_a_atn': '-', 'aqpln_stk_ostk': '60,000', 'aqpln_stk_estk': '-', 'aqpln_prc_ostk': '504,000,000', 'aqpln_prc_estk': '-', 'aqexpd_bgd': '2022년 07월 01일', 'aqexpd_edd': '2022년 09월 30일', 'hdexpd_bgd': '-', 'hdexpd_edd': '-', 'aq_pp': '주식가격의 안정 및 주주가치 제고', 'aq_mth': '코스닥 시장 장내 직접취득', 'cs_iv_bk': 'NH투자증권', 'aq_wtn_div_ostk': '100,000', 'aq_wtn_div_ostk_rt': '1.11', 'aq_wtn_div_estk': '-', 'aq_wtn_div_estk_rt': '-', 'eaq_ostk': '-', 'eaq_ostk_rt': '-', 'eaq_estk': '-', 'eaq_estk_rt': '-', 'aq_dd': '2022년 06월 30일', 'd1_prodlm_ostk': '8,968', 'd1_prodlm_estk': '-'}

# %%
from dart import get_treasury_stock_sell
import time
from datetime import datetime

for index, row in example_df[(example_df["disclosure_type"] == "자기주식 처분 결정") & (example_df["unique_number"].notna())].iterrows():
    disclosed_date = datetime.strptime(row["disclosed_at"], "%Y-%m-%d %H:%M")
    
    date = disclosed_date.strftime("%Y%m%d")
    unique_number = row["unique_number"]
    result = get_treasury_stock_sell(unique_number, date)
    if(result['status'] == '000'):
        print(result['list'][0])
    else:
        print(result['message'])
    time.sleep(0.5)
# Out:
# {'rcept_no': '20220630000763', 'corp_cls': 'K', 'corp_code': '01199727', 'corp_name': '샘씨엔에스', 'od_a_at_t': '1', 'od_a_at_b': '-', 'adt_a_atn': '참석', 'cs_iv_bk': '-', 'aq_wtn_div_ostk': '1,022,100', 'aq_wtn_div_ostk_rt': '2.04', 'aq_wtn_div_estk': '-', 'aq_wtn_div_estk_rt': '-', 'eaq_ostk': '-', 'eaq_ostk_rt': '-', 'eaq_estk': '-', 'eaq_estk_rt': '-', 'dppln_stk_ostk': '31,000', 'dppln_stk_estk': '-', 'dpstk_prc_ostk': '157,480,000', 'dpstk_prc_estk': '-', 'dppln_prc_ostk': '5,080', 'dppln_prc_estk': '-', 'dpprpd_bgd': '2022년 06월 30일', 'dpprpd_edd': '2022년 06월 30일', 'dp_pp': '우리사주조합 무상출연', 'dp_m_mkt': '-', 'dp_m_ovtm': '-', 'dp_m_otc': '-', 'dp_m_etc': '31,000', 'dp_dd': '2022년 06월 30일', 'd1_slodlm_ostk': '-', 'd1_slodlm_estk': '-'}
# {'rcept_no': '20220630000466', 'corp_cls': 'K', 'corp_code': '01146822', 'corp_name': '아이퀘스트', 'od_a_at_t': '-', 'od_a_at_b': '-', 'adt_a_atn': '-', 'cs_iv_bk': '-', 'aq_wtn_div_ostk': '450,000', 'aq_wtn_div_ostk_rt': '4.5', 'aq_wtn_div_estk': '-', 'aq_wtn_div_estk_rt': '-', 'eaq_ostk': '-', 'eaq_ostk_rt': '-', 'eaq_estk': '-', 'eaq_estk_rt': '-', 'dppln_stk_ostk': '20,000', 'dppln_stk_estk': '-', 'dpstk_prc_ostk': '2,950', 'dpstk_prc_estk': '-', 'dppln_prc_ostk': '59,000,000', 'dppln_prc_estk': '-', 'dpprpd_bgd': '2022년 06월 30일', 'dpprpd_edd': '2022년 07월 07일', 'dp_pp': '주식매수선택권 행사에 따른 자기주식 교부', 'dp_m_mkt': '-', 'dp_m_ovtm': '-', 'dp_m_otc': '-', 'dp_m_etc': '20,000', 'dp_dd': '2022년 06월 30일', 'd1_slodlm_ostk': '-', 'd1_slodlm_estk': '-'}

# %%
example_df[(example_df["disclosure_type"] == "타법인 주식 및 출자증권 양도결정") & (example_df["unique_number"].notna())]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 example_df[(example_df["disclosure_type"] == "타법인 주식 및 출자증권 양도결정") & (example_df["unique_number"].notna())]
#
# NameError: name 'example_df' is not defined

# %%
from dart import get_stock_sale
import time
from datetime import datetime

for index, row in example_df[(example_df["disclosure_type"] == "타법인 주식 및 출자증권 양도결정") & (example_df["unique_number"].notna())].iterrows():
    disclosed_date = datetime.strptime(row["disclosed_at"], "%Y-%m-%d %H:%M")
    
    date = disclosed_date.strftime("%Y%m%d")
    unique_number = row["unique_number"]
    result = get_stock_sale(unique_number, date)
    if(result['status'] == '000'):
        print(result['list'][0])
    else:
        print(result['message'])
    time.sleep(0.5)
# Out:
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.

# %%
import sys
sys.path.append('../dags')

from disclosure_common import extract_text
url = 'https://kind.krx.co.kr/common/disclsviewer.do?method=search&acptno=20250922000507&docno=&viewerhost=&viewerport='

print(extract_text(url, "기술이전계약해지"))
# Out:
# :: 72050_투자판단 관련 주요경영사항
# 투자판단 관련 주요경영사항
# 1. 제목
# 표적항암 항체치료제 후보물질(PAb001-ADC) 기술이전 계약 종료 및 권리 회수
# 2. 주요내용
# - 당사는 2021년 3월 26일 중국 소재 Qilu Pharmaceutical Co. Ltd.과 체결한 표적항암 항체치료제 후보물질(PAb001-ADC) 기술이전 계약에 대해 양사 합의 하의 종료 및 항암 타깃 MUC-1에 대한 항체치료제 PAb001의 항체약물복합체(ADC) 후보물질 1종에 대한 전세계 독점적 권리를 회수함
# - 당사가 이미 수령한 선급금(Upfront Payment) USD 3,000,000(실수령액 세금제외 USD 2,526,786)에 대한 반환 의무 없음
# 3. 사실발생(확인)일
# 2025-09-22
# 4. 결정일
# 2025-09-22
# - 사외이사 참석여부
# 참석(명)
# -
# 불참(명)
# -
# - 감사(사외이사가 아닌 감사위원) 참석여부
# -
# 5. 기타 투자판단과 관련한 중요사항
# - 당사는 2021년 3월 26일 중국 소재 Qilu Pharmaceutical Co. Ltd.과 ADC 후보물질 1종 한정 용도의 표적항암 항체치료제 후보물질(PAb001) 기술이전 계약을 체결한 바 있음. Qilu Pharmaceutical은 ADC 후보물질의 후속 임상개발을 위해 노력하였으나, 기업환경의 변화로 인해 개발경과가 미진하였음. 따라서 당사는 Qilu Pharmaceutical와의 상호 합의의 계약 종료를 통해 PAb001의 ADC 후보물질 독점적 권리를 회수함.
# - 본 계약 종료에 대한 합의 사항으로 Qilu Pharmaceutical가 생산한 PAb001 GMP grade 항체, ADC 후보물질, 연구기록문서를 결정일로부터 60영업일 이내 수령하며 및 해당 연구결과물/개량 기술에 대한 비독점적 연구/상업화 라이선스 권리를 부여 받음.
# - 상기 '사실발생(확인)일' 및 '결정일'은 양사 계약 종료 서명본 수령일자임.
# ※ 관련공시
# 2021-03-31 투자판단 관련 주요경영사항(표적항암 항체치료제 후보물질(PAb001-ADC) 기술이전 계약 체결)

# %%
import sys

sys.path.append('../dags')

from dart import get_convertible_bond

# 전환사채 발행정보
# ==================================================
# 회사명: 셀피글로벌
# 접수번호: 20230314001096
# 이사회결의일: -

# 발행정보
# 사채종류: -
# 발행금액: -
# 발행방법: 사모
# 사채만기일: -

# 이자율 정보
# 표면이자율: -
# 만기이자율: -

# 전환 정보
# 전환가액: - (1주당)
# 전환비율: -
# 주식총수 대비: -
# 전환청구기간: - ~ -
# 최저조정가액: -

# 일정
# 청약일: -
# 납입일: -

# 기타정보
# 증권신고서 제출대상: 아니오

print(get_convertible_bond("00308896", "20220624"))
# Out:
# {'rcept_no': '20230314001096', 'corp_cls': 'K', 'corp_code': '00308896', 'corp_name': '셀피글로벌', 'bddd': '-', 'od_a_at_t': '-', 'od_a_at_b': '-', 'adt_a_atn': '-', 'fdpp_fclt': '-', 'fdpp_bsninh': '-', 'fdpp_op': '-', 'fdpp_dtrp': '-', 'fdpp_ocsa': '-', 'fdpp_etc': '-', 'ftc_stt_atn': '미해당', 'bd_tm': '-', 'bd_knd': '-', 'bd_fta': '-', 'atcsc_rmislmt': '-', 'ovis_fta': '-', 'ovis_fta_crn': '-', 'ovis_ster': '-', 'ovis_isar': '-', 'ovis_mktnm': '-', 'bd_intr_ex': '-', 'bd_intr_sf': '-', 'bd_mtd': '-', 'bdis_mthn': '사모', 'cv_rt': '-', 'cv_prc': '-', 'cvisstk_knd': '-', 'cvisstk_cnt': '-', 'cvisstk_tisstk_vs': '-', 'cvrqpd_bgd': '-', 'cvrqpd_edd': '-', 'act_mktprcfl_cvprc_lwtrsprc': '-', 'act_mktprcfl_cvprc_lwtrsprc_bs': '-', 'rmislmt_lt70p': '-', 'abmg': '-', 'sbd': '-', 'pymd': '-', 'rpmcmp': '-', 'grint': '-', 'rs_sm_atn': '아니오', 'ex_sm_r': '-', 'ovis_ltdtl': '-'}
# 전환사채 발행정보
# ====================
# 회사명: 셀피글로벌
# 이사회결의일: -
#
# 발행정보
# 사채종류: -
# 발행금액: -
# 발행방법: 사모
# 사채만기일: -
#
# 이자율 정보
# 표면이자율: -
# 만기이자율: -
#
# 전환 정보
# 전환가액: - (1주당)
# 전환비율: -
# 주식총수 대비: -
# 전환청구기간: - ~ -
# 최저조정가액: -
#
# 일정
# 청약일: -
# 납입일: -
#
# 기타정보
# 증권신고서 제출대상: 아니오

# %%
import sys

sys.path.append('../dags')
from dart import get_treasury_stock_trust

print(get_treasury_stock_trust("00372873", "20220630"))
# Out:
# 자기주식취득 신탁계약 체결정보
# ====================
# 회사명: KTis
# 이사회결의일: 2022년 06월 30일
#
# 계약 정보
# 계약금액: 5,000,000,000
# 계약기간: 2022년 07월 01일 ~ 2022년 12월 31일
# 계약목적: 주가안정 및 주주가치 제고
# 계약체결기관: KB증권(KB Securities co., Ltd.)
# 계약체결 예정일자: 2022년 07월 01일
# 위탁투자중개업자: KB증권(KB Securities co., Ltd.)
#
# 계약 전 자기주식 보유현황
# [배당가능범위 내 취득]
#   보통주식: 2,350,081 (6.75%)
#   기타주식: - (-)
# [기타취득]
#   보통주식: - (-)
#   기타주식: - (-)
#
# 이사회 정보
# 사외이사 참석: 3명 / 불참: 0명
# 감사(위원) 참석여부: -

# %%
import sys

sys.path.append('../dags')
from dart import get_treasury_stock_trust_cancel

print(get_treasury_stock_trust_cancel("01234507", "20210226"))
# Out:
# 자기주식취득 신탁계약 해지 결정 정보
# ====================
# 회사명: 매일유업
# 이사회결의일(결정일): 2021년 02월 26일
#
# 계약 정보
# 해지 전 계약금액: 20,000,000,000
# 해지 후 계약금액: 0원 (0.0억)
# 해지 전 계약기간: 2018년 04월 20일 ~ 2021년 04월 20일
# 해지목적: 임직원 자사주지급
# 해지기관: KB증권(KB Securities Co.,Ltd.)
# 해지예정일자: 2021년 02월 26일
# 해지후 신탁재산의 반환방법: 현금 및 실물(자사주) 반환
#
# 해지 전 자기주식 보유현황
# [배당가능범위 내 취득]
#   보통주식: 245,691 (3.13%)
#   기타주식: - (-)
# [기타취득]
#   보통주식: 3,037 (0.04%)
#   기타주식: - (-)
#
# 이사회 정보
# 사외이사 참석: 3명 / 불참: -명
# 감사(위원) 참석여부: -

# %%
import sys

sys.path.append('../dags')
from dart import get_capital_reduction

print(get_capital_reduction("00370255", "20210113"))
# Out:
# {'status': '000', 'message': '정상', 'list': [{'rcept_no': '20210128000321', 'corp_cls': 'K', 'corp_code': '00370255', 'corp_name': '테크엘', 'bddd': '-', 'od_a_at_t': '-', 'od_a_at_b': '-', 'adt_a_atn': '-', 'fv_ps': '-', 'crstk_ostk_cnt': '-', 'crstk_estk_cnt': '-', 'bfcr_cpt': '-', 'atcr_cpt': '-', 'bfcr_tisstk_ostk': '-', 'atcr_tisstk_ostk': '-', 'bfcr_tisstk_estk': '-', 'atcr_tisstk_estk': '-', 'cr_rt_ostk': '-', 'cr_rt_estk': '-', 'cr_std': '-', 'cr_mth': '-', 'cr_rs': '-', 'crsc_gmtsck_prd': '-', 'crsc_trnmsppd': '-', 'crsc_osprpd': '-', 'crsc_trspprpd': '-', 'crsc_osprpd_bgd': '-', 'crsc_osprpd_edd': '-', 'crsc_trspprpd_bgd': '-', 'crsc_trspprpd_edd': '-', 'crsc_nstkdlprd': '-', 'crsc_nstklstprd': '-', 'cdobprpd_bgd': '-', 'cdobprpd_edd': '-', 'ospr_nstkdl_pl': '-', 'ftc_stt_atn': '미해당'}]}
# 감자 결정 정보
# ====================
# 회사명: 테크엘
# 법인구분: K
# 이사회결의일(결정일): -
#
# 감자주식 종류 및 수
#   보통주식(주): -
#   기타주식(주): -
#
# 감자 정보
# 감자방법: -
# 감자사유: -
# 감자기준일: -
# 1주당 액면가액(원): -
#
# 감자비율
#   보통주식(%): -
#   기타주식(%): -
#
# 발행주식총수 (감자전/감자후)
#   감자전 - 보통주식(주): -
#   감자전 - 기타주식(주): -
#   감자후 - 보통주식(주): -
#   감자후 - 기타주식(주): -
#
# 자본금 변동
# 감자전 자본금(원): -
# 감자후 자본금(원): -
#
# 감자일정
# 주주총회 예정일: -
# 명의개서정지기간: -
# 구주권 제출기간: -
# 매매거래 정지예정기간: -
# 구주권 제출기간(시작일): -
# 구주권 제출기간(종료일): -
# 매매거래 정지예정기간(시작일): -
# 매매거래 정지예정기간(종료일): -
# 신주권교부예정일: -
# 신주상장예정일: -
#
# 채권자 이의제출기간
#   시작일: -
#   종료일: -
# 구주권/신주권 교부장소: -
#
# 기타 정보
# 사외이사 참석(명): -
# 사외이사 불참(명): -
# 감사(감사위원) 참석여부: -
# 공정거래위원회 신고대상 여부: 미해당

# %%
import sys

sys.path.append('../dags')
from dart import get_paid_in_capital_increase

try:
    print(get_paid_in_capital_increase("00442835", "20220627"))
except Exception as e:
    print(f"Error for 00442835, 20220627: {e}")
# Out:
# Error for 00442835, 20220627: 필드가 누락되어있습니다

# %%
import sys
sys.path.append('../dags')

from disclosure_common import extract_text
url = 'https://kind.krx.co.kr/common/disclsviewer.do?method=search&acptno=20210201000751&docno=&viewerhost=&viewerport='

print(extract_text(url, "생산중단"))
# Out:
# 1. 생산중단분야: 유산공장
# 2. 생산중단내역
# 생산중단 분야의 매출액(원): 81,403,944,481
# 최근매출액(원): 155,994,363,874
# 매출액대비(%): 52.18
# 대규모법인여부: 미해당
# 3. 생산중단내용: 유산공장의 생산중단
# 4. 생산중단사유: 임직원의 코로나19 확진 판정에 따른 방역 및
# 확산 등 위험 요인 방지
# 5. 향후대책: 방역 조치 후 보건 당국과 협의하여 안전하다고
# 판단될 경우 2021년 2월 14일 생산재개 예정
# 6. 생산중단영향: 생산의 일시적인 차질은 있으나 재개 예정일까지 충분한 재고를 확보하고 있으므로 당사의 정상적인 영업활동에는 지장이 없을 것으로 예상됨
# 7. 생산중단일자: 2021-01-31
# 8. 생산재개예정일자: 2021-02-14
# 9. 이사회결의일(결정일): 2021-01-31
# - 사외이사 참석여부
# 참석(명): -
# 불참(명): -
# - 감사(사외이사가 아닌 감사위원) 참석여부: -
# 10. 기타 투자판단과 관련한 중요사항: - 상기 2항의 '생산중단 분야의 매출액'은 2019년 유산공장 제품 관련 매출액 기준이며, '최근 매출액'은 2019년 연결기준입니다.
# - 상기 8항의 '생산재개예정일자'는 내부상황에 따라 변동될 수 있습니다.
# - 상기 9항의 '이사회결의일(결정일)'은 양산시 행정명령일입니다.
# ※ 관련공시: -
