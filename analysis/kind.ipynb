# %%
import pandas as pd

# %%
import sys
import os
sys.path.append('../dags')

from database import create_database_engine


# 환경 변수 설정
os.environ["POSTGRES_USER"] = "airflow"
os.environ["POSTGRES_PASSWORD"] = "airflow"
os.environ["POSTGRES_DB"] = "events"
os.environ["POSTGRES_PORT"] = "5433"

engine = create_database_engine(host="127.0.0.1")
print("Successfully connected to the database")
# Out:
# Successfully connected to the database

# %%
import pandas as pd
from datetime import datetime
table = "kind"
# 날짜 범위 설정

query = f"""SELECT * FROM {table}
WHERE stock_code is not NULL
  AND company_name is not NULL
  AND market IN ('KOSPI', 'KOSDAQ')
ORDER BY disclosed_at ASC"""

df = pd.read_sql(query, engine)
print(f"데이터베이스에서 조회된 공시 이벤트 수: {len(df)}")
df
# Out:
# WARNING:  database "events" has a collation version mismatch
# DETAIL:  The database was created using collation version 2.36, but the operating system provides version 2.41.
# HINT:  Rebuild all objects in this database that use the default collation and run ALTER DATABASE events REFRESH COLLATION VERSION, or build PostgreSQL with the right library version.
# 데이터베이스에서 조회된 공시 이벤트 수: 130997
#             id   disclosure_id        disclosed_at company_name    stock_code  \
# 0       157475  20201231000584 2021-01-04 07:30:00        아시아종묘  KR7154030001
# 1       157474  20210104000005 2021-01-04 08:01:00         대웅제약  KR7069620003
# 2       157473  20210104000022 2021-01-04 08:02:00           대웅  KR7003090008
# 3       157472  20210104000038 2021-01-04 08:29:00     에스케이바이오팜
# 4       157471  20210104000042 2021-01-04 08:40:00          디모아  KR7016670002
# ...        ...             ...                 ...          ...           ...
# 130992       4  20220630001052 2022-06-30 18:14:00       코아시아씨엠  KR7196450001
# 130993       5  20220630001036 2022-06-30 18:14:00       코아시아씨엠  KR7196450001
# 130994       6  20220630001035 2022-06-30 18:14:00       코아시아씨엠  KR7196450001
# 130995       2  20220630001078 2022-06-30 18:24:00       코아시아씨엠  KR7196450001
# 130996       1  20220630001079 2022-06-30 18:48:00        이원컴포텍  KR7088290002
#
#        short_code  market                              title summary_kr raw  \
# 0          154030  KOSDAQ              사외이사의선임ㆍ해임또는중도퇴임에관한신고
# 1          069620   KOSPI                     투자판단 관련 주요경영사항
# 2          003090   KOSPI        투자판단 관련 주요경영사항(자회사의 주요경영사항)
# 3                   KOSPI                 타법인 주식 및 출자증권 양도결정
# 4          016670  KOSDAQ                               영업정지
# ...           ...     ...                                ...        ...  ..
# 130992     196450  KOSDAQ                     타법인주식및출자증권취득결정
# 130993     196450  KOSDAQ                   전환사채권발행결정(제10회차)
# 130994     196450  KOSDAQ                     타법인주식및출자증권취득결정
# 130995     196450  KOSDAQ                      증권 발행결과(자율공시)
# 130996     088290  KOSDAQ  유상증자결정(자율공시)(종속회사의 주요경영사항)(제3자배정)
#
#                                                detail_url  \
# 0       https://kind.krx.co.kr/common/disclsviewer.do?...
# 1       https://kind.krx.co.kr/common/disclsviewer.do?...
# 2       https://kind.krx.co.kr/common/disclsviewer.do?...
# 3       https://kind.krx.co.kr/common/disclsviewer.do?...
# 4       https://kind.krx.co.kr/common/disclsviewer.do?...
# ...                                                   ...
# 130992  https://kind.krx.co.kr/common/disclsviewer.do?...
# 130993  https://kind.krx.co.kr/common/disclsviewer.do?...
# 130994  https://kind.krx.co.kr/common/disclsviewer.do?...
# 130995  https://kind.krx.co.kr/common/disclsviewer.do?...
# 130996  https://kind.krx.co.kr/common/disclsviewer.do?...
#
#                        created_at                 updated_at  is_modify
# 0      2025-09-20 12:22:30.082533 2025-09-20 12:22:30.082533          0
# 1      2025-09-20 12:22:30.082207 2025-09-20 12:22:30.082207          0
# 2      2025-09-20 12:22:30.081843 2025-09-20 12:22:30.081843          0
# 3      2025-09-20 12:22:30.081515 2025-09-20 12:22:30.081515          0
# 4      2025-09-20 12:22:30.081166 2025-09-20 12:22:30.081166          0
# ...                           ...                        ...        ...
# 130992 2025-08-20 07:21:10.832003 2025-09-21 09:44:55.884903          0
# 130993 2025-08-20 07:21:10.832915 2025-09-21 09:44:55.887118          0
# 130994 2025-08-20 07:21:10.833531 2025-09-21 09:44:55.889670          0
# 130995 2025-08-20 07:21:10.830859 2025-09-21 09:44:55.880183          0
# 130996 2025-08-20 07:21:10.813957 2025-09-21 09:44:55.787550          0
#
# [130997 rows x 14 columns]

# %%
df.describe()
# Out:
#                   id                   disclosed_at  \
# count  130997.000000                         130997
# mean    89978.940709  2021-09-26 14:25:23.175187200
# min         1.000000            2021-01-04 07:30:00
# 25%     56544.000000            2021-03-31 16:14:00
# 50%     89979.000000            2021-10-06 15:54:00
# 75%    123609.000000            2022-03-10 14:56:00
# max    157475.000000            2022-06-30 18:48:00
# std     39045.624441                            NaN
#
#                           created_at                     updated_at  \
# count                         130997                         130997
# mean   2025-09-20 07:30:12.657538304  2025-09-20 11:05:39.154875392
# min       2025-08-20 07:21:10.813957     2025-09-20 08:17:24.599952
# 25%    2025-09-20 09:08:24.425541888  2025-09-20 09:14:46.956185088
# 50%    2025-09-20 10:04:22.154513920  2025-09-20 10:10:32.541658880
# 75%    2025-09-20 11:31:24.195070976  2025-09-20 11:39:46.994968064
# max       2025-09-20 12:22:30.082533     2025-09-21 10:08:43.980064
# std                              NaN                            NaN
#
#            is_modify
# count  130997.000000
# mean        0.006931
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# std         0.082967

# %%
df["is_modify"].value_counts()
# Out:
# is_modify
# 0    130089
# 1       908
# Name: count, dtype: int64

# %%
df["title"].value_counts()
# Out:
# title
# 임원ㆍ주요주주특정증권등소유상황보고서                                                           18180
# 주식등의대량보유상황보고서(일반)                                                             10278
# 분기보고서(일반법인)                                                                    8000
# 주주총회소집공고                                                                       6787
# 주주총회소집결의                                                                       6566
#                                                                               ...
# 투자판단 관련 주요경영사항(자궁내막증 치료제 TU2670의 이탈리아 임상 2a상 시험 계획 승인)                            1
# 기타 경영사항(자율공시)(최대주주 및 특수관계인의 보유주식의 보호예수 기간 연장)                                     1
# 기타 경영사항(특허권 취득)(자율공시)(고전압 펄스 전기장 처리를 이용한 차가버섯 추출물의 제조방법 및 이를 포함하는 화장료 조성물)        1
# 기타 주요경영사항(자율공시)(코스닥 이전상장 승인)                                                      1
# 투자판단 관련 주요경영사항(자본시장과 금융투자에 관한 법률" 위반혐의 3심)                                        1
# Name: count, Length: 2810, dtype: int64

# %%
df[df["is_modify"] == 0]

# %%
from config import keywords

# %%
import pandas as pd
example_df = pd.read_csv("~/Downloads/kind_disclosures_20250822_070850.csv")

# %%
example_df["short_code"] = example_df["short_code"].apply(
    lambda v: f"{int(float(v)):06d}" if pd.notna(v) else None
)
example_df
# Out:
#          disclosed_at company_name    stock_code short_code  market  \
# 0    2022-06-30 18:48        이원컴포텍  KR7088290002     088290  KOSDAQ
# 1    2022-06-30 18:24       코아시아씨엠  KR7196450001     196450  KOSDAQ
# 2    2022-06-30 18:14         코아시아  KR7045970001     045970  KOSDAQ
# 3    2022-06-30 18:14       코아시아씨엠  KR7196450001     196450  KOSDAQ
# 4    2022-06-30 18:14       코아시아씨엠  KR7196450001     196450  KOSDAQ
# ..                ...          ...           ...        ...     ...
# 495  2022-06-29 17:34        골프존데카           NaN       None   KONEX
# 496  2022-06-29 17:31           GS  KR7078930005     078930   KOSPI
# 497  2022-06-29 17:27        오늘이엔엠  KR7192410009     192410  KOSDAQ
# 498  2022-06-29 17:26        케이피에프  KR7024880007     024880  KOSDAQ
# 499  2022-06-29 17:23           태성  KR7323280008     323280  KOSDAQ
#
#                                  title   disclosure_id  \
# 0    유상증자결정(자율공시)(종속회사의 주요경영사항)(제3자배정)  20220630001079
# 1                        증권 발행결과(자율공시)  20220630001078
# 2                      주권 관련 사채권의 취득결정  20220630001053
# 3                       타법인주식및출자증권취득결정  20220630001052
# 4                     전환사채권발행결정(제10회차)  20220630001036
# ..                                 ...             ...
# 495                  주식등의대량보유상황보고서(일반)  20220629000784
# 496                  주식등의대량보유상황보고서(일반)  20220629000780
# 497                  주식등의대량보유상황보고서(일반)  20220629000776
# 498                        타인에대한채무보증결정  20220629000770
# 499             기업인수목적회사의예치ㆍ신탁자금인출사실발생  20220629000746
#
#                                             detail_url
# 0    https://kind.krx.co.kr/common/disclsviewer.do?...
# 1    https://kind.krx.co.kr/common/disclsviewer.do?...
# 2    https://kind.krx.co.kr/common/disclsviewer.do?...
# 3    https://kind.krx.co.kr/common/disclsviewer.do?...
# 4    https://kind.krx.co.kr/common/disclsviewer.do?...
# ..                                                 ...
# 495  https://kind.krx.co.kr/common/disclsviewer.do?...
# 496  https://kind.krx.co.kr/common/disclsviewer.do?...
# 497  https://kind.krx.co.kr/common/disclsviewer.do?...
# 498  https://kind.krx.co.kr/common/disclsviewer.do?...
# 499  https://kind.krx.co.kr/common/disclsviewer.do?...
#
# [500 rows x 8 columns]

# %%
corp_codes_df = pd.read_csv("corp_codes.csv")
corp_codes_df["corp_code"] = corp_codes_df["corp_code"].apply(
    lambda v: f"{int(float(v)):08d}" if pd.notna(v) else None
)
corp_codes_df
# Out:
#        corp_code                  corp_name  \
# 0       00434003                         다코
# 1       00430964                      굿앤엘에스
# 2       00388953          크레디피아제이십오차유동화전문회사
# 3       00179984                     연방건설산업
# 4       00420143             브룩스피알아이오토메이션잉크
# ...          ...                        ...
# 114012  01956964                   새중앙새마을금고
# 114013  01956973  현대인베스트선진인더스트리얼일반사모부동산투자회사
# 114014  01957015                인이지(Ineeji)
# 114015  00109693                         DL
# 114016  01939879              큐브수성유동화전문유한회사
#
#                                             corp_eng_name stock_code  \
# 0                                        Daco corporation        NaN
# 1                                      Good & LS Co.,Ltd.        NaN
# 2       Credipia 25th Asset Securitization Specialty L...        NaN
# 3                                                youn bao        NaN
# 4                             BROOKS-PRI Automation, Inc.        NaN
# ...                                                   ...        ...
# 114012                           Saejungangsaemaeulgeumgo        NaN
# 114013  Hyundai Investment Sunjin Industrial Private R...        NaN
# 114014                                   INEEJI Co., Ltd.        NaN
# 114015                                DL Holdings CO.,LTD     000210
# 114016    Cube Suseong Securitization Specialty Co., Ltd.        NaN
#
#         modify_date
# 0          20170630
# 1          20170630
# 2          20170630
# 3          20170630
# 4          20170630
# ...             ...
# 114012     20250918
# 114013     20250918
# 114014     20250918
# 114015     20250919
# 114016     20250919
#
# [114017 rows x 5 columns]

# %%
# example_df에 unique_number 필드 추가 (기본값 None)
example_df["unique_number"] = None

# short_code와 stock_code가 같은 경우 corp_code 값을 unique_number에 매핑
for idx, row in example_df.iterrows():
    if pd.notna(row["short_code"]):
        matching_corp = corp_codes_df[corp_codes_df["stock_code"] == row["short_code"]]
        if not matching_corp.empty:
            corp_code = matching_corp.iloc[0]["corp_code"]
            # corp_code를 8자리 문자열로 변환
            if pd.notna(corp_code):
                example_df.loc[idx, "unique_number"] = f"{int(corp_code):08d}"

print(f"매핑 결과:")
print(f"전체 행 수: {len(example_df)}")
print(f"unique_number가 매핑된 행 수: {example_df['unique_number'].notna().sum()}")
print(f"unique_number가 매핑되지 않은 행 수: {example_df['unique_number'].isna().sum()}")
# Out:
# 매핑 결과:
# 전체 행 수: 500
# unique_number가 매핑된 행 수: 430
# unique_number가 매핑되지 않은 행 수: 70

# %%
example_df
# Out:
#          disclosed_at company_name    stock_code short_code  market  \
# 0    2022-06-30 18:48        이원컴포텍  KR7088290002     088290  KOSDAQ
# 1    2022-06-30 18:24       코아시아씨엠  KR7196450001     196450  KOSDAQ
# 2    2022-06-30 18:14         코아시아  KR7045970001     045970  KOSDAQ
# 3    2022-06-30 18:14       코아시아씨엠  KR7196450001     196450  KOSDAQ
# 4    2022-06-30 18:14       코아시아씨엠  KR7196450001     196450  KOSDAQ
# ..                ...          ...           ...        ...     ...
# 495  2022-06-29 17:34        골프존데카           NaN       None   KONEX
# 496  2022-06-29 17:31           GS  KR7078930005     078930   KOSPI
# 497  2022-06-29 17:27        오늘이엔엠  KR7192410009     192410  KOSDAQ
# 498  2022-06-29 17:26        케이피에프  KR7024880007     024880  KOSDAQ
# 499  2022-06-29 17:23           태성  KR7323280008     323280  KOSDAQ
#
#                                  title   disclosure_id  \
# 0    유상증자결정(자율공시)(종속회사의 주요경영사항)(제3자배정)  20220630001079
# 1                        증권 발행결과(자율공시)  20220630001078
# 2                      주권 관련 사채권의 취득결정  20220630001053
# 3                       타법인주식및출자증권취득결정  20220630001052
# 4                     전환사채권발행결정(제10회차)  20220630001036
# ..                                 ...             ...
# 495                  주식등의대량보유상황보고서(일반)  20220629000784
# 496                  주식등의대량보유상황보고서(일반)  20220629000780
# 497                  주식등의대량보유상황보고서(일반)  20220629000776
# 498                        타인에대한채무보증결정  20220629000770
# 499             기업인수목적회사의예치ㆍ신탁자금인출사실발생  20220629000746
#
#                                             detail_url unique_number
# 0    https://kind.krx.co.kr/common/disclsviewer.do?...      00409140
# 1    https://kind.krx.co.kr/common/disclsviewer.do?...      01031502
# 2    https://kind.krx.co.kr/common/disclsviewer.do?...      00271501
# 3    https://kind.krx.co.kr/common/disclsviewer.do?...      01031502
# 4    https://kind.krx.co.kr/common/disclsviewer.do?...      01031502
# ..                                                 ...           ...
# 495  https://kind.krx.co.kr/common/disclsviewer.do?...          None
# 496  https://kind.krx.co.kr/common/disclsviewer.do?...      00500254
# 497  https://kind.krx.co.kr/common/disclsviewer.do?...      00623184
# 498  https://kind.krx.co.kr/common/disclsviewer.do?...      00157636
# 499  https://kind.krx.co.kr/common/disclsviewer.do?...      01366000
#
# [500 rows x 9 columns]

# %%
example_df["title"].value_counts().head(20)
# Out:
# title
# 단일판매ㆍ공급계약체결               71
# 주식등의대량보유상황보고서(일반)         60
# 임원ㆍ주요주주특정증권등소유상황보고서       58
# 최대주주등소유주식변동신고서            17
# 주식매수선택권부여에관한신고            15
# 사외이사의선임ㆍ해임또는중도퇴임에관한신고     13
# 주식등의대량보유상황보고서(약식)         12
# 지속가능경영보고서 등 관련사항(자율공시)    12
# 단일판매ㆍ공급계약체결(자율공시)         10
# 타법인주식및출자증권취득결정             9
# 타인에대한채무보증결정                9
# 임시주주총회 결과                  8
# 자기주식취득 신탁계약 체결 결정          7
# 유상증자결정                     7
# 증권 발행결과(자율공시)              7
# 임시주주총회결과                   6
# 신규시설투자등                    6
# 합병등종료보고서                   5
# 주주총회소집공고                   5
# 타법인주식및출자증권처분결정             5
# Name: count, dtype: int64

# %%
from config import keywords
# example_df에 disclosure_type 필드 추가
example_df["disclosure_type"] = None

# keywords를 기반으로 disclosure_type 매핑
for disclosure_type, title_variations in keywords.items():
    if title_variations:  # 빈 리스트가 아닌 경우
        # 각 title_variation이 title에 포함되어 있는지 확인
        for variation in title_variations:
            mask = example_df["title"].str.contains(variation, na=False)
            example_df.loc[mask, "disclosure_type"] = disclosure_type
    else:  # 빈 리스트인 경우, key 자체를 검색
        mask = example_df["title"].str.contains(disclosure_type, na=False)
        example_df.loc[mask, "disclosure_type"] = disclosure_type

# 결과 확인
print("disclosure_type 분포:")
print(example_df["disclosure_type"].value_counts(dropna=False))
print(f"\n전체 행 수: {len(example_df)}")
print(f"매핑된 행 수: {example_df['disclosure_type'].notna().sum()}")
print(f"매핑되지 않은 행 수: {example_df['disclosure_type'].isna().sum()}")

example_df
# Out:
# disclosure_type 분포:
# disclosure_type
# None                  182
# 지분공시                  147
# 단일판매ㆍ공급계약체결            86
# 유상증자 결정                20
# 타법인 주식 및 출자증권 양수결정     18
# 전환사채권 발행결정             10
# 타법인 주식 및 출자증권 양도결정      7
# 자기주식취득 신탁계약 체결 결정       7
# 실적공시                    5
# 회사합병 결정                 4
# 유형자산 양도 결정              2
# 배당                      2
# 자기주식취득 신탁계약 해지 결정       2
# 무상증자 결정                 2
# 자기주식 처분 결정              2
# 소송등의판결ㆍ결정               1
# 자기주식 취득 결정              1
# 유형자산 양수 결정              1
# 상각형 조건부자본증권 발행결정        1
# Name: count, dtype: int64
#
# 전체 행 수: 500
# 매핑된 행 수: 318
# 매핑되지 않은 행 수: 182
# /var/folders/bs/f41tt40n4051glsbp8qq036c0000gp/T/ipykernel_16974/1578182872.py:13: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask = example_df["title"].str.contains(disclosure_type, na=False)
# /var/folders/bs/f41tt40n4051glsbp8qq036c0000gp/T/ipykernel_16974/1578182872.py:10: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask = example_df["title"].str.contains(variation, na=False)
# /var/folders/bs/f41tt40n4051glsbp8qq036c0000gp/T/ipykernel_16974/1578182872.py:10: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask = example_df["title"].str.contains(variation, na=False)
# /var/folders/bs/f41tt40n4051glsbp8qq036c0000gp/T/ipykernel_16974/1578182872.py:10: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask = example_df["title"].str.contains(variation, na=False)
# /var/folders/bs/f41tt40n4051glsbp8qq036c0000gp/T/ipykernel_16974/1578182872.py:10: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask = example_df["title"].str.contains(variation, na=False)
# /var/folders/bs/f41tt40n4051glsbp8qq036c0000gp/T/ipykernel_16974/1578182872.py:10: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask = example_df["title"].str.contains(variation, na=False)
# /var/folders/bs/f41tt40n4051glsbp8qq036c0000gp/T/ipykernel_16974/1578182872.py:10: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask = example_df["title"].str.contains(variation, na=False)
# /var/folders/bs/f41tt40n4051glsbp8qq036c0000gp/T/ipykernel_16974/1578182872.py:10: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask = example_df["title"].str.contains(variation, na=False)
# /var/folders/bs/f41tt40n4051glsbp8qq036c0000gp/T/ipykernel_16974/1578182872.py:10: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask = example_df["title"].str.contains(variation, na=False)
# /var/folders/bs/f41tt40n4051glsbp8qq036c0000gp/T/ipykernel_16974/1578182872.py:10: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask = example_df["title"].str.contains(variation, na=False)
#          disclosed_at company_name    stock_code short_code  market  \
# 0    2022-06-30 18:48        이원컴포텍  KR7088290002     088290  KOSDAQ
# 1    2022-06-30 18:24       코아시아씨엠  KR7196450001     196450  KOSDAQ
# 2    2022-06-30 18:14         코아시아  KR7045970001     045970  KOSDAQ
# 3    2022-06-30 18:14       코아시아씨엠  KR7196450001     196450  KOSDAQ
# 4    2022-06-30 18:14       코아시아씨엠  KR7196450001     196450  KOSDAQ
# ..                ...          ...           ...        ...     ...
# 495  2022-06-29 17:34        골프존데카           NaN       None   KONEX
# 496  2022-06-29 17:31           GS  KR7078930005     078930   KOSPI
# 497  2022-06-29 17:27        오늘이엔엠  KR7192410009     192410  KOSDAQ
# 498  2022-06-29 17:26        케이피에프  KR7024880007     024880  KOSDAQ
# 499  2022-06-29 17:23           태성  KR7323280008     323280  KOSDAQ
#
#                                  title   disclosure_id  \
# 0    유상증자결정(자율공시)(종속회사의 주요경영사항)(제3자배정)  20220630001079
# 1                        증권 발행결과(자율공시)  20220630001078
# 2                      주권 관련 사채권의 취득결정  20220630001053
# 3                       타법인주식및출자증권취득결정  20220630001052
# 4                     전환사채권발행결정(제10회차)  20220630001036
# ..                                 ...             ...
# 495                  주식등의대량보유상황보고서(일반)  20220629000784
# 496                  주식등의대량보유상황보고서(일반)  20220629000780
# 497                  주식등의대량보유상황보고서(일반)  20220629000776
# 498                        타인에대한채무보증결정  20220629000770
# 499             기업인수목적회사의예치ㆍ신탁자금인출사실발생  20220629000746
#
#                                             detail_url unique_number  \
# 0    https://kind.krx.co.kr/common/disclsviewer.do?...      00409140
# 1    https://kind.krx.co.kr/common/disclsviewer.do?...      01031502
# 2    https://kind.krx.co.kr/common/disclsviewer.do?...      00271501
# 3    https://kind.krx.co.kr/common/disclsviewer.do?...      01031502
# 4    https://kind.krx.co.kr/common/disclsviewer.do?...      01031502
# ..                                                 ...           ...
# 495  https://kind.krx.co.kr/common/disclsviewer.do?...          None
# 496  https://kind.krx.co.kr/common/disclsviewer.do?...      00500254
# 497  https://kind.krx.co.kr/common/disclsviewer.do?...      00623184
# 498  https://kind.krx.co.kr/common/disclsviewer.do?...      00157636
# 499  https://kind.krx.co.kr/common/disclsviewer.do?...      01366000
#
#         disclosure_type
# 0               유상증자 결정
# 1                  None
# 2                  None
# 3    타법인 주식 및 출자증권 양수결정
# 4            전환사채권 발행결정
# ..                  ...
# 495                지분공시
# 496                지분공시
# 497                지분공시
# 498                None
# 499                None
#
# [500 rows x 10 columns]

# %%
def format_convertible_bond_info(data):
    """전환사채 발행정보를 포맷팅하여 출력하는 함수"""
    if not data or data.get('status') != '000' or not data.get('list'):
        print("❌ 데이터가 없습니다.")
        return
    
    bond_info = data['list'][0]
    
    # 숫자 포맷팅 함수 (억원 단위로 변환)
    def format_amount(amount_str):
        if not amount_str or amount_str == '-':
            return '-'
        try:
            amount = int(amount_str)
            return f"{amount:,}원 ({amount/100000000:.1f}억)"
        except:
            return amount_str
    
    # 퍼센트 포맷팅 함수
    def format_percent(percent_str):
        if not percent_str or percent_str == '-':
            return '-'
        return f"{percent_str}%"
    
    print(f"📊 전환사채 발행정보")
    print(f"=" * 50)
    print(f"회사명: {bond_info.get('corp_name', '-')}")
    print(f"접수번호: {bond_info.get('rcept_no', '-')}")
    print(f"이사회결의일: {bond_info.get('bddd', '-')}")
    print()
    
    print(f"💰 발행정보")
    print(f"사채종류: {bond_info.get('bd_knd', '-')}")
    print(f"발행금액: {format_amount(bond_info.get('bd_fta'))}")
    print(f"발행방법: {bond_info.get('bdis_mthn', '-')}")
    print(f"사채만기일: {bond_info.get('bd_mtd', '-')}")
    print()
    
    print(f"📈 이자율 정보")
    print(f"표면이자율: {format_percent(bond_info.get('bd_intr_ex'))}")
    print(f"만기이자율: {format_percent(bond_info.get('bd_intr_sf'))}")
    print()
    
    print(f"🔄 전환 정보")
    print(f"전환가액: {format_amount(bond_info.get('cv_prc'))} (1주당)")
    print(f"전환비율: {format_percent(bond_info.get('cv_rt'))}")
    # print(f"전환주식수: {bond_info.get('cvisstk_cnt', '-'):,}주" if bond_info.get('cvisstk_cnt', '-') != '-' else "전환주식수: -")
    print(f"주식총수 대비: {format_percent(bond_info.get('cvisstk_tisstk_vs'))}")
    print(f"전환청구기간: {bond_info.get('cvrqpd_bgd', '-')} ~ {bond_info.get('cvrqpd_edd', '-')}")
    print(f"최저조정가액: {format_amount(bond_info.get('act_mktprcfl_cvprc_lwtrsprc'))}")
    print()
    
    print(f"📅 일정")
    print(f"청약일: {bond_info.get('sbd', '-')}")
    print(f"납입일: {bond_info.get('pymd', '-')}")
    print()
    
    # 자금조달 목적이 있는 경우만 출력
    funding_purposes = []
    if bond_info.get('fdpp_fclt') not in [None, '-', '']:
        funding_purposes.append(f"시설자금: {format_amount(bond_info.get('fdpp_fclt'))}")
    if bond_info.get('fdpp_op') not in [None, '-', '']:
        funding_purposes.append(f"운영자금: {format_amount(bond_info.get('fdpp_op'))}")
    if bond_info.get('fdpp_dtrp') not in [None, '-', '']:
        funding_purposes.append(f"채무상환자금: {format_amount(bond_info.get('fdpp_dtrp'))}")
    if bond_info.get('fdpp_ocsa') not in [None, '-', '']:
        funding_purposes.append(f"타법인증권취득자금: {format_amount(bond_info.get('fdpp_ocsa'))}")
    if bond_info.get('fdpp_etc') not in [None, '-', '']:
        funding_purposes.append(f"기타자금: {format_amount(bond_info.get('fdpp_etc'))}")
    
    if funding_purposes:
        print(f"💼 자금조달 목적")
        for purpose in funding_purposes:
            print(f"{purpose}")
        print()
    
    print(f"ℹ️ 기타정보")
    if bond_info.get('rpmcmp') not in [None, '-', '']:
        print(f"대표주관회사: {bond_info.get('rpmcmp', '-')}")
    if bond_info.get('grint') not in [None, '-', '']:
        print(f"보증기관: {bond_info.get('grint', '-')}")
    print(f"증권신고서 제출대상: {bond_info.get('rs_sm_atn', '-')}")
    if bond_info.get('ex_sm_r') not in [None, '-', '']:
        print(f"제출면제사유: {bond_info.get('ex_sm_r', '-')}")

# %%
import time
from datetime import datetime
from dart import get_convertible_bond

for index, row in example_df[(example_df["disclosure_type"] == "전환사채권 발행결정") & (example_df["unique_number"].notna())].iterrows():
    disclosed_date = datetime.strptime(row["disclosed_at"], "%Y-%m-%d %H:%M")
    
    date = disclosed_date.strftime("%Y%m%d")
    print(date)
    unique_number = row["unique_number"]
    result = get_convertible_bond(unique_number, date)
    if(result['status'] == '000'):
        format_convertible_bond_info(result)
    else:
        print(result['message'])
    time.sleep(0.5)
# Out:
# 20220630
# 📊 전환사채 발행정보
# ==================================================
# 회사명: 코아시아씨엠
# 접수번호: 20220630001013
# 이사회결의일: 2022년 06월 30일
#
# 💰 발행정보
# 사채종류: 무기명식 이권부 무보증 사모 전환사채
# 발행금액: 11,000,000,000
# 발행방법: 사모
# 사채만기일: 2027년 06월 30일
#
# 📈 이자율 정보
# 표면이자율: 0.0%
# 만기이자율: 2.0%
#
# 🔄 전환 정보
# 전환가액: 2,300 (1주당)
# 전환비율: 100%
# 주식총수 대비: 10.4%
# 전환청구기간: 2023년 06월 30일 ~ 2027년 05월 30일
# 최저조정가액: -
#
# 📅 일정
# 청약일: 2022년 06월 30일
# 납입일: 2022년 06월 30일
#
# 💼 자금조달 목적
# 타법인증권취득자금: 11,000,000,000
#
# ℹ️ 기타정보
# 증권신고서 제출대상: 아니오
# 제출면제사유: 사모발행 (사채발행일로부터 1년간 전환 금지 및 분할 금지)
# 20220630
# 조회된 데이타가 없습니다.
# 20220630
# 조회된 데이타가 없습니다.
# 20220630
# 조회된 데이타가 없습니다.
# 20220630
# 조회된 데이타가 없습니다.
# 20220630
# 조회된 데이타가 없습니다.
# 20220630
# 조회된 데이타가 없습니다.

# %% [markdown]
# 2025.09.23 16:59:34
# 기업명: 서플러스글로벌(시가총액: 943억)
# 보고서명: 주요사항보고서(전환사채권발행결정)
#
# 발행금액 : 83억(전체대비 : 7.96%)
# 발행방법 : 사모
# 전환가액 : 2,602원(현재가 : 2,550원)
# 최저조정 : -
# 표면이율 : 0.0%
# 만기이율 : 0.0%
#
# 납입일자 : 2025-10-01
# 청구시작 : 2026-10-01
# 청구종료 : 2030-09-01
#
# * 투자자
# 타이거 코스닥벤처 와이즈메자닌 322 일반 사모투자신탁
# 타이거 코스닥벤처 위닝메자닌 326 일반 사모투자신탁
# 타이거 코스닥벤처 파워메자닌 337 일반 사모투자신탁
# 타이거 코스닥벤처 으뜸 338 일반 사모투자신탁
# 타이거 코스닥벤처 프리즘 339 일반 사모투자신탁
# ...

# %%
example_df[(example_df["disclosure_type"] == "타법인 주식 및 출자증권 양수결정") & (example_df["unique_number"].notna())]
# Out:
#          disclosed_at company_name    stock_code short_code  market  \
# 3    2022-06-30 18:14       코아시아씨엠  KR7196450001     196450  KOSDAQ
# 5    2022-06-30 18:14       코아시아씨엠  KR7196450001     196450  KOSDAQ
# 7    2022-06-30 18:09       하나금융지주  KR7086790003     086790   KOSPI
# 38   2022-06-30 17:29         삼성공조  KR7006660005     006660   KOSPI
# 44   2022-06-30 17:26           SK  KR7034730002     034730   KOSPI
# 53   2022-06-30 17:23      SK이노베이션  KR7096770003     096770   KOSPI
# 61   2022-06-30 17:20      SK이노베이션  KR7096770003     096770   KOSPI
# 71   2022-06-30 17:13           엔켐  KR7348370008     348370  KOSDAQ
# 72   2022-06-30 17:13           엔켐  KR7348370008     348370  KOSDAQ
# 77   2022-06-30 17:10          한진칼  KR7180640005     180640   KOSPI
# 87   2022-06-30 17:05      SK이노베이션  KR7096770003     096770   KOSPI
# 116  2022-06-30 16:48         대한항공  KR7003490000     003490   KOSPI
# 155  2022-06-30 16:23           기아  KR7000270009     000270   KOSPI
# 162  2022-06-30 16:20        현대모비스  KR7012330007     012330   KOSPI
# 260  2022-06-30 15:22           한창  KR7005110002     005110   KOSPI
# 344  2022-06-30 12:35         에이엔피  KR7015260003     015260   KOSPI
# 444  2022-06-30 12:35         에이엔피  KR7015260003     015260   KOSPI
#
#                                  title   disclosure_id  \
# 3                       타법인주식및출자증권취득결정  20220630001052
# 5                       타법인주식및출자증권취득결정  20220630001035
# 7          타법인주식및출자증권취득결정(자회사의 주요경영사항)  20220630001073
# 38                      타법인주식및출자증권취득결정  20220630000931
# 44         타법인주식및출자증권취득결정(자회사의 주요경영사항)  20220630000979
# 53         타법인주식및출자증권취득결정(자회사의 주요경영사항)  20220630000960
# 61   타법인주식및출자증권취득결정(자율공시)(자회사의 주요경영사항)  20220630000967
# 71                      타법인주식및출자증권취득결정  20220630000925
# 72                      타법인주식및출자증권취득결정  20220630000906
# 77         타법인주식및출자증권취득결정(자회사의 주요경영사항)  20220630000856
# 87   타법인주식및출자증권취득결정(자율공시)(자회사의 주요경영사항)  20220630000917
# 116                     타법인주식및출자증권취득결정  20220630000799
# 155               타법인주식및출자증권취득결정(자율공시)  20220630000777
# 162               타법인주식및출자증권취득결정(자율공시)  20220630000764
# 260                     타법인주식및출자증권취득결정  20220630000459
# 344                     타법인주식및출자증권취득결정  20220630000222
# 444                     타법인주식및출자증권취득결정  20220630000222
#
#                                             detail_url unique_number  \
# 3    https://kind.krx.co.kr/common/disclsviewer.do?...      01031502
# 5    https://kind.krx.co.kr/common/disclsviewer.do?...      01031502
# 7    https://kind.krx.co.kr/common/disclsviewer.do?...      00547583
# 38   https://kind.krx.co.kr/common/disclsviewer.do?...      00126201
# 44   https://kind.krx.co.kr/common/disclsviewer.do?...      00181712
# 53   https://kind.krx.co.kr/common/disclsviewer.do?...      00631518
# 61   https://kind.krx.co.kr/common/disclsviewer.do?...      00631518
# 71   https://kind.krx.co.kr/common/disclsviewer.do?...      01011526
# 72   https://kind.krx.co.kr/common/disclsviewer.do?...      01011526
# 77   https://kind.krx.co.kr/common/disclsviewer.do?...      00983040
# 87   https://kind.krx.co.kr/common/disclsviewer.do?...      00631518
# 116  https://kind.krx.co.kr/common/disclsviewer.do?...      00113526
# 155  https://kind.krx.co.kr/common/disclsviewer.do?...      00106641
# 162  https://kind.krx.co.kr/common/disclsviewer.do?...      00164788
# 260  https://kind.krx.co.kr/common/disclsviewer.do?...      00163716
# 344  https://kind.krx.co.kr/common/disclsviewer.do?...      00143314
# 444  https://kind.krx.co.kr/common/disclsviewer.do?...      00143314
#
#         disclosure_type
# 3    타법인 주식 및 출자증권 양수결정
# 5    타법인 주식 및 출자증권 양수결정
# 7    타법인 주식 및 출자증권 양수결정
# 38   타법인 주식 및 출자증권 양수결정
# 44   타법인 주식 및 출자증권 양수결정
# 53   타법인 주식 및 출자증권 양수결정
# 61   타법인 주식 및 출자증권 양수결정
# 71   타법인 주식 및 출자증권 양수결정
# 72   타법인 주식 및 출자증권 양수결정
# 77   타법인 주식 및 출자증권 양수결정
# 87   타법인 주식 및 출자증권 양수결정
# 116  타법인 주식 및 출자증권 양수결정
# 155  타법인 주식 및 출자증권 양수결정
# 162  타법인 주식 및 출자증권 양수결정
# 260  타법인 주식 및 출자증권 양수결정
# 344  타법인 주식 및 출자증권 양수결정
# 444  타법인 주식 및 출자증권 양수결정

# %%
import time
from datetime import datetime
from dart import get_stock_acquisition

for index, row in example_df[(example_df["disclosure_type"] == "타법인 주식 및 출자증권 양수결정") & (example_df["unique_number"].notna())].iterrows():
    disclosed_date = datetime.strptime(row["disclosed_at"], "%Y-%m-%d %H:%M")
    
    date = disclosed_date.strftime("%Y%m%d")
    unique_number = row["unique_number"]
    result = get_stock_acquisition(unique_number, date)
    if(result['status'] == '000'):
        print(result['list'][0])
    else:
        print(result['message'])
    time.sleep(0.5)
# Out:
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.

# %%
import time
from datetime import datetime
from dart import get_treasury_stock_trust

for index, row in example_df[(example_df["disclosure_type"] == "자기주식취득 신탁계약 체결 결정") & (example_df["unique_number"].notna())].iterrows():
    disclosed_date = datetime.strptime(row["disclosed_at"], "%Y-%m-%d %H:%M")
    
    date = disclosed_date.strftime("%Y%m%d")
    unique_number = row["unique_number"]
    result = get_treasury_stock_trust(unique_number, date)
    if(result['status'] == '000'):
        print(result['list'][0])
    else:
        print(result['message'])
    time.sleep(0.5)
# Out:
# {'rcept_no': '20220630000744', 'corp_cls': 'Y', 'corp_code': '00372873', 'corp_name': 'KTis', 'bddd': '2022년 06월 30일', 'od_a_at_t': '3', 'od_a_at_b': '0', 'adt_a_atn': '-', 'cs_iv_bk': 'KB증권(KB Securities co., Ltd.)', 'aq_wtn_div_ostk': '2,350,081', 'aq_wtn_div_ostk_rt': '6.75', 'aq_wtn_div_estk': '-', 'aq_wtn_div_estk_rt': '-', 'eaq_ostk': '-', 'eaq_ostk_rt': '-', 'eaq_estk': '-', 'eaq_estk_rt': '-', 'ctr_prc': '5,000,000,000', 'ctr_pd_bgd': '2022년 07월 01일', 'ctr_pd_edd': '2022년 12월 31일', 'ctr_pp': '주가안정 및 주주가치 제고', 'ctr_cns_int': 'KB증권(KB Securities co., Ltd.)', 'ctr_cns_prd': '2022년 07월 01일'}
# {'rcept_no': '20220630000648', 'corp_cls': 'Y', 'corp_code': '00372882', 'corp_name': 'KTcs', 'bddd': '2022년 06월 30일', 'od_a_at_t': '3', 'od_a_at_b': '0', 'adt_a_atn': '-', 'cs_iv_bk': 'NH투자증권 (NH INVESTMENT & SECURITIES CO.,LTD.)', 'aq_wtn_div_ostk': '2,544,056', 'aq_wtn_div_ostk_rt': '5.96', 'aq_wtn_div_estk': '-', 'aq_wtn_div_estk_rt': '-', 'eaq_ostk': '-', 'eaq_ostk_rt': '-', 'eaq_estk': '-', 'eaq_estk_rt': '-', 'ctr_prc': '5,000,000,000', 'ctr_pd_bgd': '2022년 07월 01일', 'ctr_pd_edd': '2022년 12월 31일', 'ctr_pp': '주가안정 및 주주가치 제고', 'ctr_cns_int': 'NH투자증권(NH INVESTMENT & SECURITIES CO.,LTD.)', 'ctr_cns_prd': '2022년 07월 01일'}
# 조회된 데이타가 없습니다.
# {'rcept_no': '20221229000344', 'corp_cls': 'K', 'corp_code': '00610083', 'corp_name': '비아트론', 'bddd': '2022년 12월 29일', 'od_a_at_t': '1', 'od_a_at_b': '-', 'adt_a_atn': '참석', 'cs_iv_bk': '대신증권', 'aq_wtn_div_ostk': '792,976', 'aq_wtn_div_ostk_rt': '6.54', 'aq_wtn_div_estk': '-', 'aq_wtn_div_estk_rt': '-', 'eaq_ostk': '-', 'eaq_ostk_rt': '-', 'eaq_estk': '-', 'eaq_estk_rt': '-', 'ctr_prc': '5,000,000,000', 'ctr_pd_bgd': '2022년 12월 30일', 'ctr_pd_edd': '2023년 06월 29일', 'ctr_pp': '주가안정 및 주주가치 제고', 'ctr_cns_int': '대신증권', 'ctr_cns_prd': '2022년 12월 30일'}
# {'rcept_no': '20220630000161', 'corp_cls': 'K', 'corp_code': '01310773', 'corp_name': '엔시스', 'bddd': '2022년 06월 30일', 'od_a_at_t': '3', 'od_a_at_b': '-', 'adt_a_atn': '-', 'cs_iv_bk': 'NH투자증권(주)', 'aq_wtn_div_ostk': '-', 'aq_wtn_div_ostk_rt': '-', 'aq_wtn_div_estk': '-', 'aq_wtn_div_estk_rt': '-', 'eaq_ostk': '7', 'eaq_ostk_rt': '0.00', 'eaq_estk': '-', 'eaq_estk_rt': '-', 'ctr_prc': '5,000,000,000', 'ctr_pd_bgd': '2022년 06월 30일', 'ctr_pd_edd': '2023년 06월 29일', 'ctr_pp': '주가안정 및 주주가치 제고', 'ctr_cns_int': '엔에이치투자증권 주식회사(NH INVESTMENT & SECURITIES CO.,LTD. )', 'ctr_cns_prd': '2022년 06월 30일'}
# {'rcept_no': '20221229000344', 'corp_cls': 'K', 'corp_code': '00610083', 'corp_name': '비아트론', 'bddd': '2022년 12월 29일', 'od_a_at_t': '1', 'od_a_at_b': '-', 'adt_a_atn': '참석', 'cs_iv_bk': '대신증권', 'aq_wtn_div_ostk': '792,976', 'aq_wtn_div_ostk_rt': '6.54', 'aq_wtn_div_estk': '-', 'aq_wtn_div_estk_rt': '-', 'eaq_ostk': '-', 'eaq_ostk_rt': '-', 'eaq_estk': '-', 'eaq_estk_rt': '-', 'ctr_prc': '5,000,000,000', 'ctr_pd_bgd': '2022년 12월 30일', 'ctr_pd_edd': '2023년 06월 29일', 'ctr_pp': '주가안정 및 주주가치 제고', 'ctr_cns_int': '대신증권', 'ctr_cns_prd': '2022년 12월 30일'}
# {'rcept_no': '20220630000161', 'corp_cls': 'K', 'corp_code': '01310773', 'corp_name': '엔시스', 'bddd': '2022년 06월 30일', 'od_a_at_t': '3', 'od_a_at_b': '-', 'adt_a_atn': '-', 'cs_iv_bk': 'NH투자증권(주)', 'aq_wtn_div_ostk': '-', 'aq_wtn_div_ostk_rt': '-', 'aq_wtn_div_estk': '-', 'aq_wtn_div_estk_rt': '-', 'eaq_ostk': '7', 'eaq_ostk_rt': '0.00', 'eaq_estk': '-', 'eaq_estk_rt': '-', 'ctr_prc': '5,000,000,000', 'ctr_pd_bgd': '2022년 06월 30일', 'ctr_pd_edd': '2023년 06월 29일', 'ctr_pp': '주가안정 및 주주가치 제고', 'ctr_cns_int': '엔에이치투자증권 주식회사(NH INVESTMENT & SECURITIES CO.,LTD. )', 'ctr_cns_prd': '2022년 06월 30일'}

# %%
{'rcept_no': '20220630000744', 'corp_cls': 'Y', 'corp_code': '00372873', 'corp_name': 'KTis', 'bddd': '2022년 06월 30일', 'od_a_at_t': '3', 'od_a_at_b': '0', 'adt_a_atn': '-', 'cs_iv_bk': 'KB증권(KB Securities co., Ltd.)', 'aq_wtn_div_ostk': '2,350,081', 'aq_wtn_div_ostk_rt': '6.75', 'aq_wtn_div_estk': '-', 'aq_wtn_div_estk_rt': '-', 'eaq_ostk': '-', 'eaq_ostk_rt': '-', 'eaq_estk': '-', 'eaq_estk_rt': '-', 'ctr_prc': '5,000,000,000', 'ctr_pd_bgd': '2022년 07월 01일', 'ctr_pd_edd': '2022년 12월 31일', 'ctr_pp': '주가안정 및 주주가치 제고', 'ctr_cns_int': 'KB증권(KB Securities co., Ltd.)', 'ctr_cns_prd': '2022년 07월 01일'}

# %%
2024.09.05 16:02:35
기업명: 에스트래픽(시가총액: 995억)
보고서명: 주요사항보고서(자기주식취득신탁계약체결결정)

계약금액 : 30억
시총대비 : 3.15%
계약목적 : 주주가치 제고를 위한 자사주 취득 및 소각(15억원) 목적의 신탁계약
체결기관 : 삼성증권

시작일자 : 2024-09-06
종료일자 : 2025-03-05


공시링크: https://dart.fss.or.kr/dsaf001/main.do?rcpNo=20240905000252
회사정보: https://finance.naver.com/item/main.nhn?code=234300

# %%
from dart import get_treasury_stock_buy
import time
from datetime import datetime

for index, row in example_df[(example_df["disclosure_type"] == "자기주식 취득 결정") & (example_df["unique_number"].notna())].iterrows():
    disclosed_date = datetime.strptime(row["disclosed_at"], "%Y-%m-%d %H:%M")
    
    date = disclosed_date.strftime("%Y%m%d")
    unique_number = row["unique_number"]
    result = get_treasury_stock_buy(unique_number, date)
    if(result['status'] == '000'):
        print(result['list'][0])
    else:
        print(result['message'])
    time.sleep(0.5)
# Out:
# {'rcept_no': '20220630000670', 'corp_cls': 'K', 'corp_code': '00109781', 'corp_name': '대림제지', 'od_a_at_t': '3', 'od_a_at_b': '-', 'adt_a_atn': '-', 'aqpln_stk_ostk': '60,000', 'aqpln_stk_estk': '-', 'aqpln_prc_ostk': '504,000,000', 'aqpln_prc_estk': '-', 'aqexpd_bgd': '2022년 07월 01일', 'aqexpd_edd': '2022년 09월 30일', 'hdexpd_bgd': '-', 'hdexpd_edd': '-', 'aq_pp': '주식가격의 안정 및 주주가치 제고', 'aq_mth': '코스닥 시장 장내 직접취득', 'cs_iv_bk': 'NH투자증권', 'aq_wtn_div_ostk': '100,000', 'aq_wtn_div_ostk_rt': '1.11', 'aq_wtn_div_estk': '-', 'aq_wtn_div_estk_rt': '-', 'eaq_ostk': '-', 'eaq_ostk_rt': '-', 'eaq_estk': '-', 'eaq_estk_rt': '-', 'aq_dd': '2022년 06월 30일', 'd1_prodlm_ostk': '8,968', 'd1_prodlm_estk': '-'}

# %%
from dart import get_treasury_stock_sell
import time
from datetime import datetime

for index, row in example_df[(example_df["disclosure_type"] == "자기주식 처분 결정") & (example_df["unique_number"].notna())].iterrows():
    disclosed_date = datetime.strptime(row["disclosed_at"], "%Y-%m-%d %H:%M")
    
    date = disclosed_date.strftime("%Y%m%d")
    unique_number = row["unique_number"]
    result = get_treasury_stock_sell(unique_number, date)
    if(result['status'] == '000'):
        print(result['list'][0])
    else:
        print(result['message'])
    time.sleep(0.5)
# Out:
# {'rcept_no': '20220630000763', 'corp_cls': 'K', 'corp_code': '01199727', 'corp_name': '샘씨엔에스', 'od_a_at_t': '1', 'od_a_at_b': '-', 'adt_a_atn': '참석', 'cs_iv_bk': '-', 'aq_wtn_div_ostk': '1,022,100', 'aq_wtn_div_ostk_rt': '2.04', 'aq_wtn_div_estk': '-', 'aq_wtn_div_estk_rt': '-', 'eaq_ostk': '-', 'eaq_ostk_rt': '-', 'eaq_estk': '-', 'eaq_estk_rt': '-', 'dppln_stk_ostk': '31,000', 'dppln_stk_estk': '-', 'dpstk_prc_ostk': '157,480,000', 'dpstk_prc_estk': '-', 'dppln_prc_ostk': '5,080', 'dppln_prc_estk': '-', 'dpprpd_bgd': '2022년 06월 30일', 'dpprpd_edd': '2022년 06월 30일', 'dp_pp': '우리사주조합 무상출연', 'dp_m_mkt': '-', 'dp_m_ovtm': '-', 'dp_m_otc': '-', 'dp_m_etc': '31,000', 'dp_dd': '2022년 06월 30일', 'd1_slodlm_ostk': '-', 'd1_slodlm_estk': '-'}
# {'rcept_no': '20220630000466', 'corp_cls': 'K', 'corp_code': '01146822', 'corp_name': '아이퀘스트', 'od_a_at_t': '-', 'od_a_at_b': '-', 'adt_a_atn': '-', 'cs_iv_bk': '-', 'aq_wtn_div_ostk': '450,000', 'aq_wtn_div_ostk_rt': '4.5', 'aq_wtn_div_estk': '-', 'aq_wtn_div_estk_rt': '-', 'eaq_ostk': '-', 'eaq_ostk_rt': '-', 'eaq_estk': '-', 'eaq_estk_rt': '-', 'dppln_stk_ostk': '20,000', 'dppln_stk_estk': '-', 'dpstk_prc_ostk': '2,950', 'dpstk_prc_estk': '-', 'dppln_prc_ostk': '59,000,000', 'dppln_prc_estk': '-', 'dpprpd_bgd': '2022년 06월 30일', 'dpprpd_edd': '2022년 07월 07일', 'dp_pp': '주식매수선택권 행사에 따른 자기주식 교부', 'dp_m_mkt': '-', 'dp_m_ovtm': '-', 'dp_m_otc': '-', 'dp_m_etc': '20,000', 'dp_dd': '2022년 06월 30일', 'd1_slodlm_ostk': '-', 'd1_slodlm_estk': '-'}

# %%
example_df[(example_df["disclosure_type"] == "타법인 주식 및 출자증권 양도결정") & (example_df["unique_number"].notna())]
# Out:
#          disclosed_at company_name    stock_code short_code  market  \
# 12   2022-06-30 17:58         코아시아  KR7045970001     045970  KOSDAQ
# 13   2022-06-30 17:56         코아시아  KR7045970001     045970  KOSDAQ
# 207  2022-06-30 15:56           한창  KR7005110002     005110   KOSPI
# 292  2022-06-30 14:53         KTcs  KR7058850009     058850   KOSPI
# 346  2022-06-30 11:28         팅크웨어  KR7084730001     084730  KOSDAQ
# 446  2022-06-30 11:28         팅크웨어  KR7084730001     084730  KOSDAQ
#
#                     title   disclosure_id  \
# 12         타법인주식및출자증권처분결정  20220630001055
# 13         타법인주식및출자증권처분결정  20220630001050
# 207        타법인주식및출자증권처분결정  20220630000630
# 292  타법인주식및출자증권처분결정(자율공시)  20220630000440
# 346        타법인주식및출자증권처분결정  20220630000203
# 446        타법인주식및출자증권처분결정  20220630000203
#
#                                             detail_url unique_number  \
# 12   https://kind.krx.co.kr/common/disclsviewer.do?...      00271501
# 13   https://kind.krx.co.kr/common/disclsviewer.do?...      00271501
# 207  https://kind.krx.co.kr/common/disclsviewer.do?...      00163716
# 292  https://kind.krx.co.kr/common/disclsviewer.do?...      00372882
# 346  https://kind.krx.co.kr/common/disclsviewer.do?...      00438036
# 446  https://kind.krx.co.kr/common/disclsviewer.do?...      00438036
#
#         disclosure_type
# 12   타법인 주식 및 출자증권 양도결정
# 13   타법인 주식 및 출자증권 양도결정
# 207  타법인 주식 및 출자증권 양도결정
# 292  타법인 주식 및 출자증권 양도결정
# 346  타법인 주식 및 출자증권 양도결정
# 446  타법인 주식 및 출자증권 양도결정

# %%
from dart import get_stock_sale
import time
from datetime import datetime

for index, row in example_df[(example_df["disclosure_type"] == "타법인 주식 및 출자증권 양도결정") & (example_df["unique_number"].notna())].iterrows():
    disclosed_date = datetime.strptime(row["disclosed_at"], "%Y-%m-%d %H:%M")
    
    date = disclosed_date.strftime("%Y%m%d")
    unique_number = row["unique_number"]
    result = get_stock_sale(unique_number, date)
    if(result['status'] == '000'):
        print(result['list'][0])
    else:
        print(result['message'])
    time.sleep(0.5)
# Out:
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
# 조회된 데이타가 없습니다.
