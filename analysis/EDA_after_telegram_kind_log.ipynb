# %%
import sys
import os
sys.path.append('../dags')

from database import create_database_engine


# 환경 변수 설정
os.environ["POSTGRES_USER"] = "airflow"
os.environ["POSTGRES_PASSWORD"] = "airflow"
os.environ["POSTGRES_DB"] = "events"
os.environ["POSTGRES_PORT"] = "5433"

engine = create_database_engine(host="127.0.0.1")
print("Successfully connected to the database")
# Out:
# Successfully connected to the database

# %%
import pandas as pd
from datetime import datetime
table = "kind"
# 날짜 범위 설정
start_date = datetime(2022, 7, 1)
end_date = datetime(2023, 12, 31)

query = f"""SELECT * FROM {table}
WHERE stock_code != ''
  AND market IN ('KOSPI', 'KOSDAQ', 'KOSDAQ GLOBAL')
  AND disclosed_at >= %(start_date)s
  AND disclosed_at <= %(end_date)s
  AND label is not NULL
ORDER BY disclosed_at ASC"""

df = pd.read_sql(query, engine, params={"start_date": start_date, "end_date": end_date})
print(f"데이터베이스에서 조회된 공시 이벤트 수: {len(df)}")
df.head()
# Out:
# WARNING:  database "events" has a collation version mismatch
# DETAIL:  The database was created using collation version 2.36, but the operating system provides version 2.41.
# HINT:  Rebuild all objects in this database that use the default collation and run ALTER DATABASE events REFRESH COLLATION VERSION, or build PostgreSQL with the right library version.
# 데이터베이스에서 조회된 공시 이벤트 수: 9808
#        id   disclosure_id        disclosed_at company_name    stock_code  \
# 0  325697  20220701000005 2022-07-01 07:49:00       CG인바이츠  KR7083790006
# 1  325691  20220701000107 2022-07-01 10:03:00        강원에너지  KR7114190002
# 2  325686  20220701000122 2022-07-01 10:24:00         비츠로셀  KR7082920000
# 3  325685  20220701000123 2022-07-01 10:26:00        비츠로테크  KR7042370007
# 4  325676  20220701000136 2022-07-01 10:43:00       동원시스템즈  KR7014820005
#
#   short_code  market                                title  \
# 0     083790  KOSDAQ  투자판단 관련 주요경영사항(임상 2상 시험계획 조기 종료 신청)
# 1     114190  KOSDAQ                 타법인주식및출자증권취득결정(자율공시)
# 2     082920  KOSDAQ                          단일판매ㆍ공급계약체결
# 3     042370  KOSDAQ             단일판매ㆍ공급계약체결(자회사의 주요경영사항)
# 4     014820   KOSPI                        신규시설투자등(자율공시)
#
#                                           summary_kr  \
# 0  이 임상2상 시험은 코로나19 환자에서 카모스타트의 유효성과 안전성을 평가하기 위해...
# 1  강원이솔루션은 2022년 7월 1일 이차전지 사업의 핵심기술 확보를 위해 20,00...
# 2  회사는 방위사업청과 15,107,298,910원 규모의 리튬전지류 및 기뢰정비장비용...
# 3  해당 기업은 방위사업청과 2022년 6월에 공급계약을 체결하여 전지조립체를 공급했으...
# 4  이 기업은 충청남도 아산시에 위치한 2차전지 캔 신공장 건설을 위해 약 585억 원...
#
#                                                  raw  \
# 0  1. 제목: 코로나19 바이러스(SARS-CoV-2) 감염이 확진된 COVID-19...
# 1  1. 발행회사\n회사명(국적): 주식회사\n강원이솔루션\n(대한민국)\n대표이사: ...
# 2  1. 판매ㆍ공급계약 내용: 방위사업청 공급계약 (리튬전지류 및 기뢰정비장비용 전지조...
# 3  1. 판매ㆍ공급계약 내용: 방위사업청 공급계약 (리튬전지류 및 기뢰정비장비용 전지조...
# 4  1. 투자구분: 신규시설투자\n- 투자대상: 2차전지 캔 신공장 신축공사\n2. 투...
#
#                                           detail_url  \
# 0  https://kind.krx.co.kr/common/disclsviewer.do?...
# 1  https://kind.krx.co.kr/common/disclsviewer.do?...
# 2  https://kind.krx.co.kr/common/disclsviewer.do?...
# 3  https://kind.krx.co.kr/common/disclsviewer.do?...
# 4  https://kind.krx.co.kr/common/disclsviewer.do?...
#
#                   created_at                 updated_at  is_modify  \
# 0 2025-10-20 06:55:14.045559 2025-10-28 02:53:39.321648          0
# 1 2025-10-20 06:55:14.045559 2025-10-28 02:53:39.321648          0
# 2 2025-10-20 06:55:14.045559 2025-10-28 02:53:39.321648          0
# 3 2025-10-20 06:55:14.045559 2025-10-28 02:53:39.321648          0
# 4 2025-10-20 06:55:14.045559 2025-10-28 02:53:39.321648          0
#
#       disclosure_type dart_unique_id  \
# 0            임상 계획 신청
# 1  타법인 주식 및 출자증권 양수결정
# 2         단일판매ㆍ공급계약체결
# 3         단일판매ㆍ공급계약체결
# 4              신규시설투자
#
#                                               masked  label
# 0  이 임상2상 시험은 코로나19 환자에서 회사 A의 유효성과 안전성을 평가하기 위해 ...     -1
# 1  회사 A는 2022년 7월 1일 이차전지 사업의 핵심기술 확보를 위해 20,000주...      1
# 2  회사 A는 방위사업청과 15,107,298,910원 규모의 리튬전지류 및 기뢰정비장...      1
# 3  해당 기업은 방위사업청과 2022년 6월에 공급계약을 체결하여 전지조립체를 공급했으...      0
# 4  이 기업은 충청남도 아산시에 위치한 2차전지 캔 신공장 건설을 위해 약 585억 원...      0

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm


# market 종류와 각각의 비율 분석
market_counts = df['market'].value_counts()
print("시장별 공시 분포:")
print(market_counts)
print(f"\n총 공시 건수: {len(df)}")
print("\n시장별 비율:")
for market, count in market_counts.items():
    ratio = count / len(df) * 100
    print(f"{market}: {count}건 ({ratio:.1f}%)")

# 시각화
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# 막대 그래프
market_counts.plot(kind='bar', ax=ax1, color=['skyblue', 'lightcoral'])
ax1.set_title('Disclosure Distribution by Market', fontsize=14, pad=20)
ax1.set_xlabel('Market', fontsize=12)
ax1.set_ylabel('Number of Disclosures', fontsize=12)
ax1.tick_params(axis='x', rotation=45)

# 각 막대 위에 값 표시
for i, v in enumerate(market_counts.values):
    ax1.text(i, v + len(df)*0.01, str(v), ha='center', va='bottom', fontsize=11)

# 파이 차트
market_ratios = market_counts / len(df) * 100
ax2.pie(market_ratios.values, labels=market_ratios.index, autopct='%1.1f%%', 
        startangle=90, colors=['skyblue', 'lightcoral', 'lightgreen'])
ax2.set_title('Disclosure Distribution by Market', fontsize=14, pad=20)

plt.tight_layout()
plt.show()
# Out:
# 시장별 공시 분포:
# market
# KOSDAQ    5753
# KOSPI     4055
# Name: count, dtype: int64
#
# 총 공시 건수: 9808
#
# 시장별 비율:
# KOSDAQ: 5753건 (58.7%)
# KOSPI: 4055건 (41.3%)

# %%
# disclosed_at을 datetime으로 변환 (이미 KST 기준으로 저장됨)
df['disclosed_at'] = pd.to_datetime(df['disclosed_at'])

# 이미 KST 기준이므로 그대로 사용
df['disclosed_at_kst'] = df['disclosed_at']
df = df.sort_values('disclosed_at_kst')
df['time_only'] = df['disclosed_at_kst'].dt.time

# 장중 시간 정의 (9:00 ~ 15:20) - KST 기준
import datetime
market_open = datetime.time(9, 0)
market_close = datetime.time(15, 20)

# 장중/장외 분류
df['market_session'] = df['time_only'].apply(
    lambda x: 'Trading Hours' if market_open <= x <= market_close else 'After Hours'
)

# 결과 집계
session_counts = df['market_session'].value_counts()
print("공시 발표 시간대별 분포 (KST 기준):")
print(session_counts)
print(f"\n장중 비율: {session_counts.get('Trading Hours', 0) / len(df) * 100:.1f}%")
print(f"장외 비율: {session_counts.get('After Hours', 0) / len(df) * 100:.1f}%")

# 시각화
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# 막대 그래프
session_counts.plot(kind='bar', ax=ax1, color=['lightblue', 'lightcoral'])
ax1.set_title('Disclosure Distribution by Trading Session (KST)', fontsize=14, pad=20)
ax1.set_xlabel('Trading Session', fontsize=12)
ax1.set_ylabel('Number of Disclosures', fontsize=12)
ax1.tick_params(axis='x', rotation=45)

# 각 막대 위에 값 표시
for i, v in enumerate(session_counts.values):
    ax1.text(i, v + len(df)*0.01, str(v), ha='center', va='bottom', fontsize=11)

# 파이 차트
session_ratios = session_counts / len(df) * 100
ax2.pie(session_ratios.values, labels=session_ratios.index, autopct='%1.1f%%', 
        startangle=90, colors=['lightblue', 'lightcoral'])
ax2.set_title('Disclosure Distribution by Trading Session (KST)', fontsize=14, pad=20)

plt.tight_layout()
plt.show()

plt.tight_layout()
plt.show()
# Out:
# 공시 발표 시간대별 분포 (KST 기준):
# market_session
# After Hours      5944
# Trading Hours    3864
# Name: count, dtype: int64
#
# 장중 비율: 39.4%
# 장외 비율: 60.6%

# %%
import pandas as pd
from datetime import datetime

TABLE = "abnormal_return_kind_log"
# abnormal return 컬럼
abn_return_cols = (
    [f"abn_ret_minus_{i}m" for i in range(59, 0, -1)] +
    ["abn_ret_0m"] +
    [f"abn_ret_{i}m" for i in range(1, 61)]
)

# abn_return_cols를 쿼리 내에서 컬럼명 문자열로 변환
abn_return_col_str = ",\n    ".join(abn_return_cols)

query = f"""
SELECT ar.event_id,
    ar.event_ts,
    {abn_return_col_str},
    k.company_name,
    k.disclosure_type,
    k.masked,
    k.label
FROM {TABLE} ar
JOIN "kind" k ON ar.event_id = k.id
WHERE k.disclosed_at >= '{start_date.strftime('%Y-%m-%d')}'
  AND k.disclosed_at <= '{end_date.strftime('%Y-%m-%d')}'
ORDER BY k.disclosed_at ASC
"""

target_df = pd.read_sql(query, engine)
target_df
# Out:
#       event_id                  event_ts  abn_ret_minus_59m  \
# 0       325691 2022-07-01 10:03:00+00:00          -0.007148
# 1       325686 2022-07-01 10:24:00+00:00           0.000476
# 2       325685 2022-07-01 10:26:00+00:00           0.002865
# 3       325676 2022-07-01 10:43:00+00:00          -0.000162
# 4       325672 2022-07-01 11:03:00+00:00           0.000968
# ...        ...                       ...                ...
# 3579    375890 2023-12-28 14:46:00+00:00          -0.000361
# 3580    375886 2023-12-28 14:53:00+00:00          -0.000883
# 3581    375978 2023-12-28 14:56:00+00:00           0.000279
# 3582    375977 2023-12-28 14:56:00+00:00           0.000279
# 3583    375966 2023-12-28 15:10:00+00:00          -0.001788
#
#       abn_ret_minus_58m  abn_ret_minus_57m  abn_ret_minus_56m  \
# 0             -0.005285           0.000471          -0.012082
# 1              0.000476          -0.007229          -0.000477
# 2             -0.000477          -0.002379           0.000009
# 3             -0.001130          -0.000968           0.000322
# 4              0.002677          -0.000773          -0.001581
# ...                 ...                ...                ...
# 3579           0.000000          -0.000946           0.000585
# 3580           0.000139          -0.003026          -0.000327
# 3581          -0.000418          -0.000418          -0.000279
# 3582          -0.000418          -0.000418          -0.000279
# 3583           0.000000          -0.000139           0.000000
#
#       abn_ret_minus_55m  abn_ret_minus_54m  abn_ret_minus_53m  \
# 0              0.008214          -0.002471           0.000944
# 1             -0.002379          -0.001425          -0.000949
# 2              0.003340           0.002373          -0.000476
# 3             -0.000967          -0.000644           0.000161
# 4             -0.000484          -0.001068           0.000162
# ...                 ...                ...                ...
# 3579           0.000361          -0.000721           0.001305
# 3580          -0.000418          -0.001025          -0.000279
# 3581           0.004040           0.000139          -0.002226
# 3582           0.004040           0.000139          -0.002226
# 3583           0.001788          -0.000278           0.000000
#
#       abn_ret_minus_52m  ...  abn_ret_55m  abn_ret_56m  abn_ret_57m  \
# 0             -0.006312  ...     0.000000    -0.001969     0.007349
# 1              0.008139  ...    -0.000965     0.000483    -0.000965
# 2             -0.002376  ...    -0.002390     0.001931    -0.000483
# 3             -0.003180  ...     0.002006     0.000326    -0.000489
# 4             -0.001101  ...    -0.000490     0.001876    -0.001264
# ...                 ...  ...          ...          ...          ...
# 3579          -0.002251  ...          NaN          NaN          NaN
# 3580          -0.000418  ...          NaN          NaN          NaN
# 3581           0.005926  ...          NaN          NaN          NaN
# 3582           0.005926  ...          NaN          NaN          NaN
# 3583          -0.000278  ...          NaN          NaN          NaN
#
#       abn_ret_58m  abn_ret_59m  abn_ret_60m  company_name     disclosure_type  \
# 0       -0.000450     0.004910    -0.000482         강원에너지  타법인 주식 및 출자증권 양수결정
# 1        0.001931    -0.000483    -0.000483          비츠로셀         단일판매ㆍ공급계약체결
# 2       -0.000483     0.000483    -0.000483         비츠로테크         단일판매ㆍ공급계약체결
# 3       -0.001517    -0.000163     0.000815        동원시스템즈              신규시설투자
# 4        0.000000    -0.001428     0.000163        HD현대미포         단일판매ㆍ공급계약체결
# ...           ...          ...          ...           ...                 ...
# 3579          NaN          NaN          NaN        윤성에프앤씨         단일판매ㆍ공급계약체결
# 3580          NaN          NaN          NaN         까뮤이앤씨         단일판매ㆍ공급계약체결
# 3581          NaN          NaN          NaN            한창     주권 관련 사채권 양수 결정
# 3582          NaN          NaN          NaN            한창     주권 관련 사채권 양수 결정
# 3583          NaN          NaN          NaN          대원화성                영업정지
#
#                                                  masked  label
# 0     회사 A는 2022년 7월 1일 이차전지 사업의 핵심기술 확보를 위해 20,000주...      1
# 1     회사 A는 방위사업청과 15,107,298,910원 규모의 리튬전지류 및 기뢰정비장...      1
# 2     해당 기업은 방위사업청과 2022년 6월에 공급계약을 체결하여 전지조립체를 공급했으...      0
# 3     이 기업은 충청남도 아산시에 위치한 2차전지 캔 신공장 건설을 위해 약 585억 원...      0
# 4     이 회사 A는 오세아니아의 선주와 LPG선 1척 공급 계약을 체결했으며, 계약금액은...      1
# ...                                                 ...    ...
# 3579  이 회사는 2차전지 믹싱시스템 공급을 위한 계약을 2023년 12월 27일에 체결하...      1
# 3580  이 회사는 전라남도 목포시에서 진행 중인 수산식품 수출단지 조성 건축공사 수주 계약...      1
# 3581  회사 A는 2023년 12월 28일 13회차 전환사채를 취득했으며, 이는 종속회사인...      0
# 3582  회사 A는 2023년 12월 28일에 16회차 무기명식 이권부 무보증 사모 전환사채...      0
# 3583  회사 A는 수익구조 악화로 인해 벽지사업부문을 2023년 12월 28일부로 중단하며...     -1
#
# [3584 rows x 126 columns]

# %%
for m in range(1, 11):
    plus_cols = [
        f"abn_ret_minus_{abs(i)}m" if i < 0 else f"abn_ret_{i}m"
        for i in range(-m+1, m + 1)
    ]
    target_df[f"CAR_{m}m"] = target_df[plus_cols].sum(axis=1)

# %%
for m in range(10, 61, 10):
    plus_cols = [
        f"abn_ret_minus_{abs(i)}m" if i < 0 else f"abn_ret_{i}m"
        for i in range(-m+1, m + 1)
    ]
    target_df[f"CAR_{m}m"] = target_df[plus_cols].sum(axis=1)

# %%
print("\n=== 기본 데이터 분석 ===")

# 컬럼 정보
print(f"컬럼 수: {len(target_df.columns)}")
print(f"컬럼명: {list(target_df.columns)}")

# 데이터 타입
print("\n데이터 타입:")
print(target_df.dtypes)

# 결측값 확인
print("\n결측값 현황:")
print(target_df.isnull().sum())
# Out:
# === 기본 데이터 분석 ===
# 컬럼 수: 141
# 컬럼명: ['event_id', 'event_ts', 'abn_ret_minus_59m', 'abn_ret_minus_58m', 'abn_ret_minus_57m', 'abn_ret_minus_56m', 'abn_ret_minus_55m', 'abn_ret_minus_54m', 'abn_ret_minus_53m', 'abn_ret_minus_52m', 'abn_ret_minus_51m', 'abn_ret_minus_50m', 'abn_ret_minus_49m', 'abn_ret_minus_48m', 'abn_ret_minus_47m', 'abn_ret_minus_46m', 'abn_ret_minus_45m', 'abn_ret_minus_44m', 'abn_ret_minus_43m', 'abn_ret_minus_42m', 'abn_ret_minus_41m', 'abn_ret_minus_40m', 'abn_ret_minus_39m', 'abn_ret_minus_38m', 'abn_ret_minus_37m', 'abn_ret_minus_36m', 'abn_ret_minus_35m', 'abn_ret_minus_34m', 'abn_ret_minus_33m', 'abn_ret_minus_32m', 'abn_ret_minus_31m', 'abn_ret_minus_30m', 'abn_ret_minus_29m', 'abn_ret_minus_28m', 'abn_ret_minus_27m', 'abn_ret_minus_26m', 'abn_ret_minus_25m', 'abn_ret_minus_24m', 'abn_ret_minus_23m', 'abn_ret_minus_22m', 'abn_ret_minus_21m', 'abn_ret_minus_20m', 'abn_ret_minus_19m', 'abn_ret_minus_18m', 'abn_ret_minus_17m', 'abn_ret_minus_16m', 'abn_ret_minus_15m', 'abn_ret_minus_14m', 'abn_ret_minus_13m', 'abn_ret_minus_12m', 'abn_ret_minus_11m', 'abn_ret_minus_10m', 'abn_ret_minus_9m', 'abn_ret_minus_8m', 'abn_ret_minus_7m', 'abn_ret_minus_6m', 'abn_ret_minus_5m', 'abn_ret_minus_4m', 'abn_ret_minus_3m', 'abn_ret_minus_2m', 'abn_ret_minus_1m', 'abn_ret_0m', 'abn_ret_1m', 'abn_ret_2m', 'abn_ret_3m', 'abn_ret_4m', 'abn_ret_5m', 'abn_ret_6m', 'abn_ret_7m', 'abn_ret_8m', 'abn_ret_9m', 'abn_ret_10m', 'abn_ret_11m', 'abn_ret_12m', 'abn_ret_13m', 'abn_ret_14m', 'abn_ret_15m', 'abn_ret_16m', 'abn_ret_17m', 'abn_ret_18m', 'abn_ret_19m', 'abn_ret_20m', 'abn_ret_21m', 'abn_ret_22m', 'abn_ret_23m', 'abn_ret_24m', 'abn_ret_25m', 'abn_ret_26m', 'abn_ret_27m', 'abn_ret_28m', 'abn_ret_29m', 'abn_ret_30m', 'abn_ret_31m', 'abn_ret_32m', 'abn_ret_33m', 'abn_ret_34m', 'abn_ret_35m', 'abn_ret_36m', 'abn_ret_37m', 'abn_ret_38m', 'abn_ret_39m', 'abn_ret_40m', 'abn_ret_41m', 'abn_ret_42m', 'abn_ret_43m', 'abn_ret_44m', 'abn_ret_45m', 'abn_ret_46m', 'abn_ret_47m', 'abn_ret_48m', 'abn_ret_49m', 'abn_ret_50m', 'abn_ret_51m', 'abn_ret_52m', 'abn_ret_53m', 'abn_ret_54m', 'abn_ret_55m', 'abn_ret_56m', 'abn_ret_57m', 'abn_ret_58m', 'abn_ret_59m', 'abn_ret_60m', 'company_name', 'disclosure_type', 'masked', 'label', 'CAR_1m', 'CAR_2m', 'CAR_3m', 'CAR_4m', 'CAR_5m', 'CAR_6m', 'CAR_7m', 'CAR_8m', 'CAR_9m', 'CAR_10m', 'CAR_20m', 'CAR_30m', 'CAR_40m', 'CAR_50m', 'CAR_60m']
#
# 데이터 타입:
# event_id                           int64
# event_ts             datetime64[ns, UTC]
# abn_ret_minus_59m                float64
# abn_ret_minus_58m                float64
# abn_ret_minus_57m                float64
#                             ...
# CAR_20m                          float64
# CAR_30m                          float64
# CAR_40m                          float64
# CAR_50m                          float64
# CAR_60m                          float64
# Length: 141, dtype: object
#
# 결측값 현황:
# event_id               0
# event_ts               0
# abn_ret_minus_59m    331
# abn_ret_minus_58m    325
# abn_ret_minus_57m    316
#                     ...
# CAR_20m                0
# CAR_30m                0
# CAR_40m                0
# CAR_50m                0
# CAR_60m                0
# Length: 141, dtype: int64

# %%
car_cols = [f'CAR_{m}m' for m in range(10, 61, 10)]
target_df[car_cols].describe().round(4)
# Out:
#          CAR_10m    CAR_20m    CAR_30m    CAR_40m    CAR_50m    CAR_60m
# count  3584.0000  3584.0000  3584.0000  3584.0000  3584.0000  3584.0000
# mean      0.0094     0.0090     0.0088     0.0105     0.0099     0.0096
# std       0.0247     0.0249     0.0256     0.0308     0.0325     0.0327
# min      -0.1309    -0.1608    -0.2359    -0.2576    -0.2649    -0.2542
# 25%      -0.0006    -0.0014    -0.0017    -0.0018    -0.0026    -0.0033
# 50%       0.0042     0.0044     0.0043     0.0050     0.0049     0.0047
# 75%       0.0131     0.0138     0.0142     0.0154     0.0162     0.0161
# max       0.2582     0.2831     0.2841     0.2821     0.2886     0.2949

# %%
car_cols = [f'CAR_{m}m' for m in range(1, 11)]
target_df[car_cols].describe().round(4)
# Out:
#           CAR_1m     CAR_2m     CAR_3m     CAR_4m     CAR_5m     CAR_6m  \
# count  3584.0000  3584.0000  3584.0000  3584.0000  3584.0000  3584.0000
# mean      0.0123     0.0119     0.0115     0.0110     0.0105     0.0100
# std       0.0224     0.0240     0.0251     0.0257     0.0254     0.0252
# min      -0.0860    -0.0763    -0.0896    -0.1047    -0.1085    -0.1391
# 25%       0.0003     0.0004     0.0002     0.0000     0.0000    -0.0000
# 50%       0.0047     0.0048     0.0050     0.0046     0.0045     0.0044
# 75%       0.0146     0.0136     0.0137     0.0135     0.0129     0.0127
# max       0.1594     0.2590     0.2401     0.2466     0.2474     0.2470
#
#           CAR_7m     CAR_8m     CAR_9m    CAR_10m
# count  3584.0000  3584.0000  3584.0000  3584.0000
# mean      0.0096     0.0095     0.0095     0.0094
# std       0.0246     0.0242     0.0245     0.0247
# min      -0.1284    -0.1237    -0.1389    -0.1309
# 25%      -0.0004    -0.0004    -0.0005    -0.0006
# 50%       0.0043     0.0044     0.0043     0.0042
# 75%       0.0127     0.0127     0.0129     0.0131
# max       0.2590     0.2587     0.2585     0.2582

# %%
target_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3584 entries, 0 to 3583
# Columns: 141 entries, event_id to CAR_60m
# dtypes: datetime64[ns, UTC](1), float64(135), int64(2), object(3)
# memory usage: 3.9+ MB

# %%
ret_columns = [
    "abn_ret_minus_60m", "abn_ret_minus_50m", "abn_ret_minus_40m",
    "abn_ret_minus_30m", "abn_ret_minus_20m", "abn_ret_minus_10m",
    "abn_ret_10m", "abn_ret_20m", "abn_ret_30m",
    "abn_ret_40m", "abn_ret_50m", "abn_ret_60m"
]

# %%
target_df['disclosure_type'].value_counts()
# Out:
# disclosure_type
# 단일판매ㆍ공급계약체결           1465
# 매출액변동                  609
# 자기주식취득 신탁계약 체결 결정      216
# 타법인 주식 및 출자증권 양수결정     199
# 자기주식 취득 결정             130
# 특허권취득                  116
# 자기주식 처분 결정              98
# 신규시설투자                  87
# 자기주식 소각 결정              72
# 자기주식취득 신탁계약 해지 결정       66
# 무상증자 결정                 61
# 임상 계획 신청                58
# 유상증자 결정                 54
# 임상 계획 승인                48
# 전환사채권 발행결정              45
# 회사합병 결정                 43
# 타법인 주식 및 출자증권 양도결정      39
# 유형자산 양수 결정              38
# 유형자산 양도 결정              27
# 생산중단                    23
# 임상 계획 결과 발표             11
# 품목허가 신청                 10
# 단일판매ㆍ공급계약해지             10
# 회사분할 결정                  8
# 주권 관련 사채권 양수 결정          8
# 상각형 조건부자본증권 발행결정         7
# 교환사채권 발행결정               6
# 감자 결정                    5
# 소송 등의 제기                 4
# 품목허가 승인                  4
# 기술이전계약체결                 4
# 임상 계획 철회                 4
# 품목허가 철회                  3
# 주권 관련 사채권 양도 결정          2
# 횡령ㆍ배임혐의발생                2
# 자산양수도(기타), 풋백옵션          1
# 영업정지                     1
# Name: count, dtype: int64

# %%
# config.py의 keywords 딕셔너리를 사용해서 한글-영어 카테고리 매핑 생성
category_mapping = {
    # 임상 관련
    "임상 계획 철회": "Clinical Trial Withdrawal",
    "임상 계획 신청": "Clinical Trial Application", 
    "임상 계획 승인": "Clinical Trial Approval",
    "임상 계획 결과 발표": "Clinical Trial Results",
    
    # 자산 관련
    "자산양수도(기타), 풋백옵션": "Asset Transfer & Putback Option",
    
    # 경영 관련
    "부도발생": "Default Occurrence",
    "영업정지": "Business Suspension", 
    "회생절차 개시신청": "Rehabilitation Procedure Initiation",
    "해산사유 발생": "Dissolution Cause Occurrence",
    
    # 자본 변동
    "유상증자 결정": "Paid-in Capital Increase Decision",
    "무상증자 결정": "Free Capital Increase Decision", 
    "유무상증자 결정": "Paid/Free Capital Increase Decision",
    "감자 결정": "Capital Reduction Decision",
    "주식분할 결정": "Stock Split Decision",
    
    # 금융 관련
    "채권은행 등의 관리절차 개시": "Creditor Bank Management Procedure Initiation",
    "채권은행 등의 관리절차 중단": "Creditor Bank Management Procedure Suspension",
    
    # 소송/분쟁
    "소송 등의 제기": "Litigation Filing",
    "소송등의판결ㆍ결정": "Litigation Judgment/Decision",
    
    # 해외 상장
    "해외 증권시장 주권등 상장 결정": "Overseas Securities Market Listing Decision",
    "해외 증권시장 주권등 상장폐지 결정": "Overseas Securities Market Delisting Decision", 
    "해외 증권시장 주권등 상장": "Overseas Securities Market Listing",
    "해외 증권시장 주권등 상장폐지": "Overseas Securities Market Delisting",
    
    # 채권 발행
    "전환사채권 발행결정": "Convertible Bond Issuance Decision",
    "신주인수권부사채권 발행결정": "Bond with Warrant Issuance Decision",
    "교환사채권 발행결정": "Exchangeable Bond Issuance Decision",
    "상각형 조건부자본증권 발행결정": "Contingent Convertible Security Issuance Decision",
    
    # 자사주 관련
    "자기주식 취득 결정": "Treasury Stock Acquisition Decision",
    "자기주식 처분 결정": "Treasury Stock Disposal Decision", 
    "자기주식 소각 결정": "Treasury Stock Retirement Decision",
    "자기주식취득 신탁계약 체결 결정": "Treasury Stock Acquisition Trust Contract Decision",
    "자기주식취득 신탁계약 해지 결정": "Treasury Stock Acquisition Trust Contract Termination Decision",
    
    # 영업 양수도
    "영업양수 결정": "Business Acquisition Decision",
    "영업양도 결정": "Business Transfer Decision",
    
    # 자산 취득/처분
    "유형자산 양수 결정": "Tangible Asset Acquisition Decision",
    "유형자산 양도 결정": "Tangible Asset Transfer Decision",
    "타법인 주식 및 출자증권 양수결정": "Other Corporation Stock Acquisition Decision",
    "타법인 주식 및 출자증권 양도결정": "Other Corporation Stock Transfer Decision",
    "주권 관련 사채권 양수 결정": "Stock-related Bond Acquisition Decision",
    "주권 관련 사채권 양도 결정": "Stock-related Bond Transfer Decision",
    
    # 기업 구조 변경
    "회사합병 결정": "Company Merger Decision",
    "회사분할 결정": "Company Spin-off Decision", 
    "회사분할합병 결정": "Company Split-Merger Decision",
    "주식교환ㆍ이전 결정": "Stock Exchange/Transfer Decision",
    
    # 공시 관련
    "지분공시": "Equity Disclosure",
    "실적공시": "Earnings Disclosure",
    
    # 계약 관련
    "단일판매ㆍ공급계약해지": "Single Sales/Supply Contract Termination",
    "단일판매ㆍ공급계약체결": "Single Sales/Supply Contract Execution",
    
    # 기타
    "생산중단": "Production Suspension",
    "배당": "Dividend",
    "매출액변동": "Revenue Change",
    "특허권취득": "Patent Acquisition",
    "신규시설투자": "New Facility Investment",
    "기술이전계약해지": "Technology Transfer Contract Termination",
    "기술이전계약체결": "Technology Transfer Contract Execution",
    
    # 품목허가 관련
    "품목허가 철회": "Product Approval Withdrawal",
    "품목허가 신청": "Product Approval Application",
    "품목허가 승인": "Product Approval",
    
    # 기타
    "횡령ㆍ배임혐의발생": "Embezzlement/Malfeasance Allegation",
    "공개매수": "Public Tender Offer"
}

import pandas as pd
pd.DataFrame(list(category_mapping.items()), columns=["category_kr", "category_en"])
# Out:
#             category_kr                                        category_en
# 0              임상 계획 철회                          Clinical Trial Withdrawal
# 1              임상 계획 신청                         Clinical Trial Application
# 2              임상 계획 승인                            Clinical Trial Approval
# 3           임상 계획 결과 발표                             Clinical Trial Results
# 4       자산양수도(기타), 풋백옵션                    Asset Transfer & Putback Option
# 5                  부도발생                                 Default Occurrence
# 6                  영업정지                                Business Suspension
# 7             회생절차 개시신청                Rehabilitation Procedure Initiation
# 8               해산사유 발생                       Dissolution Cause Occurrence
# 9               유상증자 결정                  Paid-in Capital Increase Decision
# 10              무상증자 결정                     Free Capital Increase Decision
# 11             유무상증자 결정                Paid/Free Capital Increase Decision
# 12                감자 결정                         Capital Reduction Decision
# 13              주식분할 결정                               Stock Split Decision
# 14      채권은행 등의 관리절차 개시      Creditor Bank Management Procedure Initiation
# 15      채권은행 등의 관리절차 중단      Creditor Bank Management Procedure Suspension
# 16             소송 등의 제기                                  Litigation Filing
# 17            소송등의판결ㆍ결정                       Litigation Judgment/Decision
# 18    해외 증권시장 주권등 상장 결정        Overseas Securities Market Listing Decision
# 19  해외 증권시장 주권등 상장폐지 결정      Overseas Securities Market Delisting Decision
# 20       해외 증권시장 주권등 상장                 Overseas Securities Market Listing
# 21     해외 증권시장 주권등 상장폐지               Overseas Securities Market Delisting
# 22           전환사채권 발행결정                 Convertible Bond Issuance Decision
# 23       신주인수권부사채권 발행결정                Bond with Warrant Issuance Decision
# 24           교환사채권 발행결정                Exchangeable Bond Issuance Decision
# 25     상각형 조건부자본증권 발행결정  Contingent Convertible Security Issuance Decision
# 26           자기주식 취득 결정                Treasury Stock Acquisition Decision
# 27           자기주식 처분 결정                   Treasury Stock Disposal Decision
# 28           자기주식 소각 결정                 Treasury Stock Retirement Decision
# 29    자기주식취득 신탁계약 체결 결정  Treasury Stock Acquisition Trust Contract Deci...
# 30    자기주식취득 신탁계약 해지 결정  Treasury Stock Acquisition Trust Contract Term...
# 31              영업양수 결정                      Business Acquisition Decision
# 32              영업양도 결정                         Business Transfer Decision
# 33           유형자산 양수 결정                Tangible Asset Acquisition Decision
# 34           유형자산 양도 결정                   Tangible Asset Transfer Decision
# 35   타법인 주식 및 출자증권 양수결정       Other Corporation Stock Acquisition Decision
# 36   타법인 주식 및 출자증권 양도결정          Other Corporation Stock Transfer Decision
# 37      주권 관련 사채권 양수 결정            Stock-related Bond Acquisition Decision
# 38      주권 관련 사채권 양도 결정               Stock-related Bond Transfer Decision
# 39              회사합병 결정                            Company Merger Decision
# 40              회사분할 결정                          Company Spin-off Decision
# 41            회사분할합병 결정                      Company Split-Merger Decision
# 42           주식교환ㆍ이전 결정                   Stock Exchange/Transfer Decision
# 43                 지분공시                                  Equity Disclosure
# 44                 실적공시                                Earnings Disclosure
# 45          단일판매ㆍ공급계약해지           Single Sales/Supply Contract Termination
# 46          단일판매ㆍ공급계약체결             Single Sales/Supply Contract Execution
# 47                 생산중단                              Production Suspension
# 48                   배당                                           Dividend
# 49                매출액변동                                     Revenue Change
# 50                특허권취득                                 Patent Acquisition
# 51               신규시설투자                            New Facility Investment
# 52             기술이전계약해지           Technology Transfer Contract Termination
# 53             기술이전계약체결             Technology Transfer Contract Execution
# 54              품목허가 철회                        Product Approval Withdrawal
# 55              품목허가 신청                       Product Approval Application
# 56              품목허가 승인                                   Product Approval
# 57            횡령ㆍ배임혐의발생                Embezzlement/Malfeasance Allegation
# 58                 공개매수                                Public Tender Offer

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from config import keywords



df_with_returns = target_df.copy()
category_counts = df_with_returns['disclosure_type'].value_counts()

# 카테고리별 건수 시각화
plt.figure(figsize=(15, 8))
category_counts_sorted = category_counts.sort_values(ascending=False)

# 한글 카테고리를 영어로 매핑
category_counts_sorted_en = category_counts_sorted.copy()
category_counts_sorted_en.index = [category_mapping.get(cat, cat) for cat in category_counts_sorted_en.index]

plt.subplot(1, 2, 1)
plt.bar(range(len(category_counts_sorted_en)), category_counts_sorted_en.values)
plt.title('Disclosure Count by Category')
plt.xlabel('Category')
plt.ylabel('Count')
plt.xticks(range(len(category_counts_sorted_en)), category_counts_sorted_en.index, rotation=45, ha='right')

# 상위 15 카테고리만 별도 표시
plt.subplot(1, 2, 2)
top_15 = category_counts_sorted_en.head(15)
plt.bar(range(len(top_15)), top_15.values)
plt.title('Top 15 Disclosure Categories by Count')
plt.xlabel('Category')
plt.ylabel('Count')
plt.xticks(range(len(top_15)), top_15.index, rotation=45, ha='right')

plt.tight_layout()
plt.show()

print(f"총 {len(category_counts)}개 카테고리, 총 {category_counts.sum()}건의 공시")
print("\n상위 15개 카테고리:")
print(category_counts_sorted.head(15))
# Out:
# 총 37개 카테고리, 총 3584건의 공시
#
# 상위 15개 카테고리:
# disclosure_type
# 단일판매ㆍ공급계약체결           1465
# 매출액변동                  609
# 자기주식취득 신탁계약 체결 결정      216
# 타법인 주식 및 출자증권 양수결정     199
# 자기주식 취득 결정             130
# 특허권취득                  116
# 자기주식 처분 결정              98
# 신규시설투자                  87
# 자기주식 소각 결정              72
# 자기주식취득 신탁계약 해지 결정       66
# 무상증자 결정                 61
# 임상 계획 신청                58
# 유상증자 결정                 54
# 임상 계획 승인                48
# 전환사채권 발행결정              45
# Name: count, dtype: int64

# %%
# category_mapping의 순서를 지키기 위해 OrderedDict의 순서를 따른다
import pandas as pd

# 각 카테고리가 몇 건씩 있는지 계산
category_counts = df_with_returns['disclosure_type'].value_counts()

category_df = pd.DataFrame([
    {
        "category_kr": cat, 
        "category_en": category_mapping[cat],
        "observations": category_counts.get(cat, 0)
    }
    for cat in category_mapping.keys()
    if cat in df_with_returns['disclosure_type'].unique()
])

category_df = category_df.sort_values("observations", ascending=False)
display(category_df)
# Out:
#            category_kr                                        category_en  \
# 27         단일판매ㆍ공급계약체결             Single Sales/Supply Contract Execution
# 29               매출액변동                                     Revenue Change
# 16   자기주식취득 신탁계약 체결 결정  Treasury Stock Acquisition Trust Contract Deci...
# 20  타법인 주식 및 출자증권 양수결정       Other Corporation Stock Acquisition Decision
# 13          자기주식 취득 결정                Treasury Stock Acquisition Decision
# 30               특허권취득                                 Patent Acquisition
# 14          자기주식 처분 결정                   Treasury Stock Disposal Decision
# 31              신규시설투자                            New Facility Investment
# 15          자기주식 소각 결정                 Treasury Stock Retirement Decision
# 17   자기주식취득 신탁계약 해지 결정  Treasury Stock Acquisition Trust Contract Term...
# 7              무상증자 결정                     Free Capital Increase Decision
# 1             임상 계획 신청                         Clinical Trial Application
# 6              유상증자 결정                  Paid-in Capital Increase Decision
# 2             임상 계획 승인                            Clinical Trial Approval
# 10          전환사채권 발행결정                 Convertible Bond Issuance Decision
# 24             회사합병 결정                            Company Merger Decision
# 21  타법인 주식 및 출자증권 양도결정          Other Corporation Stock Transfer Decision
# 18          유형자산 양수 결정                Tangible Asset Acquisition Decision
# 19          유형자산 양도 결정                   Tangible Asset Transfer Decision
# 28                생산중단                              Production Suspension
# 3          임상 계획 결과 발표                             Clinical Trial Results
# 34             품목허가 신청                       Product Approval Application
# 26         단일판매ㆍ공급계약해지           Single Sales/Supply Contract Termination
# 22     주권 관련 사채권 양수 결정            Stock-related Bond Acquisition Decision
# 25             회사분할 결정                          Company Spin-off Decision
# 12    상각형 조건부자본증권 발행결정  Contingent Convertible Security Issuance Decision
# 11          교환사채권 발행결정                Exchangeable Bond Issuance Decision
# 8                감자 결정                         Capital Reduction Decision
# 35             품목허가 승인                                   Product Approval
# 32            기술이전계약체결             Technology Transfer Contract Execution
# 0             임상 계획 철회                          Clinical Trial Withdrawal
# 9             소송 등의 제기                                  Litigation Filing
# 33             품목허가 철회                        Product Approval Withdrawal
# 23     주권 관련 사채권 양도 결정               Stock-related Bond Transfer Decision
# 36           횡령ㆍ배임혐의발생                Embezzlement/Malfeasance Allegation
# 5                 영업정지                                Business Suspension
# 4      자산양수도(기타), 풋백옵션                    Asset Transfer & Putback Option
#
#     observations
# 27          1465
# 29           609
# 16           216
# 20           199
# 13           130
# 30           116
# 14            98
# 31            87
# 15            72
# 17            66
# 7             61
# 1             58
# 6             54
# 2             48
# 10            45
# 24            43
# 21            39
# 18            38
# 19            27
# 28            23
# 3             11
# 34            10
# 26            10
# 22             8
# 25             8
# 12             7
# 11             6
# 8              5
# 35             4
# 32             4
# 0              4
# 9              4
# 33             3
# 23             2
# 36             2
# 5              1
# 4              1

# %%
df_with_returns.isnull().sum()
df_with_returns.describe()
df_with_returns.info()

df_with_returns.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3584 entries, 0 to 3583
# Columns: 141 entries, event_id to CAR_60m
# dtypes: datetime64[ns, UTC](1), float64(135), int64(2), object(3)
# memory usage: 3.9+ MB
#    event_id                  event_ts  abn_ret_minus_59m  abn_ret_minus_58m  \
# 0    325691 2022-07-01 10:03:00+00:00          -0.007148          -0.005285
# 1    325686 2022-07-01 10:24:00+00:00           0.000476           0.000476
# 2    325685 2022-07-01 10:26:00+00:00           0.002865          -0.000477
# 3    325676 2022-07-01 10:43:00+00:00          -0.000162          -0.001130
# 4    325672 2022-07-01 11:03:00+00:00           0.000968           0.002677
#
#    abn_ret_minus_57m  abn_ret_minus_56m  abn_ret_minus_55m  abn_ret_minus_54m  \
# 0           0.000471          -0.012082           0.008214          -0.002471
# 1          -0.007229          -0.000477          -0.002379          -0.001425
# 2          -0.002379           0.000009           0.003340           0.002373
# 3          -0.000968           0.000322          -0.000967          -0.000644
# 4          -0.000773          -0.001581          -0.000484          -0.001068
#
#    abn_ret_minus_53m  abn_ret_minus_52m  ...    CAR_6m    CAR_7m    CAR_8m  \
# 0           0.000944          -0.006312  ... -0.000950 -0.008553 -0.004737
# 1          -0.000949           0.008139  ...  0.017700  0.015332  0.019134
# 2          -0.000476          -0.002376  ... -0.001933 -0.002421 -0.003380
# 3           0.000161          -0.003180  ...  0.017782  0.012287  0.018564
# 4           0.000162          -0.001101  ...  0.000285  0.001671  0.000899
#
#      CAR_9m   CAR_10m   CAR_20m   CAR_30m   CAR_40m   CAR_50m   CAR_60m
# 0 -0.001476  0.005192 -0.008342 -0.003640  0.009501 -0.007204 -0.008546
# 1  0.015332  0.021047  0.040364  0.030922  0.029071  0.039132  0.031948
# 2 -0.000979  0.000474 -0.004271  0.006729  0.024854  0.021497  0.021057
# 3  0.009611  0.009698  0.012785  0.011305  0.009232  0.003966  0.000721
# 4  0.001384 -0.000201  0.002646  0.008496  0.010007  0.009466  0.007764
#
# [5 rows x 141 columns]

# %%
df_with_returns['label'].value_counts()
# Out:
# label
#  1    2251
#  0    1041
# -1     292
# Name: count, dtype: int64

# %% [markdown]
# # AI Inference

# %%
# label 비율 시각화
plt.figure(figsize=(6, 6))

# label 비율 계산
label_counts = df_with_returns['label'].value_counts()
label_ratios = (label_counts / len(df_with_returns) * 100).round(2)

# 색상 매핑 (라벨 순서에 맞게)
colors = ['#2E8B57', '#A9A9A9', '#DC143C']  # 1: positive(초록), 0: neutral(회색), -1: negative(빨강)

# x축 라벨 설정: 1=Positive(초록), 0=Neutral(회색), -1=Negative(빨강)
label_order = [1, 0, -1]
label_names = ['Positive (1)', 'Neutral (0)', 'Negative (-1)']

# 막대 그래프 생성
bars = plt.bar(range(len(label_order)), [label_ratios.get(l, 0) for l in label_order], color=colors)

# 막대 위에 비율 표시
for i, label in enumerate(label_order):
    if label in label_counts:
        ratio = label_ratios[label]
        count = label_counts[label]
        plt.text(i, ratio + 0.5, f'{ratio}%\n({count:,})',
                 ha='center', va='bottom', fontsize=11)

plt.title('AI Sentiment Analysis Label Distribution', fontsize=16, pad=20)
plt.xlabel('Sentiment Label', fontsize=12)
plt.ylabel('ratio (%)', fontsize=12)
plt.ylim(0, max(label_ratios.values) * 1.15)

plt.xticks(range(len(label_order)), label_names)
plt.grid(axis='y', alpha=0.3, linestyle='--')

plt.tight_layout()
plt.show()

print("=== AI Sentiment Analysis Label Distribution ===")
for i, label in enumerate(label_order):
    if label in label_counts:
        count = label_counts[label]
        ratio = label_ratios[label]
        print(f"{label_names[i].split()[0].lower()}: {count:,}건 ({ratio}%)")
# Out:
# === AI Sentiment Analysis Label Distribution ===
# positive: 2,251건 (62.81%)
# neutral: 1,041건 (29.05%)
# negative: 292건 (8.15%)

# %% [markdown]
# # Event Study

# %% [markdown]
# ## 10 minute interval

# %%
df_with_returns = df_with_returns.dropna()

# %%
# SAFER version: only create CAR_event columns for which all referenced abn_ret columns exist.
import numpy as np

df_with_returns["CAR_event_-60"] = 0
for m in range(-59, 61):
    plus_cols = [
        f"abn_ret_minus_{abs(i)}m" if i < 0 else f"abn_ret_{i}m"
        for i in range(-59, m+1)
    ]
    df_with_returns[f"CAR_event_{m}"] = df_with_returns[plus_cols].sum(axis=1)
# Out:
# /var/folders/5r/tdks4c2x5vgdpqkw390mgzqm0000gn/T/ipykernel_64136/2917127618.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_returns[f"CAR_event_{m}"] = df_with_returns[plus_cols].sum(axis=1)
# /var/folders/5r/tdks4c2x5vgdpqkw390mgzqm0000gn/T/ipykernel_64136/2917127618.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_returns[f"CAR_event_{m}"] = df_with_returns[plus_cols].sum(axis=1)
# /var/folders/5r/tdks4c2x5vgdpqkw390mgzqm0000gn/T/ipykernel_64136/2917127618.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_returns[f"CAR_event_{m}"] = df_with_returns[plus_cols].sum(axis=1)
# /var/folders/5r/tdks4c2x5vgdpqkw390mgzqm0000gn/T/ipykernel_64136/2917127618.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_returns[f"CAR_event_{m}"] = df_with_returns[plus_cols].sum(axis=1)
# /var/folders/5r/tdks4c2x5vgdpqkw390mgzqm0000gn/T/ipykernel_64136/2917127618.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_returns[f"CAR_event_{m}"] = df_with_returns[plus_cols].sum(axis=1)
# /var/folders/5r/tdks4c2x5vgdpqkw390mgzqm0000gn/T/ipykernel_64136/2917127618.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_returns[f"CAR_event_{m}"] = df_with_returns[plus_cols].sum(axis=1)
# /var/folders/5r/tdks4c2x5vgdpqkw390mgzqm0000gn/T/ipykernel_64136/2917127618.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_returns[f"CAR_event_{m}"] = df_with_returns[plus_cols].sum(axis=1)
# /var/folders/5r/tdks4c2x5vgdpqkw390mgzqm0000gn/T/ipykernel_64136/2917127618.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_returns[f"CAR_event_{m}"] = df_with_returns[plus_cols].sum(axis=1)
# /var/folders/5r/tdks4c2x5vgdpqkw390mgzqm0000gn/T/ipykernel_64136/2917127618.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_returns[f"CAR_event_{m}"] = df_with_returns[plus_cols].sum(axis=1)
# /var/folders/5r/tdks4c2x5vgdpqkw390mgzqm0000gn/T/ipykernel_64136/2917127618.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_returns[f"CAR_event_{m}"] = df_with_returns[plus_cols].sum(axis=1)
# /var/folders/5r/tdks4c2x5vgdpqkw390mgzqm0000gn/T/ipykernel_64136/2917127618.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_returns[f"CAR_event_{m}"] = df_with_returns[plus_cols].sum(axis=1)
# /var/folders/5r/tdks4c2x5vgdpqkw390mgzqm0000gn/T/ipykernel_64136/2917127618.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_returns[f"CAR_event_{m}"] = df_with_returns[plus_cols].sum(axis=1)
# /var/folders/5r/tdks4c2x5vgdpqkw390mgzqm0000gn/T/ipykernel_64136/2917127618.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_returns[f"CAR_event_{m}"] = df_with_returns[plus_cols].sum(axis=1)
# /var/folders/5r/tdks4c2x5vgdpqkw390mgzqm0000gn/T/ipykernel_64136/2917127618.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_returns[f"CAR_event_{m}"] = df_with_returns[plus_cols].sum(axis=1)
# /var/folders/5r/tdks4c2x5vgdpqkw390mgzqm0000gn/T/ipykernel_64136/2917127618.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_returns[f"CAR_event_{m}"] = df_with_returns[plus_cols].sum(axis=1)
# /var/folders/5r/tdks4c2x5vgdpqkw390mgzqm0000gn/T/ipykernel_64136/2917127618.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_returns[f"CAR_event_{m}"] = df_with_returns[plus_cols].sum(axis=1)
# /var/folders/5r/tdks4c2x5vgdpqkw390mgzqm0000gn/T/ipykernel_64136/2917127618.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_returns[f"CAR_event_{m}"] = df_with_returns[plus_cols].sum(axis=1)
# /var/folders/5r/tdks4c2x5vgdpqkw390mgzqm0000gn/T/ipykernel_64136/2917127618.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_returns[f"CAR_event_{m}"] = df_with_returns[plus_cols].sum(axis=1)
# /var/folders/5r/tdks4c2x5vgdpqkw390mgzqm0000gn/T/ipykernel_64136/2917127618.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_returns[f"CAR_event_{m}"] = df_with_returns[plus_cols].sum(axis=1)
# /var/folders/5r/tdks4c2x5vgdpqkw390mgzqm0000gn/T/ipykernel_64136/2917127618.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_returns[f"CAR_event_{m}"] = df_with_returns[plus_cols].sum(axis=1)
# /var/folders/5r/tdks4c2x5vgdpqkw390mgzqm0000gn/T/ipykernel_64136/2917127618.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_returns[f"CAR_event_{m}"] = df_with_returns[plus_cols].sum(axis=1)
# /var/folders/5r/tdks4c2x5vgdpqkw390mgzqm0000gn/T/ipykernel_64136/2917127618.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_returns[f"CAR_event_{m}"] = df_with_returns[plus_cols].sum(axis=1)
# /var/folders/5r/tdks4c2x5vgdpqkw390mgzqm0000gn/T/ipykernel_64136/2917127618.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_returns[f"CAR_event_{m}"] = df_with_returns[plus_cols].sum(axis=1)
# /var/folders/5r/tdks4c2x5vgdpqkw390mgzqm0000gn/T/ipykernel_64136/2917127618.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_returns[f"CAR_event_{m}"] = df_with_returns[plus_cols].sum(axis=1)

# %%
ret_columns = [
    'CAR_event_-60', 'CAR_event_-50', 'CAR_event_-40',
    'CAR_event_-30', 'CAR_event_-20', 'CAR_event_-10',
    'CAR_event_0',
    'CAR_event_10', 'CAR_event_20', 'CAR_event_30',
    'CAR_event_40', 'CAR_event_50', 'CAR_event_60'
]
df_with_returns[ret_columns].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2255 entries, 0 to 3577
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CAR_event_-60  2255 non-null   int64
#  1   CAR_event_-50  2255 non-null   float64
#  2   CAR_event_-40  2255 non-null   float64
#  3   CAR_event_-30  2255 non-null   float64
#  4   CAR_event_-20  2255 non-null   float64
#  5   CAR_event_-10  2255 non-null   float64
#  6   CAR_event_0    2255 non-null   float64
#  7   CAR_event_10   2255 non-null   float64
#  8   CAR_event_20   2255 non-null   float64
#  9   CAR_event_30   2255 non-null   float64
#  10  CAR_event_40   2255 non-null   float64
#  11  CAR_event_50   2255 non-null   float64
#  12  CAR_event_60   2255 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 246.6 KB

# %%
ret_columns = [
    'CAR_event_-60', 'CAR_event_-50', 'CAR_event_-40',
    'CAR_event_-30', 'CAR_event_-20', 'CAR_event_-10',
    'CAR_event_0',
    'CAR_event_10', 'CAR_event_20', 'CAR_event_30',
    'CAR_event_40', 'CAR_event_50', 'CAR_event_60'
]

print("Mean")
print(df_with_returns.groupby('label')[ret_columns].mean().to_string())

print()
print("Stdandard deviation")
print(df_with_returns.groupby('label')[ret_columns].std().to_string())
# Out:
# Mean
#        CAR_event_-60  CAR_event_-50  CAR_event_-40  CAR_event_-30  CAR_event_-20  CAR_event_-10  CAR_event_0  CAR_event_10  CAR_event_20  CAR_event_30  CAR_event_40  CAR_event_50  CAR_event_60
# label
# -1               0.0       0.000757       0.000459       0.000983       0.001198       0.001622     0.005224      0.003470      0.002981      0.003064      0.000550     -0.000853     -0.001055
#  0               0.0      -0.000561      -0.000751      -0.000665      -0.000379       0.000044     0.013649      0.009061      0.008823      0.008422      0.011258      0.010856      0.010038
#  1               0.0       0.000050       0.000134       0.000341       0.000483       0.000561     0.015993      0.012653      0.011864      0.011667      0.013755      0.013228      0.012838
#
# Stdandard deviation
#        CAR_event_-60  CAR_event_-50  CAR_event_-40  CAR_event_-30  CAR_event_-20  CAR_event_-10  CAR_event_0  CAR_event_10  CAR_event_20  CAR_event_30  CAR_event_40  CAR_event_50  CAR_event_60
# label
# -1               0.0       0.006786       0.008422       0.011999       0.012308       0.013914     0.018089      0.019479      0.019382      0.024041      0.027909      0.034043      0.031253
#  0               0.0       0.007108       0.009963       0.010865       0.013103       0.014562     0.025891      0.026532      0.028168      0.028000      0.032734      0.033290      0.032225
#  1               0.0       0.004965       0.006906       0.008206       0.009448       0.010669     0.023852      0.027913      0.026705      0.027217      0.033769      0.035306      0.035044

# %%
import matplotlib.pyplot as plt
ret_columns = [
    'CAR_event_-60', 'CAR_event_-50', 'CAR_event_-40',
    'CAR_event_-30', 'CAR_event_-20', 'CAR_event_-10',
    'CAR_event_0',
    'CAR_event_10', 'CAR_event_20', 'CAR_event_30',
    'CAR_event_40', 'CAR_event_50', 'CAR_event_60'
]
# Label order, color, and name: Match with frontend plot style
label_order = [1, 0, -1]
# 색깔은 file_context_0에서와 동일하게 (before telegram abnormal return plot)

# 색상 매핑 (라벨 순서에 맞게)
colors = ['#2E8B57', '#A9A9A9', '#DC143C']  # 1: positive(초록), 0: neutral(회색), -1: negative(빨강)

# x축 라벨 설정: 1=Positive(초록), 0=Neutral(회색), -1=Negative(빨강)
label_names = ['Positive (1)', 'Neutral (0)', 'Negative (-1)']

car_time_points = list(range(-60, 1, 10)) + list(range(10, 61, 10))
car_time_labels = ret_columns

plt.figure(figsize=(12, 6))
for label, c, name in zip(label_order, colors, label_names):
    grp = df_with_returns[df_with_returns['label'] == label]
    yvals = grp[car_time_labels].mean()
    # (0,0) 점은 없는 상태로, time_points와 mean만 플롯
    plt.plot(
        car_time_points,
        list(yvals.values),
        label=name,
        color=c,
        marker='o',
        linewidth=2,
        markersize=7
    )

plt.axvline(0, color="#666", linestyle="--", lw=1)
plt.legend(fontsize=13)
plt.xticks(sorted(set(car_time_points + [0])))
plt.xlabel("Minutes from Disclosure", fontsize=13)
plt.ylabel("Mean Event-time CAR", fontsize=13)
plt.title("Event-time CAR by AI Label (After Telegram launched: 2022.7~2023.12)", fontsize=15)
plt.grid(alpha=0.3, linestyle='-')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# 모든 분 포함: -60, -59, ..., 0, 1, ..., 60
ret_columns = [f"CAR_event_{m}" for m in range(-60, 61)]

label_order = [1, 0, -1]
colors = ['#2E8B57', '#A9A9A9', '#DC143C']  # 1: positive(초록), 0: neutral(회색), -1: negative(빨강)
label_names = ['Positive (1)', 'Neutral (0)', 'Negative (-1)']

car_time_points = list(range(-60, 61))
car_time_labels = ret_columns

plt.figure(figsize=(15, 6))
for label, c, name in zip(label_order, colors, label_names):
    grp = df_with_returns[df_with_returns['label'] == label]
    # 혹시 열이 전부 없는 경우 에러 방지: 존재하는 컬럼만 사용
    available_cols = [col for col in car_time_labels if col in grp.columns]
    if len(available_cols) == 0:
        continue
    yvals = grp[available_cols].mean()
    xvals = [int(col.replace("CAR_event_", "")) for col in available_cols]
    plt.plot(
        xvals,
        yvals.values,
        label=name,
        color=c,
        marker='o',
        linewidth=2,
        markersize=4
    )

plt.axvline(0, color="#666", linestyle="--", lw=1)
plt.legend(fontsize=13)
plt.xticks(range(-60, 61, 10))
plt.xlabel("Minutes from Disclosure", fontsize=13)
plt.ylabel("Mean Event-time CAR", fontsize=13)
plt.title("Event-time CAR by AI Label (After Telegram launched: 2022.7~2023.12)", fontsize=15)
plt.grid(alpha=0.3, linestyle='-')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 공시 종류별 감성 분포

# %%
df_with_returns.groupby('disclosure_type')[ret_columns].mean().round(2)
# Out:
#                     CAR_event_-60  CAR_event_-59  CAR_event_-58  \
# disclosure_type
# 감자 결정                         0.0           -0.0            0.0
# 교환사채권 발행결정                    0.0           -0.0            0.0
# 기술이전계약체결                      0.0           -0.0            0.0
# 단일판매ㆍ공급계약체결                   0.0           -0.0           -0.0
# 단일판매ㆍ공급계약해지                   0.0            0.0            0.0
# 매출액변동                         0.0            0.0            0.0
# 무상증자 결정                       0.0            0.0            0.0
# 상각형 조건부자본증권 발행결정              0.0            0.0            0.0
# 생산중단                          0.0            0.0           -0.0
# 소송 등의 제기                      0.0           -0.0           -0.0
# 신규시설투자                        0.0           -0.0           -0.0
# 유상증자 결정                       0.0           -0.0            0.0
# 유형자산 양도 결정                    0.0           -0.0           -0.0
# 유형자산 양수 결정                    0.0            0.0            0.0
# 임상 계획 결과 발표                   0.0            0.0            0.0
# 임상 계획 승인                      0.0            0.0            0.0
# 임상 계획 신청                      0.0           -0.0           -0.0
# 임상 계획 철회                      0.0            0.0            0.0
# 자기주식 소각 결정                    0.0           -0.0           -0.0
# 자기주식 처분 결정                    0.0           -0.0           -0.0
# 자기주식 취득 결정                    0.0            0.0            0.0
# 자기주식취득 신탁계약 체결 결정             0.0            0.0           -0.0
# 자기주식취득 신탁계약 해지 결정             0.0           -0.0           -0.0
# 자산양수도(기타), 풋백옵션               0.0           -0.0            0.0
# 전환사채권 발행결정                    0.0           -0.0           -0.0
# 주권 관련 사채권 양도 결정               0.0           -0.0           -0.0
# 주권 관련 사채권 양수 결정               0.0           -0.0           -0.0
# 타법인 주식 및 출자증권 양도결정            0.0           -0.0           -0.0
# 타법인 주식 및 출자증권 양수결정            0.0           -0.0           -0.0
# 특허권취득                         0.0            0.0           -0.0
# 품목허가 승인                       0.0           -0.0           -0.0
# 품목허가 신청                       0.0           -0.0           -0.0
# 품목허가 철회                       0.0            0.0            0.0
# 회사분할 결정                       0.0           -0.0            0.0
# 회사합병 결정                       0.0            0.0            0.0
# 횡령ㆍ배임혐의발생                     0.0           -0.0           -0.0
#
#                     CAR_event_-57  CAR_event_-56  CAR_event_-55  \
# disclosure_type
# 감자 결정                         0.0            0.0            0.0
# 교환사채권 발행결정                    0.0            0.0            0.0
# 기술이전계약체결                     -0.0           -0.0           -0.0
# 단일판매ㆍ공급계약체결                  -0.0           -0.0           -0.0
# 단일판매ㆍ공급계약해지                   0.0            0.0            0.0
# 매출액변동                        -0.0           -0.0           -0.0
# 무상증자 결정                       0.0            0.0            0.0
# 상각형 조건부자본증권 발행결정              0.0            0.0            0.0
# 생산중단                         -0.0           -0.0           -0.0
# 소송 등의 제기                     -0.0           -0.0            0.0
# 신규시설투자                       -0.0           -0.0           -0.0
# 유상증자 결정                       0.0           -0.0           -0.0
# 유형자산 양도 결정                   -0.0           -0.0           -0.0
# 유형자산 양수 결정                    0.0            0.0            0.0
# 임상 계획 결과 발표                   0.0            0.0           -0.0
# 임상 계획 승인                     -0.0            0.0           -0.0
# 임상 계획 신청                     -0.0           -0.0           -0.0
# 임상 계획 철회                      0.0            0.0           -0.0
# 자기주식 소각 결정                   -0.0           -0.0           -0.0
# 자기주식 처분 결정                   -0.0           -0.0           -0.0
# 자기주식 취득 결정                   -0.0            0.0            0.0
# 자기주식취득 신탁계약 체결 결정             0.0           -0.0            0.0
# 자기주식취득 신탁계약 해지 결정            -0.0           -0.0           -0.0
# 자산양수도(기타), 풋백옵션               0.0           -0.0            0.0
# 전환사채권 발행결정                    0.0            0.0            0.0
# 주권 관련 사채권 양도 결정              -0.0           -0.0           -0.0
# 주권 관련 사채권 양수 결정              -0.0           -0.0           -0.0
# 타법인 주식 및 출자증권 양도결정           -0.0           -0.0           -0.0
# 타법인 주식 및 출자증권 양수결정           -0.0           -0.0           -0.0
# 특허권취득                        -0.0           -0.0           -0.0
# 품목허가 승인                      -0.0           -0.0           -0.0
# 품목허가 신청                       0.0           -0.0           -0.0
# 품목허가 철회                       0.0            0.0            0.0
# 회사분할 결정                      -0.0           -0.0            0.0
# 회사합병 결정                       0.0            0.0            0.0
# 횡령ㆍ배임혐의발생                    -0.0           -0.0           -0.0
#
#                     CAR_event_-54  CAR_event_-53  CAR_event_-52  \
# disclosure_type
# 감자 결정                       -0.00          -0.00           0.00
# 교환사채권 발행결정                   0.00           0.01           0.01
# 기술이전계약체결                    -0.00          -0.00          -0.00
# 단일판매ㆍ공급계약체결                 -0.00          -0.00          -0.00
# 단일판매ㆍ공급계약해지                  0.01           0.01           0.00
# 매출액변동                       -0.00          -0.00          -0.00
# 무상증자 결정                      0.00           0.00           0.00
# 상각형 조건부자본증권 발행결정             0.00           0.00           0.00
# 생산중단                        -0.00           0.00          -0.00
# 소송 등의 제기                     0.00           0.00           0.00
# 신규시설투자                      -0.00          -0.00          -0.00
# 유상증자 결정                     -0.00          -0.00           0.00
# 유형자산 양도 결정                  -0.00          -0.00           0.00
# 유형자산 양수 결정                   0.00           0.00           0.00
# 임상 계획 결과 발표                  0.00           0.00           0.00
# 임상 계획 승인                    -0.00          -0.00          -0.00
# 임상 계획 신청                    -0.00          -0.00          -0.00
# 임상 계획 철회                    -0.00          -0.00           0.00
# 자기주식 소각 결정                  -0.00          -0.00          -0.00
# 자기주식 처분 결정                   0.00           0.00           0.00
# 자기주식 취득 결정                   0.00           0.00           0.00
# 자기주식취득 신탁계약 체결 결정            0.00           0.00           0.00
# 자기주식취득 신탁계약 해지 결정           -0.00          -0.00          -0.00
# 자산양수도(기타), 풋백옵션             -0.00           0.00           0.00
# 전환사채권 발행결정                   0.00           0.00           0.00
# 주권 관련 사채권 양도 결정             -0.01          -0.01          -0.00
# 주권 관련 사채권 양수 결정             -0.00          -0.00          -0.00
# 타법인 주식 및 출자증권 양도결정          -0.00          -0.00          -0.00
# 타법인 주식 및 출자증권 양수결정          -0.00          -0.00          -0.00
# 특허권취득                       -0.00          -0.00          -0.00
# 품목허가 승인                     -0.00          -0.00          -0.00
# 품목허가 신청                     -0.00          -0.00          -0.00
# 품목허가 철회                      0.00           0.00           0.00
# 회사분할 결정                      0.00           0.00           0.00
# 회사합병 결정                      0.00           0.00           0.00
# 횡령ㆍ배임혐의발생                   -0.00          -0.00          -0.00
#
#                     CAR_event_-51  ...  CAR_event_51  CAR_event_52  \
# disclosure_type                    ...
# 감자 결정                        0.00  ...         -0.10         -0.10
# 교환사채권 발행결정                   0.01  ...          0.00          0.00
# 기술이전계약체결                    -0.00  ...          0.08          0.08
# 단일판매ㆍ공급계약체결                 -0.00  ...          0.01          0.01
# 단일판매ㆍ공급계약해지                  0.00  ...          0.01          0.01
# 매출액변동                       -0.00  ...          0.00          0.00
# 무상증자 결정                      0.00  ...          0.07          0.07
# 상각형 조건부자본증권 발행결정             0.00  ...          0.00          0.01
# 생산중단                        -0.00  ...         -0.00         -0.00
# 소송 등의 제기                     0.00  ...          0.02          0.02
# 신규시설투자                      -0.00  ...          0.01          0.01
# 유상증자 결정                      0.00  ...          0.02          0.02
# 유형자산 양도 결정                  -0.00  ...          0.01          0.02
# 유형자산 양수 결정                   0.00  ...          0.01          0.01
# 임상 계획 결과 발표                  0.00  ...          0.05          0.05
# 임상 계획 승인                    -0.00  ...          0.00          0.00
# 임상 계획 신청                    -0.00  ...          0.00          0.00
# 임상 계획 철회                    -0.00  ...          0.00          0.01
# 자기주식 소각 결정                  -0.00  ...          0.01          0.01
# 자기주식 처분 결정                   0.00  ...         -0.00         -0.00
# 자기주식 취득 결정                   0.00  ...          0.02          0.02
# 자기주식취득 신탁계약 체결 결정            0.00  ...          0.01          0.01
# 자기주식취득 신탁계약 해지 결정           -0.00  ...          0.00          0.00
# 자산양수도(기타), 풋백옵션              0.00  ...         -0.01         -0.00
# 전환사채권 발행결정                   0.00  ...          0.02          0.02
# 주권 관련 사채권 양도 결정             -0.00  ...          0.00          0.00
# 주권 관련 사채권 양수 결정             -0.00  ...         -0.00         -0.00
# 타법인 주식 및 출자증권 양도결정          -0.00  ...          0.02          0.02
# 타법인 주식 및 출자증권 양수결정           0.00  ...          0.01          0.01
# 특허권취득                       -0.00  ...          0.00          0.00
# 품목허가 승인                     -0.00  ...         -0.00         -0.00
# 품목허가 신청                     -0.00  ...          0.00          0.00
# 품목허가 철회                      0.00  ...          0.01          0.01
# 회사분할 결정                      0.00  ...          0.09          0.08
# 회사합병 결정                      0.00  ...          0.03          0.03
# 횡령ㆍ배임혐의발생                   -0.00  ...         -0.00         -0.00
#
#                     CAR_event_53  CAR_event_54  CAR_event_55  CAR_event_56  \
# disclosure_type
# 감자 결정                      -0.09         -0.09         -0.07         -0.06
# 교환사채권 발행결정                  0.00          0.00         -0.00         -0.00
# 기술이전계약체결                    0.08          0.08          0.07          0.08
# 단일판매ㆍ공급계약체결                 0.01          0.01          0.01          0.01
# 단일판매ㆍ공급계약해지                 0.01          0.01          0.01          0.01
# 매출액변동                       0.00          0.00          0.00          0.00
# 무상증자 결정                     0.06          0.06          0.06          0.06
# 상각형 조건부자본증권 발행결정            0.01          0.01          0.01          0.01
# 생산중단                       -0.00         -0.00         -0.00         -0.00
# 소송 등의 제기                    0.02          0.02          0.02          0.02
# 신규시설투자                      0.02          0.02          0.02          0.02
# 유상증자 결정                     0.02          0.02          0.02          0.02
# 유형자산 양도 결정                  0.02          0.01          0.01          0.01
# 유형자산 양수 결정                  0.01          0.01          0.01          0.01
# 임상 계획 결과 발표                 0.05          0.05          0.05          0.05
# 임상 계획 승인                    0.00          0.00          0.00          0.01
# 임상 계획 신청                    0.00          0.00          0.00          0.00
# 임상 계획 철회                    0.01          0.01          0.01          0.01
# 자기주식 소각 결정                  0.01          0.01          0.01          0.01
# 자기주식 처분 결정                 -0.00         -0.00         -0.00         -0.00
# 자기주식 취득 결정                  0.02          0.02          0.02          0.02
# 자기주식취득 신탁계약 체결 결정           0.01          0.01          0.01          0.01
# 자기주식취득 신탁계약 해지 결정           0.00          0.00          0.00          0.00
# 자산양수도(기타), 풋백옵션            -0.00         -0.00         -0.00         -0.01
# 전환사채권 발행결정                  0.02          0.02          0.02          0.02
# 주권 관련 사채권 양도 결정             0.00          0.00          0.00          0.01
# 주권 관련 사채권 양수 결정             0.00          0.00          0.00          0.00
# 타법인 주식 및 출자증권 양도결정          0.02          0.02          0.02          0.02
# 타법인 주식 및 출자증권 양수결정          0.01          0.01          0.01          0.01
# 특허권취득                       0.00          0.00          0.00          0.00
# 품목허가 승인                    -0.00         -0.00         -0.00         -0.00
# 품목허가 신청                     0.00          0.00          0.00          0.00
# 품목허가 철회                     0.01          0.01          0.01          0.00
# 회사분할 결정                     0.09          0.09          0.10          0.10
# 회사합병 결정                     0.03          0.03          0.03          0.03
# 횡령ㆍ배임혐의발생                  -0.00         -0.00         -0.00         -0.00
#
#                     CAR_event_57  CAR_event_58  CAR_event_59  CAR_event_60
# disclosure_type
# 감자 결정                      -0.06         -0.06         -0.07         -0.08
# 교환사채권 발행결정                 -0.00          0.00          0.00          0.00
# 기술이전계약체결                    0.07          0.08          0.08          0.07
# 단일판매ㆍ공급계약체결                 0.01          0.01          0.01          0.01
# 단일판매ㆍ공급계약해지                 0.01          0.01          0.00          0.00
# 매출액변동                       0.00          0.00          0.00          0.00
# 무상증자 결정                     0.06          0.06          0.06          0.06
# 상각형 조건부자본증권 발행결정            0.01          0.01          0.01          0.01
# 생산중단                       -0.00         -0.00         -0.00         -0.00
# 소송 등의 제기                    0.02          0.02          0.02          0.02
# 신규시설투자                      0.02          0.02          0.02          0.02
# 유상증자 결정                     0.02          0.02          0.02          0.02
# 유형자산 양도 결정                  0.01          0.01          0.02          0.02
# 유형자산 양수 결정                  0.01          0.01          0.01          0.01
# 임상 계획 결과 발표                 0.05          0.05          0.05          0.05
# 임상 계획 승인                    0.01          0.01          0.01          0.01
# 임상 계획 신청                    0.00          0.00          0.00          0.00
# 임상 계획 철회                    0.01          0.01          0.01          0.01
# 자기주식 소각 결정                  0.01          0.01          0.01          0.01
# 자기주식 처분 결정                 -0.00         -0.00         -0.00         -0.00
# 자기주식 취득 결정                  0.02          0.02          0.02          0.02
# 자기주식취득 신탁계약 체결 결정           0.01          0.01          0.01          0.01
# 자기주식취득 신탁계약 해지 결정          -0.00          0.00          0.00          0.00
# 자산양수도(기타), 풋백옵션            -0.00         -0.00         -0.01         -0.01
# 전환사채권 발행결정                  0.02          0.02          0.02          0.02
# 주권 관련 사채권 양도 결정             0.00          0.00          0.00          0.00
# 주권 관련 사채권 양수 결정             0.00          0.00          0.00          0.00
# 타법인 주식 및 출자증권 양도결정          0.02          0.02          0.02          0.02
# 타법인 주식 및 출자증권 양수결정          0.01          0.01          0.01          0.01
# 특허권취득                       0.00          0.00          0.00          0.00
# 품목허가 승인                    -0.00         -0.00         -0.00         -0.00
# 품목허가 신청                    -0.00         -0.00         -0.00          0.00
# 품목허가 철회                     0.01          0.01          0.01          0.01
# 회사분할 결정                     0.10          0.10          0.07          0.06
# 회사합병 결정                     0.03          0.03          0.03          0.03
# 횡령ㆍ배임혐의발생                  -0.00         -0.00         -0.00         -0.00
#
# [36 rows x 121 columns]

# %%
df_with_returns.groupby('disclosure_type')[ret_columns].std()
# Out:
#                     CAR_event_-60  CAR_event_-59  CAR_event_-58  \
# disclosure_type
# 감자 결정                         0.0       0.000667       0.000901
# 교환사채권 발행결정                    0.0       0.001108       0.008391
# 기술이전계약체결                      0.0       0.000763       0.000888
# 단일판매ㆍ공급계약체결                   0.0       0.002439       0.003663
# 단일판매ㆍ공급계약해지                   0.0       0.002059       0.003062
# 매출액변동                         0.0       0.002038       0.003274
# 무상증자 결정                       0.0       0.004596       0.004258
# 상각형 조건부자본증권 발행결정              0.0       0.000735       0.000859
# 생산중단                          0.0       0.002373       0.003508
# 소송 등의 제기                      NaN            NaN            NaN
# 신규시설투자                        0.0       0.001729       0.002643
# 유상증자 결정                       0.0       0.002140       0.002226
# 유형자산 양도 결정                    0.0       0.001493       0.001797
# 유형자산 양수 결정                    0.0       0.002266       0.002077
# 임상 계획 결과 발표                   0.0       0.006879       0.007691
# 임상 계획 승인                      0.0       0.002618       0.003439
# 임상 계획 신청                      0.0       0.001688       0.002723
# 임상 계획 철회                      0.0       0.000607       0.000873
# 자기주식 소각 결정                    0.0       0.001773       0.002158
# 자기주식 처분 결정                    0.0       0.001896       0.002386
# 자기주식 취득 결정                    0.0       0.001750       0.002056
# 자기주식취득 신탁계약 체결 결정             0.0       0.002446       0.002649
# 자기주식취득 신탁계약 해지 결정             0.0       0.002372       0.003275
# 자산양수도(기타), 풋백옵션               NaN            NaN            NaN
# 전환사채권 발행결정                    0.0       0.001676       0.003093
# 주권 관련 사채권 양도 결정               0.0       0.001747       0.000897
# 주권 관련 사채권 양수 결정               0.0       0.001563       0.003120
# 타법인 주식 및 출자증권 양도결정            0.0       0.010592       0.010511
# 타법인 주식 및 출자증권 양수결정            0.0       0.001905       0.002935
# 특허권취득                         0.0       0.001869       0.003056
# 품목허가 승인                       0.0       0.001015       0.000606
# 품목허가 신청                       0.0       0.001219       0.001273
# 품목허가 철회                       0.0       0.003171       0.000735
# 회사분할 결정                       0.0       0.000628       0.001276
# 회사합병 결정                       0.0       0.004267       0.005049
# 횡령ㆍ배임혐의발생                     0.0       0.000820       0.000028
#
#                     CAR_event_-57  CAR_event_-56  CAR_event_-55  \
# disclosure_type
# 감자 결정                    0.002346       0.002402       0.000732
# 교환사채권 발행결정               0.008349       0.008480       0.006412
# 기술이전계약체결                 0.001116       0.002418       0.001384
# 단일판매ㆍ공급계약체결              0.004300       0.004961       0.005150
# 단일판매ㆍ공급계약해지              0.004601       0.005372       0.005543
# 매출액변동                    0.003548       0.003492       0.003777
# 무상증자 결정                  0.004162       0.005152       0.005461
# 상각형 조건부자본증권 발행결정         0.001665       0.000681       0.001431
# 생산중단                     0.003644       0.003762       0.004748
# 소송 등의 제기                      NaN            NaN            NaN
# 신규시설투자                   0.002920       0.003314       0.003210
# 유상증자 결정                  0.002732       0.003304       0.002958
# 유형자산 양도 결정               0.003292       0.002904       0.003206
# 유형자산 양수 결정               0.003788       0.005331       0.005572
# 임상 계획 결과 발표              0.005540       0.005488       0.004627
# 임상 계획 승인                 0.003968       0.005999       0.005734
# 임상 계획 신청                 0.003202       0.003532       0.004333
# 임상 계획 철회                 0.000424       0.000447       0.003970
# 자기주식 소각 결정               0.001981       0.002716       0.002547
# 자기주식 처분 결정               0.002871       0.003258       0.003046
# 자기주식 취득 결정               0.002549       0.002846       0.002958
# 자기주식취득 신탁계약 체결 결정        0.003436       0.003377       0.003499
# 자기주식취득 신탁계약 해지 결정        0.003468       0.004447       0.004984
# 자산양수도(기타), 풋백옵션               NaN            NaN            NaN
# 전환사채권 발행결정               0.003785       0.004521       0.003937
# 주권 관련 사채권 양도 결정          0.003934       0.005961       0.006418
# 주권 관련 사채권 양수 결정          0.002700       0.003154       0.002197
# 타법인 주식 및 출자증권 양도결정       0.013170       0.017896       0.017997
# 타법인 주식 및 출자증권 양수결정       0.003339       0.004153       0.004099
# 특허권취득                    0.003113       0.002866       0.002870
# 품목허가 승인                  0.000805       0.000869       0.002358
# 품목허가 신청                  0.001132       0.001565       0.000914
# 품목허가 철회                  0.001222       0.003651       0.003095
# 회사분할 결정                  0.000444       0.002224       0.002630
# 회사합병 결정                  0.007633       0.007577       0.009295
# 횡령ㆍ배임혐의발생                0.000371       0.002413       0.002679
#
#                     CAR_event_-54  CAR_event_-53  CAR_event_-52  \
# disclosure_type
# 감자 결정                    0.001084       0.001234       0.001732
# 교환사채권 발행결정               0.007448       0.017101       0.019391
# 기술이전계약체결                 0.001931       0.002618       0.001673
# 단일판매ㆍ공급계약체결              0.005608       0.005765       0.006031
# 단일판매ㆍ공급계약해지              0.003161       0.003503       0.001528
# 매출액변동                    0.004039       0.004146       0.004230
# 무상증자 결정                  0.005591       0.007332       0.008024
# 상각형 조건부자본증권 발행결정         0.000914       0.000773       0.001480
# 생산중단                     0.006356       0.005936       0.007112
# 소송 등의 제기                      NaN            NaN            NaN
# 신규시설투자                   0.003682       0.003300       0.003481
# 유상증자 결정                  0.003612       0.004091       0.005032
# 유형자산 양도 결정               0.003246       0.003005       0.004525
# 유형자산 양수 결정               0.006009       0.006307       0.005034
# 임상 계획 결과 발표              0.006740       0.006074       0.006157
# 임상 계획 승인                 0.005601       0.004654       0.005644
# 임상 계획 신청                 0.004879       0.005402       0.005697
# 임상 계획 철회                 0.003344       0.004999       0.002304
# 자기주식 소각 결정               0.002832       0.002892       0.003125
# 자기주식 처분 결정               0.003851       0.005459       0.006044
# 자기주식 취득 결정               0.003326       0.003256       0.003609
# 자기주식취득 신탁계약 체결 결정        0.003104       0.003744       0.004133
# 자기주식취득 신탁계약 해지 결정        0.005210       0.005245       0.006046
# 자산양수도(기타), 풋백옵션               NaN            NaN            NaN
# 전환사채권 발행결정               0.003224       0.005423       0.006193
# 주권 관련 사채권 양도 결정          0.006873       0.007570       0.006240
# 주권 관련 사채권 양수 결정          0.002546       0.002151       0.002622
# 타법인 주식 및 출자증권 양도결정       0.025843       0.025962       0.028393
# 타법인 주식 및 출자증권 양수결정       0.004582       0.004824       0.005543
# 특허권취득                    0.003620       0.003456       0.004283
# 품목허가 승인                  0.001971       0.001547       0.001834
# 품목허가 신청                  0.000990       0.001663       0.001728
# 품목허가 철회                  0.002153       0.000697       0.000194
# 회사분할 결정                  0.002739       0.002322       0.000717
# 회사합병 결정                  0.008709       0.008531       0.009619
# 횡령ㆍ배임혐의발생                0.002468       0.001753       0.002811
#
#                     CAR_event_-51  ...  CAR_event_51  CAR_event_52  \
# disclosure_type                    ...
# 감자 결정                    0.001737  ...      0.163306      0.168995
# 교환사채권 발행결정               0.027743  ...      0.013686      0.016231
# 기술이전계약체결                 0.001931  ...      0.119048      0.118487
# 단일판매ㆍ공급계약체결              0.005644  ...      0.028996      0.028900
# 단일판매ㆍ공급계약해지              0.001295  ...      0.020483      0.019986
# 매출액변동                    0.004345  ...      0.021113      0.021351
# 무상증자 결정                  0.007138  ...      0.116597      0.114891
# 상각형 조건부자본증권 발행결정         0.001265  ...      0.017388      0.018014
# 생산중단                     0.006516  ...      0.016974      0.017807
# 소송 등의 제기                      NaN  ...           NaN           NaN
# 신규시설투자                   0.003685  ...      0.025087      0.025100
# 유상증자 결정                  0.004516  ...      0.058878      0.059935
# 유형자산 양도 결정               0.005290  ...      0.072045      0.071857
# 유형자산 양수 결정               0.005787  ...      0.020871      0.020078
# 임상 계획 결과 발표              0.004012  ...      0.108157      0.109444
# 임상 계획 승인                 0.004749  ...      0.021943      0.022165
# 임상 계획 신청                 0.005727  ...      0.016239      0.016752
# 임상 계획 철회                 0.002551  ...      0.000173      0.008708
# 자기주식 소각 결정               0.003538  ...      0.027751      0.027837
# 자기주식 처분 결정               0.007908  ...      0.027103      0.022461
# 자기주식 취득 결정               0.003778  ...      0.023039      0.022457
# 자기주식취득 신탁계약 체결 결정        0.004149  ...      0.022178      0.021563
# 자기주식취득 신탁계약 해지 결정        0.005031  ...      0.012879      0.012878
# 자산양수도(기타), 풋백옵션               NaN  ...           NaN           NaN
# 전환사채권 발행결정               0.005543  ...      0.061716      0.061400
# 주권 관련 사채권 양도 결정          0.007255  ...      0.015693      0.013943
# 주권 관련 사채권 양수 결정          0.001265  ...      0.010571      0.010899
# 타법인 주식 및 출자증권 양도결정       0.022868  ...      0.058457      0.056531
# 타법인 주식 및 출자증권 양수결정       0.005253  ...      0.028861      0.028551
# 특허권취득                    0.003948  ...      0.012925      0.013391
# 품목허가 승인                  0.001519  ...      0.003246      0.003212
# 품목허가 신청                  0.003643  ...      0.012416      0.012912
# 품목허가 철회                  0.000684  ...      0.008506      0.009903
# 회사분할 결정                  0.004854  ...      0.042774      0.032026
# 회사합병 결정                  0.010613  ...      0.055100      0.054719
# 횡령ㆍ배임혐의발생                0.002678  ...      0.000574      0.000125
#
#                     CAR_event_53  CAR_event_54  CAR_event_55  CAR_event_56  \
# disclosure_type
# 감자 결정                   0.142748      0.138080      0.119608      0.098283
# 교환사채권 발행결정              0.013656      0.012636      0.014029      0.013618
# 기술이전계약체결                0.121191      0.125656      0.125416      0.127546
# 단일판매ㆍ공급계약체결             0.029045      0.029115      0.028877      0.028792
# 단일판매ㆍ공급계약해지             0.023648      0.022998      0.022164      0.021049
# 매출액변동                   0.021157      0.021398      0.021384      0.020921
# 무상증자 결정                 0.115885      0.117434      0.117383      0.118855
# 상각형 조건부자본증권 발행결정        0.018832      0.018339      0.017188      0.017202
# 생산중단                    0.018129      0.017967      0.017690      0.017735
# 소송 등의 제기                     NaN           NaN           NaN           NaN
# 신규시설투자                  0.026376      0.026832      0.026965      0.026433
# 유상증자 결정                 0.059616      0.060857      0.060425      0.059560
# 유형자산 양도 결정              0.071908      0.072015      0.071909      0.071945
# 유형자산 양수 결정              0.020822      0.020859      0.019940      0.018612
# 임상 계획 결과 발표             0.108611      0.109091      0.109430      0.109572
# 임상 계획 승인                0.021931      0.023830      0.023436      0.026282
# 임상 계획 신청                0.015918      0.016269      0.016531      0.016542
# 임상 계획 철회                0.006241      0.007747      0.006989      0.011275
# 자기주식 소각 결정              0.027900      0.027854      0.027338      0.026680
# 자기주식 처분 결정              0.022021      0.022373      0.022705      0.022363
# 자기주식 취득 결정              0.021219      0.020504      0.020090      0.019753
# 자기주식취득 신탁계약 체결 결정       0.021991      0.021821      0.021438      0.020886
# 자기주식취득 신탁계약 해지 결정       0.012927      0.013288      0.014247      0.014169
# 자산양수도(기타), 풋백옵션              NaN           NaN           NaN           NaN
# 전환사채권 발행결정              0.062999      0.063967      0.063035      0.062742
# 주권 관련 사채권 양도 결정         0.012300      0.012813      0.012539      0.014590
# 주권 관련 사채권 양수 결정         0.012333      0.011240      0.010959      0.011533
# 타법인 주식 및 출자증권 양도결정      0.055053      0.053504      0.053811      0.055111
# 타법인 주식 및 출자증권 양수결정      0.028021      0.028778      0.028102      0.027997
# 특허권취득                   0.014088      0.013122      0.012984      0.013037
# 품목허가 승인                 0.002770      0.003918      0.002088      0.002365
# 품목허가 신청                 0.010535      0.012182      0.011932      0.012052
# 품목허가 철회                 0.010146      0.011213      0.007685      0.002510
# 회사분할 결정                 0.039960      0.043914      0.064568      0.057519
# 회사합병 결정                 0.054070      0.054478      0.054630      0.053625
# 횡령ㆍ배임혐의발생               0.000363      0.000562      0.001143      0.001010
#
#                     CAR_event_57  CAR_event_58  CAR_event_59  CAR_event_60
# disclosure_type
# 감자 결정                   0.100063      0.102134      0.111669      0.129693
# 교환사채권 발행결정              0.013017      0.010899      0.012859      0.012056
# 기술이전계약체결                0.128095      0.132115      0.127768      0.129364
# 단일판매ㆍ공급계약체결             0.028283      0.028325      0.028365      0.028518
# 단일판매ㆍ공급계약해지             0.020657      0.018487      0.014831      0.013021
# 매출액변동                   0.021189      0.021624      0.022355      0.022479
# 무상증자 결정                 0.116068      0.119125      0.121350      0.120618
# 상각형 조건부자본증권 발행결정        0.017191      0.018163      0.018209      0.018946
# 생산중단                    0.017204      0.017845      0.017397      0.018174
# 소송 등의 제기                     NaN           NaN           NaN           NaN
# 신규시설투자                  0.025807      0.026099      0.025950      0.025471
# 유상증자 결정                 0.057203      0.058081      0.057837      0.057388
# 유형자산 양도 결정              0.071955      0.071976      0.070937      0.071131
# 유형자산 양수 결정              0.018984      0.017582      0.019052      0.018384
# 임상 계획 결과 발표             0.109520      0.109627      0.109669      0.108567
# 임상 계획 승인                0.025982      0.025824      0.025817      0.026302
# 임상 계획 신청                0.016767      0.016627      0.016495      0.015843
# 임상 계획 철회                0.008746      0.013984      0.014209      0.011942
# 자기주식 소각 결정              0.026542      0.026681      0.026581      0.027057
# 자기주식 처분 결정              0.023054      0.023342      0.023424      0.023751
# 자기주식 취득 결정              0.019963      0.019707      0.019788      0.020167
# 자기주식취득 신탁계약 체결 결정       0.020863      0.020776      0.020681      0.021132
# 자기주식취득 신탁계약 해지 결정       0.013996      0.014298      0.015605      0.015325
# 자산양수도(기타), 풋백옵션              NaN           NaN           NaN           NaN
# 전환사채권 발행결정              0.063066      0.063644      0.062857      0.062964
# 주권 관련 사채권 양도 결정         0.015432      0.015993      0.015560      0.015846
# 주권 관련 사채권 양수 결정         0.011212      0.009898      0.009646      0.010458
# 타법인 주식 및 출자증권 양도결정      0.054870      0.052672      0.052762      0.052977
# 타법인 주식 및 출자증권 양수결정      0.027786      0.027439      0.026317      0.024626
# 특허권취득                   0.013036      0.012135      0.012955      0.012501
# 품목허가 승인                 0.002529      0.001493      0.001329      0.002716
# 품목허가 신청                 0.013585      0.013468      0.012381      0.012558
# 품목허가 철회                 0.009330      0.007027      0.006329      0.006249
# 회사분할 결정                 0.059696      0.056892      0.025024      0.018556
# 회사합병 결정                 0.053344      0.052422      0.051537      0.051899
# 횡령ㆍ배임혐의발생               0.000933      0.001038      0.001276      0.001171
#
# [36 rows x 121 columns]

# %%
# 공시 종류별 sentiment 분포 분석 (disclosure_type 기준)
disclosure_sentiment = df_with_returns.groupby(['disclosure_type', 'label']).size().unstack(fill_value=0)

# label 컬럼 정렬: negative(-1), neutral(0), positive(1) 순서
label_sort_order = [-1, 0, 1]
filtered_columns = [col for col in label_sort_order if col in disclosure_sentiment.columns]
disclosure_sentiment = disclosure_sentiment[filtered_columns]

# 비율로 변환
disclosure_sentiment_pct = disclosure_sentiment.div(disclosure_sentiment.sum(axis=1), axis=0) * 100

# 수치 요약 전체 DataFrame으로 만들어서 출력 (전체 공시 종류)
summary_df = disclosure_sentiment.copy()
for col in disclosure_sentiment_pct.columns:
    summary_df[f"{col}_pct"] = disclosure_sentiment_pct[col].round(1)

# 샘플 개수(행별 합) 기준 내림차순 정렬
summary_df['total_count'] = summary_df[[col for col in [-1, 0, 1] if col in summary_df.columns]].sum(axis=1)
summary_df = summary_df.sort_values('total_count', ascending=False)
summary_df = summary_df.drop(columns=['total_count'])

print("=== 전체 공시 종류별 감정 분포 ===")
summary_df
# Out:
# === 전체 공시 종류별 감정 분포 ===
# label               -1    0    1  -1_pct  0_pct  1_pct
# disclosure_type
# 단일판매ㆍ공급계약체결          1  274  652     0.1   29.6   70.3
# 매출액변동               74   58  229    20.5   16.1   63.4
# 자기주식취득 신탁계약 체결 결정    2   48  106     1.3   30.8   67.9
# 타법인 주식 및 출자증권 양수결정   2   36   86     1.6   29.0   69.4
# 자기주식 취득 결정           0    5   77     0.0    6.1   93.9
# 특허권취득                0    2   79     0.0    2.5   97.5
# 신규시설투자               0   19   40     0.0   32.2   67.8
# 자기주식 처분 결정          18   33    1    34.6   63.5    1.9
# 자기주식 소각 결정           3    5   40     6.2   10.4   83.3
# 무상증자 결정              1   12   32     2.2   26.7   71.1
# 임상 계획 신청             5   17   22    11.4   38.6   50.0
# 자기주식취득 신탁계약 해지 결정   11   28    0    28.2   71.8    0.0
# 임상 계획 승인             5    7   22    14.7   20.6   64.7
# 유상증자 결정              4   24    5    12.1   72.7   15.2
# 회사합병 결정              1    0   23     4.2    0.0   95.8
# 타법인 주식 및 출자증권 양도결정  10    9    4    43.5   39.1   17.4
# 전환사채권 발행결정           1   20    1     4.5   90.9    4.5
# 유형자산 양수 결정           0    4   16     0.0   20.0   80.0
# 생산중단                17    2    0    89.5   10.5    0.0
# 유형자산 양도 결정           2    4    9    13.3   26.7   60.0
# 품목허가 신청              0    2    5     0.0   28.6   71.4
# 임상 계획 결과 발표          0    1    4     0.0   20.0   80.0
# 품목허가 승인              0    0    4     0.0    0.0  100.0
# 주권 관련 사채권 양수 결정      0    3    1     0.0   75.0   25.0
# 감자 결정                1    0    2    33.3    0.0   66.7
# 교환사채권 발행결정           1    2    0    33.3   66.7    0.0
# 상각형 조건부자본증권 발행결정     1    2    0    33.3   66.7    0.0
# 단일판매ㆍ공급계약해지          3    0    0   100.0    0.0    0.0
# 기술이전계약체결             0    1    2     0.0   33.3   66.7
# 주권 관련 사채권 양도 결정      1    1    0    50.0   50.0    0.0
# 임상 계획 철회             2    0    0   100.0    0.0    0.0
# 품목허가 철회              0    2    0     0.0  100.0    0.0
# 회사분할 결정              0    2    0     0.0  100.0    0.0
# 횡령ㆍ배임혐의발생            1    1    0    50.0   50.0    0.0
# 자산양수도(기타), 풋백옵션      0    0    1     0.0    0.0  100.0
# 소송 등의 제기             0    1    0     0.0  100.0    0.0

# %%
# 상위 20개 공시 종류만 선택 (데이터가 많은 순서대로)
top_disclosures = df_with_returns['disclosure_type'].value_counts().head(25).index
disclosure_sentiment_top = disclosure_sentiment.loc[top_disclosures]
disclosure_sentiment_pct_top = disclosure_sentiment_pct.loc[top_disclosures]

# 색상 매핑: negative(빨강), neutral(회색), positive(초록)
sentiment_colors = {
    -1: "#DC143C", # 빨강 (negative)
     0: "#999999", # 회색 (neutral)
     1: "#2E8B57"  # 초록 (positive)
}
plot_colors = [sentiment_colors[col] for col in filtered_columns]

# 시각화 (세로로 2개 배치)
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 16))

# 1. 절대 개수
disclosure_sentiment_top.plot(kind='bar', stacked=True, ax=ax1, color=plot_colors)
ax1.set_title('Sentiment Distribution by Disclosure Type (Absolute Count)', fontsize=14)
ax1.set_xlabel('Disclosure Type', fontsize=12)
ax1.set_ylabel('Count', fontsize=12)
ax1.legend([ 'Negative', 'Neutral', 'Positive' ], title='Sentiment', bbox_to_anchor=(1.05, 1), loc='upper left')

x_labels = [category_mapping.get(cat, cat) for cat in top_disclosures]
ax1.set_xticklabels(x_labels, rotation=45, ha='right')

# 2. 비율(%)
disclosure_sentiment_pct_top.plot(kind='bar', stacked=True, ax=ax2, color=plot_colors)
ax2.set_title('Sentiment Distribution by Disclosure Type (Percentage)', fontsize=14)
ax2.set_xlabel('Disclosure Type', fontsize=12)
ax2.set_ylabel('Percentage (%)', fontsize=12)
ax2.legend([ 'Negative', 'Neutral', 'Positive' ], title='Sentiment', bbox_to_anchor=(1.05, 1), loc='upper left')

ax2.set_xticklabels(x_labels, rotation=45, ha='right')

plt.tight_layout()
plt.show()
