# %%
import pandas as pd

df = pd.read_csv("~/Downloads/data-1754723317533.csv")

# %%
import polars as pl
import datetime
import zoneinfo

ohlcv = pl.read_parquet("/Volumes/APFS/KOSPI/ohlcv/20231114_1m.parquet")
tzinfo = zoneinfo.ZoneInfo("Asia/Seoul")
target_ts = datetime.datetime(2023, 11, 14, 9, 10, tzinfo=tzinfo)
ohlcv.filter(
    (pl.col("종목코드") == "KR7002810000")
)
# Out:
# shape: (78, 7)
# ┌──────────────┬──────────────────────────┬───────┬───────┬───────┬───────┬────────┐
# │ 종목코드     ┆ ts                       ┆ open  ┆ high  ┆ low   ┆ close ┆ volume │
# │ ---          ┆ ---                      ┆ ---   ┆ ---   ┆ ---   ┆ ---   ┆ ---    │
# │ str          ┆ datetime[μs, Asia/Seoul] ┆ i64   ┆ i64   ┆ i64   ┆ i64   ┆ i64    │
# ╞══════════════╪══════════════════════════╪═══════╪═══════╪═══════╪═══════╪════════╡
# │ KR7002810000 ┆ 2023-11-14 09:00:00 KST  ┆ 12320 ┆ 12320 ┆ 12320 ┆ 12320 ┆ 5      │
# │ KR7002810000 ┆ 2023-11-14 09:01:00 KST  ┆ 12330 ┆ 12330 ┆ 12330 ┆ 12330 ┆ 5      │
# │ KR7002810000 ┆ 2023-11-14 09:07:00 KST  ┆ 12380 ┆ 12380 ┆ 12380 ┆ 12380 ┆ 127    │
# │ KR7002810000 ┆ 2023-11-14 09:10:00 KST  ┆ 12400 ┆ 12400 ┆ 12400 ┆ 12400 ┆ 8      │
# │ KR7002810000 ┆ 2023-11-14 09:21:00 KST  ┆ 12470 ┆ 12470 ┆ 12470 ┆ 12470 ┆ 9      │
# │ …            ┆ …                        ┆ …     ┆ …     ┆ …     ┆ …     ┆ …      │
# │ KR7002810000 ┆ 2023-11-14 15:17:00 KST  ┆ 12570 ┆ 12580 ┆ 12570 ┆ 12580 ┆ 2      │
# │ KR7002810000 ┆ 2023-11-14 15:18:00 KST  ┆ 12570 ┆ 12570 ┆ 12570 ┆ 12570 ┆ 1      │
# │ KR7002810000 ┆ 2023-11-14 15:19:00 KST  ┆ 12580 ┆ 12580 ┆ 12580 ┆ 12580 ┆ 153    │
# │ KR7002810000 ┆ 2023-11-14 15:30:00 KST  ┆ 12600 ┆ 12600 ┆ 12600 ┆ 12600 ┆ 106    │
# │ KR7002810000 ┆ 2023-11-14 15:46:00 KST  ┆ 12600 ┆ 12600 ┆ 12600 ┆ 12600 ┆ 1      │
# └──────────────┴──────────────────────────┴───────┴───────┴───────┴───────┴────────┘

# %%
import polars as pl
import datetime
import zoneinfo

partitioned = pl.scan_parquet("/Volumes/APFS/KOSPI/partitioned/체결일자=20231101/0.parquet")
lf = partitioned.filter(
    (pl.col("종목코드") == "KR7046440004")
)

# %%
lf
# Out:
# <i>naive plan: (run <b>LazyFrame.explain(optimized=True)</b> to see the optimized plan)</i>
#     <p></p>
#     <div>FILTER [(col("종목코드")) == ("KR7046440004")]<p></p>FROM<p></p>  Parquet SCAN [/Volumes/APFS/KOSPI/partitioned/체결일자=20231101/0.parquet]<p></p>  PROJECT */5 COLUMNS</div>

# %%
# ret 컬럼 중 하나라도 null이 아닌 행 필터링
df[
    ~(df[['ret_1m', 'ret_3m', 'ret_10m', 'ret_15m', 'ret_30m', 'ret_60m']].isna().all(axis=1))
]
# Out:
#          id    stock_code  market company_name  \
# 0     64686  KR7051910008   KOSPI         LG화학
# 1     64687  KR7018250001   KOSPI         애경산업
# 3     64689  KR7280360009   KOSPI        롯데웰푸드
# 4     64692  KR7178920005   KOSPI       PI첨단소재
# 6     64694  KR7019680008   KOSPI           대교
# ...     ...           ...     ...          ...
# 1106  68129  KR7450080007   KOSPI       에코프로머티
# 1107  68130  KR7230360000  KOSDAQ        에코마케팅
# 1108  68131  KR7230360000  KOSDAQ        에코마케팅
# 1109  68132  KR7361570005  KOSDAQ        알비더블유
# 1110  68133  KR7003670007   KOSPI       포스코퓨처엠
#
#                          report_name            disclosed_at  \
# 0           조회공시요구(풍문또는보도)에대한답변(미확정)  2023-11-01 00:33:24+00
# 1                  기업설명회(IR)개최(안내공시)  2023-11-01 00:33:30+00
# 3             연결재무제표기준영업(잠정)실적(공정공시)  2023-11-01 01:05:03+00
# 4                     영업(잠정)실적(공정공시)  2023-11-01 01:52:56+00
# 6             연결재무제표기준영업(잠정)실적(공정공시)  2023-11-01 03:04:33+00
# ...                              ...                     ...
# 1106       조회공시요구(현저한시황변동)에대한답변(미확정)  2023-12-28 05:55:03+00
# 1107  [기재정정]연결재무제표기준영업실적등에대한전망(공정공시)  2023-12-28 05:56:27+00
# 1108          [기재정정]영업실적등에대한전망(공정공시)  2023-12-28 05:56:32+00
# 1109     기타주요경영사항(제1회차 전환사채 발행결정 철회)  2023-12-28 06:10:49+00
# 1110                     단일판매ㆍ공급계약체결  2023-12-28 06:21:51+00
#
#                                              summary_kr  \
# 0     LG화학은 여수 NCC 2공장 매각과 관련하여 아직 구체적인 결정이 내려지지 않았으...
# 1     애경산업은 2023년 11월 8일 오전 9시에 기업설명회(IR)를 개최하여 2023...
# 3     롯데웰푸드는 2023년 3분기 연결기준 매출액이 10,865억 원으로 예상치를 다소...
# 4     PI첨단소재는 2023년 3분기 매출액 614억 원과 영업이익 42억 원을 기록했으...
# 6     대교는 2023년 3분기 연결 기준 매출액 1,615억 원, 영업손실 68억 원, ...
# ...                                                 ...
# 1106  에코프로머티리얼즈는 신규 고객 확보와 관련된 사업 협의를 진행 중이며, 아직 확정된...
# 1107  에코마케팅은 2023년 매출액 3,500억 원과 영업이익 530억 원을 기록할 것으...
# 1108  에코마케팅은 2023년 매출액이 490억 원, 영업이익이 200억 원으로 예상되며,...
# 1109  알비더블유는 2023년 7월 21일 이사회에서 결정했던 제1회차 무기명식 이권부 무...
# 1110  포스코퓨처엠은 포스코와 2024년 한 해 동안 생석회, 석회석, 백운석류의 상품 공...
#
#                                                     raw  \
# 0     2023.11.01 09:33:22\n기업명: LG화학(시가총액: 30조 8,136...
# 1     2023.11.01 09:33:27\n기업명: 애경산업(시가총액: 5,810억)\n...
# 3     2023.11.01 10:05:02\n기업명: 롯데웰푸드(시가총액: 1조 793억)...
# 4     2023.11.01 10:52:55\n기업명: PI첨단소재(시가총액: 7,562억)...
# 6     2023.11.01 12:04:32\n기업명: 대교(시가총액: 2,130억)\n보고...
# ...                                                 ...
# 1106  2023.12.28 14:55:02\n기업명: 에코프로머티(시가총액: 13조 658...
# 1107  2023.12.28 14:56:26\n기업명: 에코마케팅(시가총액: 3,350억)\...
# 1108  2023.12.28 14:56:31\n기업명: 에코마케팅(시가총액: 3,350억)\...
# 1109  2023.12.28 15:10:48\n기업명: 알비더블유(시가총액: 1,143억)\...
# 1110  2023.12.28 15:21:50\n기업명: 포스코퓨처엠(시가총액: 27조 7,3...
#
#                       created_at  ret_1m  ret_3m  ret_10m  ret_15m  ret_30m  \
# 0     2025-07-08 17:09:01.716527   -0.34   -0.69    -0.92    -0.34    -0.34
# 1     2025-07-08 17:09:01.716527   -0.23    0.45     0.23     1.14     0.00
# 3     2025-07-08 17:09:01.716527   -1.03    0.09     0.52     1.21     0.26
# 4     2025-07-08 17:09:01.716527   -0.39   -0.97     0.19     0.39     1.55
# 6     2025-07-08 17:09:01.716527    0.00   -0.20     0.00     0.00     0.00
# ...                          ...     ...     ...      ...      ...      ...
# 1106  2025-07-08 17:09:03.053194   -0.21   -0.63    -2.05    -3.57    -3.52
# 1107  2025-07-08 17:09:03.053194   -0.19   -0.39    -0.39    -0.58    -0.48
# 1108  2025-07-08 17:09:03.053194   -0.19   -0.39    -0.39    -0.58    -0.48
# 1109  2025-07-08 17:09:03.053194   -0.38   -0.13    -0.75    -0.75      NaN
# 1110  2025-07-08 17:09:03.053194    0.00    0.00      NaN      NaN      NaN
#
#       ret_60m     label   score
# 0       -1.49   neutral  0.9986
# 1        0.45   neutral  0.9999
# 3        0.09  positive  0.6497
# 4        3.10  negative  0.8858
# 6        0.20  negative  0.9998
# ...       ...       ...     ...
# 1106    -1.00   neutral  0.9997
# 1107      NaN  positive  0.7258
# 1108      NaN  positive  0.4016
# 1109      NaN   neutral  0.9426
# 1110      NaN  positive  0.9831
#
# [858 rows x 17 columns]

# %%
df[
    (df[['ret_1m', 'ret_3m', 'ret_10m', 'ret_15m', 'ret_30m', 'ret_60m']].isna().all(axis=1)) &
    (pd.to_datetime(df['disclosed_at']).dt.tz_convert('Asia/Seoul').dt.dayofweek.isin([0,1,2,3,4])) &
    (pd.to_datetime(df['disclosed_at']).dt.tz_convert('Asia/Seoul').dt.strftime('%Y%m%d').isin(target_dates))
]
# Out:
#          id    stock_code  market company_name             report_name  \
# 2     64688  KR7046440004  KOSDAQ      KG모빌리언스  연결재무제표기준영업(잠정)실적(공정공시)
# 5     64693  KR7262260003  KOSDAQ         에이프로             단일판매ㆍ공급계약체결
# 9     64697  KR7144510005  KOSDAQ          지씨셀  연결재무제표기준영업(잠정)실적(공정공시)
# 20    64708  KR7066970005   KOSPI         엘앤에프             기업설명회(IR)개최
# 23    64711  KR7234690006  KOSDAQ        녹십자웰빙          영업(잠정)실적(공정공시)
# ...     ...           ...     ...          ...                     ...
# 944   67619  KR7086670007  KOSDAQ          비엠티               현금ㆍ현물배당결정
# 952   67627  KR7056730005  KOSDAQ        CNT85             단일판매ㆍ공급계약체결
# 953   67628  KR7099320004  KOSDAQ        쎄트렉아이                 전환청구권행사
# 1082  68067  KR7150840007  KOSDAQ        인트로메딕          전환청구권행사(제12회차)
# 1111  68134  KR7001260009   KOSPI         남광토건             단일판매ㆍ공급계약체결
#
#                 disclosed_at  \
# 2     2023-11-01 00:53:05+00
# 5     2023-11-01 01:58:42+00
# 9     2023-11-01 04:37:35+00
# 20    2023-11-01 05:37:51+00
# 23    2023-11-01 05:57:57+00
# ...                      ...
# 944   2023-12-15 05:29:57+00
# 952   2023-12-15 06:23:56+00
# 953   2023-12-15 06:26:50+00
# 1082  2023-12-27 02:33:22+00
# 1111  2023-12-28 06:30:06+00
#
#                                              summary_kr  \
# 2     KG모빌리언스는 2023년 3분기에 매출 763억 원과 영업이익 101억 원을 기록...
# 5     에이프로는 미국의 L-H Battery Company와 2차전지 활성화장비 공급 계...
# 9     지씨셀이 2023년 3분기 연결 재무제표 기준으로 매출액 454억 원, 영업손실 1...
# 20    엘앤에프는 2023년 11월 6일 오후 2시에 기업설명회(IR)를 개최하여 2023...
# 23    녹십자웰빙은 2023년 3분기 매출액 293억 원, 영업이익 35억 원, 순이익 2...
# ...                                                 ...
# 944   비엠티는 2023년 결산 배당으로 보통주에 250원의 현금 배당을 결정했으며, 배당...
# 952   CNT85는 다국적 기업과 2차전지 시설물 공사를 위한 도급계약을 체결했으며, 계약...
# 953   쎄트렉아이는 2024년 1월 8일 상장을 앞두고 전환청구권 행사로 1,865,671...
# 1082  인트로메딕은 2024년 1월 12일에 1,204,819주의 전환청구권을 행사하여 시...
# 1111  남광토건은 남양주 다산동 일원에서지금ㆍ도농6-2구역 재개발 정비사업의 공사를 위해 ...
#
#                                                     raw  \
# 2     2023.11.01 09:53:04\n기업명: KG모빌리언스(시가총액: 1,862억...
# 5     2023.11.01 10:58:41\n기업명: 에이프로(시가총액: 1,753억)\n...
# 9     2023.11.01 13:37:34\n기업명: 지씨셀(시가총액: 4,614억)\n보...
# 20    2023.11.01 14:37:47\n기업명: 엘앤에프(시가총액: 4조 6,977억...
# 23    2023.11.01 14:57:56\n기업명: 녹십자웰빙(시가총액: 1,097억)\...
# ...                                                 ...
# 944   2023.12.15 14:29:56\n기업명: 비엠티(시가총액: 1,217억)\n보...
# 952   2023.12.15 15:23:55\n기업명: CNT85(시가총액: 613억)\n보...
# 953   2023.12.15 15:26:49\n기업명: 쎄트렉아이(시가총액: 2,662억)\...
# 1082  2023.12.27 11:33:21\n기업명: 인트로메딕(시가총액: 2,237억)\...
# 1111  2023.12.28 15:30:05\n기업명: 남광토건(시가총액: 753억)\n보고...
#
#                       created_at  ret_1m  ret_3m  ret_10m  ret_15m  ret_30m  \
# 2     2025-07-08 17:09:01.716527     NaN     NaN      NaN      NaN      NaN
# 5     2025-07-08 17:09:01.716527     NaN     NaN      NaN      NaN      NaN
# 9     2025-07-08 17:09:01.716527     NaN     NaN      NaN      NaN      NaN
# 20    2025-07-08 17:09:01.716527     NaN     NaN      NaN      NaN      NaN
# 23    2025-07-08 17:09:01.716527     NaN     NaN      NaN      NaN      NaN
# ...                          ...     ...     ...      ...      ...      ...
# 944   2025-07-08 17:09:03.053194     NaN     NaN      NaN      NaN      NaN
# 952   2025-07-08 17:09:03.053194     NaN     NaN      NaN      NaN      NaN
# 953   2025-07-08 17:09:03.053194     NaN     NaN      NaN      NaN      NaN
# 1082  2025-07-08 17:09:03.053194     NaN     NaN      NaN      NaN      NaN
# 1111  2025-07-08 17:09:03.053194     NaN     NaN      NaN      NaN      NaN
#
#       ret_60m     label   score
# 2         NaN  positive  0.9999
# 5         NaN  positive  0.9999
# 9         NaN  positive  0.5010
# 20        NaN   neutral  0.9998
# 23        NaN  positive  0.9967
# ...       ...       ...     ...
# 944       NaN  positive  0.9999
# 952       NaN  positive  0.9999
# 953       NaN   neutral  0.9963
# 1082      NaN   neutral  0.9995
# 1111      NaN  positive  0.9972
#
# [254 rows x 17 columns]

# %%
# null인 ret 값들을 가진 종목들의 OHLCV 데이터 확인
import os
from pathlib import Path

# null ret 값을 가진 행들 필터링
null_ret_df = df[
    (df[['ret_1m', 'ret_3m', 'ret_10m', 'ret_15m', 'ret_30m', 'ret_60m']].isna().all(axis=1)) &
    (pd.to_datetime(df['disclosed_at']).dt.tz_convert('Asia/Seoul').dt.dayofweek.isin([0,1,2,3,4])) &
    (pd.to_datetime(df['disclosed_at']).dt.tz_convert('Asia/Seoul').dt.strftime('%Y%m%d').isin(target_dates))
]

print(f"null ret 값을 가진 공시 건수: {len(null_ret_df)}")

# 각 종목별로 OHLCV 파일 존재 여부 확인
kospi_ohlcv_dir = Path("/Volumes/APFS/KOSPI/ohlcv")
kosdaq_ohlcv_dir = Path("/Volumes/APFS/KOSDAQ/ohlcv")

missing_files = []
existing_files = []

for idx, row in null_ret_df.iterrows():
    stock_code = row['stock_code']
    market = row['market']
    disclosed_date = pd.to_datetime(row['disclosed_at']).tz_convert('Asia/Seoul').strftime('%Y%m%d')
    
    # 시장에 따라 디렉터리 선택
    if market == 'KOSPI':
        ohlcv_dir = kospi_ohlcv_dir
    elif market == 'KOSDAQ':
        ohlcv_dir = kosdaq_ohlcv_dir
    else:
        continue
    
    # 해당 날짜의 OHLCV 파일 경로
    ohlcv_file = ohlcv_dir / f"{disclosed_date}_1m.parquet"
    
    if ohlcv_file.exists():
        # 파일이 존재하면 해당 종목의 데이터가 있는지 확인
        try:
            ohlcv_data = pl.read_parquet(ohlcv_file)
            # 종목코드를 'code' 컬럼으로 변경 (파일 구조에 맞게)
            stock_data = ohlcv_data.filter(pl.col("종목코드") == stock_code)
            
            if len(stock_data) > 0:
                existing_files.append({
                    'id': row['id'],
                    'stock_code': stock_code,
                    'market': market,
                    'disclosed_date': disclosed_date,
                    'company_name': row['company_name'],
                    'ohlcv_records': len(stock_data)
                })
                print(f"✓ {market} {stock_code} ({row['company_name']}) - {disclosed_date}: {len(stock_data)}개 레코드")
            else:
                missing_files.append({
                    'id': row['id'],
                    'stock_code': stock_code,
                    'market': market,
                    'disclosed_date': disclosed_date,
                    'company_name': row['company_name'],
                    'reason': '파일은 존재하지만 해당 종목 데이터 없음'
                })
                print(f"✗ {market} {stock_code} ({row['company_name']}) - {disclosed_date}: 파일은 있지만 종목 데이터 없음")
        except Exception as e:
            missing_files.append({
                'id': row['id'],
                'stock_code': stock_code,
                'market': market,
                'disclosed_date': disclosed_date,
                'company_name': row['company_name'],
                'reason': f'파일 읽기 오류: {str(e)}'
            })
            print(f"✗ {market} {stock_code} ({row['company_name']}) - {disclosed_date}: 파일 읽기 오류")
    else:
        missing_files.append({
            'id': row['id'],
            'stock_code': stock_code,
            'market': market,
            'disclosed_date': disclosed_date,
            'company_name': row['company_name'],
            'reason': 'OHLCV 파일 없음'
        })
        print(f"✗ {market} {stock_code} ({row['company_name']}) - {disclosed_date}: OHLCV 파일 없음")

print(f"\n=== 요약 ===")
print(f"OHLCV 데이터가 존재하는 종목: {len(existing_files)}개")
print(f"OHLCV 데이터가 없는 종목: {len(missing_files)}개")

# 데이터가 존재하는 종목들 상세 정보
if existing_files:
    print(f"\n=== OHLCV 데이터가 존재하는 종목들 ===")
    existing_df = pd.DataFrame(existing_files)
    print(existing_df)

# 데이터가 없는 종목들 상세 정보
if missing_files:
    print(f"\n=== OHLCV 데이터가 없는 종목들 ===")
    missing_df = pd.DataFrame(missing_files)
    print(missing_df.groupby('reason').size())
# Out:
# null ret 값을 가진 공시 건수: 254
# ✗ KOSDAQ KR7046440004 (KG모빌리언스) - 20231101: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7262260003 (에이프로) - 20231101: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7144510005 (지씨셀) - 20231101: 파일은 있지만 종목 데이터 없음
# ✗ KOSPI KR7066970005 (엘앤에프) - 20231101: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7234690006 (녹십자웰빙) - 20231101: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7122870009 (와이지엔터테인먼트) - 20231101: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7018310003 (삼목에스폼) - 20231101: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7376300000 (디어유) - 20231106: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7079810008 (디이엔티) - 20231106: 파일은 있지만 종목 데이터 없음
# ✗ KOSPI KR7066970005 (엘앤에프) - 20231106: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7214430001 (아이쓰리시스템) - 20231106: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7194480000 (데브시스터즈) - 20231106: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7032620007 (유비케어) - 20231106: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7235980000 (메드팩토) - 20231106: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7207760000 (미스터블루) - 20231106: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7078130002 (국일제지) - 20231108: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7237880000 (클리오) - 20231109: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7014620009 (성광벤드) - 20231109: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7032820003 (우리기술) - 20231109: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7418550000 (제이오) - 20231109: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7086890001 (이수앱지스) - 20231109: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7170790000 (파이오링크) - 20231109: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7335890000 (비올) - 20231109: 파일은 있지만 종목 데이터 없음
# ✗ KOSPI KR7034230003 (파라다이스) - 20231109: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7068790005 (DMS) - 20231109: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7256840000 (한국비엔씨) - 20231109: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR8344390008 (고스트스튜디오) - 20231109: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7352480008 (씨앤씨인터내셔널) - 20231109: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7067290007 (JW신약) - 20231109: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7234300002 (에스트래픽) - 20231109: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7142210004 (유니트론텍) - 20231109: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7052330008 (코텍) - 20231109: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7104830005 (원익머트리얼즈) - 20231109: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7006730006 (서부T&D) - 20231109: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7065450009 (빅텍) - 20231109: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR
- 20231215: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7072020001 (중앙백신) - 20231215: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7044340008 (위닉스) - 20231215: 파일은 있지만 종목 데이터 없음
# ✗ KOSPI KR7022100002 (포스코DX) - 20231215: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7086670007 (비엠티) - 20231215: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7056730005 (CNT85) - 20231215: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7099320004 (쎄트렉아이) - 20231215: 파일은 있지만 종목 데이터 없음
# ✗ KOSDAQ KR7150840007 (인트로메딕) - 20231227: 파일은 있지만 종목 데이터 없음
# ✓ KOSPI KR7001260009 (남광토건) - 20231228: 100개 레코드
#
# === 요약 ===
# OHLCV 데이터가 존재하는 종목: 4개
# OHLCV 데이터가 없는 종목: 250개
#
# === OHLCV 데이터가 존재하는 종목들 ===
#       id    stock_code  market disclosed_date company_name  ohlcv_records
# 0  66755  KR7298830001  KOSDAQ       20231115      슈어소프트테크            389
# 1  66777  KR7001260009   KOSPI       20231116         남광토건            266
# 2  67360  KR7214370009  KOSDAQ       20231208          케어젠            370
# 3  68134  KR7001260009   KOSPI       20231228         남광토건            100
#
# === OHLCV 데이터가 없는 종목들 ===
# reason
# 파일은 존재하지만 해당 종목 데이터 없음    250
# dtype: int64

# %%
# OHLCV 대신 partitioned 폴더에서 데이터 존재 여부 확인
print("=== Partitioned 폴더에서 데이터 존재 여부 확인 ===")

KOSPI_PARTITION_DIR = Path("/Volumes/APFS/KOSPI/partitioned")
KOSDAQ_PARTITION_DIR = Path("/Volumes/APFS/KOSDAQ/partitioned")

import polars as pl
from pathlib import Path

existing_partition_files = []
missing_partition_files = []

# null ret 값을 가진 행들 필터링
null_returns_df = df[
    (df[['ret_1m', 'ret_3m', 'ret_10m', 'ret_15m', 'ret_30m', 'ret_60m']].isna().all(axis=1)) &
    (pd.to_datetime(df['disclosed_at']).dt.tz_convert('Asia/Seoul').dt.dayofweek.isin([0,1,2,3,4])) &
    (pd.to_datetime(df['disclosed_at']).dt.tz_convert('Asia/Seoul').dt.strftime('%Y%m%d').isin(target_dates))
]

for _, row in null_returns_df.iterrows():
    stock_code = row['stock_code']
    market = row['market']
    # disclosed_at이 이미 문자열인 경우 처리
    if isinstance(row['disclosed_at'], str):
        disclosed_date = pd.to_datetime(row['disclosed_at']).strftime('%Y%m%d')
    else:
        disclosed_date = row['disclosed_at'].strftime('%Y%m%d')
    
    # 시장별 파티션 디렉터리 설정
    if market == 'KOSPI':
        partition_dir = KOSPI_PARTITION_DIR
    elif market == 'KOSDAQ':
        partition_dir = KOSDAQ_PARTITION_DIR
    else:
        missing_partition_files.append({
            'id': row['id'],
            'stock_code': stock_code,
            'market': market,
            'disclosed_date': disclosed_date,
            'company_name': row['company_name'],
            'reason': '알 수 없는 시장'
        })
        continue
    
    # 파티션 파일 경로 확인
    partition_path = partition_dir / f"체결일자={disclosed_date}"
    
    if partition_path.exists():
        try:
            # 해당 종목의 데이터가 있는지 확인
            df_partition = pl.scan_parquet(
                partition_path,
                hive_partitioning=True,
                low_memory=True,
            ).filter(
                (pl.col("체결일자") == int(disclosed_date)) &
                (pl.col("종목코드") == stock_code)
            ).select(["종목코드", "체결일자"]).limit(1).collect()
            
            if len(df_partition) > 0:
                existing_partition_files.append({
                    'id': row['id'],
                    'stock_code': stock_code,
                    'market': market,
                    'disclosed_date': disclosed_date,
                    'company_name': row['company_name']
                })
                print(f"✓ {market} {stock_code} ({row['company_name']}) - {disclosed_date}: 파티션 데이터 존재")
            else:
                missing_partition_files.append({
                    'id': row['id'],
                    'stock_code': stock_code,
                    'market': market,
                    'disclosed_date': disclosed_date,
                    'company_name': row['company_name'],
                    'reason': '파티션 폴더는 존재하지만 해당 종목 데이터 없음'
                })
                print(f"✗ {market} {stock_code} ({row['company_name']}) - {disclosed_date}: 파티션 폴더는 있지만 종목 데이터 없음")
        except Exception as e:
            missing_partition_files.append({
                'id': row['id'],
                'stock_code': stock_code,
                'market': market,
                'disclosed_date': disclosed_date,
                'company_name': row['company_name'],
                'reason': f'파티션 파일 읽기 오류: {str(e)}'
            })
            print(f"✗ {market} {stock_code} ({row['company_name']}) - {disclosed_date}: 파티션 파일 읽기 오류")
    else:
        missing_partition_files.append({
            'id': row['id'],
            'stock_code': stock_code,
            'market': market,
            'disclosed_date': disclosed_date,
            'company_name': row['company_name'],
            'reason': '파티션 폴더 없음'
        })
        print(f"✗ {market} {stock_code} ({row['company_name']}) - {disclosed_date}: 파티션 폴더 없음")

print(f"\n=== 파티션 데이터 요약 ===")
print(f"파티션 데이터가 존재하는 종목: {len(existing_partition_files)}개")
print(f"파티션 데이터가 없는 종목: {len(missing_partition_files)}개")

# 파티션 데이터가 존재하는 종목들 상세 정보
if existing_partition_files:
    print(f"\n=== 파티션 데이터가 존재하는 종목들 ===")
    existing_partition_df = pd.DataFrame(existing_partition_files)
    print(existing_partition_df)

# 파티션 데이터가 없는 종목들 상세 정보
if missing_partition_files:
    print(f"\n=== 파티션 데이터가 없는 종목들 ===")
    missing_partition_df = pd.DataFrame(missing_partition_files)
    print(missing_partition_df.groupby('reason').size())
# Out:
# === Partitioned 폴더에서 데이터 존재 여부 확인 ===
# ✓ KOSDAQ KR7046440004 (KG모빌리언스) - 20231101: 파티션 데이터 존재
# ✓ KOSDAQ KR7262260003 (에이프로) - 20231101: 파티션 데이터 존재
# ✓ KOSDAQ KR7144510005 (지씨셀) - 20231101: 파티션 데이터 존재
# ✗ KOSPI KR7066970005 (엘앤에프) - 20231101: 파티션 폴더는 있지만 종목 데이터 없음
# ✓ KOSDAQ KR7234690006 (녹십자웰빙) - 20231101: 파티션 데이터 존재
# ✓ KOSDAQ KR7122870009 (와이지엔터테인먼트) - 20231101: 파티션 데이터 존재
# ✓ KOSDAQ KR7018310003 (삼목에스폼) - 20231101: 파티션 데이터 존재
# ✓ KOSDAQ KR7376300000 (디어유) - 20231106: 파티션 데이터 존재
# ✓ KOSDAQ KR7079810008 (디이엔티) - 20231106: 파티션 데이터 존재
# ✗ KOSPI KR7066970005 (엘앤에프) - 20231106: 파티션 폴더는 있지만 종목 데이터 없음
# ✓ KOSDAQ KR7214430001 (아이쓰리시스템) - 20231106: 파티션 데이터 존재
# ✓ KOSDAQ KR7194480000 (데브시스터즈) - 20231106: 파티션 데이터 존재
# ✓ KOSDAQ KR7032620007 (유비케어) - 20231106: 파티션 데이터 존재
# ✓ KOSDAQ KR7235980000 (메드팩토) - 20231106: 파티션 데이터 존재
# ✓ KOSDAQ KR7207760000 (미스터블루) - 20231106: 파티션 데이터 존재
# ✗ KOSDAQ KR7078130002 (국일제지) - 20231108: 파티션 폴더는 있지만 종목 데이터 없음
# ✓ KOSDAQ KR
) - 20231114: 파티션 데이터 존재
# ✓ KOSDAQ KR7222040008 (코스맥스엔비티) - 20231114: 파티션 데이터 존재
# ✓ KOSDAQ KR7026150003 (특수건설) - 20231114: 파티션 데이터 존재
# ✓ KOSDAQ KR7228850004 (레이언스) - 20231114: 파티션 데이터 존재
# ✓ KOSDAQ KR7217330000 (싸이토젠) - 20231114: 파티션 데이터 존재
# ✓ KOSDAQ KR7122640006 (예스티) - 20231114: 파티션 데이터 존재
# ✓ KOSDAQ KR7420770000 (기가비스) - 20231114: 파티션 데이터 존재
# ✓ KOSDAQ KR7441270006 (파인엠텍) - 20231114: 파티션 데이터 존재
# ✓ KOSDAQ KR7042000000 (카페24) - 20231114: 파티션 데이터 존재
# ✓ KOSDAQ KR7388720005 (유일로보틱스) - 20231114: 파티션 데이터 존재
# ✓ KOSDAQ KR7298830001 (슈어소프트테크) - 20231115: 파티션 데이터 존재
# ✓ KOSPI KR7001260009 (남광토건) - 20231116: 파티션 데이터 존재
# ✗ KOSPI KR7101140002 (인바이오젠) - 20231116: 파티션 폴더는 있지만 종목 데이터 없음
# ✗ KOSPI KR7001080001 (만호제강) - 20231117: 파티션 폴더는 있지만 종목 데이터 없음
# ✓ KOSDAQ KR7214370009 (케어젠) - 20231208: 파티션 데이터 존재
# ✗ KOSPI KR7022100002 (포스코DX) - 20231213: 파티션 폴더는 있지만 종목 데이터 없음
# ✓ KOSDAQ KR7267320000 (나인테크) - 20231213: 파티션 데이터 존재
# ✓ KOSDAQ KR7104460001 (디와이피엔에프) - 20231213: 파티션 데이터 존재
# ✓ KOSDAQ KR8392070007 (SBI핀테크솔루션즈) - 20231213: 파티션 데이터 존재
# ✓ KOSDAQ KR7174900001 (앱클론) - 20231213: 파티션 데이터 존재
# ✓ KOSDAQ KR7251630000 (브이원텍) - 20231213: 파티션 데이터 존재
# ✓ KOSDAQ KR7122990005 (와이솔) - 20231215: 파티션 데이터 존재
# ✓ KOSDAQ KR7290650001 (엘앤씨바이오) - 20231215: 파티션 데이터 존재
# ✓ KOSDAQ KR7267320000 (나인테크) - 20231215: 파티션 데이터 존재
# ✓ KOSDAQ KR7112040001 (위메이드) - 20231215: 파티션 데이터 존재
# ✓ KOSDAQ KR7046440004 (KG모빌리언스) - 20231215: 파티션 데이터 존재
# ✓ KOSDAQ KR7264660002 (씨앤지하이테크) - 20231215: 파티션 데이터 존재
# ✓ KOSDAQ KR7072020001 (중앙백신) - 20231215: 파티션 데이터 존재
# ✓ KOSDAQ KR7044340008 (위닉스) - 20231215: 파티션 데이터 존재
# ✗ KOSPI KR7022100002 (포스코DX) - 20231215: 파티션 폴더는 있지만 종목 데이터 없음
# ✓ KOSDAQ KR7086670007 (비엠티) - 20231215: 파티션 데이터 존재
# ✓ KOSDAQ KR7056730005 (CNT85) - 20231215: 파티션 데이터 존재
# ✓ KOSDAQ KR7099320004 (쎄트렉아이) - 20231215: 파티션 데이터 존재
# ✗ KOSDAQ KR7150840007 (인트로메딕) - 20231227: 파티션 폴더는 있지만 종목 데이터 없음
# ✓ KOSPI KR7001260009 (남광토건) - 20231228: 파티션 데이터 존재
#
# === 파티션 데이터 요약 ===
# 파티션 데이터가 존재하는 종목: 241개
# 파티션 데이터가 없는 종목: 13개
#
# === 파티션 데이터가 존재하는 종목들 ===
#         id    stock_code  market disclosed_date company_name
# 0    64688  KR7046440004  KOSDAQ       20231101      KG모빌리언스
# 1    64693  KR7262260003  KOSDAQ       20231101         에이프로
# 2    64697  KR7144510005  KOSDAQ       20231101          지씨셀
# 3    64711  KR7234690006  KOSDAQ       20231101        녹십자웰빙
# 4    64715  KR7122870009  KOSDAQ       20231101    와이지엔터테인먼트
# ..     ...           ...     ...            ...          ...
# 236  67612  KR7044340008  KOSDAQ       20231215          위닉스
# 237  67619  KR7086670007  KOSDAQ       20231215          비엠티
# 238  67627  KR7056730005  KOSDAQ       20231215        CNT85
# 239  67628  KR7099320004  KOSDAQ       20231215        쎄트렉아이
# 240  68134  KR7001260009   KOSPI       20231228         남광토건
#
# [241 rows x 5 columns]
#
# === 파티션 데이터가 없는 종목들 ===
# reason
# 파티션 폴더는 존재하지만 해당 종목 데이터 없음    13
# dtype: int64
