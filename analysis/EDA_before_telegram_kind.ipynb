# %%
import sys
import os
sys.path.append('../dags')

from database import create_database_engine


# 환경 변수 설정
os.environ["POSTGRES_USER"] = "airflow"
os.environ["POSTGRES_PASSWORD"] = "airflow"
os.environ["POSTGRES_DB"] = "events"
os.environ["POSTGRES_PORT"] = "5433"

engine = create_database_engine(host="127.0.0.1")
print("Successfully connected to the database")
# Out:
# Successfully connected to the database

# %%
import pandas as pd
from datetime import datetime
table = "kind"
# 날짜 범위 설정
start_date = datetime(2021, 1, 1)
end_date = datetime(2022, 6, 30)

query = f"""SELECT * FROM {table}
WHERE stock_code != ''
  AND market IN ('KOSPI', 'KOSDAQ', 'KOSDAQ GLOBAL')
  AND disclosed_at >= %(start_date)s
  AND disclosed_at <= %(end_date)s
  AND label is not NULL
ORDER BY disclosed_at ASC"""

df = pd.read_sql(query, engine, params={"start_date": start_date, "end_date": end_date})
print(f"데이터베이스에서 조회된 공시 이벤트 수: {len(df)}")
df.head()
# Out:
# WARNING:  database "events" has a collation version mismatch
# DETAIL:  The database was created using collation version 2.36, but the operating system provides version 2.41.
# HINT:  Rebuild all objects in this database that use the default collation and run ALTER DATABASE events REFRESH COLLATION VERSION, or build PostgreSQL with the right library version.
# 데이터베이스에서 조회된 공시 이벤트 수: 13230
#        id   disclosure_id        disclosed_at company_name    stock_code  \
# 0  157471  20210104000042 2021-01-04 08:40:00          디모아  KR7016670002
# 1  157469  20210104000057 2021-01-04 09:18:00        두산퓨얼셀  KR7336260005
# 2  157467  20210104000059 2021-01-04 09:30:00        인텍플러스  KR7064290000
# 3  157460  20210104000073 2021-01-04 10:08:00        에코바이오  KR7038870002
# 4  157461  20210104000070 2021-01-04 10:08:00        에코바이오  KR7038870002
#
#   short_code  market              title  \
# 0     016670  KOSDAQ               영업정지
# 1     336260   KOSPI        단일판매ㆍ공급계약체결
# 2     064290  KOSDAQ  단일판매ㆍ공급계약체결(자율공시)
# 3     038870  KOSDAQ        단일판매ㆍ공급계약체결
# 4     038870  KOSDAQ        단일판매ㆍ공급계약체결
#
#                                           summary_kr  \
# 0  디모아는 2021년 1월 1일부터 어도비시스템즈의 국내 총판권에 대한 영업정지를 받...
# 1  이 보고서는 2020년 12월 31일에 체결된 국내 연료전지 시스템 공급 계약에 관...
# 2  이 회사는 대만의 TAKEWIN INTERNATIONAL과 2020년 12월에 비메...
# 3  이 계약은 수도권매립지관리공사와 체결한 50MW 발전 및 부대시설 위탁관리운영 계약...
# 4  이 계약은 수도권매립지관리공사와 체결한 수도권매립지 제1,2매립장 유지관리 용역으로...
#
#                                                  raw  \
# 0  영업정지 정보\n====================\n회사명: 디모아\n법인구분:...
# 1  1. 판매ㆍ공급계약 구분: 기타 판매ㆍ공급계약\n- 체결계약명: 연료전지 시스템 공...
# 2  1. 판매ㆍ공급계약 내용: 비메모리용 Substrate 검사 장비\n2. 계약내역\...
# 3  1. 판매ㆍ공급계약 내용: 50MW 발전 및 부대시설 위탁관리운영\n2. 계약내역\...
# 4  1. 판매ㆍ공급계약 내용: 수도권매립지 제 1,2매립장 시설물 유지관리 용역(장기계...
#
#                                           detail_url  \
# 0  https://kind.krx.co.kr/common/disclsviewer.do?...
# 1  https://kind.krx.co.kr/common/disclsviewer.do?...
# 2  https://kind.krx.co.kr/common/disclsviewer.do?...
# 3  https://kind.krx.co.kr/common/disclsviewer.do?...
# 4  https://kind.krx.co.kr/common/disclsviewer.do?...
#
#                   created_at                 updated_at  is_modify  \
# 0 2025-09-20 12:22:30.081166 2025-10-17 04:09:46.256941          0
# 1 2025-09-20 12:22:30.080484 2025-10-17 04:09:46.256941          0
# 2 2025-09-20 12:22:30.079747 2025-10-17 04:09:46.256941          0
# 3 2025-09-20 12:22:30.077292 2025-10-17 04:09:46.256941          0
# 4 2025-09-20 12:22:30.077638 2025-10-17 04:09:46.256941          0
#
#   disclosure_type dart_unique_id  \
# 0            영업정지       00125725
# 1     단일판매ㆍ공급계약체결       01412725
# 2     단일판매ㆍ공급계약체결       00479787
# 3     단일판매ㆍ공급계약체결       00287812
# 4     단일판매ㆍ공급계약체결       00287812
#
#                                               masked  label
# 0  회사 A는 2021년 1월 1일부터 회사 B의 국내 총판권에 대한 영업정지를 받고 ...      0
# 1  이 보고서는 2020년 12월 31일에 체결된 국내 연료전지 시스템 공급 계약에 관...      0
# 2  이 회사는 대만의 회사 A과 2020년 12월에 비메모리용 Substrate 검사 ...      0
# 3  이 계약은 수도권매립지관리공사와 체결한 50MW 발전 및 부대시설 위탁관리운영 계약...      0
# 4  이 계약은 회사 A와 체결한 수도권매립지 제1,2매립장 유지관리 용역으로, 1차년도...      0

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 시장 순서를 KOSPI, KOSDAQ(및 GLOBAL)로 정렬
market_order = ['KOSPI', 'KOSDAQ', 'KOSDAQ GLOBAL']
# Series를 위 순서로 재정렬(존재하는 시장만)
market_counts = df['market'].value_counts()
ordered_markets = [m for m in market_order if m in market_counts.index]
market_counts = market_counts.loc[ordered_markets]

print("시장별 공시 분포:")
print(market_counts)
print(f"\n총 공시 건수: {len(df)}")
print("\n시장별 비율:")
for market, count in market_counts.items():
    ratio = count / len(df) * 100
    print(f"{market}: {count}건 ({ratio:.1f}%)")

# 시각화 (figure 세로길이 더 길게, 비율(pie) figure 제거)
fig, ax1 = plt.subplots(1, 1, figsize=(10, 8))

# 색깔을 더 연하게, bar를 얇게 설정
color_map = {
    'KOSPI': '#64b5f6',        # 연한 파란색
    'KOSDAQ': '#ff8a80',       # 연한 빨간색
    'KOSDAQ GLOBAL': '#ffd180' # 연한 주황색
}
bar_colors = [color_map[m] for m in market_counts.index]

bar_width = 0.4  # bar 두께를 얇게 지정

# 직접 bar plot (pandas plot 대신 matplotlib 사용)
bars = ax1.bar(
    x=range(len(market_counts)),
    height=market_counts.values,
    color=bar_colors,
    width=bar_width
)

ax1.set_xticks(range(len(market_counts)))
ax1.set_xticklabels(market_counts.index, fontsize=13)
ax1.set_title('Disclosure Distribution by Market', fontsize=16, pad=24)
ax1.set_xlabel('Market', fontsize=14)
ax1.set_ylabel('Number of Disclosures', fontsize=14)
ax1.tick_params(axis='x', rotation=0)  # 회전 없이 일자

# 각 막대 위에 값 표시
for i, v in enumerate(market_counts.values):
    ax1.text(i, v + len(df)*0.01, str(v), ha='center', va='bottom', fontsize=13)

plt.tight_layout()
plt.show()
# Out:
# 시장별 공시 분포:
# market
# KOSPI     5218
# KOSDAQ    8012
# Name: count, dtype: int64
#
# 총 공시 건수: 13230
#
# 시장별 비율:
# KOSPI: 5218건 (39.4%)
# KOSDAQ: 8012건 (60.6%)

# %%
# disclosed_at을 datetime으로 변환 (이미 KST 기준으로 저장됨)
df['disclosed_at'] = pd.to_datetime(df['disclosed_at'])

# 이미 KST 기준이므로 그대로 사용
df['disclosed_at_kst'] = df['disclosed_at']
df = df.sort_values('disclosed_at_kst')
df['time_only'] = df['disclosed_at_kst'].dt.time

# 장중 시간 정의 (9:00 ~ 15:20) - KST 기준
import datetime
market_open = datetime.time(9, 0)
market_close = datetime.time(15, 20)

# 장중/장외 분류
df['market_session'] = df['time_only'].apply(
    lambda x: 'Trading Hours' if market_open <= x <= market_close else 'After Hours'
)

# 결과 집계
session_counts = df['market_session'].value_counts()
print("공시 발표 시간대별 분포 (KST 기준):")
print(session_counts)
print(f"\n장중 비율: {session_counts.get('Trading Hours', 0) / len(df) * 100:.1f}%")
print(f"장외 비율: {session_counts.get('After Hours', 0) / len(df) * 100:.1f}%")

# 시각화
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# 막대 그래프
session_counts.plot(kind='bar', ax=ax1, color=['lightblue', 'lightcoral'])
ax1.set_title('Disclosure Distribution by Trading Session (KST)', fontsize=14, pad=20)
ax1.set_xlabel('Trading Session', fontsize=12)
ax1.set_ylabel('Number of Disclosures', fontsize=12)
ax1.tick_params(axis='x', rotation=45)

# 각 막대 위에 값 표시
for i, v in enumerate(session_counts.values):
    ax1.text(i, v + len(df)*0.01, str(v), ha='center', va='bottom', fontsize=11)

# 파이 차트
session_ratios = session_counts / len(df) * 100
ax2.pie(session_ratios.values, labels=session_ratios.index, autopct='%1.1f%%', 
        startangle=90, colors=['lightblue', 'lightcoral'])
ax2.set_title('Disclosure Distribution by Trading Session (KST)', fontsize=14, pad=20)

plt.tight_layout()
plt.show()

plt.tight_layout()
plt.show()
# Out:
# 공시 발표 시간대별 분포 (KST 기준):
# market_session
# After Hours      7856
# Trading Hours    5374
# Name: count, dtype: int64
#
# 장중 비율: 40.6%
# 장외 비율: 59.4%

# %%
import pandas as pd
from datetime import datetime

# 1분 단위 abn_ret 컬럼을 -9분~+9분까지 모두 추가
minute_offsets = list(range(-9, 0)) + list(range(1, 10))
minute_columns = [f"ar.abn_ret_{'minus_' if m < 0 else ''}{abs(m)}m" for m in minute_offsets]

# 기존 10, 20, ... 60m 컬럼
more_minute_columns = [
    "ar.abn_ret_minus_60m",
    "ar.abn_ret_minus_50m",
    "ar.abn_ret_minus_40m",
    "ar.abn_ret_minus_30m",
    "ar.abn_ret_minus_20m",
    "ar.abn_ret_minus_10m",
    "ar.abn_ret_10m",
    "ar.abn_ret_20m",
    "ar.abn_ret_30m",
    "ar.abn_ret_40m",
    "ar.abn_ret_50m",
    "ar.abn_ret_60m"
]

all_abn_ret_cols = ',\n    '.join(minute_columns + more_minute_columns)

query = f"""
SELECT ar.event_id,
    ar.event_ts,
    {all_abn_ret_cols},
    k.company_name,
    k.disclosure_type,
    k.masked,
    k.label
FROM abnormal_return_kind ar
JOIN "kind" k ON ar.event_id = k.id
WHERE k.disclosed_at >= '{start_date.strftime('%Y-%m-%d')}'
  AND k.disclosed_at <= '{end_date.strftime('%Y-%m-%d')}'
ORDER BY k.disclosed_at ASC
"""

target_df = pd.read_sql(query, engine)
target_df
# Out:
#       event_id                  event_ts  abn_ret_minus_9m  abn_ret_minus_8m  \
# 0       157461 2021-01-04 10:08:00+00:00             -2.14             -1.20
# 1       157460 2021-01-04 10:08:00+00:00             -2.14             -1.20
# 2       157459 2021-01-04 10:08:00+00:00               NaN             -1.45
# 3       157457 2021-01-04 10:14:00+00:00             -8.59             -8.32
# 4       157455 2021-01-04 10:16:00+00:00              0.50              0.23
# ...        ...                       ...               ...               ...
# 5067     23319 2022-06-29 14:04:00+00:00              1.83              1.79
# 5068     23317 2022-06-29 14:20:00+00:00             -0.08             -0.05
# 5069     23316 2022-06-29 14:21:00+00:00              0.15             -0.02
# 5070     23309 2022-06-29 14:35:00+00:00              0.16              0.06
# 5071     23300 2022-06-29 14:46:00+00:00              0.25              0.14
#
#       abn_ret_minus_7m  abn_ret_minus_6m  abn_ret_minus_5m  abn_ret_minus_4m  \
# 0                -1.32             -1.93             -2.38             -2.05
# 1                -1.32             -1.93             -2.38             -2.05
# 2                -1.64             -1.44             -2.24             -2.49
# 3                -8.32             -8.19             -8.65             -8.42
# 4                 0.21              0.23              0.23              0.15
# ...                ...               ...               ...               ...
# 5067              2.27              2.25              0.06              2.27
# 5068             -0.10             -0.05             -0.03             -0.10
# 5069             -0.09             -0.07             -0.02             -0.08
# 5070              0.13             -0.13             -0.02              0.00
# 5071              0.19              0.19              0.19              1.10
#
#       abn_ret_minus_3m  abn_ret_minus_2m  ...  abn_ret_10m  abn_ret_20m  \
# 0                -2.45             -1.76  ...        -0.45         0.17
# 1                -2.45             -1.76  ...        -0.45         0.17
# 2                -2.69             -1.96  ...        -1.91        -0.66
# 3                -8.36             -8.10  ...        -4.90        -4.20
# 4                 0.01             -0.31  ...         0.03        -0.83
# ...                ...               ...  ...          ...          ...
# 5067              1.87              1.83  ...         0.55         0.43
# 5068             -0.16             -0.18  ...        -0.03         0.34
# 5069              0.03             -0.08  ...         0.06        -0.04
# 5070             -0.29             -0.06  ...        -0.22         0.03
# 5071              1.05              1.01  ...         0.48        -0.09
#
#       abn_ret_30m  abn_ret_40m  abn_ret_50m  abn_ret_60m  company_name  \
# 0            0.05         0.15        -0.15         0.18         에코바이오
# 1            0.05         0.15        -0.15         0.18         에코바이오
# 2           -1.47        -1.37        -0.60        -0.95         제이엘케이
# 3           -3.46        -5.53        -5.16        -6.00          엠아이텍
# 4           -0.54        -0.96        -0.57        -1.83         한화시스템
# ...           ...          ...          ...          ...           ...
# 5067        -0.82        -0.84        -0.85        -1.63     SK바이오사이언스
# 5068         0.11         0.32         0.54         0.24       코람코더원리츠
# 5069        -0.11        -0.32         0.03          NaN         DL이앤씨
# 5070         0.03        -0.08          NaN          NaN            DL
# 5071         0.19          NaN          NaN          NaN           링네트
#
#       disclosure_type                                             masked  \
# 0         단일판매ㆍ공급계약체결  이 계약은 회사 A와 체결한 수도권매립지 제1,2매립장 유지관리 용역으로, 1차년도...
# 1         단일판매ㆍ공급계약체결  이 계약은 수도권매립지관리공사와 체결한 50MW 발전 및 부대시설 위탁관리운영 계약...
# 2         단일판매ㆍ공급계약체결  이 기업은 인공지능 기반 캡슐내시경 소프트웨어 개발 및 공급계약을 주식회사 A와 체...
# 3             품목허가 승인  회사 A HANAROSTENT Trachea/Bronchium (CCC) 스텐트가 ...
# 4         단일판매ㆍ공급계약체결  이 회사 A는 2020년 12월 31일 국방과학연구소와 방위산업 보안을 위해 완성형...
# ...               ...                                                ...
# 5067          품목허가 승인  회사 A(GBP510)은 SARS-CoV-2 감염 예방을 위해 개발된 재조합 단백질...
# 5068            매출액변동  이번 재무제표는 개별 재무상태를 나타내며, 매출액이 50% 증가하여 6,835,94...
# 5069      단일판매ㆍ공급계약체결  이 회사는 서울특별시 영등포구 여의도동에서 복합시설 신축공사를 수주했으며, 계약금액...
# 5070      단일판매ㆍ공급계약체결  이 기업은 서울특별시 영등포구 여의도동의 복합시설 신축공사를 수주했으며, 계약금액은...
# 5071       자기주식 처분 결정  회사 A는 임직원 성과급 지급을 위해 2022년 6월 30일부터 9월 29일까지 1...
#
#       label
# 0         0
# 1         0
# 2         1
# 3         1
# 4        -1
# ...     ...
# 5067      1
# 5068      1
# 5069      1
# 5070      1
# 5071      0
#
# [5072 rows x 36 columns]

# %%
print("\n=== 기본 데이터 분석 ===")

# 컬럼 정보
print(f"컬럼 수: {len(target_df.columns)}")
print(f"컬럼명: {list(target_df.columns)}")

# 데이터 타입
print("\n데이터 타입:")
print(target_df.dtypes)

# 결측값 확인
print("\n결측값 현황:")
print(target_df.isnull().sum())
# Out:
# === 기본 데이터 분석 ===
# 컬럼 수: 36
# 컬럼명: ['event_id', 'event_ts', 'abn_ret_minus_9m', 'abn_ret_minus_8m', 'abn_ret_minus_7m', 'abn_ret_minus_6m', 'abn_ret_minus_5m', 'abn_ret_minus_4m', 'abn_ret_minus_3m', 'abn_ret_minus_2m', 'abn_ret_minus_1m', 'abn_ret_1m', 'abn_ret_2m', 'abn_ret_3m', 'abn_ret_4m', 'abn_ret_5m', 'abn_ret_6m', 'abn_ret_7m', 'abn_ret_8m', 'abn_ret_9m', 'abn_ret_minus_60m', 'abn_ret_minus_50m', 'abn_ret_minus_40m', 'abn_ret_minus_30m', 'abn_ret_minus_20m', 'abn_ret_minus_10m', 'abn_ret_10m', 'abn_ret_20m', 'abn_ret_30m', 'abn_ret_40m', 'abn_ret_50m', 'abn_ret_60m', 'company_name', 'disclosure_type', 'masked', 'label']
#
# 데이터 타입:
# event_id                           int64
# event_ts             datetime64[ns, UTC]
# abn_ret_minus_9m                 float64
# abn_ret_minus_8m                 float64
# abn_ret_minus_7m                 float64
# abn_ret_minus_6m                 float64
# abn_ret_minus_5m                 float64
# abn_ret_minus_4m                 float64
# abn_ret_minus_3m                 float64
# abn_ret_minus_2m                 float64
# abn_ret_minus_1m                 float64
# abn_ret_1m                       float64
# abn_ret_2m                       float64
# abn_ret_3m                       float64
# abn_ret_4m                       float64
# abn_ret_5m                       float64
# abn_ret_6m                       float64
# abn_ret_7m                       float64
# abn_ret_8m                       float64
# abn_ret_9m                       float64
# abn_ret_minus_60m                float64
# abn_ret_minus_50m                float64
# abn_ret_minus_40m                float64
# abn_ret_minus_30m                float64
# abn_ret_minus_20m                float64
# abn_ret_minus_10m                float64
# abn_ret_10m                      float64
# abn_ret_20m                      float64
# abn_ret_30m                      float64
# abn_ret_40m                      float64
# abn_ret_50m                      float64
# abn_ret_60m                      float64
# company_name                      object
# disclosure_type                   object
# masked                            object
# label                              int64
# dtype: object
#
# 결측값 현황:
# event_id                0
# event_ts                0
# abn_ret_minus_9m       50
# abn_ret_minus_8m       44
# abn_ret_minus_7m       37
# abn_ret_minus_6m       30
# abn_ret_minus_5m       23
# abn_ret_minus_4m       16
# abn_ret_minus_3m        8
# abn_ret_minus_2m        5
# abn_ret_minus_1m        2
# abn_ret_1m             28
# abn_ret_2m             48
# abn_ret_3m             73
# abn_ret_4m             95
# abn_ret_5m            114
# abn_ret_6m            132
# abn_ret_7m            159
# abn_ret_8m            189
# abn_ret_9m            216
# abn_ret_minus_60m     490
# abn_ret_minus_50m     387
# abn_ret_minus_40m     290
# abn_ret_minus_30m     199
# abn_ret_minus_20m     128
# abn_ret_minus_10m      58
# abn_ret_10m           244
# abn_ret_20m           476
# abn_ret_30m           706
# abn_ret_40m           940
# abn_ret_50m          1158
# abn_ret_60m          1391
# company_name            0
# disclosure_type         0
# masked                  0
# label                   0
# dtype: int64

# %%
abn_ret_cols = [f"abn_ret_minus_{i}m" for i in range(10, 0, -1)] + [f"abn_ret_{i}m" for i in range(1, 11)]
target_df.describe()[abn_ret_cols].round(2)
# Out:
#        abn_ret_minus_10m  abn_ret_minus_9m  abn_ret_minus_8m  \
# count            5014.00           5022.00           5028.00
# mean               -1.04             -1.04             -1.04
# std                 1.82              1.79              1.79
# min               -21.02            -21.53            -21.05
# 25%                -1.45             -1.44             -1.44
# 50%                -0.56             -0.55             -0.56
# 75%                -0.06             -0.06             -0.06
# max                39.10             35.06             34.89
#
#        abn_ret_minus_7m  abn_ret_minus_6m  abn_ret_minus_5m  abn_ret_minus_4m  \
# count           5035.00           5042.00           5049.00           5056.00
# mean              -1.04             -1.03             -1.04             -1.03
# std                1.77              1.76              1.71              1.69
# min              -21.05            -21.50            -21.29            -21.50
# 25%               -1.45             -1.43             -1.41             -1.41
# 50%               -0.56             -0.56             -0.55             -0.56
# 75%               -0.07             -0.06             -0.07             -0.06
# max               32.24             32.24             17.10             17.10
#
#        abn_ret_minus_3m  abn_ret_minus_2m  abn_ret_minus_1m  abn_ret_1m  \
# count           5064.00           5067.00           5070.00     5044.00
# mean              -1.04             -1.02             -1.01       -0.03
# std                1.68              1.64              1.63        1.13
# min              -21.53            -13.40            -13.36       -7.63
# 25%               -1.41             -1.37             -1.35       -0.31
# 50%               -0.55             -0.52             -0.50        0.00
# 75%               -0.06             -0.06             -0.03        0.25
# max               15.25             11.83             12.90       11.15
#
#        abn_ret_2m  abn_ret_3m  abn_ret_4m  abn_ret_5m  abn_ret_6m  abn_ret_7m  \
# count     5024.00     4999.00     4977.00     4958.00     4940.00     4913.00
# mean        -0.04       -0.12       -0.17       -0.22       -0.25       -0.28
# std          1.37        1.56        1.65        1.69        1.74        1.77
# min        -10.02      -13.49      -12.69      -13.88      -13.95      -13.71
# 25%         -0.42       -0.53       -0.58       -0.67       -0.72       -0.73
# 50%          0.00       -0.03       -0.05       -0.08       -0.10       -0.11
# 75%          0.32        0.31        0.31        0.32        0.32        0.33
# max         14.90       15.84       19.23       19.23       24.69       24.19
#
#        abn_ret_8m  abn_ret_9m  abn_ret_10m
# count     4883.00     4856.00      4828.00
# mean        -0.30       -0.31        -0.33
# std          1.82        1.85         1.86
# min        -17.96      -16.70       -17.71
# 25%         -0.75       -0.77        -0.78
# 50%         -0.11       -0.10        -0.11
# 75%          0.33        0.33         0.32
# max         22.33       19.52        21.87

# %%
abn_ret_cols = [f"abn_ret_minus_{i}m" for i in range(60, 0, -10)] + [f"abn_ret_{i}m" for i in range(10, 70, 10)]
target_df.describe()[abn_ret_cols].round(2)
# Out:
#        abn_ret_minus_60m  abn_ret_minus_50m  abn_ret_minus_40m  \
# count            4582.00            4685.00            4782.00
# mean               -1.08              -1.07              -1.05
# std                 2.16               2.13               2.07
# min               -22.59             -22.17             -22.30
# 25%                -1.66              -1.64              -1.59
# 50%                -0.64              -0.62              -0.62
# 75%                 0.03               0.02               0.00
# max                51.78              51.57              51.05
#
#        abn_ret_minus_30m  abn_ret_minus_20m  abn_ret_minus_10m  abn_ret_10m  \
# count            4873.00            4944.00            5014.00      4828.00
# mean               -1.05              -1.04              -1.04        -0.33
# std                 2.00               1.95               1.82         1.86
# min               -22.50             -23.12             -21.02       -17.71
# 25%                -1.55              -1.52              -1.45        -0.78
# 50%                -0.61              -0.60              -0.56        -0.11
# 75%                -0.01              -0.03              -0.06         0.32
# max                51.84              52.47              39.10        21.87
#
#        abn_ret_20m  abn_ret_30m  abn_ret_40m  abn_ret_50m  abn_ret_60m
# count      4596.00      4366.00      4132.00      3914.00      3681.00
# mean         -0.37        -0.36        -0.15        -0.20        -0.22
# std           2.09         2.27         3.18         3.22         3.31
# min         -23.17       -22.85       -22.59       -19.62       -20.66
# 25%          -0.91        -0.97        -1.06        -1.16        -1.22
# 50%          -0.16        -0.17        -0.22        -0.24        -0.26
# 75%           0.35         0.38         0.50         0.48         0.51
# max          20.01        24.13        29.28        29.81        29.60

# %%
target_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5072 entries, 0 to 5071
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   event_id           5072 non-null   int64
#  1   event_ts           5072 non-null   datetime64[ns, UTC]
#  2   abn_ret_minus_9m   5022 non-null   float64
#  3   abn_ret_minus_8m   5028 non-null   float64
#  4   abn_ret_minus_7m   5035 non-null   float64
#  5   abn_ret_minus_6m   5042 non-null   float64
#  6   abn_ret_minus_5m   5049 non-null   float64
#  7   abn_ret_minus_4m   5056 non-null   float64
#  8   abn_ret_minus_3m   5064 non-null   float64
#  9   abn_ret_minus_2m   5067 non-null   float64
#  10  abn_ret_minus_1m   5070 non-null   float64
#  11  abn_ret_1m         5044 non-null   float64
#  12  abn_ret_2m         5024 non-null   float64
#  13  abn_ret_3m         4999 non-null   float64
#  14  abn_ret_4m         4977 non-null   float64
#  15  abn_ret_5m         4958 non-null   float64
#  16  abn_ret_6m         4940 non-null   float64
#  17  abn_ret_7m         4913 non-null   float64
#  18  abn_ret_8m         4883 non-null   float64
#  19  abn_ret_9m         4856 non-null   float64
#  20  abn_ret_minus_60m  4582 non-null   float64
#  21  abn_ret_minus_50m  4685 non-null   float64
#  22  abn_ret_minus_40m  4782 non-null   float64
#  23  abn_ret_minus_30m  4873 non-null   float64
#  24  abn_ret_minus_20m  4944 non-null   float64
#  25  abn_ret_minus_10m  5014 non-null   float64
#  26  abn_ret_10m        4828 non-null   float64
#  27  abn_ret_20m        4596 non-null   float64
#  28  abn_ret_30m        4366 non-null   float64
#  29  abn_ret_40m        4132 non-null   float64
#  30  abn_ret_50m        3914 non-null   float64
#  31  abn_ret_60m        3681 non-null   float64
#  32  company_name       5072 non-null   object
#  33  disclosure_type    5072 non-null   object
#  34  masked             5072 non-null   object
#  35  label              5072 non-null   int64
# dtypes: datetime64[ns, UTC](1), float64(30), int64(2), object(3)
# memory usage: 1.4+ MB

# %%
ret_columns = [
    "abn_ret_minus_10m", "abn_ret_minus_20m", "abn_ret_minus_30m", 
    "abn_ret_minus_40m", "abn_ret_minus_50m", "abn_ret_minus_60m",
    "abn_ret_10m", "abn_ret_20m", "abn_ret_30m", 
    "abn_ret_40m", "abn_ret_50m", "abn_ret_60m"
]

# %%
target_df['disclosure_type'].value_counts()
# Out:
# disclosure_type
# 단일판매ㆍ공급계약체결           1838
# 매출액변동                 1354
# 특허권취득                  378
# 타법인 주식 및 출자증권 양수결정     278
# 자기주식취득 신탁계약 체결 결정      192
# 자기주식 처분 결정             112
# 자기주식 취득 결정             108
# 신규시설투자                 106
# 무상증자 결정                101
# 전환사채권 발행결정              70
# 유상증자 결정                 56
# 유형자산 양수 결정              55
# 타법인 주식 및 출자증권 양도결정      53
# 자기주식취득 신탁계약 해지 결정       48
# 유형자산 양도 결정              45
# 임상 계획 신청                42
# 임상 계획 승인                40
# 자기주식 소각 결정              30
# 회사합병 결정                 27
# 생산중단                    23
# 단일판매ㆍ공급계약해지             18
# 품목허가 승인                 18
# 주권 관련 사채권 양수 결정         17
# 임상 계획 결과 발표             11
# 교환사채권 발행결정              10
# 회사분할 결정                  9
# 기술이전계약체결                 6
# 품목허가 신청                  5
# 임상 계획 철회                 4
# 영업정지                     4
# 품목허가 철회                  3
# 소송 등의 제기                 3
# 자산양수도(기타), 풋백옵션          2
# 주권 관련 사채권 양도 결정          2
# 기술이전계약해지                 1
# 감자 결정                    1
# 영업양수 결정                  1
# 상각형 조건부자본증권 발행결정         1
# Name: count, dtype: int64

# %%
# config.py의 keywords 딕셔너리를 사용해서 한글-영어 카테고리 매핑 생성
category_mapping = {
    # 임상 관련
    "임상 계획 철회": "Clinical Trial Withdrawal",
    "임상 계획 신청": "Clinical Trial Application", 
    "임상 계획 승인": "Clinical Trial Approval",
    "임상 계획 결과 발표": "Clinical Trial Results",
    
    # 자산 관련
    "자산양수도(기타), 풋백옵션": "Asset Transfer & Putback Option",
    
    # 경영 관련
    "부도발생": "Default Occurrence",
    "영업정지": "Business Suspension", 
    "회생절차 개시신청": "Rehabilitation Procedure Initiation",
    "해산사유 발생": "Dissolution Cause Occurrence",
    
    # 자본 변동
    "유상증자 결정": "Paid-in Capital Increase Decision",
    "무상증자 결정": "Free Capital Increase Decision", 
    "유무상증자 결정": "Paid/Free Capital Increase Decision",
    "감자 결정": "Capital Reduction Decision",
    "주식분할 결정": "Stock Split Decision",
    
    # 금융 관련
    "채권은행 등의 관리절차 개시": "Creditor Bank Management Procedure Initiation",
    "채권은행 등의 관리절차 중단": "Creditor Bank Management Procedure Suspension",
    
    # 소송/분쟁
    "소송 등의 제기": "Litigation Filing",
    "소송등의판결ㆍ결정": "Litigation Judgment/Decision",
    
    # 해외 상장
    "해외 증권시장 주권등 상장 결정": "Overseas Securities Market Listing Decision",
    "해외 증권시장 주권등 상장폐지 결정": "Overseas Securities Market Delisting Decision", 
    "해외 증권시장 주권등 상장": "Overseas Securities Market Listing",
    "해외 증권시장 주권등 상장폐지": "Overseas Securities Market Delisting",
    
    # 채권 발행
    "전환사채권 발행결정": "Convertible Bond Issuance Decision",
    "신주인수권부사채권 발행결정": "Bond with Warrant Issuance Decision",
    "교환사채권 발행결정": "Exchangeable Bond Issuance Decision",
    "상각형 조건부자본증권 발행결정": "Contingent Convertible Security Issuance Decision",
    
    # 자사주 관련
    "자기주식 취득 결정": "Treasury Stock Acquisition Decision",
    "자기주식 처분 결정": "Treasury Stock Disposal Decision", 
    "자기주식 소각 결정": "Treasury Stock Retirement Decision",
    "자기주식취득 신탁계약 체결 결정": "Treasury Stock Acquisition Trust Contract Decision",
    "자기주식취득 신탁계약 해지 결정": "Treasury Stock Acquisition Trust Contract Termination Decision",
    
    # 영업 양수도
    "영업양수 결정": "Business Acquisition Decision",
    "영업양도 결정": "Business Transfer Decision",
    
    # 자산 취득/처분
    "유형자산 양수 결정": "Tangible Asset Acquisition Decision",
    "유형자산 양도 결정": "Tangible Asset Transfer Decision",
    "타법인 주식 및 출자증권 양수결정": "Other Corporation Stock Acquisition Decision",
    "타법인 주식 및 출자증권 양도결정": "Other Corporation Stock Transfer Decision",
    "주권 관련 사채권 양수 결정": "Stock-related Bond Acquisition Decision",
    "주권 관련 사채권 양도 결정": "Stock-related Bond Transfer Decision",
    
    # 기업 구조 변경
    "회사합병 결정": "Company Merger Decision",
    "회사분할 결정": "Company Spin-off Decision", 
    "회사분할합병 결정": "Company Split-Merger Decision",
    "주식교환ㆍ이전 결정": "Stock Exchange/Transfer Decision",
    
    # 공시 관련
    "지분공시": "Equity Disclosure",
    "실적공시": "Earnings Disclosure",
    
    # 계약 관련
    "단일판매ㆍ공급계약해지": "Single Sales/Supply Contract Termination",
    "단일판매ㆍ공급계약체결": "Single Sales/Supply Contract Execution",
    
    # 기타
    "생산중단": "Production Suspension",
    "배당": "Dividend",
    "매출액변동": "Revenue Change",
    "특허권취득": "Patent Acquisition",
    "신규시설투자": "New Facility Investment",
    "기술이전계약해지": "Technology Transfer Contract Termination",
    "기술이전계약체결": "Technology Transfer Contract Execution",
    
    # 품목허가 관련
    "품목허가 철회": "Product Approval Withdrawal",
    "품목허가 신청": "Product Approval Application",
    "품목허가 승인": "Product Approval",
    
    # 기타
    "횡령ㆍ배임혐의발생": "Embezzlement/Malfeasance Allegation",
    "공개매수": "Public Tender Offer"
}

import pandas as pd
pd.DataFrame(list(category_mapping.items()), columns=["category_kr", "category_en"])
# Out:
#             category_kr                                        category_en
# 0              임상 계획 철회                          Clinical Trial Withdrawal
# 1              임상 계획 신청                         Clinical Trial Application
# 2              임상 계획 승인                            Clinical Trial Approval
# 3           임상 계획 결과 발표                             Clinical Trial Results
# 4       자산양수도(기타), 풋백옵션                    Asset Transfer & Putback Option
# 5                  부도발생                                 Default Occurrence
# 6                  영업정지                                Business Suspension
# 7             회생절차 개시신청                Rehabilitation Procedure Initiation
# 8               해산사유 발생                       Dissolution Cause Occurrence
# 9               유상증자 결정                  Paid-in Capital Increase Decision
# 10              무상증자 결정                     Free Capital Increase Decision
# 11             유무상증자 결정                Paid/Free Capital Increase Decision
# 12                감자 결정                         Capital Reduction Decision
# 13              주식분할 결정                               Stock Split Decision
# 14      채권은행 등의 관리절차 개시      Creditor Bank Management Procedure Initiation
# 15      채권은행 등의 관리절차 중단      Creditor Bank Management Procedure Suspension
# 16             소송 등의 제기                                  Litigation Filing
# 17            소송등의판결ㆍ결정                       Litigation Judgment/Decision
# 18    해외 증권시장 주권등 상장 결정        Overseas Securities Market Listing Decision
# 19  해외 증권시장 주권등 상장폐지 결정      Overseas Securities Market Delisting Decision
# 20       해외 증권시장 주권등 상장                 Overseas Securities Market Listing
# 21     해외 증권시장 주권등 상장폐지               Overseas Securities Market Delisting
# 22           전환사채권 발행결정                 Convertible Bond Issuance Decision
# 23       신주인수권부사채권 발행결정                Bond with Warrant Issuance Decision
# 24           교환사채권 발행결정                Exchangeable Bond Issuance Decision
# 25     상각형 조건부자본증권 발행결정  Contingent Convertible Security Issuance Decision
# 26           자기주식 취득 결정                Treasury Stock Acquisition Decision
# 27           자기주식 처분 결정                   Treasury Stock Disposal Decision
# 28           자기주식 소각 결정                 Treasury Stock Retirement Decision
# 29    자기주식취득 신탁계약 체결 결정  Treasury Stock Acquisition Trust Contract Deci...
# 30    자기주식취득 신탁계약 해지 결정  Treasury Stock Acquisition Trust Contract Term...
# 31              영업양수 결정                      Business Acquisition Decision
# 32              영업양도 결정                         Business Transfer Decision
# 33           유형자산 양수 결정                Tangible Asset Acquisition Decision
# 34           유형자산 양도 결정                   Tangible Asset Transfer Decision
# 35   타법인 주식 및 출자증권 양수결정       Other Corporation Stock Acquisition Decision
# 36   타법인 주식 및 출자증권 양도결정          Other Corporation Stock Transfer Decision
# 37      주권 관련 사채권 양수 결정            Stock-related Bond Acquisition Decision
# 38      주권 관련 사채권 양도 결정               Stock-related Bond Transfer Decision
# 39              회사합병 결정                            Company Merger Decision
# 40              회사분할 결정                          Company Spin-off Decision
# 41            회사분할합병 결정                      Company Split-Merger Decision
# 42           주식교환ㆍ이전 결정                   Stock Exchange/Transfer Decision
# 43                 지분공시                                  Equity Disclosure
# 44                 실적공시                                Earnings Disclosure
# 45          단일판매ㆍ공급계약해지           Single Sales/Supply Contract Termination
# 46          단일판매ㆍ공급계약체결             Single Sales/Supply Contract Execution
# 47                 생산중단                              Production Suspension
# 48                   배당                                           Dividend
# 49                매출액변동                                     Revenue Change
# 50                특허권취득                                 Patent Acquisition
# 51               신규시설투자                            New Facility Investment
# 52             기술이전계약해지           Technology Transfer Contract Termination
# 53             기술이전계약체결             Technology Transfer Contract Execution
# 54              품목허가 철회                        Product Approval Withdrawal
# 55              품목허가 신청                       Product Approval Application
# 56              품목허가 승인                                   Product Approval
# 57            횡령ㆍ배임혐의발생                Embezzlement/Malfeasance Allegation
# 58                 공개매수                                Public Tender Offer

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from config import keywords



df_with_returns = target_df.copy()
category_counts = df_with_returns['disclosure_type'].value_counts()

# 카테고리별 건수 시각화
plt.figure(figsize=(15, 8))
category_counts_sorted = category_counts.sort_values(ascending=False)

# 한글 카테고리를 영어로 매핑
category_counts_sorted_en = category_counts_sorted.copy()
category_counts_sorted_en.index = [category_mapping.get(cat, cat) for cat in category_counts_sorted_en.index]

plt.subplot(1, 2, 1)
plt.bar(range(len(category_counts_sorted_en)), category_counts_sorted_en.values)
plt.title('Disclosure Count by Category')
plt.xlabel('Category')
plt.ylabel('Count')
plt.xticks(range(len(category_counts_sorted_en)), category_counts_sorted_en.index, rotation=45, ha='right')

# 상위 15 카테고리만 별도 표시
plt.subplot(1, 2, 2)
top_15 = category_counts_sorted_en.head(15)
plt.bar(range(len(top_15)), top_15.values)
plt.title('Top 15 Disclosure Categories by Count')
plt.xlabel('Category')
plt.ylabel('Count')
plt.xticks(range(len(top_15)), top_15.index, rotation=45, ha='right')

plt.tight_layout()
plt.show()

print(f"총 {len(category_counts)}개 카테고리, 총 {category_counts.sum()}건의 공시")
print("\n상위 15개 카테고리:")
print(category_counts_sorted.head(15))
# Out:
# 총 38개 카테고리, 총 5072건의 공시
#
# 상위 15개 카테고리:
# disclosure_type
# 단일판매ㆍ공급계약체결           1838
# 매출액변동                 1354
# 특허권취득                  378
# 타법인 주식 및 출자증권 양수결정     278
# 자기주식취득 신탁계약 체결 결정      192
# 자기주식 처분 결정             112
# 자기주식 취득 결정             108
# 신규시설투자                 106
# 무상증자 결정                101
# 전환사채권 발행결정              70
# 유상증자 결정                 56
# 유형자산 양수 결정              55
# 타법인 주식 및 출자증권 양도결정      53
# 자기주식취득 신탁계약 해지 결정       48
# 유형자산 양도 결정              45
# Name: count, dtype: int64

# %%
df_with_returns.isnull().sum()
df_with_returns.describe()
df_with_returns.info()

df_with_returns.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5072 entries, 0 to 5071
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   event_id           5072 non-null   int64
#  1   event_ts           5072 non-null   datetime64[ns, UTC]
#  2   abn_ret_minus_9m   5022 non-null   float64
#  3   abn_ret_minus_8m   5028 non-null   float64
#  4   abn_ret_minus_7m   5035 non-null   float64
#  5   abn_ret_minus_6m   5042 non-null   float64
#  6   abn_ret_minus_5m   5049 non-null   float64
#  7   abn_ret_minus_4m   5056 non-null   float64
#  8   abn_ret_minus_3m   5064 non-null   float64
#  9   abn_ret_minus_2m   5067 non-null   float64
#  10  abn_ret_minus_1m   5070 non-null   float64
#  11  abn_ret_1m         5044 non-null   float64
#  12  abn_ret_2m         5024 non-null   float64
#  13  abn_ret_3m         4999 non-null   float64
#  14  abn_ret_4m         4977 non-null   float64
#  15  abn_ret_5m         4958 non-null   float64
#  16  abn_ret_6m         4940 non-null   float64
#  17  abn_ret_7m         4913 non-null   float64
#  18  abn_ret_8m         4883 non-null   float64
#  19  abn_ret_9m         4856 non-null   float64
#  20  abn_ret_minus_60m  4582 non-null   float64
#  21  abn_ret_minus_50m  4685 non-null   float64
#  22  abn_ret_minus_40m  4782 non-null   float64
#  23  abn_ret_minus_30m  4873 non-null   float64
#  24  abn_ret_minus_20m  4944 non-null   float64
#  25  abn_ret_minus_10m  5014 non-null   float64
#  26  abn_ret_10m        4828 non-null   float64
#  27  abn_ret_20m        4596 non-null   float64
#  28  abn_ret_30m        4366 non-null   float64
#  29  abn_ret_40m        4132 non-null   float64
#  30  abn_ret_50m        3914 non-null   float64
#  31  abn_ret_60m        3681 non-null   float64
#  32  company_name       5072 non-null   object
#  33  disclosure_type    5072 non-null   object
#  34  masked             5072 non-null   object
#  35  label              5072 non-null   int64
# dtypes: datetime64[ns, UTC](1), float64(30), int64(2), object(3)
# memory usage: 1.4+ MB
#    event_id                  event_ts  abn_ret_minus_9m  abn_ret_minus_8m  \
# 0    157461 2021-01-04 10:08:00+00:00             -2.14             -1.20
# 1    157460 2021-01-04 10:08:00+00:00             -2.14             -1.20
# 2    157459 2021-01-04 10:08:00+00:00               NaN             -1.45
# 3    157457 2021-01-04 10:14:00+00:00             -8.59             -8.32
# 4    157455 2021-01-04 10:16:00+00:00              0.50              0.23
#
#    abn_ret_minus_7m  abn_ret_minus_6m  abn_ret_minus_5m  abn_ret_minus_4m  \
# 0             -1.32             -1.93             -2.38             -2.05
# 1             -1.32             -1.93             -2.38             -2.05
# 2             -1.64             -1.44             -2.24             -2.49
# 3             -8.32             -8.19             -8.65             -8.42
# 4              0.21              0.23              0.23              0.15
#
#    abn_ret_minus_3m  abn_ret_minus_2m  ...  abn_ret_10m  abn_ret_20m  \
# 0             -2.45             -1.76  ...        -0.45         0.17
# 1             -2.45             -1.76  ...        -0.45         0.17
# 2             -2.69             -1.96  ...        -1.91        -0.66
# 3             -8.36             -8.10  ...        -4.90        -4.20
# 4              0.01             -0.31  ...         0.03        -0.83
#
#    abn_ret_30m  abn_ret_40m  abn_ret_50m  abn_ret_60m  company_name  \
# 0         0.05         0.15        -0.15         0.18         에코바이오
# 1         0.05         0.15        -0.15         0.18         에코바이오
# 2        -1.47        -1.37        -0.60        -0.95         제이엘케이
# 3        -3.46        -5.53        -5.16        -6.00          엠아이텍
# 4        -0.54        -0.96        -0.57        -1.83         한화시스템
#
#    disclosure_type                                             masked  label
# 0      단일판매ㆍ공급계약체결  이 계약은 회사 A와 체결한 수도권매립지 제1,2매립장 유지관리 용역으로, 1차년도...      0
# 1      단일판매ㆍ공급계약체결  이 계약은 수도권매립지관리공사와 체결한 50MW 발전 및 부대시설 위탁관리운영 계약...      0
# 2      단일판매ㆍ공급계약체결  이 기업은 인공지능 기반 캡슐내시경 소프트웨어 개발 및 공급계약을 주식회사 A와 체...      1
# 3          품목허가 승인  회사 A HANAROSTENT Trachea/Bronchium (CCC) 스텐트가 ...      1
# 4      단일판매ㆍ공급계약체결  이 회사 A는 2020년 12월 31일 국방과학연구소와 방위산업 보안을 위해 완성형...     -1
#
# [5 rows x 36 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

# 시간축 설정 (분 단위)
time_points = [-60, -50, -40, -30, -20, -10, 0, 10, 20, 30, 40, 50, 60]

# 수익률 컬럼들 (시간순서대로 정렬)
ret_columns = [
    'abn_ret_minus_60m', 'abn_ret_minus_50m', 'abn_ret_minus_40m', 
    'abn_ret_minus_30m', 'abn_ret_minus_20m', 'abn_ret_minus_10m',
    0,  # 0분 시점은 없으므로 0으로 설정
    'abn_ret_10m', 'abn_ret_20m', 'abn_ret_30m', 
    'abn_ret_40m', 'abn_ret_50m', 'abn_ret_60m'
]

# 실제 수익률 데이터가 있는 컬럼들만 추출
valid_ret_columns = [col for col in ret_columns if col != 0]
valid_time_points = [t for t in time_points if t != 0]

# 각 시간점별 데이터 수집
all_returns = []
all_times = []

for i, col in enumerate(valid_ret_columns):
    if col in df_with_returns.columns:
        # NaN이 아닌 데이터만 추출
        valid_data = df_with_returns[col].dropna()
        if len(valid_data) > 0:
            # 해당 시간점에 대한 모든 수익률 데이터 추가
            for ret in valid_data:
                all_returns.append(ret)
                all_times.append(valid_time_points[i])

# 개별 점들을 파란색으로 표시
plt.figure(figsize=(15, 8))
plt.scatter(all_times, all_returns, alpha=0.3, color='blue', s=10, label='Individual Returns')

# 각 시간점별 평균 계산 및 빨간색 점으로 표시
mean_returns = []
mean_times = []

for i, col in enumerate(valid_ret_columns):
    if col in df_with_returns.columns:
        valid_data = df_with_returns[col].dropna()
        if len(valid_data) > 0:
            mean_ret = valid_data.mean()
            mean_returns.append(mean_ret)
            mean_times.append(valid_time_points[i])

# 평균값들을 빨간색 점으로 표시
plt.scatter(mean_times, mean_returns, color='red', s=100, marker='o', 
           label='Mean Returns', zorder=5, edgecolor='darkred', linewidth=2)

# 평균값들을 빨간색 선으로 연결
plt.plot(mean_times, mean_returns, color='red', linewidth=2, alpha=0.7, zorder=4)

# 그래프 설정
plt.axhline(y=0, color='black', linestyle='-', alpha=0.3)  # 0% 수평선
plt.axvline(x=0, color='black', linestyle='-', alpha=0.3)  # 0분 수직선

plt.xlabel('Time (minutes)', fontsize=12)
plt.ylabel('Abnormal Return (%)', fontsize=12)
plt.title('Abnormal Returns Over Time\n(Blue: Individual Returns, Red: Mean Returns)', fontsize=14, fontweight='bold')
plt.legend(fontsize=11)
plt.grid(True, alpha=0.3)

# x축 라벨 설정
plt.xticks(valid_time_points, rotation=45)

# y축 범위 설정 (데이터에 따라 조정)
plt.ylim(min(all_returns) * 1.1, max(all_returns) * 1.1)

plt.tight_layout()
plt.show()

# 통계 정보 출력
print("=== 시간별 수익률 통계 ===")
print(f"전체 데이터 포인트 수: {len(all_returns):,}")
print(f"시간 범위: {min(valid_time_points)}분 ~ {max(valid_time_points)}분")
print(f"수익률 범위: {min(all_returns):.3f}% ~ {max(all_returns):.3f}%")
print(f"전체 평균 수익률: {np.mean(all_returns):.3f}%")
print(f"전체 표준편차: {np.std(all_returns):.3f}%")

print("\n=== 시간별 평균 수익률 ===")
for time, mean_ret in zip(mean_times, mean_returns):
    print(f"{time:3d}분: {mean_ret:6.3f}%")

# 이벤트 전후 비교
before_event = [mean_ret for time, mean_ret in zip(mean_times, mean_returns) if time < 0]
after_event = [mean_ret for time, mean_ret in zip(mean_times, mean_returns) if time > 0]

if before_event and after_event:
    print(f"\n=== 이벤트 전후 비교 ===")
    print(f"이벤트 전 평균 수익률: {np.mean(before_event):.3f}%")
    print(f"이벤트 후 평균 수익률: {np.mean(after_event):.3f}%")
    print(f"이벤트 후 - 이벤트 전: {np.mean(after_event) - np.mean(before_event):.3f}%")
# Out:
# === 시간별 수익률 통계 ===
# 전체 데이터 포인트 수: 54,397
# 시간 범위: -60분 ~ 60분
# 수익률 범위: -23.170% ~ 52.470%
# 전체 평균 수익률: -0.689%
# 전체 표준편차: 2.381%
#
# === 시간별 평균 수익률 ===
# -60분: -1.076%
# -50분: -1.068%
# -40분: -1.052%
# -30분: -1.049%
# -20분: -1.041%
# -10분: -1.036%
#  10분: -0.326%
#  20분: -0.370%
#  30분: -0.363%
#  40분: -0.146%
#  50분: -0.199%
#  60분: -0.216%
#
# === 이벤트 전후 비교 ===
# 이벤트 전 평균 수익률: -1.054%
# 이벤트 후 평균 수익률: -0.270%
# 이벤트 후 - 이벤트 전: 0.784%

# %%
import pandas as pd
import numpy as np

ret_columns = [
    'abn_ret_minus_60m', 'abn_ret_minus_50m', 'abn_ret_minus_40m', 
    'abn_ret_minus_30m', 'abn_ret_minus_20m', 'abn_ret_minus_10m',
    'abn_ret_10m', 'abn_ret_20m', 'abn_ret_30m', 
    'abn_ret_40m', 'abn_ret_50m', 'abn_ret_60m'
]

# 실제 존재하는 컬럼만 필터링
valid_ret_columns = [col for col in ret_columns if col in df_with_returns.columns]

# 통계 계산을 위한 리스트 초기화
stats_data = []

for col in valid_ret_columns:
    abn_ret_data = df_with_returns[col].dropna()
    
    if len(abn_ret_data) > 0:
        total_count = len(abn_ret_data)
        total_mean = abn_ret_data.mean()
        total_std = abn_ret_data.std()
        positive_count = (abn_ret_data > 0).sum()
        total_positive_ratio = (positive_count / total_count * 100) if total_count > 0 else 0
        
        stats_data.append({
            'Column': col,
            'Count': total_count,
            'Mean (%)': round(total_mean, 3),
            'Std (%)': round(total_std, 3),
            'Positive_Count': positive_count,
            'Positive_Ratio (%)': round(total_positive_ratio, 1)
        })

# DataFrame으로 변환
stats_df = pd.DataFrame(stats_data)

# 시간순으로 정렬 (마이너스 시간이 먼저 오도록)
time_order = {
    'abn_ret_minus_60m': -60, 'abn_ret_minus_50m': -50, 'abn_ret_minus_40m': -40,
    'abn_ret_minus_30m': -30, 'abn_ret_minus_20m': -20, 'abn_ret_minus_10m': -10,
    'abn_ret_10m': 10, 'abn_ret_20m': 20, 'abn_ret_30m': 30,
    'abn_ret_40m': 40, 'abn_ret_50m': 50, 'abn_ret_60m': 60
}

stats_df['Time_Order'] = stats_df['Column'].map(time_order)
stats_df = stats_df.sort_values('Time_Order').drop('Time_Order', axis=1)


# 요약 통계
print(f"\n=== 요약 통계 ===")
print(f"총 컬럼 수: {len(stats_df)}")
print(f"총 데이터 포인트: {stats_df['Count'].sum():,}")
print(f"평균 수익률 범위: {stats_df['Mean (%)'].min():.3f}% ~ {stats_df['Mean (%)'].max():.3f}%")
print(f"표준편차 범위: {stats_df['Std (%)'].min():.3f}% ~ {stats_df['Std (%)'].max():.3f}%")

# 이벤트 전후 비교
before_event = stats_df[stats_df['Column'].str.contains('minus')]
after_event = stats_df[~stats_df['Column'].str.contains('minus')]

if len(before_event) > 0 and len(after_event) > 0:
    print(f"\n=== 이벤트 전후 비교 ===")
    print(f"이벤트 전 평균 수익률: {before_event['Mean (%)'].mean():.3f}%")
    print(f"이벤트 후 평균 수익률: {after_event['Mean (%)'].mean():.3f}%")
    print(f"이벤트 후 - 이벤트 전: {after_event['Mean (%)'].mean() - before_event['Mean (%)'].mean():.3f}%")


print("")
print("=== 전체 Abnormal Return 통계 ===")
print(stats_df.to_string(index=False))
# Out:
# === 요약 통계 ===
# 총 컬럼 수: 12
# 총 데이터 포인트: 54,397
# 평균 수익률 범위: -1.076% ~ -0.146%
# 표준편차 범위: 1.815% ~ 3.314%
#
# === 이벤트 전후 비교 ===
# 이벤트 전 평균 수익률: -1.054%
# 이벤트 후 평균 수익률: -0.270%
# 이벤트 후 - 이벤트 전: 0.784%
#
# === 전체 Abnormal Return 통계 ===
#            Column  Count  Mean (%)  Std (%)  Positive_Count  Positive_Ratio (%)
# abn_ret_minus_60m   4582    -1.076    2.156            1189                25.9
# abn_ret_minus_50m   4685    -1.068    2.135            1195                25.5
# abn_ret_minus_40m   4782    -1.052    2.073            1170                24.5
# abn_ret_minus_30m   4873    -1.049    1.998            1167                23.9
# abn_ret_minus_20m   4944    -1.041    1.951            1139                23.0
# abn_ret_minus_10m   5014    -1.036    1.815            1021                20.4
#       abn_ret_10m   4828    -0.326    1.860            1981                41.0
#       abn_ret_20m   4596    -0.370    2.088            1871                40.7
#       abn_ret_30m   4366    -0.363    2.275            1773                40.6
#       abn_ret_40m   4132    -0.146    3.176            1714                41.5
#       abn_ret_50m   3914    -0.199    3.225            1591                40.6
#       abn_ret_60m   3681    -0.216    3.314            1468                39.9

# %%
df_with_returns['label'].value_counts()
# Out:
# label
#  1    2655
#  0    1939
# -1     478
# Name: count, dtype: int64

# %% [markdown]
# # AI Inference

# %%
# label 비율 시각화
plt.figure(figsize=(6, 6))

# label 비율 계산
label_counts = df_with_returns['label'].value_counts()
label_ratios = (label_counts / len(df_with_returns) * 100).round(2)

# 색상 매핑 (라벨 순서에 맞게)
colors = ['#2E8B57', '#A9A9A9', '#DC143C']  # 1: positive(초록), 0: neutral(회색), -1: negative(빨강)

# x축 라벨 설정: 1=Positive(초록), 0=Neutral(회색), -1=Negative(빨강)
label_order = [1, 0, -1]
label_names = ['Positive (1)', 'Neutral (0)', 'Negative (-1)']

# 막대 그래프 생성
bars = plt.bar(range(len(label_order)), [label_ratios.get(l, 0) for l in label_order], color=colors)

# 막대 위에 비율 표시
for i, label in enumerate(label_order):
    if label in label_counts:
        ratio = label_ratios[label]
        count = label_counts[label]
        plt.text(i, ratio + 0.5, f'{ratio}%\n({count:,})',
                 ha='center', va='bottom', fontsize=11)

plt.title('AI Sentiment Analysis Label Distribution', fontsize=16, pad=20)
plt.xlabel('Sentiment Label', fontsize=12)
plt.ylabel('ratio (%)', fontsize=12)
plt.ylim(0, max(label_ratios.values) * 1.15)

plt.xticks(range(len(label_order)), label_names)
plt.grid(axis='y', alpha=0.3, linestyle='--')

plt.tight_layout()
plt.show()

print("=== AI Sentiment Analysis Label Distribution ===")
for i, label in enumerate(label_order):
    if label in label_counts:
        count = label_counts[label]
        ratio = label_ratios[label]
        print(f"{label_names[i].split()[0].lower()}: {count:,}건 ({ratio}%)")
# Out:
# === AI Sentiment Analysis Label Distribution ===
# positive: 2,655건 (52.35%)
# neutral: 1,939건 (38.23%)
# negative: 478건 (9.42%)

# %% [markdown]
# # Event Study

# %% [markdown]
# ## 10 minute interval

# %%
ret_columns = [
    'abn_ret_minus_60m', 'abn_ret_minus_50m', 'abn_ret_minus_40m', 
    'abn_ret_minus_30m', 'abn_ret_minus_20m', 'abn_ret_minus_10m',
    'abn_ret_10m', 'abn_ret_20m', 'abn_ret_30m', 
    'abn_ret_40m', 'abn_ret_50m', 'abn_ret_60m'
]

print("Mean")
print(df_with_returns.groupby('label')[ret_columns].mean().to_string())

print()
print("Stdandard deviation")
print(df_with_returns.groupby('label')[ret_columns].std().to_string())
# Out:
# Mean
#        abn_ret_minus_60m  abn_ret_minus_50m  abn_ret_minus_40m  abn_ret_minus_30m  abn_ret_minus_20m  abn_ret_minus_10m  abn_ret_10m  abn_ret_20m  abn_ret_30m  abn_ret_40m  abn_ret_50m  abn_ret_60m
# label
# -1             -0.370588          -0.343384          -0.332021          -0.362532          -0.325600          -0.334412    -0.403180    -0.446297    -0.491823    -0.362606    -0.526431    -0.630414
#  0             -0.893312          -0.897177          -0.893980          -0.878772          -0.885820          -0.874271    -0.274878    -0.341689    -0.363551    -0.222010    -0.281445    -0.280789
#  1             -1.342077          -1.329305          -1.300651          -1.299581          -1.285739          -1.281985    -0.349729    -0.378267    -0.342338    -0.059626    -0.095154    -0.116023
#
# Stdandard deviation
#        abn_ret_minus_60m  abn_ret_minus_50m  abn_ret_minus_40m  abn_ret_minus_30m  abn_ret_minus_20m  abn_ret_minus_10m  abn_ret_10m  abn_ret_20m  abn_ret_30m  abn_ret_40m  abn_ret_50m  abn_ret_60m
# label
# -1              1.358447           1.342652           1.301978           1.195086           1.128443           1.120969     1.373972     1.393633     1.623203     2.531904     2.514872     2.771949
#  0              2.292609           2.279196           2.160750           2.099036           2.027985           1.789526     1.707785     1.884938     2.076308     2.815937     2.853906     2.871089
#  1              2.135277           2.104689           2.083353           2.000068           1.970369           1.887940     2.029324     2.311476     2.488173     3.487073     3.542769     3.648947

# %%
# X축 -60, -50, ..., 0, 10, ..., 60, Y축 abnormal_ret_*m 평균값, 라벨별 색상/범례
# 각 데이터 포인트에 점도 표시 (marker 추가)
# 0,0도 점 찍고 연결

# 시간순으로 정렬 (마이너스 시간이 먼저 오도록)
time_order = {
    'abn_ret_minus_60m': -60, 'abn_ret_minus_50m': -50, 'abn_ret_minus_40m': -40,
    'abn_ret_minus_30m': -30, 'abn_ret_minus_20m': -20, 'abn_ret_minus_10m': -10,
    'abn_ret_10m': 10, 'abn_ret_20m': 20, 'abn_ret_30m': 30,
    'abn_ret_40m': 40, 'abn_ret_50m': 50, 'abn_ret_60m': 60
}

ordered_ret_cols = [col for col, _ in sorted(time_order.items(), key=lambda x: x[1]) if col in df_with_returns.columns]
plot_time_points = [time_order[col] for col in ordered_ret_cols]

# 0을 x축에도 추가
xticks_with_zero = sorted(set(plot_time_points + [0]))

fig, ax = plt.subplots(figsize=(12,6))

for label, color, name in zip(label_order, colors, label_names):
    grp = df_with_returns[df_with_returns['label'] == label]
    mean_vals = grp[ordered_ret_cols].mean()
    # 0,0을 시작점으로 붙여줌
    times_all = [0] + plot_time_points
    vals_all = [0.0] + list(mean_vals.values)
    # 정렬 - 시간 오름차순 정렬
    times_and_vals = sorted(zip(times_all, vals_all), key=lambda x: x[0])
    sorted_times = [x[0] for x in times_and_vals]
    sorted_vals = [x[1] for x in times_and_vals]
    ax.plot(sorted_times, sorted_vals, label=name, color=color, linewidth=2, marker='o', markersize=7)

ax.axvline(0, color="#666", linestyle="--", lw=1)
ax.legend(fontsize=13)
ax.set_xticks(xticks_with_zero)
ax.set_xlabel("Minutes from Disclosure", fontsize=13)
ax.set_ylabel("Mean Cumulative Abnormal Return (%)", fontsize=13)
ax.set_title("Event Time Abnormal Returns by AI Label (Before Telegram launched: 2021.1~2022.6)", fontsize=15)
plt.grid(alpha=0.3, linestyle='-')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 1 minute interval

# %%
ret_columns = [
    'abn_ret_minus_10m', 'abn_ret_minus_9m', 'abn_ret_minus_8m', 'abn_ret_minus_7m', 'abn_ret_minus_6m', 
    'abn_ret_minus_5m', 'abn_ret_minus_4m', 'abn_ret_minus_3m', 'abn_ret_minus_2m', 'abn_ret_minus_1m',
    'abn_ret_1m', 'abn_ret_2m', 'abn_ret_3m', 'abn_ret_4m', 'abn_ret_5m',
    'abn_ret_6m', 'abn_ret_7m', 'abn_ret_8m', 'abn_ret_9m', 'abn_ret_10m'
]

print("Mean")
print(df_with_returns.groupby('label')[ret_columns].mean().to_string())

print()
print("Stdandard deviation")
print(df_with_returns.groupby('label')[ret_columns].std().to_string())
# Out:
# Mean
#        abn_ret_minus_10m  abn_ret_minus_9m  abn_ret_minus_8m  abn_ret_minus_7m  abn_ret_minus_6m  abn_ret_minus_5m  abn_ret_minus_4m  abn_ret_minus_3m  abn_ret_minus_2m  abn_ret_minus_1m  abn_ret_1m  abn_ret_2m  abn_ret_3m  abn_ret_4m  abn_ret_5m  abn_ret_6m  abn_ret_7m  abn_ret_8m  abn_ret_9m  abn_ret_10m
# label
# -1             -0.334412         -0.334223         -0.341090         -0.357866         -0.341611         -0.343410         -0.354142         -0.362029         -0.348494         -0.331590   -0.111550   -0.147639   -0.229978   -0.248192   -0.319141   -0.358956   -0.354420   -0.363792   -0.380206    -0.403180
#  0             -0.874271         -0.883807         -0.894528         -0.888370         -0.875172         -0.882796         -0.885111         -0.885729         -0.876413         -0.867539   -0.005829   -0.042651   -0.091942   -0.143465   -0.180506   -0.196922   -0.234566   -0.237698   -0.267434    -0.274878
#  1             -1.281985         -1.276758         -1.271500         -1.273269         -1.268902         -1.272006         -1.262140         -1.266324         -1.253862         -1.231428   -0.026137   -0.023888   -0.120816   -0.182267   -0.233485   -0.275544   -0.295456   -0.324829   -0.329492    -0.349729
#
# Stdandard deviation
#        abn_ret_minus_10m  abn_ret_minus_9m  abn_ret_minus_8m  abn_ret_minus_7m  abn_ret_minus_6m  abn_ret_minus_5m  abn_ret_minus_4m  abn_ret_minus_3m  abn_ret_minus_2m  abn_ret_minus_1m  abn_ret_1m  abn_ret_2m  abn_ret_3m  abn_ret_4m  abn_ret_5m  abn_ret_6m  abn_ret_7m  abn_ret_8m  abn_ret_9m  abn_ret_10m
# label
# -1              1.120969          1.085860          1.076450          1.077549          1.096593          1.085122          1.047494          1.044746          1.017618          1.014089    0.821505    0.998491    1.180969    1.306167    1.366139    1.299437    1.421540    1.376382    1.382944     1.373972
#  0              1.789526          1.744868          1.760584          1.716503          1.688132          1.559523          1.539726          1.536728          1.421130          1.414558    1.064983    1.263195    1.457098    1.502429    1.555682    1.579280    1.651846    1.708494    1.694741     1.707785
#  1              1.887940          1.879408          1.867366          1.859005          1.860042          1.846877          1.844900          1.828106          1.820512          1.812566    1.215176    1.487071    1.688331    1.803378    1.834060    1.906745    1.905489    1.965493    2.022990     2.029324

# %%
# X축 -60, -50, ..., 60, Y축 abnormal_ret_*m 평균값, 라벨별 색상/범례
# 각 데이터 포인트에 점도 표시 (marker 추가)
# 0,0도 점 찍고 연결

# 시간순으로 정렬 (마이너스 시간이 먼저 오도록)
time_order = {
    'abn_ret_minus_10m': -10, 'abn_ret_minus_9m': -9, 'abn_ret_minus_8m': -8, 'abn_ret_minus_7m': -7,
    'abn_ret_minus_6m': -6, 'abn_ret_minus_5m': -5, 'abn_ret_minus_4m': -4, 'abn_ret_minus_3m': -3,
    'abn_ret_minus_2m': -2, 'abn_ret_minus_1m': -1,
    'abn_ret_1m': 1, 'abn_ret_2m': 2, 'abn_ret_3m': 3, 'abn_ret_4m': 4,
    'abn_ret_5m': 5, 'abn_ret_6m': 6, 'abn_ret_7m': 7, 'abn_ret_8m': 8, 'abn_ret_9m': 9, 'abn_ret_10m': 10
}

ordered_ret_cols = [col for col, _ in sorted(time_order.items(), key=lambda x: x[1]) if col in df_with_returns.columns]
plot_time_points = [time_order[col] for col in ordered_ret_cols]

# 0도 x축에 표시(xticks에 0 추가)
xticks_with_zero = sorted(list(set(plot_time_points) | {0}))

fig, ax = plt.subplots(figsize=(12,6))

for label, color, name in zip(label_order, colors, label_names):
    grp = df_with_returns[df_with_returns['label'] == label]
    mean_vals = grp[ordered_ret_cols].mean()
    # 0,0을 시작점으로 붙여줌
    times_all = [0] + plot_time_points
    vals_all = [0.0] + list(mean_vals.values)
    # 정렬 - 시간 오름차순 정렬
    times_and_vals = sorted(zip(times_all, vals_all), key=lambda x: x[0])
    sorted_times = [x[0] for x in times_and_vals]
    sorted_vals = [x[1] for x in times_and_vals]
    ax.plot(sorted_times, sorted_vals, label=name, color=color, linewidth=2, marker='o', markersize=7)

ax.axvline(0, color="#666", linestyle="--", lw=1)
ax.legend(fontsize=13)
ax.set_xticks(xticks_with_zero)
ax.set_xlabel("Minutes from Disclosure", fontsize=13)
ax.set_ylabel("Mean Cumulative Abnormal Return (%)", fontsize=13)
ax.set_title("Event Time Abnormal Returns by AI Label (Before Telegram launched: 2021.1~2022.6)", fontsize=15)
plt.grid(alpha=0.3, linestyle='-')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 공시 종류별 감성 분포

# %%
df_with_returns.groupby('disclosure_type')[ret_columns].mean().round(2)
# Out:
#                     abn_ret_minus_10m  abn_ret_minus_9m  abn_ret_minus_8m  \
# disclosure_type
# 감자 결정                           -4.66             -4.23             -4.19
# 교환사채권 발행결정                       0.29              0.20              0.31
# 기술이전계약체결                        -1.98             -1.84             -1.99
# 기술이전계약해지                        -0.60             -0.60             -0.80
# 단일판매ㆍ공급계약체결                     -1.30             -1.30             -1.30
# 단일판매ㆍ공급계약해지                      0.27              0.28              0.22
# 매출액변동                           -0.88             -0.88             -0.88
# 무상증자 결정                         -0.55             -0.55             -0.56
# 상각형 조건부자본증권 발행결정                -0.15             -0.31             -0.31
# 생산중단                             0.13              0.14              0.16
# 소송 등의 제기                         0.29              0.10             -0.07
# 신규시설투자                          -1.25             -1.26             -1.23
# 영업양수 결정                          0.39              0.38              0.39
# 영업정지                            -0.31             -0.22             -0.06
# 유상증자 결정                         -2.00             -2.03             -2.13
# 유형자산 양도 결정                      -0.83             -0.82             -0.82
# 유형자산 양수 결정                      -0.10             -0.06             -0.10
# 임상 계획 결과 발표                     -1.19             -1.26             -1.29
# 임상 계획 승인                        -3.01             -3.06             -3.06
# 임상 계획 신청                        -2.73             -2.70             -2.70
# 임상 계획 철회                        -1.09             -1.11             -1.19
# 자기주식 소각 결정                      -1.93             -1.91             -1.89
# 자기주식 처분 결정                       0.07              0.06              0.06
# 자기주식 취득 결정                      -1.62             -1.62             -1.65
# 자기주식취득 신탁계약 체결 결정               -1.16             -1.17             -1.14
# 자기주식취득 신탁계약 해지 결정               -0.00              0.01              0.03
# 자산양수도(기타), 풋백옵션                  0.33              0.42              0.44
# 전환사채권 발행결정                       0.08             -0.00             -0.01
# 주권 관련 사채권 양도 결정                 -4.58             -4.80             -4.70
# 주권 관련 사채권 양수 결정                 -0.23             -0.11             -0.10
# 타법인 주식 및 출자증권 양도결정               0.65              0.53              0.49
# 타법인 주식 및 출자증권 양수결정              -0.82             -0.85             -0.83
# 특허권취득                           -0.83             -0.83             -0.82
# 품목허가 승인                         -2.60             -2.58             -2.53
# 품목허가 신청                         -1.33             -1.42             -1.48
# 품목허가 철회                         -1.48             -1.35             -1.33
# 회사분할 결정                         -0.47             -0.47             -0.35
# 회사합병 결정                         -1.96             -1.81             -1.82
#
#                     abn_ret_minus_7m  abn_ret_minus_6m  abn_ret_minus_5m  \
# disclosure_type
# 감자 결정                          -4.70             -3.89             -4.35
# 교환사채권 발행결정                      0.25              0.30              0.18
# 기술이전계약체결                       -1.98             -2.04             -2.25
# 기술이전계약해지                       -0.84             -0.88             -0.91
# 단일판매ㆍ공급계약체결                    -1.29             -1.28             -1.28
# 단일판매ㆍ공급계약해지                     0.09              0.21              0.15
# 매출액변동                          -0.89             -0.88             -0.88
# 무상증자 결정                        -0.54             -0.55             -0.55
# 상각형 조건부자본증권 발행결정               -0.36             -0.41             -0.41
# 생산중단                            0.04              0.03              0.06
# 소송 등의 제기                        0.13              0.16              0.05
# 신규시설투자                         -1.27             -1.19             -1.23
# 영업양수 결정                         0.39              0.40              0.03
# 영업정지                           -0.15             -0.22             -0.01
# 유상증자 결정                        -2.20             -2.07             -2.12
# 유형자산 양도 결정                     -0.86             -0.87             -0.87
# 유형자산 양수 결정                     -0.11             -0.07             -0.03
# 임상 계획 결과 발표                    -1.18             -1.09             -1.18
# 임상 계획 승인                       -3.08             -3.04             -3.09
# 임상 계획 신청                       -2.73             -2.73             -2.76
# 임상 계획 철회                       -0.99             -0.93             -0.98
# 자기주식 소각 결정                     -1.93             -1.87             -1.83
# 자기주식 처분 결정                      0.06              0.07              0.04
# 자기주식 취득 결정                     -1.65             -1.62             -1.60
# 자기주식취득 신탁계약 체결 결정              -1.16             -1.13             -1.16
# 자기주식취득 신탁계약 해지 결정               0.03              0.00             -0.04
# 자산양수도(기타), 풋백옵션                 0.54              0.48              0.70
# 전환사채권 발행결정                     -0.01             -0.01             -0.02
# 주권 관련 사채권 양도 결정                -4.40             -4.59             -4.48
# 주권 관련 사채권 양수 결정                -0.09             -0.12             -0.26
# 타법인 주식 및 출자증권 양도결정              0.49              0.50              0.23
# 타법인 주식 및 출자증권 양수결정             -0.83             -0.82             -0.81
# 특허권취득                          -0.84             -0.85             -0.85
# 품목허가 승인                        -2.59             -2.60             -2.65
# 품목허가 신청                        -1.48             -1.46             -1.51
# 품목허가 철회                        -1.33             -1.07             -0.87
# 회사분할 결정                        -0.43             -0.47             -0.41
# 회사합병 결정                        -1.77             -1.80             -1.77
#
#                     abn_ret_minus_4m  abn_ret_minus_3m  abn_ret_minus_2m  \
# disclosure_type
# 감자 결정                          -4.01             -4.82             -3.89
# 교환사채권 발행결정                      0.12              0.15              0.19
# 기술이전계약체결                       -2.03             -2.07             -2.12
# 기술이전계약해지                       -0.64             -0.49             -0.80
# 단일판매ㆍ공급계약체결                    -1.27             -1.27             -1.26
# 단일판매ㆍ공급계약해지                     0.19              0.14              0.09
# 매출액변동                          -0.88             -0.89             -0.88
# 무상증자 결정                        -0.52             -0.50             -0.45
# 상각형 조건부자본증권 발행결정                0.02             -0.03             -0.42
# 생산중단                            0.12              0.07              0.09
# 소송 등의 제기                       -0.01              0.23              0.18
# 신규시설투자                         -1.22             -1.22             -1.21
# 영업양수 결정                         0.03              0.01             -0.01
# 영업정지                           -0.09             -0.11             -0.02
# 유상증자 결정                        -2.12             -2.03             -1.85
# 유형자산 양도 결정                     -0.87             -0.86             -0.88
# 유형자산 양수 결정                     -0.08             -0.10             -0.15
# 임상 계획 결과 발표                    -1.18             -1.17             -1.21
# 임상 계획 승인                       -3.08             -3.20             -3.10
# 임상 계획 신청                       -2.80             -2.82             -2.81
# 임상 계획 철회                       -1.12             -1.10             -1.00
# 자기주식 소각 결정                     -1.80             -1.84             -1.86
# 자기주식 처분 결정                      0.03              0.03              0.05
# 자기주식 취득 결정                     -1.61             -1.60             -1.59
# 자기주식취득 신탁계약 체결 결정              -1.14             -1.16             -1.17
# 자기주식취득 신탁계약 해지 결정              -0.06             -0.02             -0.06
# 자산양수도(기타), 풋백옵션                 0.80              0.56              0.39
# 전환사채권 발행결정                     -0.04             -0.02              0.01
# 주권 관련 사채권 양도 결정                -4.32             -4.30             -4.14
# 주권 관련 사채권 양수 결정                -0.33             -0.26             -0.19
# 타법인 주식 및 출자증권 양도결정              0.20              0.15             -0.08
# 타법인 주식 및 출자증권 양수결정             -0.81             -0.80             -0.78
# 특허권취득                          -0.84             -0.84             -0.83
# 품목허가 승인                        -2.55             -2.58             -2.53
# 품목허가 신청                        -1.48             -1.43             -1.50
# 품목허가 철회                        -0.93             -0.66             -0.27
# 회사분할 결정                        -0.45             -0.53             -0.46
# 회사합병 결정                        -1.55             -1.64             -1.69
#
#                     abn_ret_minus_1m  abn_ret_1m  abn_ret_2m  abn_ret_3m  \
# disclosure_type
# 감자 결정                          -3.93       -3.07       -2.60       -3.50
# 교환사채권 발행결정                      0.15       -0.45       -0.60       -0.91
# 기술이전계약체결                       -2.04       -1.44       -0.42       -0.67
# 기술이전계약해지                       -0.84       -0.24       -0.47       -0.55
# 단일판매ㆍ공급계약체결                    -1.25        0.01       -0.00       -0.10
# 단일판매ㆍ공급계약해지                     0.04        0.27        0.18        0.20
# 매출액변동                          -0.86       -0.07       -0.11       -0.19
# 무상증자 결정                        -0.40        0.08        0.07        0.07
# 상각형 조건부자본증권 발행결정               -0.03       -0.05       -0.06       -0.10
# 생산중단                            0.04       -0.16       -0.16       -0.18
# 소송 등의 제기                       -0.27       -0.13       -0.16       -2.30
# 신규시설투자                         -1.21        0.04        0.17        0.17
# 영업양수 결정                        -0.03       -0.06        0.00        0.01
# 영업정지                            0.00        0.03       -0.00        0.01
# 유상증자 결정                        -1.92        0.03       -0.05       -0.62
# 유형자산 양도 결정                     -0.85        0.05       -0.21        0.13
# 유형자산 양수 결정                     -0.16       -0.01        0.05        0.07
# 임상 계획 결과 발표                    -1.08        0.06        0.61       -0.30
# 임상 계획 승인                       -3.12       -0.15        0.60        0.47
# 임상 계획 신청                       -2.80       -0.53       -0.73       -1.06
# 임상 계획 철회                       -0.98       -0.03       -1.25       -2.70
# 자기주식 소각 결정                     -1.87       -0.12       -0.44       -0.83
# 자기주식 처분 결정                      0.06       -0.04       -0.04       -0.07
# 자기주식 취득 결정                     -1.56       -0.15       -0.14       -0.18
# 자기주식취득 신탁계약 체결 결정              -1.18        0.02       -0.03       -0.05
# 자기주식취득 신탁계약 해지 결정              -0.02       -0.06       -0.01        0.11
# 자산양수도(기타), 풋백옵션                -0.04       -0.60       -1.02       -1.57
# 전환사채권 발행결정                      0.08       -0.07       -0.16       -0.24
# 주권 관련 사채권 양도 결정                -4.26       -3.51       -3.49       -0.40
# 주권 관련 사채권 양수 결정                -0.05       -0.05       -0.05       -0.10
# 타법인 주식 및 출자증권 양도결정             -0.20        0.00        0.04        0.13
# 타법인 주식 및 출자증권 양수결정             -0.73       -0.13       -0.09       -0.12
# 특허권취득                          -0.79        0.10        0.01       -0.05
# 품목허가 승인                        -2.53        0.22        0.63        0.68
# 품목허가 신청                        -1.46       -0.11       -0.83       -1.36
# 품목허가 철회                         0.05       -0.46       -0.52       -0.68
# 회사분할 결정                        -0.44       -0.41       -0.47       -0.61
# 회사합병 결정                        -1.68        0.15        0.49        0.57
#
#                     abn_ret_4m  abn_ret_5m  abn_ret_6m  abn_ret_7m  \
# disclosure_type
# 감자 결정                    -4.35       -3.81       -3.89       -3.85
# 교환사채권 발행결정               -0.90       -0.89       -1.00       -0.97
# 기술이전계약체결                 -0.36       -0.65       -0.27       -0.33
# 기술이전계약해지                 -1.26       -1.70       -2.13       -1.97
# 단일판매ㆍ공급계약체결              -0.17       -0.22       -0.25       -0.26
# 단일판매ㆍ공급계약해지               0.03       -0.01       -0.03        0.02
# 매출액변동                    -0.23       -0.27       -0.31       -0.32
# 무상증자 결정                  -0.01       -0.02       -0.03       -0.12
# 상각형 조건부자본증권 발행결정         -0.06       -0.05       -0.41       -0.39
# 생산중단                     -0.26       -0.19       -0.17       -0.16
# 소송 등의 제기                 -3.12       -4.91       -4.82       -5.58
# 신규시설투자                    0.20        0.22        0.32        0.31
# 영업양수 결정                   0.03        0.01        0.03        0.03
# 영업정지                     -0.00       -0.01       -0.07       -0.06
# 유상증자 결정                  -1.20       -1.62       -2.11       -2.70
# 유형자산 양도 결정                0.13       -0.24       -0.32       -0.38
# 유형자산 양수 결정                0.05       -0.03        0.08        0.08
# 임상 계획 결과 발표               0.09        0.70        0.40        0.12
# 임상 계획 승인                  0.12       -0.08       -0.15       -0.10
# 임상 계획 신청                 -0.96       -1.35       -1.57       -1.66
# 임상 계획 철회                 -2.64       -4.56       -4.58       -3.76
# 자기주식 소각 결정               -0.94       -0.94       -1.00       -1.07
# 자기주식 처분 결정               -0.10       -0.09       -0.08       -0.04
# 자기주식 취득 결정               -0.30       -0.34       -0.35       -0.29
# 자기주식취득 신탁계약 체결 결정        -0.05        0.02        0.01       -0.01
# 자기주식취득 신탁계약 해지 결정         0.15        0.10        0.12        0.10
# 자산양수도(기타), 풋백옵션          -0.88       -0.82       -0.57       -0.54
# 전환사채권 발행결정               -0.27       -0.22       -0.27       -0.24
# 주권 관련 사채권 양도 결정           1.33        1.72        2.41        4.18
# 주권 관련 사채권 양수 결정          -0.14       -0.25       -0.12       -0.01
# 타법인 주식 및 출자증권 양도결정        0.00       -0.16       -0.17       -0.09
# 타법인 주식 및 출자증권 양수결정       -0.09       -0.10       -0.20       -0.33
# 특허권취득                    -0.12       -0.13       -0.16       -0.18
# 품목허가 승인                  -0.01       -0.37       -0.52       -0.28
# 품목허가 신청                  -1.51       -1.66       -1.52       -1.54
# 품목허가 철회                  -0.79       -0.59       -0.74       -0.76
# 회사분할 결정                  -0.49       -0.56       -0.51       -0.64
# 회사합병 결정                   0.94        1.07        1.32        1.30
#
#                     abn_ret_8m  abn_ret_9m  abn_ret_10m
# disclosure_type
# 감자 결정                    -4.23       -3.89        -4.31
# 교환사채권 발행결정               -1.03       -1.00        -0.96
# 기술이전계약체결                 -0.12        1.25         1.51
# 기술이전계약해지                 -1.97       -1.97        -2.04
# 단일판매ㆍ공급계약체결              -0.28       -0.28        -0.30
# 단일판매ㆍ공급계약해지              -0.06        0.01        -0.01
# 매출액변동                    -0.36       -0.38        -0.40
# 무상증자 결정                  -0.16       -0.21        -0.26
# 상각형 조건부자본증권 발행결정          0.00       -0.02         0.00
# 생산중단                     -0.22       -0.27        -0.29
# 소송 등의 제기                 -4.08       -6.40        -4.35
# 신규시설투자                    0.38        0.33         0.39
# 영업양수 결정                   0.07        0.12         0.13
# 영업정지                     -0.03       -0.07        -0.06
# 유상증자 결정                  -2.78       -2.84        -2.68
# 유형자산 양도 결정               -0.32       -0.41        -0.52
# 유형자산 양수 결정                0.11        0.11         0.09
# 임상 계획 결과 발표              -0.21       -0.19        -0.45
# 임상 계획 승인                 -0.30        0.10        -0.09
# 임상 계획 신청                 -1.61       -2.06        -1.88
# 임상 계획 철회                 -4.07       -3.96        -4.47
# 자기주식 소각 결정               -0.97       -1.05        -1.11
# 자기주식 처분 결정               -0.06       -0.05        -0.06
# 자기주식 취득 결정               -0.32       -0.33        -0.32
# 자기주식취득 신탁계약 체결 결정         0.03       -0.01         0.03
# 자기주식취득 신탁계약 해지 결정         0.23        0.15         0.09
# 자산양수도(기타), 풋백옵션          -0.21       -0.28        -0.35
# 전환사채권 발행결정               -0.21       -0.22        -0.31
# 주권 관련 사채권 양도 결정           4.17        3.03         2.52
# 주권 관련 사채권 양수 결정          -0.12       -0.05        -0.00
# 타법인 주식 및 출자증권 양도결정       -0.14       -0.27        -0.31
# 타법인 주식 및 출자증권 양수결정       -0.33       -0.34        -0.37
# 특허권취득                    -0.19       -0.17        -0.21
# 품목허가 승인                  -0.34       -0.80        -0.77
# 품목허가 신청                  -1.65       -1.65        -1.71
# 품목허가 철회                  -0.44       -0.60        -0.73
# 회사분할 결정                  -0.66       -0.79        -1.00
# 회사합병 결정                   1.02        0.66         0.79

# %%
df_with_returns.groupby('disclosure_type')[ret_columns].std()
# Out:
#                     abn_ret_minus_10m  abn_ret_minus_9m  abn_ret_minus_8m  \
# disclosure_type
# 감자 결정                             NaN               NaN               NaN
# 교환사채권 발행결정                   0.484035          0.520108          0.500854
# 기술이전계약체결                     1.520668          1.207798          1.205150
# 기술이전계약해지                          NaN               NaN               NaN
# 단일판매ㆍ공급계약체결                  1.710440          1.697614          1.689617
# 단일판매ㆍ공급계약해지                  0.743947          0.693939          0.575035
# 매출액변동                        1.519203          1.517078          1.512945
# 무상증자 결정                      1.639885          1.595260          1.568340
# 상각형 조건부자본증권 발행결정                  NaN               NaN               NaN
# 생산중단                         0.396623          0.426297          0.462813
# 소송 등의 제기                     0.901388          0.522590          0.892039
# 신규시설투자                       1.617964          1.610459          1.541473
# 영업양수 결정                           NaN               NaN               NaN
# 영업정지                         0.363444          0.421456          0.519583
# 유상증자 결정                      4.247743          4.276752          4.547163
# 유형자산 양도 결정                   1.861882          1.833718          1.839042
# 유형자산 양수 결정                   0.365376          0.404616          0.399784
# 임상 계획 결과 발표                  3.255602          3.213241          3.208332
# 임상 계획 승인                     3.259703          3.265851          3.257819
# 임상 계획 신청                     3.289919          3.243529          3.219694
# 임상 계획 철회                     3.603961          3.560272          3.442648
# 자기주식 소각 결정                   2.353857          2.380380          2.403620
# 자기주식 처분 결정                   0.363240          0.395821          0.378890
# 자기주식 취득 결정                   1.385744          1.380425          1.424334
# 자기주식취득 신탁계약 체결 결정            1.035602          1.041644          1.032841
# 자기주식취득 신탁계약 해지 결정            0.380393          0.402982          0.381122
# 자산양수도(기타), 풋백옵션              0.565685          0.565685          0.537401
# 전환사채권 발행결정                   0.585079          0.501911          0.517841
# 주권 관련 사채권 양도 결정              7.134707          6.830652          6.604377
# 주권 관련 사채권 양수 결정              1.642131          1.739177          1.695808
# 타법인 주식 및 출자증권 양도결정           5.443834          4.900652          4.882625
# 타법인 주식 및 출자증권 양수결정           1.670621          1.684182          1.652428
# 특허권취득                        1.319633          1.309462          1.294955
# 품목허가 승인                      4.008970          3.966522          3.956214
# 품목허가 신청                      2.366195          2.288449          2.257406
# 품목허가 철회                      1.780234          1.896497          1.750924
# 회사분할 결정                      0.956439          0.885684          0.788036
# 회사합병 결정                      2.516652          2.551368          2.422983
#
#                     abn_ret_minus_7m  abn_ret_minus_6m  abn_ret_minus_5m  \
# disclosure_type
# 감자 결정                            NaN               NaN               NaN
# 교환사채권 발행결정                  0.558777          0.579905          0.506223
# 기술이전계약체결                    1.238802          1.175581          1.153784
# 기술이전계약해지                         NaN               NaN               NaN
# 단일판매ㆍ공급계약체결                 1.687734          1.679200          1.676563
# 단일판매ㆍ공급계약해지                 0.601341          0.529505          0.507015
# 매출액변동                       1.499743          1.511277          1.504052
# 무상증자 결정                     1.550123          1.629051          1.654279
# 상각형 조건부자본증권 발행결정                 NaN               NaN               NaN
# 생산중단                        0.448616          0.399062          0.425194
# 소송 등의 제기                    1.104189          0.752263          0.777003
# 신규시설투자                      1.557232          1.539230          1.556844
# 영업양수 결정                          NaN               NaN               NaN
# 영업정지                        0.506055          0.418838          0.473524
# 유상증자 결정                     4.413546          4.223459          4.109171
# 유형자산 양도 결정                  1.814138          1.836105          1.757312
# 유형자산 양수 결정                  0.431264          0.653240          0.541035
# 임상 계획 결과 발표                 3.231756          3.024442          3.114275
# 임상 계획 승인                    3.300415          3.319633          3.295116
# 임상 계획 신청                    3.219914          3.202371          3.130001
# 임상 계획 철회                    3.325953          3.297342          3.442330
# 자기주식 소각 결정                  2.394241          2.252514          2.348217
# 자기주식 처분 결정                  0.367398          0.334327          0.324976
# 자기주식 취득 결정                  1.370777          1.352549          1.353881
# 자기주식취득 신탁계약 체결 결정           1.021399          0.991968          0.999978
# 자기주식취득 신탁계약 해지 결정           0.364761          0.375618          0.339923
# 자산양수도(기타), 풋백옵션             0.572756          0.763675          1.096016
# 전환사채권 발행결정                  0.461723          0.497085          0.502220
# 주권 관련 사채권 양도 결정             6.625591          6.349819          6.095260
# 주권 관련 사채권 양수 결정             1.372972          0.857058          0.776031
# 타법인 주식 및 출자증권 양도결정          4.524254          4.509787          2.480064
# 타법인 주식 및 출자증권 양수결정          1.646850          1.659094          1.614608
# 특허권취득                       1.275735          1.287200          1.282334
# 품목허가 승인                     3.939983          3.995414          3.878383
# 품목허가 신청                     2.274317          2.267620          2.407661
# 품목허가 철회                     1.149971          1.405240          1.257073
# 회사분할 결정                     0.822579          0.828885          0.828836
# 회사합병 결정                     2.429504          2.452645          2.436889
#
#                     abn_ret_minus_4m  abn_ret_minus_3m  abn_ret_minus_2m  \
# disclosure_type
# 감자 결정                            NaN               NaN               NaN
# 교환사채권 발행결정                  0.577236          0.536134          0.274137
# 기술이전계약체결                    1.121814          0.928240          0.938753
# 기술이전계약해지                         NaN               NaN               NaN
# 단일판매ㆍ공급계약체결                 1.661227          1.670004          1.658418
# 단일판매ㆍ공급계약해지                 0.470480          0.404595          0.377441
# 매출액변동                       1.502148          1.488569          1.474321
# 무상증자 결정                     1.577786          1.581287          1.528478
# 상각형 조건부자본증권 발행결정                 NaN               NaN               NaN
# 생산중단                        0.365698          0.368825          0.343947
# 소송 등의 제기                    0.727278          0.610000          0.163707
# 신규시설투자                      1.528790          1.478149          1.524488
# 영업양수 결정                          NaN               NaN               NaN
# 영업정지                        0.428369          0.460326          0.034034
# 유상증자 결정                     4.114801          3.985491          3.315272
# 유형자산 양도 결정                  1.749972          1.718639          1.727084
# 유형자산 양수 결정                  0.482762          0.334855          0.317314
# 임상 계획 결과 발표                 3.072655          3.102902          3.146161
# 임상 계획 승인                    3.307140          3.276020          3.335208
# 임상 계획 신청                    3.150069          3.115142          3.089223
# 임상 계획 철회                    3.286055          3.418435          3.438076
# 자기주식 소각 결정                  2.314986          2.277433          2.314556
# 자기주식 처분 결정                  0.318710          0.342057          0.302922
# 자기주식 취득 결정                  1.315537          1.324464          1.310993
# 자기주식취득 신탁계약 체결 결정           0.982789          0.985487          0.963458
# 자기주식취득 신탁계약 해지 결정           0.353529          0.404927          0.358038
# 자산양수도(기타), 풋백옵션             1.018234          0.791960          0.799031
# 전환사채권 발행결정                  0.458892          0.453576          0.387683
# 주권 관련 사채권 양도 결정             6.420530          6.392245          5.748778
# 주권 관련 사채권 양수 결정             0.842975          0.804355          0.456516
# 타법인 주식 및 출자증권 양도결정          2.498659          2.250353          0.929887
# 타법인 주식 및 출자증권 양수결정          1.588619          1.565259          1.549024
# 특허권취득                       1.272576          1.261847          1.218403
# 품목허가 승인                     3.950505          3.911328          3.946756
# 품목허가 신청                     2.383783          2.401139          2.350164
# 품목허가 철회                     0.951017          1.033634          0.617981
# 회사분할 결정                     0.751816          0.858591          0.888802
# 회사합병 결정                     2.578323          2.483785          2.487426
#
#                     abn_ret_minus_1m  abn_ret_1m  abn_ret_2m  abn_ret_3m  \
# disclosure_type
# 감자 결정                            NaN         NaN         NaN         NaN
# 교환사채권 발행결정                  0.372553    1.249444    1.234610    2.647684
# 기술이전계약체결                    0.830343    1.307283    1.400254    1.861437
# 기술이전계약해지                         NaN         NaN         NaN         NaN
# 단일판매ㆍ공급계약체결                 1.640015    1.140249    1.360466    1.511540
# 단일판매ㆍ공급계약해지                 0.309297    0.912675    0.581187    0.366445
# 매출액변동                       1.481337    1.075827    1.277831    1.410754
# 무상증자 결정                     1.506576    0.541609    0.689380    0.975795
# 상각형 조건부자본증권 발행결정                 NaN         NaN         NaN         NaN
# 생산중단                        0.345015    0.396290    0.436135    0.393126
# 소송 등의 제기                    0.520032    0.556507    0.837695    3.662813
# 신규시설투자                      1.442543    1.278291    1.377590    1.670446
# 영업양수 결정                          NaN         NaN         NaN         NaN
# 영업정지                        0.021602    0.088459    0.056789    0.063966
# 유상증자 결정                     3.355187    2.668841    3.267934    4.618196
# 유형자산 양도 결정                  1.746082    1.229728    1.156390    1.622604
# 유형자산 양수 결정                  0.343449    0.257927    0.469294    0.542766
# 임상 계획 결과 발표                 2.989580    3.245528    3.603161    4.968266
# 임상 계획 승인                    3.296247    1.495577    3.499933    3.434107
# 임상 계획 신청                    3.108623    2.338205    2.679675    2.276061
# 임상 계획 철회                    3.471151    0.567950    2.135494    2.419022
# 자기주식 소각 결정                  2.331715    1.420120    2.037142    2.178213
# 자기주식 처분 결정                  0.255667    0.477966    0.509064    0.866664
# 자기주식 취득 결정                  1.298198    1.154234    1.276565    1.262442
# 자기주식취득 신탁계약 체결 결정           0.951409    0.807837    0.900043    0.895358
# 자기주식취득 신탁계약 해지 결정           0.283137    0.213866    0.303828    0.947837
# 자산양수도(기타), 풋백옵션             0.070711    1.039447    1.647559    2.588011
# 전환사채권 발행결정                  0.543658    0.612839    0.693709    0.950431
# 주권 관련 사채권 양도 결정             5.982123    5.374012    5.402296    0.982878
# 주권 관련 사채권 양수 결정             0.527245    0.396315    0.573427    0.427090
# 타법인 주식 및 출자증권 양도결정          0.797172    1.038220    1.579554    1.650826
# 타법인 주식 및 출자증권 양수결정          1.514140    1.015295    1.413436    1.623464
# 특허권취득                       1.219522    0.971338    0.976323    1.217215
# 품목허가 승인                     3.890076    1.544834    1.967160    1.993500
# 품목허가 신청                     2.390512    0.186414    1.313176    2.147377
# 품목허가 철회                     0.768917    0.499032    0.385530    0.107858
# 회사분할 결정                     0.762683    0.873872    0.913744    0.953625
# 회사합병 결정                     2.458153    2.177546    2.530401    3.609754
#
#                     abn_ret_4m  abn_ret_5m  abn_ret_6m  abn_ret_7m  \
# disclosure_type
# 감자 결정                      NaN         NaN         NaN         NaN
# 교환사채권 발행결정            2.084371    2.544432    2.483224    2.529209
# 기술이전계약체결              2.732467    3.098397    3.354947    3.429029
# 기술이전계약해지                   NaN         NaN         NaN         NaN
# 단일판매ㆍ공급계약체결           1.645705    1.685632    1.719855    1.776374
# 단일판매ㆍ공급계약해지           0.194169    0.227158    0.252648    0.360124
# 매출액변동                 1.484859    1.467145    1.529177    1.534377
# 무상증자 결정               1.134015    1.057807    1.123642    0.865488
# 상각형 조건부자본증권 발행결정           NaN         NaN         NaN         NaN
# 생산중단                  0.398444    0.328509    0.499316    0.638748
# 소송 등의 제기              4.716402    7.297342    7.417550    6.215469
# 신규시설투자                1.833865    2.011077    2.247244    2.218435
# 영업양수 결정                    NaN         NaN         NaN         NaN
# 영업정지                  0.080416    0.075277    0.178139    0.181659
# 유상증자 결정               4.823079    4.160938    3.309167    3.964587
# 유형자산 양도 결정            1.349627    1.559245    1.566848    1.464696
# 유형자산 양수 결정            0.467358    0.634817    0.733227    0.638559
# 임상 계획 결과 발표           3.281537    2.557076    2.766049    2.682755
# 임상 계획 승인              3.145336    3.529174    3.442536    3.638193
# 임상 계획 신청              2.261675    2.248861    2.649097    2.761355
# 임상 계획 철회              3.189248    5.860890    4.950896    4.392892
# 자기주식 소각 결정            2.468786    2.309572    2.237856    2.132859
# 자기주식 처분 결정            0.731233    0.860980    0.833128    0.859935
# 자기주식 취득 결정            1.253356    1.308246    1.356816    1.368554
# 자기주식취득 신탁계약 체결 결정     0.912647    1.084576    1.133829    0.995950
# 자기주식취득 신탁계약 해지 결정     0.743352    0.554982    0.575179    0.467201
# 자산양수도(기타), 풋백옵션       1.506137    1.053589    0.714178    0.438406
# 전환사채권 발행결정            1.345637    1.117413    1.115424    1.247696
# 주권 관련 사채권 양도 결정       1.506137    0.947523    2.481945    4.532554
# 주권 관련 사채권 양수 결정       0.390072    0.658606    0.686044    0.695171
# 타법인 주식 및 출자증권 양도결정    1.800745    1.766705    2.031414    2.123317
# 타법인 주식 및 출자증권 양수결정    1.812939    2.003304    2.080587    1.987863
# 특허권취득                 1.141802    1.255272    1.181537    1.160610
# 품목허가 승인               1.802612    1.503056    1.656867    1.358614
# 품목허가 신청               2.371687    2.377673    2.394654    2.417588
# 품목허가 철회               0.164418    0.447996    0.175784    0.461303
# 회사분할 결정               1.228332    1.123868    0.968407    1.143675
# 회사합병 결정               4.522218    4.939181    5.921495    5.746473
#
#                     abn_ret_8m  abn_ret_9m  abn_ret_10m
# disclosure_type
# 감자 결정                      NaN         NaN          NaN
# 교환사채권 발행결정            2.410578    2.484392     2.845454
# 기술이전계약체결              3.698641    3.097200     2.902545
# 기술이전계약해지                   NaN         NaN          NaN
# 단일판매ㆍ공급계약체결           1.773495    1.781845     1.756687
# 단일판매ㆍ공급계약해지           0.314566    0.403252     0.436465
# 매출액변동                 1.593474    1.648068     1.634433
# 무상증자 결정               0.901731    0.887411     0.916678
# 상각형 조건부자본증권 발행결정           NaN         NaN          NaN
# 생산중단                  0.611291    0.671009     0.735806
# 소송 등의 제기              4.504270    8.237794     6.646804
# 신규시설투자                2.439978    2.294085     2.518371
# 영업양수 결정                    NaN         NaN          NaN
# 영업정지                  0.134753    0.126853     0.139284
# 유상증자 결정               4.298073    4.025493     3.834895
# 유형자산 양도 결정            1.556017    1.533671     1.811020
# 유형자산 양수 결정            0.703748    0.690908     0.824489
# 임상 계획 결과 발표           3.193710    2.965920     3.712285
# 임상 계획 승인              4.010989    4.429045     4.247480
# 임상 계획 신청              2.602328    2.749905     2.805298
# 임상 계획 철회              4.598949    4.529500     4.966072
# 자기주식 소각 결정            2.146275    2.197874     2.354507
# 자기주식 처분 결정            0.841840    0.865426     0.948806
# 자기주식 취득 결정            1.397433    1.301509     1.310107
# 자기주식취득 신탁계약 체결 결정     0.988295    0.980000     1.030716
# 자기주식취득 신탁계약 해지 결정     1.086839    0.854743     0.681441
# 자산양수도(기타), 풋백옵션       0.042426    0.162635     0.353553
# 전환사채권 발행결정            1.443397    1.577054     1.783755
# 주권 관련 사채권 양도 결정       4.978032    2.899138     2.736503
# 주권 관련 사채권 양수 결정       0.939933    0.917127     0.653268
# 타법인 주식 및 출자증권 양도결정    2.154448    1.924223     1.975871
# 타법인 주식 및 출자증권 양수결정    2.256481    2.442795     2.514257
# 특허권취득                 1.220263    1.261210     1.270280
# 품목허가 승인               2.180244    3.149072     3.564222
# 품목허가 신청               2.530192    2.359519     2.533352
# 품목허가 철회               0.840179    1.112759     0.955528
# 회사분할 결정               1.171214    1.187313     0.945167
# 회사합병 결정               5.277022    4.910538     5.420776

# %%
# 공시 종류별 sentiment 분포 분석 (disclosure_type 기준)
disclosure_sentiment = df_with_returns.groupby(['disclosure_type', 'label']).size().unstack(fill_value=0)

# label 컬럼 정렬: negative(-1), neutral(0), positive(1) 순서
label_sort_order = [-1, 0, 1]
filtered_columns = [col for col in label_sort_order if col in disclosure_sentiment.columns]
disclosure_sentiment = disclosure_sentiment[filtered_columns]

# 비율로 변환
disclosure_sentiment_pct = disclosure_sentiment.div(disclosure_sentiment.sum(axis=1), axis=0) * 100

# 수치 요약 전체 DataFrame으로 만들어서 출력 (전체 공시 종류)
summary_df = disclosure_sentiment.copy()
for col in disclosure_sentiment_pct.columns:
    summary_df[f"{col}_pct"] = disclosure_sentiment_pct[col].round(1)

# 샘플 개수(행별 합) 기준 내림차순 정렬
summary_df['total_count'] = summary_df[[col for col in [-1, 0, 1] if col in summary_df.columns]].sum(axis=1)
summary_df = summary_df.sort_values('total_count', ascending=False)
summary_df = summary_df.drop(columns=['total_count'])

print("=== 전체 공시 종류별 감정 분포 ===")
summary_df
# Out:
# === 전체 공시 종류별 감정 분포 ===
# label                -1     0    1  -1_pct  0_pct  1_pct
# disclosure_type
# 단일판매ㆍ공급계약체결           6  1019  813     0.3   55.4   44.2
# 매출액변동               328   194  832    24.2   14.3   61.4
# 특허권취득                 0    23  355     0.0    6.1   93.9
# 타법인 주식 및 출자증권 양수결정    5   138  135     1.8   49.6   48.6
# 자기주식취득 신탁계약 체결 결정     1    79  112     0.5   41.1   58.3
# 자기주식 처분 결정           29    81    2    25.9   72.3    1.8
# 자기주식 취득 결정            0    11   97     0.0   10.2   89.8
# 신규시설투자                0    58   48     0.0   54.7   45.3
# 무상증자 결정               2    39   60     2.0   38.6   59.4
# 전환사채권 발행결정            2    67    1     2.9   95.7    1.4
# 유상증자 결정               5    42    9     8.9   75.0   16.1
# 유형자산 양수 결정            0    26   29     0.0   47.3   52.7
# 타법인 주식 및 출자증권 양도결정   15    35    3    28.3   66.0    5.7
# 자기주식취득 신탁계약 해지 결정    10    36    2    20.8   75.0    4.2
# 유형자산 양도 결정            5    21   19    11.1   46.7   42.2
# 임상 계획 신청             15     8   19    35.7   19.0   45.2
# 임상 계획 승인              7     3   30    17.5    7.5   75.0
# 자기주식 소각 결정            3     2   25    10.0    6.7   83.3
# 회사합병 결정               2     1   24     7.4    3.7   88.9
# 생산중단                 13     8    2    56.5   34.8    8.7
# 단일판매ㆍ공급계약해지          15     3    0    83.3   16.7    0.0
# 품목허가 승인               0     0   18     0.0    0.0  100.0
# 주권 관련 사채권 양수 결정       2    14    1    11.8   82.4    5.9
# 임상 계획 결과 발표           3     1    7    27.3    9.1   63.6
# 교환사채권 발행결정            1     9    0    10.0   90.0    0.0
# 회사분할 결정               0     5    4     0.0   55.6   44.4
# 기술이전계약체결              0     0    6     0.0    0.0  100.0
# 품목허가 신청               0     5    0     0.0  100.0    0.0
# 영업정지                  3     0    1    75.0    0.0   25.0
# 임상 계획 철회              4     0    0   100.0    0.0    0.0
# 소송 등의 제기              1     2    0    33.3   66.7    0.0
# 품목허가 철회               0     3    0     0.0  100.0    0.0
# 주권 관련 사채권 양도 결정       0     2    0     0.0  100.0    0.0
# 자산양수도(기타), 풋백옵션       0     2    0     0.0  100.0    0.0
# 기술이전계약해지              0     1    0     0.0  100.0    0.0
# 상각형 조건부자본증권 발행결정      0     1    0     0.0  100.0    0.0
# 영업양수 결정               0     0    1     0.0    0.0  100.0
# 감자 결정                 1     0    0   100.0    0.0    0.0

# %%
# 상위 20개 공시 종류만 선택 (데이터가 많은 순서대로)
top_disclosures = df_with_returns['disclosure_type'].value_counts().head(25).index
disclosure_sentiment_top = disclosure_sentiment.loc[top_disclosures]
disclosure_sentiment_pct_top = disclosure_sentiment_pct.loc[top_disclosures]

# 색상 매핑: negative(빨강), neutral(회색), positive(초록)
sentiment_colors = {
    -1: "#DC143C", # 빨강 (negative)
     0: "#999999", # 회색 (neutral)
     1: "#2E8B57"  # 초록 (positive)
}
plot_colors = [sentiment_colors[col] for col in filtered_columns]

# 시각화 (세로 2개로 배치)
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 16))

# 1. 절대 개수
disclosure_sentiment_top.plot(kind='bar', stacked=True, ax=ax1, color=plot_colors)
ax1.set_title('Sentiment Distribution by Disclosure Type (Absolute Count)', fontsize=14)
ax1.set_xlabel('Disclosure Type', fontsize=12)
ax1.set_ylabel('Count', fontsize=12)
ax1.legend([ 'Negative', 'Neutral', 'Positive' ], title='Sentiment', bbox_to_anchor=(1.05, 1), loc='upper left')

x_labels = [category_mapping.get(cat, cat) for cat in top_disclosures]
ax1.set_xticklabels(x_labels, rotation=45, ha='right')

# 2. 비율(%)
disclosure_sentiment_pct_top.plot(kind='bar', stacked=True, ax=ax2, color=plot_colors)
ax2.set_title('Sentiment Distribution by Disclosure Type (Percentage)', fontsize=14)
ax2.set_xlabel('Disclosure Type', fontsize=12)
ax2.set_ylabel('Percentage (%)', fontsize=12)
ax2.legend([ 'Negative', 'Neutral', 'Positive' ], title='Sentiment', bbox_to_anchor=(1.05, 1), loc='upper left')

ax2.set_xticklabels(x_labels, rotation=45, ha='right')

plt.tight_layout()
plt.show()
